# %% [markdown]
# # Import necessary libs

# %%
from datetime import datetime, timedelta
from bs4 import BeautifulSoup as bs
from dotenv import load_dotenv
import threading, queue
import pandas as pd
import numpy as np
import requests
import logging
import boto3
import json
import re
import os

# Get environment variable
load_dotenv('.env')
AWS_ACCESS_KEY_ID = os.getenv("AWS_ACCESS_KEY_ID")
AWS_SECRET_ACCESS_KEY = os.getenv("AWS_SECRET_ACCESS_KEY")

#initialize S3
S3 = boto3.resource('s3',
    aws_access_key_id=AWS_ACCESS_KEY_ID,
    aws_secret_access_key=AWS_SECRET_ACCESS_KEY
)

#initialize dynamodb
dynamodb = boto3.resource('dynamodb', region_name='ap-southeast-2',
  aws_access_key_id=AWS_ACCESS_KEY_ID,
  aws_secret_access_key=AWS_SECRET_ACCESS_KEY
)

table_scrape_hist = dynamodb.Table('ScrapingHistory')

last_refresh = datetime.now()

# %% [markdown]
# # Necessary functions

# %%
# Function for filter the urls
def include_url_lambda(x):
    url = x.get("href")
    if url in visited_links:
        return False
    visited_links.add(url)
    if not include_url.search(url):
        return False
    to_visits.put(url)
    return True

# Function for scraping data from urls
def scrape_fn(url):
    while True:
        try:
            resp = requests.get(url)
            html = bs(resp.text)
            _ = [x for x in filter(include_url_lambda, html.findAll("a", {"rel": "bookmark"}))]
            raw_pages[url] = resp.text
            raw_articles[url] = html.findAll("article", {"class": "main-article"})[0]
            break
        except Exception as e:
            print(f"Error: {e} -- Trying to reconnect to url {url}.")
            
# Wrapper function for validate outdated of s3 credential and auto replacing
def validate_update(fn):
    def return_fn(*ar, **kw):
        global S3, last_refresh, refresh_time
        _now = datetime.now()
        if (last_refresh + refresh_time) <= _now:
            S3 = boto3.resource('s3', 
                aws_access_key_id=AWS_ACCESS_KEY_ID,
                aws_secret_access_key=AWS_SECRET_ACCESS_KEY
            )
            last_refresh = _now

        return fn(*ar, **kw)
    return return_fn

# Store the data to the S3 instance
@validate_update
def store_data_on_s3(prefix, source, ext_data, raw_data):
    try:
        now = datetime.now()
        filename = f"{prefix}-{now.strftime('%Y-%m-%d_%H:%M:%S')}.json"

        # Simple extracted recipes
        ext_s3 = S3.Object("eltrial", f"SCRAPING/SIMPLE_EXTRACTED/{filename}")

        # Save raw pages for debugging and correction
        raw_s3 = S3.Object("eltrial", f"SCRAPING/RAW/{filename}")

        ext_json = json.dumps(ext_data)
        raw_json = json.dumps(raw_data)

        ext_s3.put(Body=ext_json, ACL='public-read')
        raw_s3.put(Body=raw_json, ACL='public-read')
        
        table_scrape_hist.put_item(
            Item={
                "source": source,
                "timestamp": now.strftime("%Y-%m-%d %H:%M:%S"),
            }
        )
        
        print("Storing the data is completed")
    except Exception as e:
        print(f"Error: {e}")

# %% [markdown]
# # Settings

# %%
MAX_THREAD = 100
NOT_FOUND_TEXT = "Oops! That page can’t be found."
include_url = re.compile("food-recipe")
# include_url = re.compile("\/food-recipe|\/food-recommend|\/easy-menu")
BASE_URL = "https://food.mthai.com/food-recipe"
refresh_time = timedelta(hours=1)

# %% [markdown]
# # Crawl data from sources

# %%
# Main Thread

if __name__ == "__main__":
    
    visited_links = set()
    to_visits = queue.Queue()
    raw_pages = {}
    raw_articles = {}
    num_page = 1
    
    while True:
        
        if num_page == 1:
            start_url = BASE_URL
        else:
            start_url = f"{BASE_URL}/page/{num_page}"
        
        print(f"Searching for page {num_page}.")
        resp = requests.get(start_url)
        page_text = resp.text
        
        # Stop crawling when current page is not found.
        if resp.status_code == 404:
            print("Not found...\nComplete scraping.")
            break
        
        html = bs(page_text)
        _ = [x for x in filter(include_url_lambda, html.findAll("a", {"rel": "bookmark"}))]

        while True:
            threads = []

            if to_visits.empty():
                break

            qsize = to_visits.qsize()
            num_threads = min(MAX_THREAD, qsize)
            print(f"Generating {num_threads} threads ...")
            for _t in range(num_threads):
                _url = to_visits.get()
                _thread = threading.Thread(target=scrape_fn, args=(_url,))
                _thread.start()
                threads.append(_thread)

            for _t in threads:
                _t.join()
            print(f"finish run {num_threads} threads. {to_visits.qsize()} remaining urls")

            del threads
        print("finished.")
        
        num_page += 1
# Out:
# Searching for page 1.
# Generating 13 threads ...
# finish run 13 threads. 8 remaining urls
# Generating 8 threads ...
# finish run 8 threads. 5 remaining urls
# Generating 5 threads ...
# finish run 5 threads. 1 remaining urls
# Generating 1 threads ...
# finish run 1 threads. 0 remaining urls
# finished.
# Searching for page 2.
# Generating 11 threads ...
# finish run 11 threads. 11 remaining urls
# Generating 11 threads ...
# finish run 11 threads. 11 remaining urls
# Generating 11 threads ...
# finish run 11 threads. 3 remaining urls
# Generating 3 threads ...
# finish run 3 threads. 0 remaining urls
# finished.
# Searching for page 3.
# Generating 9 threads ...
# finish run 9 threads. 6 remaining urls
# Generating 6 threads ...
# finish run 6 threads. 6 remaining urls
# Generating 6 threads ...
# finish run 6 threads. 2 remaining urls
# Generating 2 threads ...
# finish run 2 threads. 2 remaining urls
# Generating 2 threads ...
# finish run 2 threads. 0 remaining urls
# finished.
# Searching for page 4.
# Generating 9 threads ...
# finish run 9 threads. 5 remaining urls
# Generating 5 threads ...
# finish run 5 threads. 1 remaining urls
# Generating 1 threads ...
# finish run 1 threads. 0 remaining urls
# finished.
# Searching for page 5.
# Generating 10 threads ...
# finish run 10 threads. 4 remaining urls
# Generating 4 threads ...
# finish run 4 threads. 1 remaining urls
# Generating 1 threads ...
# finish run 1 threads. 0 remaining urls
# finished.
# Searching for page 6.
# Generating 11 threads ...
# finish run 11 threads. 9 remaining urls
# Generating 9 threads ...
# finish run 9 threads. 3 remaining urls
# Generating 3 threads ...
# finish run 3 threads. 1 remaining urls
# Generating 1 threads ...
# finish run 1 threads. 4 remaining urls
# Generating 4 threads ...
# finish run 4 threads. 3 remaining urls
# Generating 3 threads ...
# finish run 3 threads. 0 remaining urls
# finished.
# Searching for page 7.
# Generating 8 threads ...
# finish run 8 threads. 0 remaining urls
# finished.
# Searching for page 8.
# Generating 12 threads ...
# finish run 12 threads. 6 remaining urls
# Generating 6 threads ...
# finish run 6 threads. 1 remaining urls
# Generating 1 threads ...
# finish run 1 threads. 6 remaining urls
# Generating 6 threads ...
# finish run 6 threads. 0 remaining urls
# finished.
# Searching for page 9.
# Generating 6 threads ...
# finish run 6 threads. 0 remaining urls
# finished.
# Searching for page 10.
# Generating 7 threads ...
# finish run 7 threads. 1 remaining urls
# Generating 1 threads ...
# finish run 1 threads. 0 remaining urls
# finished.
# Searching for page 11.
# Generating 6 threads ...
# finish run 6 threads. 0 remaining urls
# finished.
# Searching for page 12.
# Generating 9 threads ...
# finish run 9 threads. 5 remaining urls
# Generating 5 threads ...
# finish run 5 threads. 4 remaining urls
# Generating 4 threads ...
# finish run 4 threads. 0 remaining urls
# finished.
# Searching for page 13.
# Generating 9 threads ...
# finish run 9 threads. 13 remaining urls
# Generating 13 threads ...
# finish run 13 threads. 7 remaining urls
# Generating 7 threads ...
# finish run 7 threads. 0 remaining urls
# finished.
# Searching for page 14.
# Generating 9 threads ...
# finish run 9 threads. 0 remaining urls
# finished.
# Searching for page 15.
# Generating 4 threads ...
# finish run 4 threads. 1 remaining urls
# Generating 1 threads ...
# finish run 1 threads. 0 remaining urls
# finished.
# Searching for page 16.
# Generating 6 threads ...
# finish run 6 threads. 1 remaining urls
# Generating 1 threads ...
# finish run 1 threads. 0 remaining urls
# finished.
# Searching for page 17.
# Generating 8 threads ...
# finish run 8 threads. 1 remaining urls
# Generating 1 threads ...
# finish run 1 threads. 0 remaining urls
# finished.
# Searching for page 18.
# Generating 6 threads ...
# finish run 6 threads. 4 remaining urls
# Generating 4 threads ...
# finish run 4 threads. 0 remaining urls
# finished.
# Searching for page 19.
# Generating 7 threads ...
# finish run 7 threads. 1 remaining urls
# Generating 1 threads ...
# finish run 1 threads. 0 remaining urls
# finished.
# Searching for page 20.
# Generating 7 threads ...
# finish run 7 threads. 0 remaining urls
# finished.
# Searching for page 21.
# Generating 8 threads ...
# finish run 8 threads. 1 remaining urls
# Generating 1 threads ...
# finish run 1 threads. 0 remaining urls
# finished.
# Searching for page 22.
# Generating 9 threads ...
# finish run 9 threads. 2 remaining urls
# Generating 2 threads ...
# finish run 2 threads. 0 remaining urls
# finished.
# Searching for page 23.
# Generating 9 threads ...
# finish run 9 threads. 0 remaining urls
# finished.
# Searching for page 24.
# Generating 10 threads ...
# finish run 10 threads. 6 remaining urls
# Generating 6 threads ...
# finish run 6 threads. 5 remaining urls
# Generating 5 threads ...
# finish run 5 threads. 2 remaining urls
# Generating 2 threads ...
# finish run 2 threads. 0 remaining urls
# finished.
# Searching for page 25.
# Generating 6 threads ...
# finish run 6 threads. 2 remaining urls
# Generating 2 threads ...
# finish run 2 threads. 0 remaining urls
# finished.
# Searching for page 26.
# Generating 11 threads ...
# finish run 11 threads. 0 remaining urls
# finished.
# Searching for page 27.
# Generating 8 threads ...
# finish run 8 threads. 0 remaining urls
# finished.
# Searching for page 28.
# Generating 9 threads ...
# finish run 9 threads. 2 remaining urls
# Generating 2 threads ...
# finish run 2 threads. 3 remaining urls
# Generating 3 threads ...
# finish run 3 threads. 7 remaining urls
# Generating 7 threads ...
# finish run 7 threads. 0 remaining urls
# finished.
# Searching for page 29.
# Generating 8 threads ...
# finish run 8 threads. 3 remaining urls
# Generating 3 threads ...
# finish run 3 threads. 2 remaining urls
# Generating 2 threads ...
# finish run 2 threads. 3 remaining urls
# Generating 3 threads ...
# finish run 3 threads. 2 remaining urls
# Generating 2 threads ...
# finish run 2 threads. 0 remaining urls
# finished.
# Searching for page 30.
# Generating 8 threads ...
# finish run 8 threads. 1 remaining urls
# Generating 1 threads ...
# finish run 1 threads. 0 remaining urls
# finished.
# Searching for page 31.
# Generating 8 threads ...
# finish run 8 threads. 1 remaining urls
# Generating 1 threads ...
# finish run 1 threads. 0 remaining urls
# finished.
# Searching for page 32.
# Generating 8 threads ...
# finish run 8 threads. 0 remaining urls
# finished.
# Searching for page 33.
# Generating 10 threads ...
# finish run 10 threads. 3 remaining urls
# Generating 3 threads ...
# finish run 3 threads. 4 remaining urls
# Generating 4 threads ...
# finish run 4 threads. 0 remaining urls
# finished.
# Searching for page 34.
# Generating 10 threads ...
# finish run 10 threads. 0 remaining urls
# finished.
# Searching for page 35.
# Generating 9 threads ...
# finish run 9 threads. 0 remaining urls
# finished.
# Searching for page 36.
# Generating 9 threads ...
# finish run 9 threads. 1 remaining urls
# Generating 1 threads ...
# finish run 1 threads. 0 remaining urls
# finished.
# Searching for page 37.
# Generating 9 threads ...
# finish run 9 threads. 0 remaining urls
# finished.
# Searching for page 38.
# Generating 7 threads ...
# finish run 7 threads. 0 remaining urls
# finished.
# Searching for page 39.
# Generating 11 threads ...
# finish run 11 threads. 0 remaining urls
# finished.
# Searching for page 40.
# Generating 10 threads ...
# finish run 10 threads. 13 remaining urls
# Generating 13 threads ...
# finish run 13 threads. 1 remaining urls
# Generating 1 threads ...
# finish run 1 threads. 0 remaining urls
# finished.
# Searching for page 41.
# Generating 10 threads ...
# finish run 10 threads. 2 remaining urls
# Generating 2 threads ...
# finish run 2 threads. 0 remaining urls
# finished.
# Searching for page 42.
# Generating 5 threads ...
# finish run 5 threads. 0 remaining urls
# finished.
# Searching for page 43.
# Generating 8 threads ...
# finish run 8 threads. 6 remaining urls
# Generating 6 threads ...
# finish run 6 threads. 0 remaining urls
# finished.
# Searching for page 44.
# Generating 7 threads ...
# finish run 7 threads. 1 remaining urls
# Generating 1 threads ...
# finish run 1 threads. 0 remaining urls
# finished.
# Searching for page 45.
# Generating 10 threads ...
# finish run 10 threads. 1 remaining urls
# Generating 1 threads ...
# finish run 1 threads. 0 remaining urls
# finished.
# Searching for page 46.
# Generating 9 threads ...
# finish run 9 threads. 2 remaining urls
# Generating 2 threads ...
# finish run 2 threads. 0 remaining urls
# finished.
# Searching for page 47.
# Generating 9 threads ...
# finish run 9 threads. 0 remaining urls
# finished.
# Searching for page 48.
# Generating 7 threads ...
# finish run 7 threads. 0 remaining urls
# finished.
# Searching for page 49.
# Generating 10 threads ...
# finish run 10 threads. 0 remaining urls
# finished.
# Searching for page 50.
# Generating 9 threads ...
# finish run 9 threads. 2 remaining urls
# Generating 2 threads ...
# finish run 2 threads. 0 remaining urls
# finished.
# Searching for page 51.
# Generating 7 threads ...
# finish run 7 threads. 0 remaining urls
# finished.
# Searching for page 52.
# Generating 11 threads ...
# finish run 11 threads. 0 remaining urls
# finished.
# Searching for page 53.
# Generating 10 threads ...
# finish run 10 threads. 2 remaining urls
# Generating 2 threads ...
# finish run 2 threads. 0 remaining urls
# finished.
# Searching for page 54.
# Generating 10 threads ...
# finish run 10 threads. 5 remaining urls
# Generating 5 threads ...
# finish run 5 threads. 0 remaining urls
# finished.
# Searching for page 55.
# Generating 9 threads ...
# finish run 9 threads. 3 remaining urls
# Generating 3 threads ...
# finish run 3 threads. 0 remaining urls
# finished.
# Searching for page 56.
# Generating 10 threads ...
# finish run 10 threads. 0 remaining urls
# finished.
# Searching for page 57.
# Generating 8 threads ...
# finish run 8 threads. 1 remaining urls
# Generating 1 threads ...
# finish run 1 threads. 0 remaining urls
# finished.
# Searching for page 58.
# Generating 10 threads ...
# finish run 10 threads. 4 remaining urls
# Generating 4 threads ...
# finish run 4 threads. 0 remaining urls
# finished.
# Searching for page 59.
# Generating 8 threads ...
# finish run 8 threads. 1 remaining urls
# Generating 1 threads ...
# finish run 1 threads. 0 remaining urls
# finished.
# Searching for page 60.
# Generating 10 threads ...
# finish run 10 threads. 0 remaining urls
# finished.
# Searching for page 61.
# Generating 8 threads ...
# finish run 8 threads. 0 remaining urls
# finished.
# Searching for page 62.
# Generating 3 threads ...
# finish run 3 threads. 1 remaining urls
# Generating 1 threads ...
# finish run 1 threads. 0 remaining urls
# finished.
# Searching for page 63.
# Generating 12 threads ...
# finish run 12 threads. 0 remaining urls
# finished.
# Searching for page 64.
# Generating 8 threads ...
# finish run 8 threads. 0 remaining urls
# finished.
# Searching for page 65.
# Generating 11 threads ...
# finish run 11 threads. 0 remaining urls
# finished.
# Searching for page 66.
# Generating 11 threads ...
# finish run 11 threads. 0 remaining urls
# finished.
# Searching for page 67.
# Generating 10 threads ...
# finish run 10 threads. 0 remaining urls
# finished.
# Searching for page 68.
# Generating 11 threads ...
# finish run 11 threads. 1 remaining urls
# Generating 1 threads ...
# finish run 1 threads. 0 remaining urls
# finished.
# Searching for page 69.
# Generating 10 threads ...
# finish run 10 threads. 0 remaining urls
# finished.
# Searching for page 70.
# Generating 8 threads ...
# finish run 8 threads. 0 remaining urls
# finished.
# Searching for page 71.
# Generating 11 threads ...
# finish run 11 threads. 0 remaining urls
# finished.
# Searching for page 72.
# Generating 10 threads ...
# finish run 10 threads. 0 remaining urls
# finished.
# Searching for page 73.
# Generating 12 threads ...
# finish run 12 threads. 0 remaining urls
# finished.
# Searching for page 74.
# Generating 12 threads ...
# finish run 12 threads. 0 remaining urls
# finished.
# Searching for page 75.
# Generating 11 threads ...
# finish run 11 threads. 0 remaining urls
# finished.
# Searching for page 76.
# Generating 8 threads ...
# finish run 8 threads. 0 remaining urls
# finished.
# Searching for page 77.
# Not found...
# Complete scraping.

# %%
# Print number of pages
len(raw_pages), len(raw_articles)
# Out:
# (910, 910)

# %% [markdown]
# # Simple Extract Recipe From Pages

# %%
ingredients = {}
EXCLUDE_WORDS = set(["หมายถึง", "อาหารเจ", "เคล็ดลับความอร่อย"])
ingredient_word = re.compile("ส่วนผสม|วัตถุดิบ|เครื่องปรุง|ส่วนประกอบ|วัตุดิบ|อัตราส่วน")
how_to_word = re.compile("ขั้นตอนการทำ|วิธีทำ|วิธีการทำ")

process = 0
_include = 0
_not_include = []

for url, page in raw_articles.items():
    strong = page.findAll(["strong", "p", "h1", "h2", "h3", "li", "a"])
    
    header_exists = False
    title = ""
    for s in strong:
        text = s.text
        is_ingredient = ingredient_word.search(text)
        is_how_to = how_to_word.search(text)

        if (s.name in ["strong", "h3", "h1"]) and not (is_ingredient or is_how_to) and text not in EXCLUDE_WORDS:
            title = f"{text}_{url}"
        else:
            if not header_exists:
                if is_ingredient:
                    header_exists = True
            else:
                if is_how_to:
                    header_exists = False
                else:
                    if s.name == "li":
                        if title not in ingredients:
                            ingredients[title] = [text]
                        else:
                            ingredients[title].append(text)
         
    process += 1
    print("\r", end=f"{process}")
# Out:
# 910

# %%
ingredients
# Out:
# {'ข้าวผัดกุ้ง_https://food.mthai.com/food-recipe/138335.html': ['น้ำมันรำข้าว',
#   'กระเทียมสับ 2 ช้อนโต๊ะ',
#   'มันกุ้ง 80 กรัม',
#   'เกลือ 1/2 ช้อนชา',
#   'กุ้งสด 60 กรัม',
#   'ข้าวสวย 1 ถ้วย',
#   'ซอสหอยนางรม 2 ช้อนโต๊ะ',
#   'แครอท (ซอย) 2 ช้อนโต๊ะ',
#   'ต้นหอม (ซอย) 2 ช้อนโต๊ะ',
#   'พริกไทยขาว (ป่น) 1 ช้อนชา'],
#  ' ผัดเปรี้ยวหวาน_https://food.mthai.com/food-recipe/142292.html': ['เนื้อหมูสันนอก\xa0 200 กรัม',
#   'สับปะรด 40 กรัม',
#   'ซอสมะเขือเทศ 40 กรัม',
#   'ซอสพริก 15 กรัม',
#   'น้ำตาลทรายแดง 15 กรัม',
#   'น้ำมันรำข้าว 30 กรัม',
#   'กระเทียมสับ 10 กรัม',
#   'หอมหัวใหญ่ 50 กรัม',
#   'แตงกวา 50 กรัม',
#   'มะเขือเทศ\xa0 50 กรัม',
#   'สับปะรด 70 กรัม',
#   'ต้นหอม\xa0 15 กรัม'],
#  ' ราดหน้าหมูคะน้า\xa0_https://food.mthai.com/food-recipe/124172.html': ['ซอสหอยนางรม 3 ช้อนโต๊ะ',
#   'ซอสปรุงรส 2 ช้อนชา',
#   'ซีอิ๊วขาว 2 1/2 ช้อนโต๊ะ',
#   'น้ำมันงา 1 ช้อนโต๊ะ',
#   'น้ำตาลทราย 2 ช้อนชา',
#   'แป้งมันสำปะหลัง 1 ช้อนโต๊ะ',
#   'พริกไทยป่น 2 ช้อนชา',
#   'น้ำเปล่า 1/4 ถ้วย',
#   'เนื้อหมูสันนอก 500 กรัม',
#   'ไข่ขาว 2 ฟอง',
#   'น้ำมันรำข้าว 1 ช้อนโต๊ะ',
#   'กระเทียมสับ 2 ช้อนโต๊ะ',
#   'เต้าเจี้ยว 1 ช้อนโต๊ะ',
#   'น้ำเปล่า 1 ลิตร',
#   'ซอสหอยนางรม 2 ช้อนโต๊ะ',
#   'ซีอิ๊วขาว 2 ช้อนโต๊ะ',
#   'ซอสปรุงรส 1 ช้อนโต๊ะ',
#   'น้ำตาลทราย 3 ช้อนโต๊ะ',
#   'คะน้าฮ่องกง ตามชอบ',
#   'แป้งมันละลายน้ำ 2 ช้อนโต๊ะ'],
#  'กุ้งกระเทียมนำพาบารมี_https://food.mthai.com/food-recipe/109122.html': ['กุ้งแชบ๊วยขนาดใหญ่ผ่าหลังดึงเส้นดำออก 12 ตัว',
#   'ซอสปรุงอาหารตราแม็กกี้ 4 ช้อนโต๊ะ',
#   'เม็ดพริกไทยบุบพอแตก 1 ช้อนโต๊ะ',
#   'กระเทียมสับหยาบเจียวพอเหลือง 200 กรัม',
#   'น้ำมันสำหรับทอด'],
#  'หมายถึง\xa0_https://food.mthai.com/food-recipe/128300.html': ['แป้งข้าวเหนียว 200 กรัม',
#   'น้ำกะทิ 2 ถ้วย',
#   'น้ำตาลปี๊บ 100 กรัม',
#   'มะพร้าวทึนทึก 2 ถ้วย',
#   'น้ำตาลปี๊บ 100 กรัม',
#   'น้ำเปล่า 1 ถ้วย'],
#  '2. ขนมเข่ง_https://food.mthai.com/food-recipe/128300.html': ['แป้งข้าวเหนียว 1 กิโล',
#   'มะพร้าวขูด 300 กรัม',
#   'น้ำตาลปี๊บ 1 กิโลกรัม',
#   'น้ำ 1 ถ้วย',
#   'กระทงสำหรับใส่ขนม',
#   'น้ำมันพืชใช้ทากระทง'],
#  '3. ขนมถ้วยฟู_https://food.mthai.com/food-recipe/128300.html': ['แป้งสาลี 200 กรัม',
#   'ผงฟู 1 ช้อนชา',
#   'ไข่ไก่สด 2 ฟอง',
#   'น้ำ 100 กรัม',
#   'น้ำมะนาว 1 ช้อนชา',
#   'กลิ่นมะลิ 1/2 ช้อนชา',
#   'น้ำตาล 180 กรัม',
#   'SP 10 กรัม',
#   'นมข้นจืด 50 กรัม',
#   'สีผสมอาหาร สีที่ต้องการ',
#   'เตรียมถ้วยกระดาษรองด้วยพิมพ์อลูมิเนียมตักให้เต็มถ้วยไม่ต้องเผื่อ เพราะเราตั้งใจให้มันฟูขึ้นเลยถ้วยกระดาษ',
#   'เราเตรียมลังถึงไว้น้ำเดือดจัดแล้ว วางขนมลงไปในซึ้ง แล้วหรี่ไฟให้เหลือไฟอ่อน ใช้เวลานึ่งประมาณ 15 นาที แค่นี้ก็เป็นอันเสร็จเรียบร้อยแล้วค่ะ'],
#  '4. ขนมสาลี่_https://food.mthai.com/food-recipe/128300.html': ['แป้งสาลี 1 ถ้วยตวง',
#   'น้ำตาลทราย 2 1/2 ถ้วยตวง',
#   'ไข่เป็ด 10 ฟอง',
#   'สีผสมอาหารตามใจชอบ (สีเขียว สีชมพู สีเหลืองไข่ไก่)',
#   'ลูกเกด สำหรับแปะหน้าใส่ไม่ใส่ก็ได้',
#   'แป้งสาลีนำไปร่อน เทลงไปในส่วนผสมของไข่ คนให้เข้ากันเบาๆ จนแป้งละลายดี เติมสีผสมอาหารลงไป',
#   'นำกระดาษรองอบ ปูลงในถาดหรือพิมพ์ที่จะใช้นึ่งขนม เทแป้งลงในถาด แต่งหน้าด้วยลูกเกดตามชอบ',
#   'ตั้งหม้อนึ่งหรือซึ้ง รอให้น้ำเดือด นำลงไปนึ่ง ทิ้งไว้ประมาณ 15 – 20 นาที หรือจนกว่าจะสุก เมื่อสุกดีแล้วจึงยกลง ทิ้งไว้ให้เย็นแล้วจึงตัดเป็นชิ้นขนาดตามชอบ'],
#  '5.\xa0หมั่นโถ_https://food.mthai.com/food-recipe/128300.html': ['แป้งสาลี 1 1/2 ถ้วย',
#   'แป้งเค้ก 1/2ถ้วย',
#   'น้ำตาลทราย 1/4 ถ้วย',
#   'เกลือ 1/2 ช้อนชา',
#   'ยีสต์ 1 ช้อนโต๊ะ',
#   'น้ำอุ่น 1 ถ้วย',
#   'กระดาษไขตัดสี่เหลี่ยม'],
#  'ไก่ย่างขมิ้น_https://food.mthai.com/food-recipe/136810.html': ['ตะไคร้ (สับ) 15 กรัม',
#   'ขิง (สับ) 15 กรัม',
#   'พริกไทย\xa0\xa01 ช้อนโต๊ะ',
#   'ซอสหอยนางรม 2 ช้อนโต๊ะ',
#   'ซีอิ๊วขาว 1 ช้อนโต๊ะ',
#   'น้ำตาลทราย 1 ช้อนโต๊ะ',
#   'เกลือ 1/4 ช้อนชา',
#   'ผงขมิ้น\xa0\xa02 ช้อนโต๊ะ',
#   'กะทิ\xa0\xa0300 มิลลิลิตร',
#   'สะโพกไก่\xa0\xa0300 กรัม'],
#  'หมึกต้มหวาน_https://food.mthai.com/food-recipe/115011.html': ['ปลาหมึกกล้วยสด 1 กก',
#   'น้ำตาลมะพร้าว 1 1/2 แว่น\n',
#   'กะทิแยกหัวหาง 1/2 กก\n',
#   'เกลือ 2 ช้อนชา\n',
#   'ตะไคร้ทุบและหั่นเป็นท่อน 3 ต้น หรือใบเตย 3 ใบ(มัดรวมกัน)\n',
#   'ข้าวเหนียวแช่น้ำ 3-5 ชั่วโมง 200 กรัม\n',
#   'ผงปรุงรสเล็กน้อย\n',
#   'ไม้กลัด'],
#  'มาม่าผัดสุกี้แห้ง_https://food.mthai.com/food-recipe/143114.html': ['น้ำมันรำข้าว \xa040 กรัม\n',
#   'กระเทียม (สับ) 30 กรัม\n',
#   'ลูกชิ้นหมู 50 กรัม\n',
#   'ไข่ไก่ \xa03 ฟอง\n',
#   'บะหมี่กึ่งสำเร็จรูป \xa0(ลวก) 300 กรัม\n',
#   'น้ำจิ้มสุกี้\xa01 ถ้วย\n',
#   'ซอสหอยนางรม 1+1/2 ช้อนโต๊ะ\n',
#   'ซอสปรุงรส 1/2 ช้อนโต๊ะ\n',
#   'น้ำตาลทราย 1 ช้อนโต๊ะ\n',
#   'ผักบุ้ง \xa050 กรัม\n',
#   'ผักกาดขาว 50 กรัม\n',
#   'คื่นช่าย 50 กรัม\n',
#   'กุ้ง (ลวก) 100 กรัม\n',
#   'ปลาหมึก \xa0(ลวก) 100 กรัม\n',
#   'พริกแดงจินดา\xa0(สับ) ตามชอบค่ะ'],
#  'ส่วนที่ 1 เตรียมหมักไก่_https://food.mthai.com/food-recipe/145832.html': ['ขิงฝาน 20 กรัม',
#   'ซอสพริก 200 กรัม',
#   'ซอสหอยนางรม 2 ช้อนโต๊ะ',
#   'เกลือป่น 2 ช้อนชา',
#   'เหล้าจีน\xa02 ช้อนโต๊ะ',
#   'น้ำตาลทรายแดง 100 กรัม',
#   'หอมใหญ่สับ 60 กรัม',
#   'น้ำซุป\xa0400 มิลลิลิตร'],
#  'กุ้งผัดหัวปลี\xa0_https://food.mthai.com/food-recipe/133496.html': ['น้ำมันรำข้าว 2 ช้อนโต๊ะ',
#   'กระเทียม (สับ) 1 ช้อนโต๊ะ',
#   'กุ้ง\xa0 150 กรัม',
#   'ซอสหอยนางรม 1 ช้อนโต๊ะ',
#   'ซีอิ๊วขาว 1 ช้อนโต๊ะ',
#   'หัวปลี (ลวก) 200 กรัม'],
#  ' กลิ่นกาสะลอง_https://food.mthai.com/food-recipe/142493.html': ['กะทิแท้ 1 ถ้วย',
#   'พริกแกงเผ็ด 40 กรัม',
#   'ผงกะหรี่ 1 ช้อนโต๊ะ',
#   'เนื้อน่องลาย หั่นชิ้นหนา 5 มิลลิเมตร 200 กรัม',
#   'น้ำสต๊อกไก่ 2 ถ้วย',
#   'น้ำตาลมะพร้าว 1 ช้อนโต๊ะ',
#   'น้ำปลา 1 ช้อนโต๊ะ',
#   'น้ำมะนาว 2 ช้อนชา',
#   'เส้นข้าวซอย ลวกสุก 3 ก้อน',
#   'เส้นบะหมี่ทอดกรอบ 1 ก้อน',
#   'ต้นหอมซอยและใบผักชีสำหรับตกแต่ง',
#   'หอมแดงหั่น ผักกาดดอง พริกป่นคั่วน้ำมันและมะนาวผ่าซีกสำหรับจัดเสิร์ฟ'],
#  'ไข่ตุ๋นทรงเครื่อง_https://food.mthai.com/food-recipe/145822.html': ['ไข่ไก่ 6 ฟอง',
#   'โชยุ ตามชอบค่ะ',
#   'น้ำซุป\xa0 1+1/2 ถ้วย',
#   'พริกไทยป่น ตามชอบค่ะ',
#   'น้ำมันรำข้าว 80 กรัม',
#   'กระเทียม 50 กรัม',
#   'หมูสับ 100 กรัม',
#   'กุ้งสับ 50 กรัม',
#   'กุ้งขาว 100 กรัม',
#   'ซีอิ๊วขาว 1 ช้อนโต๊ะ',
#   'น้ำตาลทราย 1/2 ช้อนชา',
#   'ซีอิ๊วดำ 1/2 ช้อนโต๊ะ',
#   'พริกไทยป่น 1/4 ช้อนชา'],
#  'แกงจืดปลาหมึกยัดไส้_https://food.mthai.com/food-recipe/132288.html': ['กุ้งสับ 40 กรัม',
#   'แครอท 15 กรัม',
#   'หมูสับ 40 กรัม',
#   'แครอท 15 กรัม',
#   'ผงปรุงรสหมู 1/2 ช้อนชา',
#   'ปลาหมึก 4 ตัว',
#   'มันม่วงบด ตามชอบ',
#   'ผักโขม (ลวก) ตามชอบ',
#   'ซุปก้อนรสหมู 1 ก้อน',
#   'แครอท 20 กรัม',
#   'ผักกาดขาว 20 กรัม',
#   'ต้นหอม 5 กรัม',
#   'ล้างปลาหมึกให้สะอาด แล้วนำไปยัดไส้ กลัดด้วยไม้แหลม วางเรียงเตรียมไว้',
#   'ต้มน้ำให้เดือด ใส่ซุปก้อนลงไปตามด้วยแครอท',
#   'ใส่ปลาหมึกที่ยัดไส้แล้วลงไป และตามด้วยผักกาดขาว โรยต้นหอม เสร็จแล้วก็ตักใส่จานเสิร์ฟทันที หรือจะผ่าปลาหมึกให้เป็นแว่นดูสวยงาม'],
#  ' ผัดพริกแกงปลาดุกกรอบ\xa0_https://food.mthai.com/food-recipe/145628.html': ['ปลาดุก 300 กรัม',
#   'แป้งทอดกรอบ ตามชอบค่ะ',
#   'น้ำมันรำข้าว 2 ช้อนโต๊ะ',
#   'พริกแกงเผ็ด 30 กรัม',
#   'กระชาย (ซอย) 40 กรัม',
#   'พริกไทยอ่อน 20 กรัม',
#   'น้ำสะอาด 1/4 ถ้วย',
#   'น้ำปลา 2 ช้อนโต๊ะ',
#   'น้ำตาลปี๊บ 1/2 ช้อนโต๊ะ',
#   'ใบมะกรูด 10 กรัม',
#   'พริกชี้ฟ้า (ซอย) 15 กรัม'],
#  'ผัดหมี่กรอบกุ้งสับ_https://food.mthai.com/food-recipe/145682.html': ['เต้าหู้เหลือง ตามชอบค่ะ',
#   'เส้นหมี่แช่น้ำ 1 ห่อ',
#   'ไข่ไก่ 2 ฟอง',
#   'น้ำมัน 2 ช้อนโต๊ะ',
#   'หอมแดงสับ 2 ช้อนโต๊ะ',
#   'กุ้งสับ 150 กรัม',
#   'น้ำจิ้มไก่ 200 มิลลิลิตร',
#   'น้ำปลา 1 ช้อนโต๊ะ',
#   'น้ำมะขามเปียก 1 ช้อนโต๊ะ',
#   'พริกป่น 1 ช้อนชา',
#   'ต้นหอม ตามชอบค่ะ'],
#  'ปลาหมึกคั่วพริกเกลือ\xa0_https://food.mthai.com/food-recipe/131889.html': ['หมึกกล้วยขนาด 5 นิ้ว 4 ตัว',
#   'แป้งสาลีอเนกประสงค์ 1 ถ้วย',
#   'เกลือป่น 1/4 ช้อนชา',
#   'พริกไทยดำป่น 1/2 ช้อนชา',
#   'น้ำมันพืช 2 ช้อนโต๊ะ',
#   'กระเทียมไทยสับละเอียด 1/4 ถ้วย',
#   'พริกขี้หนูซอย 1 ช้อนโต๊ะ',
#   'เกลือสมุทร 1 ช้อนชา',
#   'น้ำตาลทราย 1 ช้อนชา',
#   'ใบผักชีและพริกขี้ฟ้าแดงหั่นแว่น สำหรับตกแต่ง',
#   'นมสดชนิดจืดสำหรับแช่หมึก',
#   'น้ำมันปาล์มสำหรับทอด'],
#  'แกงเขียวหวานปลาหมึกยัดไส้_https://food.mthai.com/food-recipe/123217.html': ['เนื้อหมูบด 200 กรัม',
#   'พริกแกงเขียวหวาน 1 ช้อนโต๊ะ (ในส่วนของการหมักหมูบด)',
#   'เกลือ 1/2 ช้อนชา',
#   'ปลาหมึก ตามจำนวนของหมูบด',
#   'น้ำกะทิ 2 ขวด',
#   'พริกแกงเขียวหวาน 3 ช้อนโต๊ะ',
#   'น้ำเปล่า 1 ถ้วย',
#   'น้ำปลา 2 ช้อนโต๊ะ',
#   'น้ำตาลปี๊บ 1/2 ช้อนโต๊ะ',
#   'เกลือ 1/2 ช้อนชา',
#   'พริกชี้ฟ้าหั่นแฉลบ',
#   'ใบมะกรูดฉีก',
#   'ใบโหระพา'],
#  'ยำไข่ปลาหมึดทอด_https://food.mthai.com/food-recipe/109849.html': ['ไข่ปลาหมึก',
#   'แป้งทอดกรอบ',
#   'ผงปรุงรส',
#   'น้ำปลา',
#   'น้ำมะนาว',
#   'พริกขี้หนูตำ',
#   'น้ำตาล'],
#  'ปลาหมึกยักษ์ทอดกรอบ_https://food.mthai.com/food-recipe/110126.html': ['แป้งโกกิ',
#   'เกร็ดขนมปัง',
#   'ไข่ 1 ฟอง',
#   'โซดาแช่เย็น',
#   'ปลาหมึกกล้วยตัวใหญ่',
#   'ผงปรุงรส',
#   'ผงลาบ หรือผงรสอะไรก็ได้ตามชอบ',
#   'ไม้เสียบ',
#   'น้ำมันสำหรับทอด',
#   'แป้งโกกิสำหรับคลุกแห้ง ผสมกับเกร็ดขนมปังป่นโดยทำการทุบให้ละเอียด ใส่ผงลาบหรือผงรสชาติที่เตรียมไว้ คลุกให้เข้ากัน',
#   'เตรียมปลาหมึก ล้างปลาหมึกให้สะอาด ผ่ากลางตามความยาวของตัวปลาหมึก ผ่าขึ้นไปขนถึงหัวปลาหมึก จัดการนำตาปลาหมึกหรือสิ่งที่ไม่จำเป็นของหัวปลาหมึกออก แผ่ปลาหมึกออกและบั้งด้านข้างตามแนวขวางเป็นเหมือนก้างปลา',
#   'ใช้ไม้เสียบตัวปลาหมึก เพื่อเป็นการดัดตัวปลาหมึกให้ตรงและแผ่ เวลาทอดจะได้ไม่หด',
#   'ตั้งกระทะ เทน้ำมันจนท่วมกระทะ เปิดไฟกลาง รอให้น้ำมันเดือด',
#   'นำปลาหมึกชุบแป้งโกกิที่ผสมเหลวให้ทั่ว จากนั้นก็นำมาคลุกกับแป้งโกกิแห้งจนทั่วตัวปลาหมึก',
#   'นำปลาหมึกลงไปทอดจนสุกเหลือง เมื่อสุกแล้วตักขึ้นมาพักบนตะแกรง'],
#  'ปลาหมึกผัดไข่เค็ม_https://food.mthai.com/food-recipe/112702.html': ['ไข่แดงเค็ม 4 ลูก',
#   'ไข่เค็ม 1 ลูก',
#   'น้ำเปล่า 1/3 ถ้วย',
#   'พริกเผา 1 ช้อนโต๊ะ',
#   'ซอสหอยนางรม 2 ช้อนโต๊ะ',
#   'ซีอิ๊วขาว 1 ช้อนโต๊ะ',
#   'น้ำตาลทราย 2 ช้อนชา',
#   'กระเทียมสับ 1 ช้อนโต๊ะ',
#   'ปลาหมึกหั่นแว่น 350 กรัม',
#   'คื่นช่าย ตามชอบ',
#   'ต้นหอม ตามชอบ',
#   'พริกชี้ฟ้าแดง ตามชอบ'],
#  'ฉู่ฉี่ปลาหมึกยัดไส้_https://food.mthai.com/food-recipe/105390.html': ['ปลาหมึกสดทั้งตัว',
#   'หมูสับ',
#   'กระเทียม พริกไทยโขลกละเอียด',
#   'พริกแกง',
#   'กะทิ',
#   'น้ำปลา',
#   'น้ำตาลปึก',
#   'ใบมะกรูด',
#   'พริกชี้ฟ้าแดง'],
#  '1.เอ็นข้อไก่ทอด_https://food.mthai.com/food-recipe/122196.html': ['น้ำปลา 2 ช้อนโต๊ะ',
#   'น้ำมะนาว 3 ช้อนโต๊ะ',
#   'พริกป่น ตามชอบ',
#   'เอ็นข้อไก่ทอด 200 กรัม',
#   'หอมแดงซอย 5 หัว',
#   'ผักชีฝรั่งซอย',
#   'ต้นหอมซอย',
#   'ผักชีซอย',
#   'ข้าวคั่ว',
#   'ใส่เอ็นข้อไก้ทอดลงไป คลุกให้เข้ากันกับเครื่องปรุง',
#   'ใส่หอมแดง ผักชีฝรั่ง ต้นหอมซอย และผักชี คลุกเคล้าให้เข้ากัน เสร็จแล้วก็ใส่ข้าวคั่วเป็นสิ่งสุดท้าย คลุกเบาๆ แล้วก็ตักใส่จานเสิร์ฟ'],
#  'สูตร กุ้งแช่เบียร์_https://food.mthai.com/food-recipe/122196.html': ['กุ้งขาว 350 กรัม',
#   'เบียร์ 1 ขวด',
#   'พริกเขียว',
#   'รากผักชี',
#   'กระเทียบ 6-8 กลีบ',
#   'น้ำมะนาว 4 ช้อนโต๊ะ',
#   'น้ำเลมอน พร้อมเปลือก',
#   'วาซาบิ 2 ช้อนโต๊ะ',
#   'น้ำปลา 3 ช้อนโต๊ะ',
#   'น้ำเชื่อม 1 ช้อนโต๊ะ'],
#  '3. กุ้งแช่น้ำปลา_https://food.mthai.com/food-recipe/122196.html': ['กุ้งแชบ๊วย 9-10 ตัว',
#   'กระเทียม 7-8 กลีบ',
#   'รากผักชี 4-5 ราก',
#   'พริกขี้หนูสวน ตามชอบ',
#   'น้ำมะนาว 3 ช้อนโต๊ะ',
#   'น้ำปลา 2 ช้อนโต๊ะ',
#   'น้ำตาลปี๊บ 1 1/2 ช้อนโต๊ะ',
#   'เกลือ 1/3 ช้อนชา',
#   'น้ำปลา 1/3 ช้อนชา (สำหรับแช่กุ้ง)',
#   'สะระแหน่',
#   'มะระหั่นแว่น',
#   'กะหล่ำซอย'],
#  '4. หัวหอมทอด_https://food.mthai.com/food-recipe/122196.html': ['หอมใหญ่ 2 ลูก',
#   'แป้งทอดกรอบ 1/2 ถ้วยตวง',
#   'แป้งมันบด 4 ช้อนโต๊ะ',
#   'แป้งสาลีอเนกประสงค์ 4 ช้อนโต๊ะ',
#   'เกล็ดขนมปัง',
#   'น้ำโซดาเย็นจัด 1/2 ถ้วงตวง',
#   'น้ำมันพืช 3 ถ้วยตวง'],
#  '5.\xa0หมูมะนาว_https://food.mthai.com/food-recipe/122196.html': ['สันคอหมูหั่นบาง 200 กรัม',
#   'กระเทียม 10 – 12 หัว',
#   'พริก',
#   'เกลือ 1 หยิบมือ',
#   'น้ำมะนาว 4 ช้อนโต๊ะ',
#   'น้ำปลา 3 ช้อนโต๊ะ',
#   'น้ำตาลทราย 1 1/2 ช้อนโต๊ะ',
#   'ผักเครื่องเคียง (ก้านคะน้าลวก,กระหล่ำปลีซอย,กระเทียมสด และใบสะระแหน่)'],
#  '6.ปลาหมึกนึ่งมะนาว_https://food.mthai.com/food-recipe/122196.html': ['ปลาหมึกกล้วย 2 หรือ 3 ตัว ตามขนาด',
#   'พริกขี้หนูซอย 1 ช้อนโต๊ะ',
#   'กระเทียมสับ 2 ช้อนโต๊ะ',
#   'น้ำมะนาว 4 ช้อนโต๊ะ',
#   'น้ำปลา 3 ช้อนโต๊ะ',
#   'น้ำตาลทราย 1 ช้อนชา'],
#  '7. ยำไข่เยี่ยวม้า_https://food.mthai.com/food-recipe/122196.html': ['ไข่เยี่ยวม้า 3-4 ฟอง',
#   'น้ำปลา 2 ช้อนโต๊ะ',
#   'น้ำตาลทราย 1 ช้อนโต๊ะ',
#   'น้ำมะนาว 4 ช้อนโต๊ะ',
#   'พริกซอย',
#   'กระเทียมดองซอย',
#   'ขิงซอย',
#   'หอมแดงซอย',
#   'ผักชี',
#   'ถั่วลิสงคั่ว'],
#  'สูตรถั่วคั่ว_https://food.mthai.com/food-recipe/122196.html': ['ถั่วลิสง 3 ช้อนโต๊ะ',
#   'เม็ดมะม่วงหิมพานต์ 1 ถ้วย',
#   'ถั่วลิสงแบบมีเปลือก 3 ช้อนโต๊ะ',
#   'พริกแห้งตามใจชอบ',
#   'ใบมะกรูดซอย ตามใจชอบ',
#   'น้ำมันพืช 1 ช้อนโต๊ะ',
#   'ถั่วปากอ้า 1/2 ถ้วย',
#   'ถั่วแปบ 1/2 ถ้วย',
#   'ผงปรุงรส 1 ช้อนโต๊ะ',
#   'เกลือป่น 1/2 ช้อนโต๊ะ',
#   'ผงปาปริก้า 1/2 ช้อนโต๊ะ',
#   'พริกขี้หนูซอย ตามชอบ',
#   'ต้นหอมซอย ตามชอบ',
#   'มะนาวหั่น ตามชอบ'],
#  'สูตรไส้อ่อนทอดกระเทียม_https://food.mthai.com/food-recipe/122196.html': ['ไส้อ่อนหมู 1 กิโลกรัม',
#   'เกลือป่น 1 ช้อนชา',
#   'น้ำมันพืช 1 ถ้วย',
#   'กระเทียมตำ 150 กรัม',
#   'เกลือป่นสำหรับทอดกระเทียม 1 หยิบมือ',
#   'ซอสปรุงรส 1 ช้อนโต๊ะ',
#   'น้ำตาลทราย 1 ช้อนชา',
#   'พริกไทย 1 ช้อนชา'],
#  'สูตรยำก้านคะน้า_https://food.mthai.com/food-recipe/122196.html': ['น้ำปลา 2 ช้อนโต๊ะ',
#   'น้ำตาลทราย 2 ช้อนชา',
#   'น้ำมะนาว 3 ช้อนโต๊ะ',
#   'พริกขี้หนูซอย ตามชอบ',
#   'ก้านคะน้า 150 กรัม',
#   'กุ้งขาวลวก 100 กรัม',
#   'หอมแดงซอย ตามชอบ'],
#  'สูตรหอยแมลงภู่อบกะปิ_https://food.mthai.com/food-recipe/122196.html': ['กะปิ 1/2 ช้อนโต๊ะ',
#   'พริกไทยบดหยาบ 1 ช้อนโต๊ะ',
#   'น้ำเปล่า 1/4 ถ้วย',
#   'หอมแดง 5 หัว',
#   'ใบโหระพา ตามชอบ',
#   'หอยแมลงภู่ 1 กิโลกรัม',
#   'กระเทียม 10 กลีบ',
#   'รากผักชี 2 ต้น',
#   'พริกจินดา ตามชอบ',
#   'เนื้อสับปะรด 1 ช้อนโต๊ะ',
#   'น้ำปลา 3 ช้อนโต๊ะ',
#   'น้ำส้ม 1 ช้อนโต๊ะ',
#   'น้ำมะนาว 3 ช้อนโต๊ะ',
#   'น้ำตาลทราย 1 ช้อนโต๊ะ'],
#  'หอยแมลงภู่อบกะปิ_https://food.mthai.com/food-recipe/123610.html': ['กะปิ 1/2 ช้อนโต๊ะ',
#   'พริกไทยบดหยาบ 1 ช้อนโต๊ะ',
#   'น้ำเปล่า 1/4 ถ้วย',
#   'หอมแดง 5 หัว',
#   'ใบโหระพา ตามชอบ',
#   'หอยแมลงภู่ 1 กิโลกรัม',
#   'กระเทียม 10 กลีบ',
#   'รากผักชี 2 ต้น',
#   'พริกจินดา ตามชอบ',
#   'เนื้อสับปะรด 1 ช้อนโต๊ะ',
#   'น้ำปลา 3 ช้อนโต๊ะ',
#   'น้ำส้ม 1 ช้อนโต๊ะ',
#   'น้ำมะนาว 3 ช้อนโต๊ะ',
#   'น้ำตาลทราย 1 ช้อนโต๊ะ'],
#  'หอยเชลล์ย่างเนย\xa0_https://food.mthai.com/food-recipe/141325.html': ['เนย\u200b (จืด) 50 กรัม',
#   'กระเทียม (สับ) 1/4 ถ้วย',
#   'พริกไทยดำ 1/2 ช้อนโต๊ะ',
#   'เกลือ 1/4 ช้อนชา',
#   'พาร์สลีย์ ตามชอบค่ะ',
#   'หอยเชลล์ 12~15 ตัว'],
#  'เนื้อน่องลายย่างจิ้มแจ่ว\xa0_https://food.mthai.com/food-recipe/129068.html': ['เนื้อน่องลาย 400 กรัม',
#   'ซอสหอยนางรม 2 ช้อนโต๊ะ',
#   'ซอสปรุงรส 1 ช้อนโต๊ะ',
#   'พริกไทยป่น 1/2 ช้อนโต๊ะ',
#   'น้ำตาลปี๊บ 1/2 ช้อนโต๊ะ',
#   'ข้าวคั่ว 1 ช้อนโต๊ะ',
#   'น้ำมะขามเปียก 3/4 ถ้วย',
#   'น้ำตาลปี๊บ 1/2 ช้อนโต๊ะ',
#   'ข้าวคั่ว 1 ช้อนโต๊ะ',
#   'พริกป่น',
#   'ผักชีฝรั่ง + หอมแดง'],
#  'ยำส้มโอ_https://food.mthai.com/food-recipe/134667.html': ['น้ำมะนาว 40 มิลลิลิตร',
#   'น้ำตาลทราย 1 ช้อนโต๊ะ',
#   'เกลือ 1/2 ช้อนชา',
#   'หอมแดง (ซอย) 20 กรัม',
#   'พริกขี้หนู (ซอย) 10 กรัม',
#   'ส้มโอ 150 กรัม',
#   'ต้นหอม(ซอย) ตามชอบ',
#   'กุ้ง (ลวก) 5 ตัว',
#   'หอมเจียว 30 กรัม',
#   'เม็ดมะม่วงหิมพานต์ (คั่ว) 30 กรัม'],
#  'ไก่ต้มเหล้าจีน_https://food.mthai.com/food-recipe/143192.html': ['น้ำเปล่า \xa01 ลิตร',
#   'ขิง 20 กรัม',
#   'กระเทียม 20 กรัม',
#   'ซีอิ๊วขาว\xa02 ช้อนโต๊ะ',
#   'ซอสหอยนางรม \xa02 ช้อนโต๊ะ',
#   'น้ำตาลทราย 1/2 ช้อนโต๊ะ',
#   'สะโพกไก่ 1 กิโลกรัม',
#   'เหล้าจีน 2 ช้อนโต๊ะ',
#   'เต้าเจี้ยว 2 ช้อนโต๊ะ',
#   'น้ำปลา 1 ช้อนโต๊ะ',
#   'น้ำส้มสายชู 1 ช้อนโต๊ะ',
#   'น้ำมะนาว\xa01 ช้อนโต๊ะ',
#   'น้ำตาลทราย 1 ช้อนโต๊ะ',
#   'กระเทียม (สับ) 10 กรัม',
#   'พริกแดงจินดา\xa0(สับ) 15 กรัม หรือตามชอบค่ะ',
#   'ขิง (สับ) 10 กรัม'],
#  'หมูสามชั้นทอดน้ำปลา_https://food.mthai.com/food-recipe/126481.html': ['หมูสามชั้น 1/2 กิโลกรัม',
#   'น้ำปลา 2 ช้อนโต๊ะ',
#   'ซอสปรุงรส 1/2 ช้อนโต๊ะ',
#   'น้ำตาลทราย 1 1/2 ช้อนชา',
#   'กระเทียม 6-8 กลีบ',
#   'พริกขี้หนูสวน ตามชอบ',
#   'น้ำปลา 3 ช้อนโต๊ะ',
#   'น้ำมะนาว 3 ช้อนโต๊ะ',
#   'น้ำตาลทราย ช้อนโต๊ะ'],
#  'อ่องปูนา_https://food.mthai.com/food-recipe/143899.html': ['ปูนา',
#   'ไข่แดง 2 ฟอง',
#   'เกลือ 1 ช้อนชา'],
#  'พาสต้าครีมซอสเห็ด_https://food.mthai.com/food-recipe/135691.html': ['เส้นสปาเกตตี้ 150 กรัม',
#   'น้ำมันรำข้าว 1/4 ถ้วย',
#   'น้ำมันมะกอก 1 ช้อนโต๊ะ',
#   'กระเทียมสับ 1/2 ช้อนโต๊ะ',
#   'หอมหัวใหญ่สับ 1/2 ช้อนโต๊ะ',
#   'แป้งสาลีอเนกประสงค์ 2 1/2 ช้อนชา',
#   'วิปปิ้งครีม 1/4 ถ้วย',
#   'นมข้นจืด 140 มิลลิลิตร',
#   'แฮม หั่นเต๋า 50 กรัม',
#   'เห็ดแชมปิญอง 50 กรัม',
#   'เกลือป่น 1/4 ช้อนชา',
#   'พริกไทยดำ 1/4 ช้อนชา',
#   'พาร์เมซานชีส ตามชอบ',
#   'พาร์สเลย์สับ ตามชอบ'],
#  'สูตรหมักหมูกระทะ พร้อมน้ำจิ้มรสเด็ด_https://food.mthai.com/food-recipe/145801.html': ['สันคอหมู 500 กรัม',
#   'ไข่ไก่ 2 ฟอง',
#   'ซอสหอยนางรม 2 ช้อนโต๊ะ',
#   'น้ำตาลปี๊บ 2 ช้อนโต๊ะ',
#   'ซอสปรุงรส 2 ช้อนโต๊ะ',
#   'พริกไทยป่น 1 ช้อนโต๊ะ',
#   'แป้งข้าวโพด 1 1/2 ช้อนโต๊ะ',
#   'ผงฟู 2 ช้อนชา',
#   'งาขาว ตามชอบ',
#   'น้ำเปล่า 1/2 ถ้วย',
#   'น้ำตาล 1/2 ถ้วย',
#   'น้ำส้มสายชู 3 ช้อนโต๊ะ',
#   'น้ำปลา 3 ช้อนโต๊ะ',
#   'กระเทียมดองสับ 2 ช้อนโต๊ะ',
#   'พริกจินดา ตามชอบ',
#   'กระเทียมสับ 2 ช้อนโต๊ะ',
#   'ซอสพริก 2 ช้อนโต๊ะ',
#   'งาขาวตามชอบ',
#   'ผักชีซอย'],
#  'สูตร สุกี้โบราณ พร้อมน้ำจิ้มเต้าหู้ยี้_https://food.mthai.com/food-recipe/145801.html': ['น้ำ 6 ถ้วย',
#   'สาหร่ายคอมบุแผ่นสี่เหลี่ยม 1 ชิ้น',
#   'ปลาโอขูดแห้ง 1 ถ้วย',
#   'พริกไทยขาวเม็ด 1 ช้อนชา',
#   'รากผักชีซอย 3 ราก',
#   'กระเทียมไทยแกะเปลือก 15 กลีบ',
#   'ผงพะโล้ 1 ช้อนชา',
#   'หมูสันนอกหั่นชิ้นบางพอคำ 250 กรัม',
#   'ซีอิ๊วขาว 1/2 ช้อนโต๊ะ',
#   'น้ำมันหอย 1/2 ช้อนโต๊ะ',
#   'น้ำตาลทราย 3/4 ช้อนชา',
#   'ไข่ขาว 1 ฟอง',
#   'เต้าหู้ยี้ 1/2 ช้อนโต๊ะ',
#   'น้ำมันพืช 1/2 ช้อนโต๊ะ',
#   'แป้งข้าวโพด 1/2 ช้อนโต๊ะ',
#   'จากนั้นใส่น้ำมันพืชและแป้งข้าวโพด นวดให้เข้ากันปิดพลาสติกแรป หมักในตู้เย็นนาน 2 ชั่วโมง',
#   'กระเทียมไทยแกะเปลือก 1/4 ถ้วย',
#   'กระเทียมดองแกะเปลือกเอาแต่เนื้อ 2 ช้อนโต๊ะ',
#   'น้ำกระเทียมดอง 1/2 ช้อนโต๊ะ',
#   'พริกจินดาแดง 5 เม็ด',
#   'เต้าหู้ยี้ทั้งน้ำและเนื้อ 1/4 ถ้วย กับอีก 2 ช้อนโต๊ะ',
#   'น้ำ 1/4 ถ้วย',
#   'น้ำตาลทราย 2 ช้อนโต๊ะ',
#   'น้ำมันหอย 1/2 ช้อนโต๊ะ',
#   'น้ำมันงา 1 1/2 ช้อนโต๊ะ',
#   'ซอสมะเขือเทศ 2 ช้อนโต๊ะ',
#   'น้ำส้มสายชู 2 ช้อนโต๊ะ',
#   'งาขาวคั่วและผักชีซอยสำหรับโรย'],
#  'เตรียมเครื่องสุกี้_https://food.mthai.com/food-recipe/145801.html': ['สุกี้หม้อไฟใส่น้ำซุปดาชิ 5 ถ้วย',
#   'หมูหมัก 250 กรัม',
#   'ไข่ไก่ 1 ฟอง',
#   'กุ้งขาวแกะเปลือกผ่าดึงเอาเส้นดำออก',
#   'ปลาหมึกกล้วยและปลาหมึกกรอบบั้งตาราง',
#   'วุ้นเส้นแห้งแช่น้ำจนนุ่มตัดท่อนสั้น 80 กรัม',
#   'ผักกาดขาว ผักบุ้งจีน ต้นหอม ขึ้นฉ่าย สำหรับจัดเสิร์ฟ',
#   'น้ำจิ้มสุกี้สำหรับจัดเสิร์ฟ'],
#  'ส่วนของน้ำซุปจิ้มจุ่ม_https://food.mthai.com/food-recipe/145801.html': ['ใบมะกรูด 4 ใบ',
#   'พริกแห้ง 5 เม็ด',
#   'หอมแดง 3 หัว',
#   'ผักชีฝรั่ง 2 ต้น',
#   'น้ำซุปกระดูกหมู',
#   'ตะไคร้ 2 ต้น',
#   'โหระพา 1 ต้น',
#   'น้ำปลา 1 ช้อนโต๊ะ',
#   'ข่า 1 หัว'],
#  'ส่วนของน้ำจิ้ม_https://food.mthai.com/food-recipe/145801.html': ['น้ำมะขามคั้น 1 ถ้วย',
#   'งาขาวคั่ว 2 ช้อนชา',
#   'น้ำตาลปี๊บ 3 ช้อนโต๊ะ',
#   'น้ำปลา 4 ช้อนโต๊ะ',
#   'หอมแดงซอย 1 ช้อนโต๊ะ',
#   'ข้าวคั่ว 1 1/2 ช้อนโต๊ะ',
#   'พริกป่น 1 ช้อนชา',
#   'ผักชีฝรั่งหั่นฝอย',
#   'เตรียมเนื้อสัตว์ ผักต่างๆ ตามความชอบ',
#   'โรยส่วนผสมของน้ำจิ้มที่เหลือลงไป',
#   'ตั้งเตากับหม้อดิน เทน้ำซุปที่เตรียมไว้ลงไปในหม้อดิน และรอให้เดือดอีกทีหนึ่งก็จักกันลวกเนื้อสัตว์ที่หมักด้วยไข่ไก่และผักได้เลยค่ะ'],
#  'สูตร ยำวุ้นเส้นโบราณ_https://food.mthai.com/food-recipe/145801.html': ['วุ้นเส้นลวก 300 กรัม',
#   'กระเทียมเจียว',
#   'ไก่รวนสับ 200 กรัม',
#   'น้ำปลา 2 1/2 ช้อนโต๊ะ',
#   'น้ำมะนาว 4 ช้อนโต๊ะ',
#   'น้ำตาลทราย 1 1/2 ช้อนโต๊ะ',
#   'พริกแดงซอย',
#   'หอมแดงซอย',
#   'กุ้งแห้ง',
#   'ผักชี',
#   'หมูยอลวก',
#   'ถั่วลิสงคั่ว'],
#  'สูตร ชาบูหม่าหล่า_https://food.mthai.com/food-recipe/145801.html': ['เนื้อวัวส่วนสันแหลมหั่นชิ้นบาง 1 ถ้วย',
#   'เนื้อปลากะพงแล่ชิ้นบาง 1 ถ้วย',
#   'กุ้งขาวแกะเปลือกเด็ดหัวไว้หาง ผ่าหลังดึงเส้นดำออก 15 ตัว',
#   'เต้าหู้ขาวหั่นท่อน 2 ก้อน',
#   'สันคอหมูหั่นชิ้นบาง 1 ถ้วย',
#   'เห็ดเข็มทอง 1 ถ้วย',
#   'เห็ด งหั่นท่อน 4 ต้น',
#   'ตังโอ๋ 6',
#   'ออรินจิหั่นชิ้น 1 ถ้วย',
#   'ข้าวโพดหวาน 1 ฝัก',
#   'ปวยเล้งหั่นท่อน 4 ต้น',
#   'ตังโอ๋ 6 ต้น',
#   'ลูกชิ้นต่างๆ สำหรับจัดเสิร์ฟ',
#   'น้ำมันพืช 2 ช้อนโต๊ะ',
#   'กระเทียมจีน 3 กลีบ',
#   'เก่าคี่ 1 ช้อนชา',
#   'ฮัวเจียว 1 ช้อนโต๊ะ',
#   'ลูกกระวานขาวคั่วบุบ 3 เม็ด',
#   'ลูกกระวานเขียว 3 เม็ด',
#   'น้ำมันงา 1 ช้อนโต๊ะ',
#   'น้ำสต๊อกหมู 7 ถ้วย',
#   'ขิงแก่หั่นแว่น 3 แว่น',
#   'โป๊ยกั๊ก 2 ดอก',
#   'ตังกุย 1 แผ่น',
#   'อบเชยหั่นท่อน 3 ท่อน',
#   'พริกแห้ง 10-15 เม็ด',
#   'น้ำตาลกรวด 5-6 เม็ด',
#   'เกลือสมุทร 3/4 ช้อนชา',
#   'ซีอิ๊วขาว 2 ช้อนโต๊ะ'],
#  'น้ำจิ้มชาบู_https://food.mthai.com/food-recipe/145801.html': ['ซีอิ๊วขาว 6 ช้อนโต๊ะ',
#   'น้ำส้มสายชูหมักจากข้าว 2 ช้อนโต๊ะ',
#   'น้ำซุปหม่าล่า 2 ช้อนโต๊ะ',
#   'ต้นหอมซอย',
#   'กระเทียมสับ',
#   'และพริกขี้หนูสีแดงหั่นแว่น สำหรับจัดเสิร์ฟ'],
#  'สูตร หม่าล่าปิ้งย่าง_https://food.mthai.com/food-recipe/145801.html': ['พริกชวงเจียง 1 ช้อนโต๊ะ',
#   'พริกไทยดำ 1 ช้อนโต๊ะ',
#   'พริกขี้หนูแห้ง 4 ชิ้น',
#   'พริกป่น 1 ช้อนโต๊ะ',
#   'ยี่หร่า 1 ช้อนโต๊ะ',
#   'กระเทียม 8 กลีบ',
#   'ขิง 1 หัว',
#   'ผงพะโล้ 1 ช้อนโต๊ะ',
#   'ซีอิ๊วขาว 2 ช้อนโต๊ะ',
#   'น้ำมันมะกอก 2 ช้อนโต๊ะ',
#   'ฮอยซินซอส 1 ช้อนโต๊ะ',
#   'น้ำตาลทรายแดง 1 ช้อนโต๊ะ',
#   'เนื้อสัตว์หรือผักอะไรก็ได้ที่นำมาหมักกับหม่าล่า',
#   'นำหม่าล่ามาหมักกับเนื้อสัตว์ที่เตรียมไว้เสียบไม้แล้วนำไปแช่ตู้เย็น ส่วนผักไม่ต้องหมักเสียบไม้ได้เลย',
#   'ตั้งเตารอให้ร้อนนำเนื้อที่หมักมาปิ้งได้เลยส่วนผักให้นำมาปิ้งให้สุกก่อนแล้วค่อยทาด้วยหม่าล่า',
#   'เสร็จแล้วก็เรียงใส่ถาด อยากกินเท่าไหร่ก็ปิ้งเท่านั้นเลยค่ะ'],
#  'สูตร เนื้อย่าง จิ้มแจ่ว_https://food.mthai.com/food-recipe/145801.html': ['เนื้อวัว 500 กรัม',
#   'ซอสหอยนางรม 2 ช้อนโต๊ะ',
#   'ซอสปรุงรส 1 1/2 ช้อนโต๊ะ',
#   'น้ำปลา 2 ช้อนโต๊ะ',
#   'น้ำตาลปี๊บ 2 ช้อนโต๊ะ',
#   'พริกไทย',
#   'ข้าวคั่ว 2 ช้อนโต๊ะ',
#   'น้ำปลา 2 ช้อนโต๊ะ',
#   'น้ำมะนาว 3 ช้อนโต๊ะ',
#   'พริกป่น',
#   'ข้าวคั่ว 1 ช้อนโต๊ะ',
#   'หอมแดง',
#   'ผักชี',
#   'มาทำน้ำจิ้มระหว่างหมักเนื้อวัว ใส่น้ำปลา น้ำมะนาว และพริกป่น ความเผ็ดตามใจชอบ จากนั้นก็ใส่ข้าวคั่ว หอมแดงซอยและผักชีซอย คนให้เข้ากัน',
#   'ตั้งกระทะย่างเนื้อ ย่างจนสุกทั้งสองด้าน จากนั้นก็นำมาหั่นเป็นชิ้นยาวๆ เสร็จแล้วก็เสิร์ฟพร้อมกับน้ำจิ้มแจ่วได้เลยค่ะ'],
#  'วิธีผ่ากุ้ง_https://food.mthai.com/food-recipe/145801.html': ['ตกแต่งกุ้ง ตัดหนวดให้เรียบร้อย',
#   'นำกรรไกรตัดเปลือกกุ้ง จะตัดเป็นแนวยาวที่ละส่วน เราจะเริ่มที่ตัวกันก่อน โดยให้หัวกุ้งหันเข้าหาตัว แล้วใช้กรรไกรตัดเฉพาะเปลือกตั้งแต่กลางตัวไปยังหาง',
#   'ส่วนหัวให้ทำเหมือนกัน ใช้กรรไกรตัดเลาะเปลือกเป็นแนวยาวไปถึงสุดหัวของกุ้ง',
#   'นำมีดผ่าเนื้อตรงส่วนตัวกุ้งตามแนวกรรไกรที่ตัดเปลือกเอาไว้ ดึงเส้นดำกลางลำตัว',
#   'ส่วนหัวกุ้ง ให้เงะเปลือกกุ้ง ก็จะเห็นเยื้อหุ้มมันกุ้งอยู่ ให้กรรไกรตัดเยื้อออกแล้วจะเห็นถุงสีดำๆ รสชาติมันไม่อร่อยให้เอาออก พยายามอย่าให้ถุงแตก แต่ถ้าพลาดไปทำมันแตกแล้วก็ไม่ต้องตกใจให้นำไปผ่านน้ำเบาๆ',
#   'แบ่งกุ้งออกเป็น 2 ซีก แล้วเตรียมไปเผาได้เลย'],
#  'เคล็ดลับการเผากุ้งเหมือนร้านอาหารทะเลดัง_https://food.mthai.com/food-recipe/145801.html': ['ตั้งเตาถ่านไฟอ่อนๆ นำกุ้งลงไปย่างพร้อมกับปิดฝาเพื่อให้กุ้งสุกทั่วๆ กัน ใช้เวลา 3 นาที เป็นเวลากำลังดี การเผากุ้งอย่าให้นานเกินไปจะทำให้เนื้อกุ้งกระด้างไม่อร่อย ถ้ายิ่งกุ้งยิ่งสด ตอนสุกเนื้อจะยิ่งฟูน่ากิน กินคู่กับน้ำจิ้มซีฟู้ดรสจัดจ้าน',
#   'ผักชี 4 ขีด',
#   'กระเทียม 4 ขีด',
#   'พริก 4 ขีด',
#   'น้ำตาลปี๊บ 1 กิโลกรัม',
#   'เกลือ 5 ช้อนโต๊ะ',
#   'น้ำมะนาว 4 กระบวย',
#   'น้ำร้อน 3 กระบวย'],
#  'สูตร ปีกไก่ทอด_https://food.mthai.com/food-recipe/145801.html': ['ปีกกลางไก่ 1 กิโลกรัม',
#   'น้ำปลา 3 ช้อนโต๊ะ',
#   'ผงปรุงรส 1 ช้อนชา',
#   'แป้งทอดกรอบ 1/4 ถ้วย'],
#  'สูตร ข้าวผัดปู\xa0_https://food.mthai.com/food-recipe/145801.html': ['น้ำมันรำข้าว 2 ช้อนโต๊ะ',
#   'เนยจืด 10 กรัม',
#   'กระเทียม (สับ) 30 กรัม',
#   'ไข่เป็ด 2 ฟอง',
#   'ข้าวสวย 400 กรัม',
#   'ซีอิ๊วขาว 2 ช้อนโต๊ะ',
#   'เกลือ 1 ช้อนชา',
#   'น้ำตาลทราย 1 ช้อนชา',
#   'พริกไทยป่น 1 ช้อนโต๊ะ',
#   'เนื้อปู 1/2 ถ้วย',
#   'ต้นหอม (ซอย) 30 กรัม',
#   'ผักชี (ซอย) 20 กรัม'],
#  'หอยแมลงภู่ผัดโหระพา\xa0_https://food.mthai.com/food-recipe/139856.html': ['น้ำมันพืช 2 ช้อนโต๊ะ',
#   'กระเทียมสับ 30 กรัม',
#   'หอยแมลงภู่ 1 กิโลกรัม',
#   'น้ำปลา 2 ช้อนโต๊ะ',
#   'ซอสหอยนางรม 2 ช้อนโต๊ะ',
#   'พริกแห้ง 1 ถ้วย',
#   'ใบโหระพา 80 กรัม'],
#  'อัลบั้มภาพ 11 ภาพ_https://food.mthai.com/food-recipe/141044.html': ['น้ำตาลปี๊บมะพร้าว',
#   'น้ำตาลทราย',
#   'น้ำกระเทียมดอง',
#   'น้ำมะขามเปียก',
#   'พริกขั่ว (หากไม่ทานเผ็ดไม่ต้องใส่)',
#   'ซอสพริก',
#   'พริกชีโรยหน้าน้ำจิ้ม',
#   'ลูกชิ้นตามชอบ แต่ครั้งนี้ใช้ลูกชิ้นหมู',
#   'แป้งทอดกรอบ',
#   'แป้งชุบทอด (หากไม่มีใช้แป้งทอดกรอบอย่างเดียวได้)',
#   'เติมน้ำเปล่านิดหน่อย และนำไปตั้งไฟ คนให้ส่วนผสมทุกอย่างละลายเข้ากันแล้วปิดไฟได้',
#   'ใส่น้ำกระเทียมดอง (1 ช้อนโต๊ะ) และ ซอสพริก (2 ช้อนโต๊ะ) ลงไปในหม้อ คนทุกอย่างให้เข้ากันกับน้ำจิ้มมะขามเปียกที่เตรียมไว้',
#   'หากใครชอบเผ็ดก็เติมพริกป่นลงไป ซอยผักชีโรย เป็นอันจบขั้นตอน'],
#  'ต้มแซ่บเครื่องใน _https://food.mthai.com/food-recipe/140885.html': ['ข่า 8-10 แว่น',
#   'ตะไคร้ 2 ต้น',
#   'หอมแดง 6-8 หัว',
#   'เครื่องในเนื้อ 500 กรัม',
#   'น้ำปลา 4 ช้อนโต๊ะ',
#   'ใบมะกรูด',
#   'พริกขี้หนู',
#   'ข้าวคั่ว',
#   'พริกป่น',
#   'น้ำมะนาว 5 ช้อนโต๊ะ'],
#  'ดักแด้คั่วปาปริก้า\xa0_https://food.mthai.com/food-recipe/142650.html': ['เนย 15 กรัม',
#   'ดักแด้ (แห้ง) 80 กรัม',
#   'ผงปรุงรส 2 ช้อนโต๊ะ',
#   'ปาปริก้า 3 ช้อนโต๊ะ'],
#  'ยำมะม่วงปลากรอบ_https://food.mthai.com/food-recipe/138952.html': ['มะม่วง',
#   'น้ำตาลปี๊บ 10 กรัม',
#   'น้ำปลาร้า 40 กรัม',
#   'กะปิ 10 กรัม',
#   'หอมแดงซอย 15 กรัม',
#   'กุ้งแห้ง 30 กรัม',
#   'ปลากรอบ 50 กรัม',
#   'พริกป่น 40 กรัม'],
#  'พริกหม่าล่า_https://food.mthai.com/food-recipe/137874.html': ['น้ำตาลทราย 2 ช้อนโต๊ะ',
#   'ซีอิ๊วขาว 1 ช้อนโต๊ะ',
#   'น้ำมันงา 1 ช้อนโต๊ะ',
#   'เกลือ 1/4 ช้อนชา',
#   'ผงปรุงรส 1/2 ช้อนโต๊ะ',
#   'พริกป่น 2 ช้อนโต๊ะ',
#   'พริกไทยป่น 1 ช้อนโต๊ะ',
#   'ผงยี่หร่า 2 ช้อนโต๊ะ',
#   'พริกหอม (ชวงเจีย) 2 ช้อนโต๊ะ',
#   'น้ำมันพืช',
#   'หอยโข่ง'],
#  'ข้าวผัดปู_https://food.mthai.com/food-recipe/143727.html': ['น้ำมันรำข้าว 2 ช้อนโต๊ะ',
#   'เนยจืด 10 กรัม',
#   'กระเทียม (สับ) 30 กรัม',
#   'ไข่เป็ด 2 ฟอง',
#   'ข้าวสวย 400 กรัม',
#   'ซีอิ๊วขาว 2 ช้อนโต๊ะ',
#   'เกลือ 1 ช้อนชา',
#   'น้ำตาลทราย 1 ช้อนชา',
#   'พริกไทยป่น 1 ช้อนโต๊ะ',
#   'เนื้อปู 1/2 ถ้วย',
#   'ต้นหอม (ซอย) 30 กรัม',
#   'ผักชี (ซอย) 20 กรัม'],
#  'ยำหมูยอกับไข่แดงเค็ม\xa0_https://food.mthai.com/food-recipe/139402.html': ['น้ำปลา 3 ช้อนโต๊ะ',
#   'น้ำตาลทราย 2 ช้อนชา',
#   'น้ำมะนาว 6 ช้อนโต๊ะ',
#   'น้ำปลาร้า 1/4 ถ้วย',
#   'หอมแดงซอย 40 กรัม',
#   'คื่นช่าย 20 กรัม',
#   'พริกขี้หนู 50 กรัม',
#   'หมูยอ 60 กรัม',
#   'ไข่แดงเค็ม 150 กรัม'],
#  'สูตร กุ้งแม่น้ำเผาสะเดาน้ำปลาหวาน รสชาติกลมกล่อม_https://food.mthai.com/food-recipe/133535.html': ['กุ้งแม่น้ำ 1-2 ตัว',
#   'สะเดา',
#   'น้ำตาลปี๊บ 3 ช้อนชา',
#   'น้ำปลา 3 ช้อนชา',
#   'น้ำมะขามเปียก 3 ช้อนชา',
#   'หอมแดง 2 ลูกซอยบาง',
#   'พริกแห้ง 2 เม็ด',
#   'หอมเจียว',
#   'ผักแนม นิยมกินผักชี และผักน้ำพริกต่างๆ'],
#  'ยำหมูกรอบ\xa0_https://food.mthai.com/food-recipe/138061.html': ['หมูกรอบ 500 กรัม',
#   'มะนาว 4 ช้อนโต๊ะ',
#   'น้ำปลา 2 ช้อนโต๊ะ',
#   'น้ำตาลทราย 1 ช้อนชา',
#   'พริกขี้หนูซอย 80 กรัม',
#   'หอมแดง 50 กรัม',
#   'ขิงซอย 60 กรัม',
#   'ต้นหอมซอย 30 กรัม',
#   'พริกขี้หนูสับ 30 กรัม'],
#  'ลาบหอยเชอรี่_https://food.mthai.com/food-recipe/138745.html': ['ตะไคร้ซอย 30 กรัม',
#   'ใบมะกรูด 20 กรัม',
#   'หอยเชอรี่ 200 กรัม',
#   'น้ำปลา 2 ช้อนโต๊ะ',
#   'น้ำมะนาว 3 ช้อนโต๊ะ',
#   'น้ำตาลทราย 1 ช้อนชา',
#   'หอมแดง 30 กรัม',
#   'ใบสะระแหน่ 20 กรัม',
#   'พริกป่น 50 กรัม',
#   'ข้าวคั่ว 2 ช้อนโต๊ะ'],
#  'แจ่วปลาร้า_https://food.mthai.com/food-recipe/142431.html': ['รากผักชี 3 ช้อนโต๊ะ',
#   'พริกแดง 40 กรัม',
#   'กระเทียม 20 กรัม',
#   'น้ำตาลทรายแดง 1 ช้อนโต๊ะ',
#   'น้ำปลา 2 ช้อนโต๊ะ',
#   'น้ำมะนาว 3 ช้อนโต๊ะ',
#   'น้ำปลาร้า 2 ช้อนโต๊ะ',
#   'ใบแมงลัก ตามชอบค่ะ',
#   'หอยนา 1 กิโลกรัม',
#   'ตะไคร้ ตามชอบค่ะ'],
#  '1.ยำหมูสะดุ้ง\xa0_https://food.mthai.com/food-recipe/137377.html': ['เนื้อหมู (สไลด์บาง) 150 กรัม',
#   'น้ำมะนาว 20 กรัม',
#   'น้ำปลา 15 กรัม',
#   'น้ำตาลทราย 1 ช้อนโต๊ะ',
#   'น้ำพริกเผา 50 กรัม',
#   'กระเทียม (สับ) 1 ช้อนโต๊ะ',
#   'พริก (สับ) 15 กรัม',
#   'ตะไคร้ (ซอย) 20 กรัม',
#   'ใบมะกรูด (ซอย) 15 กรัม',
#   'ใบสะระแหน่ 10 กรัม'],
#  '2.\xa0น้ำพริกกะปิหมูสับ_https://food.mthai.com/food-recipe/137377.html': ['กระเทียม 6 กลีบ',
#   'พริก 10 เม็ด (หรือตามชอบ)',
#   'กะปิย่าง 2 ช้อนโต๊ะ',
#   'หมูบด 150 กรัม',
#   'ตะไคร้ 2 ต้น',
#   'น้ำตาลปี๊บ 1 ช้อนโต๊ะ',
#   'น้ำปลา 1 ช้อนโต๊ะ',
#   'ใบมะกรูด',
#   'น้ำมะนาว'],
#  '3. ลาบหมูคั่ว\xa0_https://food.mthai.com/food-recipe/137377.html': ['เนื้อหมู 200 กรัม',
#   'ตับหมู 100 กรัม',
#   'หนังหมู ตามชอบ',
#   'น้ำซุป 4 ช้อนโต๊ะ',
#   'น้ำปลา 2 ช้อนชา',
#   'ผักชีซอย แล้วแต่ชอบ',
#   'ผักชีลาว แล้วแต่ชอบ',
#   'เครื่องลาบ (มีมะแขว่นผสมด้วย มีขายสำเร็จที่ตลาด อตก ร้านขายของภาคเหนือ โขลกให้ละเอียด )',
#   'พริกลาบ ถ้าไม่มีใส่พริกป่นก็ได้ 2 ช้อนโต๊ะ',
#   'น้ำมันหมู 1 ช้อนโต๊ะ',
#   'หอมเจียวกับกระเทียมเจียว เอาไว้โรยหน้าหอมๆ'],
#  '4. หมูคำหวาน_https://food.mthai.com/food-recipe/137377.html': ['สันคอหมู 500 กรัม',
#   'ซอสปรุงรส 2 ช้อนโต๊ะ',
#   'ซอสหอยนางรม 2 ช้อนโต๊ะ',
#   'น้ำปลา 1 ช้อนโต๊ะ',
#   'น้ำตาลปี๊บ 1 ช้อนโต๊ะ',
#   'พริกจินดา',
#   'รากผักชี 3-4 ต้น',
#   'ผักชี',
#   'กระเทียม 10 กลีบ',
#   'น้ำปลา 3 ช้อนโต๊ะ',
#   'น้ำส้มสายชู 2 ช้อนโต๊ะ',
#   'น้ำตาลปี๊บ 1 1/2 ช้อนโต๊ะ (สำหรับน้ำจิ้ม)',
#   'น้ำมะนาว 3 ช้อนโต๊ะ',
#   'ระหว่างหมักหมูก็หันมาทำน้ำจิ้มกันค่ะ ใส่พริกจินดา รากผักชี ผักชี น้ำปลา น้ำส้มสายชู น้ำตาลปี๊บ และน้ำมะนาว ลงไปในเครื่องปั่น เสร็จแล้วก็ตักใส่ถ้วย',
#   'ตั้งกระทะ ด้วยไฟกลางแล้วนำหมูที่หมักไว่ลงไปย่างจนสุกทั้งสองด้าน',
#   'นำหมูขึ้นมาหั่นเป็นชิ้นพอดีคำ แล้วก็ตักใส่จานเสิร์ฟคู่น้ำจิ้มที่ทำเอาไว้แล้ว'],
#  '5. ลาบหมู\xa0_https://food.mthai.com/food-recipe/137377.html': ['น้ำเปล่า 1/4 ถ้วย',
#   'หมูบด 250 กรัม',
#   'ตับ 50 กรัม',
#   'หนังหมูลวก',
#   'พริกขี้หนูคั่วป่น',
#   'ข้าวคั่ว 3 ช้อนโต๊ะ',
#   'น้ำมะนาว 1 1/2 ช้อนโต๊ะ',
#   'น้ำปลา 2 ช้อนโต๊ะ',
#   'หอมแดงซอย',
#   'ผักชีฝรั่งซอย',
#   'ผักชีสับ',
#   'ใบสะระแหน่'],
#  '6. ข้าวผัดพริกขิงหมูกรอบ_https://food.mthai.com/food-recipe/137377.html': ['น้ำมันพืช 2 ช้อนโต๊ะ',
#   'พริกแกงพริกขิง 3 ช้อนโต๊ะ',
#   'ข้าวหอมมะลิ 2 ถ้วย',
#   'น้ำปลา 1 ช้อนโต๊ะ',
#   'ซอสปรุงรส 1 ช้อนโต๊ะ',
#   'น้ำตาลทราย 1 ช้อนโต๊ะ',
#   'ถั่วฝักยาว 1 ช้อนโต๊ะ',
#   'หมูกรอบ ตามชอบ',
#   'ใบมะกรูดซอย ตามชอบ'],
#  '_https://food.mthai.com/food-recipe/137377.html': ['เนื้อหมูไม่ติดมัน สับละเอียด 1 กิโลกรัม',
#   'หอมแดง 15 หัว',
#   'กระเทียมแกะเปลือก 3 หัว',
#   'พริกป่น 5 ช้อนโต๊ะ',
#   'รากผักชี 10 ราก',
#   'น้ำตาลปี๊บ 3 ช้อนโต๊ะ',
#   'น้ำปลา \xa05 ช้อนโต๊ะ',
#   'น้ำมันพืช',
#   'น้ำสต็อก'],
#  '8. หมูมะนาว\xa0_https://food.mthai.com/food-recipe/137377.html': ['สันคอหมูหั่นบาง 200 กรัม',
#   'กระเทียม 10 – 12 หัว',
#   'พริก',
#   'เกลือ 1 หยิบมือ',
#   'น้ำมะนาว 4 ช้อนโต๊ะ',
#   'น้ำปลา 3 ช้อนโต๊ะ',
#   'น้ำตาลทราย 1 1/2 ช้อนโต๊ะ',
#   'ผักเครื่องเคียง (ก้านคะน้าลวก,กระหล่ำปลีซอย,กระเทียมสด และใบสะระแหน่)'],
#  '9. เห่าดงหมู_https://food.mthai.com/food-recipe/137377.html': ['สันคอหมูสไลด์ 300 กรัม',
#   'น้ำปลา 2 1/2 ช้อนโต๊ะ',
#   'น้ำมะนาว 3 ช้อนโต๊ะ',
#   'น้ำตาลทราย 2 ช้อนชา',
#   'พริกป่น ตามชอบ',
#   'ข้าวคั่ว 1/4 ถ้วยตวง',
#   'ใบยี่หร่า ตามชอบ',
#   'หอมแดงซอย ตามชอบ'],
#  '10. กะเพราหมูสับ\xa0_https://food.mthai.com/food-recipe/137377.html': ['น้ำมันพืช 1 ช้อนโต๊ะ',
#   'กระเทียมสับ 1 ช้อนโต๊ะ',
#   'พริก ตามชอบ',
#   'หมูสับ 200 กรัม',
#   'ซอสหอยนางรม 1 ช้อนโต๊ะ',
#   'น้ำปลา 1 ช้อนโต๊ะ',
#   'น้ำตาลทราย 2 ช้อนชา',
#   'ซีอิ๊วดำ 2 ช้อนชา',
#   'ใบกะเพรา ตามชอบ'],
#  'ยำสายบัวแซลมอน_https://food.mthai.com/food-recipe/145247.html': ['น้ำปลา 5 ช้อนโต๊ะ',
#   'น้ำกระเทียมดอง 1/4 ถ้วย',
#   'น้ำมะขาดเปียก 1 ช้อนโต๊ะ',
#   'น้ำตาลปี๊บ 1 ช้อนโต๊ะ',
#   'น้ำปลาร้า 2 ช้อนโต๊ะ',
#   'น้ำมะนาว 2 ช้อนโต๊ะ หรือตามชอบค่ะ',
#   'พริกตำ 10 กรัม',
#   'สายบัว 80 กรัม',
#   'ข้าวโพดสุก 15 กรัม',
#   'ผักชีฝรั่ง 30 กรัม',
#   'แซลมอนดิบ 300 กรัม'],
#  'ยำสมุนไพรปลาช่อนแดดเดียว\xa0_https://food.mthai.com/food-recipe/145329.html': ['น้ำมันรำข้าว 1 ลิตร',
#   'ปลาช่อนแดดเดียว 200 กรัม',
#   'น้ำปลา 2 ช้อนโต๊ะ',
#   'น้ำมะนาว 4 ช้อนโต๊ะ',
#   'น้ำตาลปี๊บ 1 ช้อนโต๊ะ',
#   'พริกเผา 2 ช้อนโต๊ะ',
#   'นมข้นจืด 1 ช้อนโต๊ะ',
#   'พริกขี้หนูซอย 30 กรัม',
#   'ข่าสับ 15 กรัม',
#   'ผักชีฝรั่ง 20 กรัม',
#   'ใบมะกรูดซอย 15 กรัม',
#   'ตะไคร้ 40 กรัม',
#   'หอมแดงซอย 40 กรัม',
#   'ถั่วลิสงคั่ว ตามชอบค่ะ'],
#  'ผัดพริกแกงหมูกรอบ\xa0_https://food.mthai.com/food-recipe/141228.html': ['หมูกรอบ 200 กรัม',
#   'น้ำมันรำข้าว 2 ช้อนโต๊ะ',
#   'พริกแกงแดง 40 กรัม',
#   'ถั่วฝักยาว 1 ถ้วย',
#   'น้ำเปล่า 2 ช้อนโต๊ะ',
#   'น้ำปลา 2 ช้อนโต๊ะ',
#   'น้ำตาลปี๊บ 1 ช้อนโต๊ะ หรือตามชอบค่ะ',
#   'พริกชี้ฟ้าแดง (สไลด์) ตามชอบค่ะ',
#   'ใบมะกรูด 15 กรัม'],
#  'ต้มยำไข่น้ำ_https://food.mthai.com/food-recipe/143630.html': ['ไข่ไก่ 4 ฟอง',
#   'น้ำปลา 2 ช้อนชา',
#   'น้ำเปล่า 1 ลิตร',
#   'ข่า 30 กรัม',
#   'ตะไคร้ 10 กรัม',
#   'ใบมะกรูด 10 กรัม',
#   'น้ำปลา 2 ช้อนโต๊ะ',
#   'น้ำพริกเผา 1 ช้อนโต๊ะ',
#   'พริกขี้หนู (สับ) 50 กรัม',
#   'ผักชีฝรั่ง (ซอย) 20 กรัม',
#   'น้ำมะนาว 60 มิลลิลิตร'],
#  'น้ำพริกลงเรือ_https://food.mthai.com/food-recipe/137322.html': ['กะปิ 50 กรัม',
#   'กระเทียม 40 กรัม',
#   'หอมแดง 40 กรัม',
#   'กุ้งแห้ง แช่น้ำให้นิ่มจะได้ตำง่าย 20 กรัม',
#   'น้ำตาลปี๊บ 2 ช้อนโต๊ะ',
#   'มะเขือพวง 20 เม็ด',
#   'พริกขี้หนู 10 เม็ด',
#   'น้ำมะขามเปียก 4 ช้อนโต๊ะ',
#   'มะดันฝานบาง 4 ช้อนโต๊ะ',
#   'หมูหวาน 2 ช้อนโต๊ะ',
#   'ไข่เค็ม 1/4 ลูก'],
#  ' ไข่ขยี้_https://food.mthai.com/food-recipe/143577.html': ['น้ำมันรำข้าว 2 ช้อนโต๊ะ',
#   'กระเทียมสับ 10 กรัม',
#   'ไข่ไก่\xa0 4 ฟอง',
#   'หอมแดง 20 กรัม',
#   'น้ำปลา 1 ช้อนโต๊ะ',
#   'ซีอิ๊วขาว 1 ช้อนโต๊ะ',
#   'พริกซอย 20 กรัม',
#   'ต้นหอมซอย 10 กรัม'],
#  ' ไข่ยู่ยี่_https://food.mthai.com/food-recipe/144797.html': ['น้ำมันรำข้าว 2 ช้อนโต๊ะ',
#   'เนยจืด 10 กรัม',
#   'ไข่ไก่ \xa04 ฟอง',
#   'ซีอิ๊วขาว 1 ช้อนโต๊ะ',
#   'น้ำตาลทราย 1/2 ช้อนชา',
#   'พริกไทยดำ 1/2 ช้อนโต๊ะ'],
#  'ไข่เจียวใส่ผักหวาน_https://food.mthai.com/food-recipe/142275.html': ['ไข่ไก่\xa04 ฟอง',
#   'น้ำปลา 1 ช้อนโต๊ะ',
#   'หมูสับ\xa0200 กรัม',
#   'ผักหวาน 150 กรัม'],
#  'ชุบหยำ\xa0_https://food.mthai.com/food-recipe/137380.html': ['กุ้งสด 10 ตัว',
#   'กะปิเคย 1 1/2 ช้อนโต๊ะ',
#   'หอมแดง 15 หัว',
#   'พริกสด 15 เม็ด',
#   'น้ำมะนาว 4 ช้อนโต๊ะ',
#   'น้ำตาลปี๊บ 1/2 ช้อนโต๊ะ',
#   'น้ำต้มสุก 4 ช้อนโต๊ะ'],
#  'น้ำพริกมะอึก_https://food.mthai.com/food-recipe/142625.html': ['กระเทียม 15 กรัม',
#   'พริกขี้หนู\xa030 กรัม',
#   'กะปิ 1 ช้อนโต๊ะ',
#   'มะอึก 350 กรัม',
#   'น้ำตาลปี๊บ 1 ช้อนโต๊ะ',
#   'น้ำปลา 1 ช้อนโต๊ะ',
#   'น้ำมะนาว 40 มิลลิลิตร'],
#  'แกงขี้เหล็ก_https://food.mthai.com/food-recipe/138138.html': ['ใบขี้เหล็ก 500 กรัม',
#   'มะเขือพวง (ทุบ) 1/2 ถ้วย',
#   'หัวกะทิแท้ 100% ตราอร่อยดี 4 ถ้วย',
#   'พริกแกงเหลือง 2 ช้อนโต๊ะ',
#   'เนื้อหมู 150 กรัม',
#   'น้ำตาลปี๊บ 1 ช้อนโต๊ะ',
#   'กะปิ 1 ช้อนโต๊ะ',
#   'ใบมะกรูด ตามชอบค่ะ'],
#  'ส่วนที่ 1 เตรียมไก่ห่อใบเตย_https://food.mthai.com/food-recipe/81018.html': ['พริกไทยขาวเม็ด 1/2 ช้อนชา',
#   'กระเทียมสับ 5 กรัม',
#   'รากผักชี 5 กรัม',
#   'เนื้อสะโพกไก่ 200 กรัม',
#   'ซอสหอยนางรม 2 ช้อนโต๊ะ',
#   'น้ำมันงา 1 ช้อนโต๊ะ',
#   'ซีอิ๊วขาว 1 ช้อนโต๊ะ',
#   'น้ำตาลทราย 1 ช้อนโต๊ะ',
#   'กะทิ 3 ช้อนโต๊ะ',
#   'ใบเตย ตามชอบค่ะ',
#   'น้ำมันรำข้าว 1 ลิตร'],
#  'ส่วนที่ 2 น้ำจิ้มไก่ห่อใบเตย_https://food.mthai.com/food-recipe/81018.html': ['น้ำเปล่า 3 ช้อนโต๊ะ',
#   'น้ำตาลทราย 1/2 ถ้วย',
#   'ซีอิ๊วขาว 4 ช้อนโต๊ะ',
#   'น้ำมะขามเปียก 1 ช้อนโต๊ะ',
#   'ซีอิ๊วดำ 1 ช้อนโต๊ะ',
#   'งาขาว 15 กรัม'],
#  '1. ต้มยำ_https://food.mthai.com/food-recipe/140989.html': ['กุ้งกุลาดำตัวใหญ่ หรือกุ้งแม่น้ำ',
#   'เห็ดฟางผ่าครึ่ง',
#   'พริกขี้หนู',
#   'ใบมะกรูดฉีกเอาก้านออก',
#   'ข่าหั่นแว่น',
#   'ตะไคร้ทุบแล้วหั่นท่อน',
#   'ผักชี โรยหน้า',
#   'น้ำพริกเผา 1 ช้อนชา',
#   'มะนาว 1 ลูก',
#   'กะทิหรือนมข้นจืด 1/2 ถ้วย',
#   'น้ำตาล 1/2 ช้อนโต๊ะ',
#   'น้ำปลา 1 ช้อนโต๊ะ',
#   'เกลือ 1 หยิบมือ',
#   'น้ำซุป (ถ้าไม่มีเป็นซุปสำเร็จรูปกับน้ำเปล่า)'],
#  'สูตร กะหล่ำปลีทอดน้ำปลา_https://food.mthai.com/food-recipe/140989.html': ['น้ำมันรำข้าว 2 ช้อนโต๊ะ',
#   'กระเทียม 6 กลีบ',
#   'กะหล่ำปลี 350 กรัม',
#   'น้ำปลา 3 ช้อนโต๊ะ'],
#  'สูตร แกงฟักทอง_https://food.mthai.com/food-recipe/140989.html': ['เนื้อหมู 150 กรัม',
#   'พริกแกงเผ็ด 1 ½ ช้อนโต๊ะ',
#   'น้ำมันสำหรับผัด 1 ช้อนโต๊ะ',
#   'ฟักทอง 250 กรัม',
#   'พริกชี้ฟ้าแดง 1 เม็ด',
#   'ใบมะกรูด 4 ใบ',
#   'ใบโหรพา 2 ช้อนโต๊ะ',
#   'น้ำตาลทราย ½ ช้อนชา',
#   'น้ำปลา 2 ช้อนโต๊ะ',
#   'กะทิ 400 มล.',
#   'จากนั้นตั้งหม้อ ใช้ไฟอ่อนๆ แล้วใส่น้ำมันสำหรับผัดลงไป แล้วรอให้นำมันร้อน จากนั้นจึงใส่พริกแกงเผ็ดลงไป แล้วผัดให้หอมแตกมัน',
#   'จากนั้นปรับไฟกลาง แล้วใส่เนื้อหมูหั่นบางลงไป แล้วผัดให้พอสุก',
#   'จากนั้นใส่กะทิลงไปครึ่งนึง แล้วรอให้เดือดพล่าน จากนั้นใส่เครื่องปรุงรสต่างๆลงไป ใส่น้ำตาลทราย น้ำปลาใส่ลงไป แล้วรอให้เดือด',
#   'จากนั้นนำฟักทองหั่นชิ้นใส่ลงไป จากนั้นเติมกะทิส่วนที่เหลือลงไป ให้พอท่วมฟักทอง',
#   'จากนั้นรอให้เดือดอีกครั้ง แล้วจึงปิดฝาหม้อ แล้วต้มต่อไปประมาณ 5 นาที ฟักทองจะสุกพอดี',
#   'เมื่อต้มให้ฟักทองสุกดีแล้ว จากนั้นจึงใส่ใบมะกรูดฉีก พริกชี้ฟ้าแดงหั่น ใบโหรพาใส่ลงไป',
#   'จากนั้นคนเบาๆ ให้ส่วนผสมเข้ากันดี แล้วปิดไฟยกลง',
#   'จะได้แกงฟักทองหมู รสชาติเข้มข้นกลมกล่อม หวานมันหอมอร่อย ฟักทองหวานมัน เนื้อหมูนุ่มๆ กับกะทิหอมมัน หอมอร่อยเข้ากัน พร้อมจัดเสิร์ฟ',
#   'จัดเสิร์ฟ แกงฟักทองหมูหอมๆ เมนูอาหารแสนอร่อย รสชาติเข้มข้นกลมกล่อม หวานมันหอมอร่อย ฟักทองหวานมัน เนื้อหมูนุ่มๆ กับกะทิหอมมัน หอมอร่อยเข้ากัน มีประโยชน์ต่อสุขภาพ',
#   'แกงฟักทองหมูหอมๆ เมนูอาหารแสนอร่อย รสชาติเข้มข้นกลมกล่อม หวานมันหอมอร่อย ฟักทองหวานมัน เนื้อหมูนุ่มๆ กับกะทิหอมมัน หอมอร่อยเข้ากัน มีประโยชน์ต่อสุขภาพ'],
#  'สูตร แกงสายบัวปลาทู_https://food.mthai.com/food-recipe/140989.html': ['สายบัวลอกเปลือกออก เด็ดเป็นท่อน 200 กรัม',
#   'ปลาทูนึ่ง แกะเอาแต่เนื้อ 1 ตัว',
#   'น้ำตาลทราย 1 ช้อนโต๊ะ',
#   'กะทิ 200 มิลลิลิตร',
#   'หอมแดง 5 หัว',
#   'พริกไทย 1 ช้อนโต๊ะ',
#   'เกลือ 1/2 ช้อนโต๊ะ',
#   'น้ำมะขามเปียก 3 ช้อนโต๊ะ',
#   'กะปิ 1/2 ช้อนโต๊ะ',
#   'ใบมะกรูด 5 ใบ'],
#  'สูตร ไข่เจียวชะอม_https://food.mthai.com/food-recipe/140989.html': ['ไข่ไก่ 3 ฟอง',
#   'ชะอม 1 ถ้วย',
#   'ซีอิ๊วขาว 1 ช้อนโต๊ะ',
#   'ผงปรุงรส 2 ช้อนชา'],
#  'สูตร ผัดคะน้าน้ำมันหอย_https://food.mthai.com/food-recipe/140989.html': ['คะน้า 400 กรัม',
#   'กระเทียมสับหยาบ 2 ช้อนโต๊ะ',
#   'พริกไทย 1 ช้อนชา',
#   'น้ำมันหอย 5 ช้อนโต๊ะ',
#   'ซิอิ๊วขาว 2 ช้อนโต๊ะ',
#   'น้ำตาล 1/4 ช้อนชา',
#   'น้ำซุป 1/2 ถ้วยตวง',
#   'น้ำมันพืชสำหรับผัด',
#   'ตักใส่จาน เหยาะพริกไทยโรยหน้า เสริฟทันทีพร้อมข้าวสวยร้อนๆ'],
#  '7. น้ำพริกผักลวก_https://food.mthai.com/food-recipe/140989.html': ['เนื้อหมูบด 400 กรัม',
#   'มะเขือเทศลูกเล็ก 20 ลูก',
#   'น้ำมันพืช 2 ช้อนโต๊ะ',
#   'พริกขี้หนูแห้ง 20 เม็ด',
#   'หอมแดง 5 หัว',
#   'กระเทียม 10 กลีบ',
#   'กะปิ 1 ช้อนโต๊ะ',
#   'เกลือ 1 หยิบมือ',
#   'ผักชีและต้นหอมซอยเพื่อโรยหน้า'],
#  'สูตร ลาบหมู_https://food.mthai.com/food-recipe/140989.html': ['น้ำเปล่า 1/4 ถ้วย',
#   'หมูบด 250 กรัม',
#   'ตับ 50 กรัม',
#   'หนังหมูลวก',
#   'พริกขี้หนูคั่วป่น',
#   'ข้าวคั่ว 3 ช้อนโต๊ะ',
#   'น้ำมะนาว 1 1/2 ช้อนโต๊ะ',
#   'น้ำปลา 2 ช้อนโต๊ะ',
#   'หอมแดงซอย',
#   'ผักชีฝรั่งซอย',
#   'ผักชีสับ',
#   'ใบสะระแหน่'],
#  'สูตร แกงส้มดอกแคกุ้ง_https://food.mthai.com/food-recipe/140989.html': ['น้ำพริกแกงส้ม 3 ช้อนโต๊ะ',
#   'กุ้งสด 10-12 ตัว',
#   'ดอกแค 400 กรัม',
#   'น้ำปลา 5 ช้อนโต๊ะ',
#   'น้ำตาลปี๊บ 2 ช้อนโต๊ะ',
#   'น้ำมะขามเปียก 1/2 ถ้วยตวง',
#   'น้ำมะนาว 2 ช้อนชา',
#   'น้ำสะอาด 5 ถ้วย'],
#  'ตับทอดกระเทียมพริกไทย_https://food.mthai.com/food-recipe/141991.html': ['กระเทียม 20 กรัม',
#   'ตับหมู 300 กรัม',
#   'นม\xa01/2 ถ้วย',
#   'น้ำมันรำข้าว 2 ช้อนโต๊ะ',
#   'ซอสหอยนางรม 2 ช้อนโต๊ะ',
#   'ซีอิ๊วขาว 1 ช้อนโต๊ะ',
#   'น้ำปลา 1/2 ช้อนโต๊ะ',
#   'น้ำตาลทราย 1 ช้อนชา',
#   'พริกไทยดำ (ตำหยาบ) 2 ช้อนชา',
#   'เนย 10 กรัม',
#   'รวมเทคนิคเรื่องตับ การทำเมนูตับหมูต่างๆ ให้อร่อย ต้องมีเคล็ดลับ',
#   'วิธีลดความคาวของตับหมู'],
#  'ทอดมันไข่ปลาหมึก_https://food.mthai.com/food-recipe/131436.html': ['เนื้อปลากราย (ขูด) 50 กรัม',
#   'เนื้อปลายี่สก (ขูด) 50 กรัม',
#   'ไข่ปลาหมึก 50 กรัม',
#   'พริกแกงเผ็ด 3/4 ถ้วย',
#   'ไข่ไก่ 1 ฟอง',
#   'น้ำปลา 1/2 ช้อนโต๊ะ',
#   'เกลือ 1/2 ช้อนชา',
#   'น้ำตาลทราย 1/2 ช้อนชา',
#   'แป้งทอดกรอบ 2 ช้อนโต๊ะ',
#   'ถั่วฝักยาว ตามชอบ',
#   'ใบมะกรูด (ซอย) ตามชอบ'],
#  ' แกงคั่วกระดูกหมู\xa0_https://food.mthai.com/food-recipe/133703.html': ['น้ำมันพืช 2 ช้อนโต๊ะ',
#   'พริกแกงใต้ 50 กรัม',
#   'กะปิ 2 ช้อนโต๊ะ',
#   'น้ำเปล่า 2 ช้อนโต๊ะ',
#   'ซี่โครงหมู 400 กรัม',
#   'น้ำปลา 2 ช้อนโต๊ะ',
#   'นมข้นจืดคาร์เนชัน 250 มิลลิลิตร',
#   'ใบมะกรูด ตามชอบ'],
#  'วันสงกรานต์_https://food.mthai.com/food-recipe/113815.html': ['ไก่ 500 กรัม (จะใช่ส่วนไหนก็ได้ เช่นน่องหรือหน้าอก)',
#   'น้ำตาลปี๊ป 2 ช้อนโต๊ะ',
#   'พริกป่น 1/2',
#   'ผงกะหรี่ 1/2 ช้อนชา',
#   'น้ำปลา (ประมาณตามขนาดของเนื้อไก่ พอปริ่มๆ ไม่ท่วมเนื้อไก่)',
#   'กระเทียม 5 กลีบเล็ก',
#   'พริกไทยเม็ด 1/4 ช้อนชา'],
#  'สูตรหมักไก่ย่าง_https://food.mthai.com/food-recipe/113815.html': ['ล้างไก่ให้สะอาด บีบน้ำออกจากไก่ให้หมดแล้ววางให้ไก่สะเด็ดน้ำ',
#   'โขลกกระเทียมและพริกไทยเม็ดให้ละเอียด',
#   'นำไก่ใส่ชามผสม เทส่วนผสมที่เตรียมไว้ลงไปคลุกให้เข้ากัน',
#   'นำขึ้นเตาย่าง ใช้เตาถ่าน ใช้ไฟอ่อนถึงปานกลาง ย่างไปเรื่อยๆ ไก่ย่างที่อร่อยต้องใช้เวลากันนิดนึง\xa0ค่อยหมั่นพลิกไก่ไปมา เพื่อให้สุกทั่วๆ หรือใช้ฝากอะไรก็ได้มาครอบตัวเนื้อไก่ เพื่อให้ความร้อนกระจายไปทั่วๆ วิธีนี้ทำให้หนังตึงอร่อย',
#   'หากใครสะดวกใช้เป็นเตาอบ ก็ใช้อุณภูมิ 220 องศา แล้วค่อยๆ อ่อนเหลือ 150 องศา ใช้ไฟบนล่าง แค่นี้ก็ได้ไก่ย่างที่มีรสชาติอร่อยและหนังกรอบๆ ตึงๆ แล้วค่ะ',
#   'สูตร สลัดอกไก่ย่าง อาหารคลีนสุดแซ่บ ',
#   'ร้านน้อมจิตต์ไก่ย่าง เอาใจคนชอบทั้งไก่บ้านและไก่เนื้อ',
#   'สูตร ตับไก่ย่าง เอาไว้กินกับข้าวเหนียวร้อนๆ',
#   'สูตร ไก่ย่างขมิ้น เนื้อนุ่มกลิ่นขมิ้นหอมฟุ้ง',
#   'สูตร ซี่โครงไก่แดง แทะเพลินจนเหลือแต่กระดูก'],
#  'ผัดกะเพรา_https://food.mthai.com/food-recipe/144224.html': ['น้ำมันรำข้าว 2 ช้อนโต๊ะ',
#   'พริก + กระเทียม \xa0(สับ) 40 กรัม',
#   'ปลาหมึก + กุ้ง 500 กรัม',
#   'ซอสหอยนางรม 2 ช้อนโต๊ะ',
#   'น้ำปลา 1 ช้อนโต๊ะ',
#   'น้ำตาลทรายแดง 2 ช้อนชา',
#   'ซีอิ๊วดำ 2 ช้อนชา',
#   'ผงปรุงรส 1 ช้อนชา',
#   'ข้าวสวย 500 กรัม',
#   'ใบกะเพรา\xa0ตามชอบค่ะ'],
#  'ปูจ๋า_https://food.mthai.com/food-recipe/124228.html': ['รากผักชี 15 กรัม',
#   'กระเทียม 15 กรัม',
#   'พริกไทยขาว 1/2 ช้อนโต๊ะ',
#   'เนื้อหมู (สับ) 400 กรัม',
#   'น้ำตาลทราย 1 ช้อนโต๊ะ',
#   'ซีอิ๊วขาว 1 ช้อนโต๊ะ',
#   'ซอสหอยนางรม 1 ช้อนโต๊ะ',
#   'ไข่ไก่ 1 ฟอง',
#   'แป้งสาลีอเนกประสงค์ 2 ช้อนโต๊ะ',
#   'เนื้อปูก้อน ตามชอบค่ะ',
#   'ผักชี (สำหรับตกแต่ง)'],
#  'ตีนไก่ต้มซีอิ๊ว_https://food.mthai.com/food-recipe/133363.html': ['น้ำมันพืช 2 ช้อนโต๊ะ',
#   'ตีนไก่ 300 กรัม',
#   'เหล้า 2 ช้อนโต๊ะ',
#   'ข่า 1 หัว',
#   'ตะไคร้ 2 หัว',
#   'ใบมะกรูด ตามชอบ',
#   'หอมหัวใหญ่ ครึ่งหัว',
#   'ซีอิ๊วขาว 1 ช้อนโต๊ะ',
#   'ซีอิ๊วดำ 2 ช้อนชา',
#   'เกลือ 1 ช้อนโต๊ะ',
#   'ซอสหอยนางรม 1 ช้อนโต๊ะ',
#   'ซอสปรุงรส 1 ช้อนโต๊ะ',
#   'ผงปรุงรส 1 ช้อนโต๊ะ',
#   'เห็ดหอม 5 หัว'],
#  'ต้มยำปลากระป๋อง_https://food.mthai.com/food-recipe/127470.html': ['ตะไคร้ 2 ต้น',
#   'ข่า 6-7 ชิ้น',
#   'ใบมะกรูด 4-5 ใบ',
#   'หอมแดง 6-7 หัว',
#   'เห็ดฟาง 7-8 ลูก',
#   'ปลากระป๋อง 3 กระป๋อง',
#   'พริกขี้หนู ตามชอบ',
#   'น้ำปลา 3 ช้อนโต๊ะ',
#   'วุ้นเส้นแช่น้ำ 50 กรัม',
#   'น้ำมะนาว ตามชอบ',
#   'ผักชีฝรั่ง'],
#  ' ต้มข่าทะเล\xa0_https://food.mthai.com/food-recipe/140002.html': ['หัวกะทิแท้ 100%',
#   'ข่า (หั่นแว่น) 40 กรัม',
#   'ตะไคร้ 30 กรัม',
#   'ใบมะกรูด 15 กรัม',
#   'กุ้งแม่น้ำ 200 กรัม',
#   'หอยแมลงภู่นิวซีแลนด์ 100 กรัม',
#   'ปลาหมึก 100 กรัม',
#   'พริก 30 กรัม',
#   'พริกแห้ง 30 กรัม',
#   'เห็ดฟาง 20 กรัม',
#   'เห็ดนางฟ้า 20 กรัม',
#   'เห็ดหูหนู 20 กรัม',
#   'น้ำตาลปี๊บ 30 กรัม',
#   'น้ำปลา 40 กรัม',
#   'ผักชีฝรั่ง 20 กรัม',
#   'ผักชี 20 กรัม',
#   'น้ำมะนาว 50 มิลลิลิตร'],
#  'สูตร หอยแมลงภู่ย่างซอสทะเลเดือด เมนูพรีเมี่ยมที่ทำเองได้_https://food.mthai.com/food-recipe/131711.html': ['เนยจืด 20 กรัม',
#   'แป้งอเนกประสงค์ 30 กรัม',
#   'ตะไคร้ 2 ต้น',
#   'ใบมะกรูด 2-3 ใบ',
#   'ข่า 2-3 ชิ้น',
#   'พริกแดง 8-10 เม็ด',
#   'น้ำพริกเผา 1 ช้อนโต๊ะ',
#   'นมสด 50 กรัม',
#   'น้ำปลา 3 ช้อนโต๊ะ',
#   'น้ำมะนาว 2 ช้อนโต๊ะ',
#   'เนยจืด (สำหรับย่างหอย) ตามชอบ',
#   'หอยแมลงภู่นิวซีแลนด์ ตามชอบ'],
#  'โป๊ะแตก_https://food.mthai.com/food-recipe/132361.html': ['กุ้ง 3-4 ตัว',
#   'ปลาหมึก 1 ตัว',
#   'หอยแมลงภู่ 3-4 ตัว',
#   'เห็ดฟาง',
#   'ตะไคร้ 1-2 ต้น',
#   'หอมแดง 1 หัว',
#   'ข่าหั่นแว่น',
#   'ใบมะกรูด',
#   'ใบกะเพรา',
#   'น้ำมะนาว 3 ช้อนโต๊ะ',
#   'พริกขี้หนู',
#   'น้ำปลา 2 ช้อนโต๊ะ'],
#  '1. ข้าวหน้าหมูเทอริยากิ_https://food.mthai.com/food-recipe/138481.html': ['เนื้อหมู',
#   'ซอสเทอริยากิ',
#   'บรอกโคลี',
#   'แครอทหั่น',
#   'ข้าวญี่ปุ่น',
#   'งาขาว'],
#  '2.\xa0ข้าวหน้าปลาซาบะ_https://food.mthai.com/food-recipe/138481.html': ['ปลาซาบะ',
#   'ข้าวญี่ปุ่น',
#   'งาดำ',
#   'ข้าวโพด'],
#  '3.\xa0ข้าวมันไก่_https://food.mthai.com/food-recipe/138481.html': ['อกไก่',
#   'แตงกวา',
#   'ข้าวหอม',
#   'น้ำจิ้มข้าวมันไก่'],
#  '4. ข้าวยำเกาหลี บิบิมบับ_https://food.mthai.com/food-recipe/138481.html': ['ข้าวญี่ปุ่น ',
#   'ผักโขม ',
#   'หมูหมัก ',
#   'เห็ด ',
#   'แครอทหั่นเต๋า ',
#   'งาขาว ',
#   'โคชูจัง'],
#  '5.\xa0สปาเก็ตตี้ซอสมะเขือเทศ_https://food.mthai.com/food-recipe/138481.html': ['เส้นสปาเก็ตตี้',
#   'หมูสับ',
#   'ซอสมะเขือเทศ',
#   'มะเขือเทศ'],
#  '6.\xa0ไข่ตุ๋นปูอัด_https://food.mthai.com/food-recipe/138481.html': ['ไข่',
#   'ปูอัด',
#   'เครื่องปรุงไข่'],
#  'ชั้นตอนการทำ_https://food.mthai.com/food-recipe/138481.html': ['ใส่น้ำในหม้อให้อยู่ในระดับน้อยกว่าถ้วยที่จะใส่',
#   'ตีไข่ปรุงไข่ในถ้วยตามใจชอบ อยากใส่ไรก็ใส่',
#   'น้ำถ้วยใส่ไปในหม้อหุงข้าว แล้วก็รอซัก10นาที อย่าทำนานเกินไปเพราะหม้อจะดำด้วย'],
#  '7. ลาบหมู_https://food.mthai.com/food-recipe/138481.html': ['หมูสับ',
#   'เครื่องปรุงรส',
#   'ข้าวคั่ว',
#   'หอมแดง'],
#  '8. มาม่าเกาหลีชีสกุ้ง_https://food.mthai.com/food-recipe/138481.html': ['มาม่าเกาหลี',
#   'กุ้งขาว',
#   'ชีส',
#   'ไข่แดง',
#   'ตอกไข่แดงใส่ด้วย เดี๋ยวจะดูไม่ค่อยมีความเกาหลี ถ่ายรูปสวยๆ'],
#  '9. แกงพะแนง_https://food.mthai.com/food-recipe/138481.html': ['สันในไก่',
#   'กะทิ',
#   'พริกแกง',
#   'พริกชี้ฟ้า',
#   'มะเขือพวง',
#   'เครื่องปรุงตามใจชอบ',
#   'พอเริ่มเดือดก็ใส่สันในไก่ที่หั่นแล้วลงไป',
#   'พอไก่เริ่มสุกก็ใส่พริกชี้ฟ้า มะเขือพวงลงไป',
#   'ในรูปรสชาติไม่จัดจ้านเท่าไหร่ แนะนำให้ลดน้ำลดกะทิอีกหน่อย'],
#  '10. ปีกไก่น้ำแดง_https://food.mthai.com/food-recipe/138481.html': ['ปีกไก่บน',
#   'ซอสมะเขือเทศ',
#   'น้ำมันหอย'],
#  '11.\xa0ข้าวหน้าหมูเกาหลีโคชูจัง_https://food.mthai.com/food-recipe/138481.html': ['ข้าวญี่ปุ่น',
#   'หมูหมัก',
#   'โคชูจัง',
#   'ข้าวโพด',
#   'งาขาว',
#   'งาดำ'],
#  '12.\xa0กล้วยบวชชี_https://food.mthai.com/food-recipe/138481.html': ['กล้วย',
#   'กะทิ',
#   'เกลือ'],
#  '13.\xa0ขนมจีบหมู_https://food.mthai.com/food-recipe/138481.html': ['หมู',
#   'แครอท',
#   'แผ่นเกี๊ยว',
#   'กระเทียมเจียว'],
#  '14.\xa0หอยลายผัดฉ่า_https://food.mthai.com/food-recipe/138481.html': ['หอยลาย',
#   'กะทิ',
#   'พริกเผา',
#   'น้ำตาล',
#   'ใบโหระพา'],
#  'วัตุดิบ_https://food.mthai.com/food-recipe/138481.html': ['เครื่องพะโล้',
#   'เต้าหู้'],
#  '16. ข้าวหมกไก่_https://food.mthai.com/food-recipe/138481.html': ['น่องไก่',
#   'ข้าว',
#   'แตงกวา',
#   'ผักชี'],
#  '17. ต้มข่าไก่_https://food.mthai.com/food-recipe/138481.html': ['ตีนไก่',
#   'ใบมะกรูด',
#   'กะทิ',
#   'พริกแกง'],
#  '18.\xa0กุ้งอบวุ้นเส้น_https://food.mthai.com/food-recipe/138481.html': ['วุ้นเส้น',
#   'กุ้ง',
#   'เครื่องปรุง',
#   'ผักชี'],
#  '20.\xa0มักกะโรนี่ซอสมะเขือเทศ_https://food.mthai.com/food-recipe/138481.html': ['มักกะโรนี',
#   'ซอสมะเขือเทศ',
#   'ปูอัด'],
#  '21.\xa0ต้มจืดเต้าหู้หมูสับ_https://food.mthai.com/food-recipe/138481.html': ['ผักกาด',
#   'หมูสับ',
#   'แครอท',
#   'เต้าหู้',
#   'สาหร่าย'],
#  'ข้าวมันไก่ทอด_https://food.mthai.com/food-recipe/126578.html': ['ข้าวหอมมะลิ 6 ถ้วย',
#   'กระเทียม 6-8 กลีบ',
#   'ขิงแก่ 3-4 ชิ้น',
#   'น้ำมันรำข้าว 1/2 ถ้วย',
#   'เกลือป่น 1/2 ช้อนชา',
#   'ซีอิ๊วขาว 1 ช้อนโต๊ะ',
#   'หนังไก่ 20 กรัม',
#   'น้ำเปล่า 5 1/2 ถ้วย',
#   'รากผักชี 2-3 ต้น',
#   'สะโพกไก่ 500 กรัม',
#   'ซอสหอยนางรม 2 ช้อนโต๊ะ',
#   'ซีอิ๊วขาว 1 ช้อนโต๊ะ (สำหรับหมักไก่)',
#   'พริกไทยป่น 1 ช้อนชา',
#   'กระเทียมสับ 1/2 ช้อนโต๊ะ',
#   'รากผักชีสับ 1/2 ช้อนโต๊ะ',
#   'แป้งทอดกรอบ',
#   'ไข่ไก่',
#   'เกล็ดขนมปัง'],
#  'ลาบหมู\xa0_https://food.mthai.com/food-recipe/126725.html': ['น้ำเปล่า 1/4 ถ้วย',
#   'หมูบด 250 กรัม',
#   'ตับ 50 กรัม',
#   'หนังหมูลวก',
#   'พริกขี้หนูคั่วป่น',
#   'ข้าวคั่ว 3 ช้อนโต๊ะ',
#   'น้ำมะนาว 1 1/2 ช้อนโต๊ะ',
#   'น้ำปลา 2 ช้อนโต๊ะ',
#   'หอมแดงซอย',
#   'ผักชีฝรั่งซอย',
#   'ผักชีสับ',
#   'ใบสะระแหน่'],
#  '': ['ไข่ไก่ 5 ฟอง',
#   'นมข้นจืด 1 กระป๋อง',
#   'ซีอิ๊วญี่ปุ่น 1 ช้อนโต๊ะ',
#   'มิริน 1 ช้อนโต๊ะ',
#   'สาเก 1 ช้อนโต๊ะ',
#   'เกลือป่น 1/2 ช้อนชา',
#   'กุ้งสด',
#   'ต้นหอมซอย',
#   'ไข่ไก่ 3 ฟอง',
#   'น้ำสต๊อก 1 ถ้วย',
#   'น้ำพริกเผา 2 ช้อนโต๊ะ',
#   'น้ำปลา 1 ช้อนโต๊ะ',
#   'กุ้งสด 3 ตัว',
#   'แป้งขนมปัง 375 กรัม',
#   'เกลือป่น 1/2 ช.ช.',
#   'ยีสต์ 5 กรัม หรือ 1+1/2 ช.ช.',
#   'น้ำตาลทราย 50 กรัม',
#   'น้ำเย็นจัด 200 กรัม',
#   'น้ำมันพืช 30 กรัม',
#   'สารเสริมคุณภาพ เอ็มเพ็ก 1 ช.ช.',
#   'สีผสมอาหาร',
#   'น้ำมันรำข้าว 2 ช้อนโต๊ะ',
#   'กระเทียมสับ 15 กรัม',
#   'หอมใหญ่ 40 กรัม',
#   'ไข่ไก่ 2 ฟอง',
#   'แหนม 250 กรัม',
#   'ซอสหอยนางรม 2 ช้อนโต๊ะ',
#   'ซีอิ๊วขาว 1 ช้อนโต๊ะ',
#   'น้ำตาลทราย 2 ช้อนชา',
#   'วุ้นเส้น (แช่น้ำ) 80 กรัม',
#   'พริกแดง 30 กรัม หรือตามชอบค่ะ',
#   'ต้นหอม 20 กรัม',
#   'ขิงอ่อน 1 กิโลกรัม',
#   'เกลือ 1 1/2 ช้อนโต๊ะ',
#   'น้ำส้มสายชู 1/2 ถ้วย',
#   'น้ำ 1 ถ้วย',
#   'น้ำตาลทราย 1 1/2 ช้อนโต๊ะ',
#   'น้ำมะนาว 1 ลูก',
#   'นำขิงขึ้นมาจากน้ำเกลือและบีบน้ำเกลือออกให้หมด จากนั้นให้นำขิงลงไปแช่ในขวดที่มีส่วนผสมน้ำดองขิง',
#   'บีบมะนาวตามลงไปและขนให้ทั่วๆ ขั้นตอนนี้คือขั้นตอนที่ทำให้ขิงเป็นสีชมพู',
#   'จากนั้นก็ปิดฝาให้มิดชิดแล้วนำเข้าตู้เย็น',
#   'ปีกบนไก่และปีกกลางไก่ 12 ชิ้น',
#   'เกลือป่นและพริกไทยป่นอย่างละ 1/2 ช้อนชา',
#   'น้ำมันพืชสำหรับทอด',
#   'แป้งสาลีอเนกประสงค์ \xa01/2 \xa0ถ้วย',
#   'แป้งข้าวโพด \xa01/2 ถ้วย',
#   'กระเทียมสับ \xa01 \xa0ช้อนโต๊ะ',
#   'ขิงก่สับ \xa01/2 \xa0ช้อนโต๊ะ',
#   'ซอสถั่วเหลือง \xa03 \xa0ช้อนโต๊ะ',
#   'น้ำเปล่า \xa03 \xa0ช้อนโต๊ะ',
#   'น้ำปลา 2 ช้อนโต๊ะ',
#   'น้ำมะนาว 3 ช้อนโต๊ะ',
#   'น้ำตาลทราย 1 1/2 ช้อนโต๊ะ',
#   'พริกขี้หนูซอย',
#   'ปลาทูทอดแกะเนื้อ 2 ตัว',
#   'ตะไคร้ซอย ตามชอบ',
#   'หอมแดงซอย',
#   'ผักชีฝรั่งซอย',
#   'ต้นหอมซอย',
#   'ผักชีซอย',
#   'ใบสาระแหน่',
#   'พริกแห้งทอด',
#   'ไข่ไก่ ฟอง',
#   'หมูบด 50 กรัม',
#   'ผงปรุงรสมาม่ารสต้มยำ',
#   'น้ำพริกเผา 1 ซอง',
#   'แครอทหั่นเต๋า ตามชอบ',
#   'ต้นหอมซอย 1 ต้น',
#   'พริกแดง ตามชอบ',
#   'บะหมี่กึ่งสำเร็จรูปลวกแล้ว 1 ซอง',
#   'บะหมี่กึ่งสำเร็จรูปที่ลวกมาแล้วใส่ลงไปตีกับไข่ คลุกให้เข้ากัน',
#   'ตั้งกระทะใส่น้ำมันให้ร้อน เทไข่ใส่ลงไปทอดให้สุกทั้งสองด้าน',
#   'เสร็จแล้วใส่จานเสิร์ฟทันที',
#   'เนยจืด 100 กรัม',
#   'หอมใหญ่ครึ่งลูก',
#   'ฟักทอง 1 ถ้วย',
#   'น้ำสต็อก 2 ถ้วย',
#   'นมสด 1 ถ้วย',
#   'พริกไทยดำ',
# ...
#   'ห่อไข่นกกระทาต้มสุกด้วนส่วนผสมของเนื้อปลาที่เตรียมไว้ให้มิดแล้วปั้นเป็นก้อนกลม (ทำจนหมด)?',
#   'ทอดส่วนผสมที่ห่อไว้ในน้ำมันร้อน (ใช้ไฟกลาง) จนสุกเหลืองตักขึ้นพักให้สะเด็ดน้ำมัน ผ่าครึ่ง จัดใส่จาน โรยใบกระเพราทอดเสิร์ฟคู่กับน้ำจิ้มไก่'],
#  ' ข้าวผัดปลาสลิดใบกระเพรา_https://food.mthai.com/food-recipe/87073.html': ['ข้าวกล้องหุงสุก 800 กรัม (6 ถ้วย)',
#   'ปลาสลิดสด140 กรัม (2 ตัว)',
#   'กระเทียมสับละเอียด 20 กรัม (4 กลีบ)',
#   'พริกขี้หนูหั่นหยาบ 8 กรัม (5 เม็ด)',
#   'รากผักชีซอย 5 กรัม (1 ราก)',
#   'น้ำมันรำข้าวสำหรับทอดปลา 40 กรัม (4 ช้อนโต๊ะ)',
#   'น้ำปลา 5 กรัม (1 ช้อนชา)',
#   'ซอสปรุงรส 5 กรัม (1 ช้อนชา)',
#   'ซีอิ้วดำ 2.5 กรัม (1-2 ช้อน)',
#   'น้ำตาลทราย 10 กรัม (2 ช้อนชา)',
#   'ใบกระเพรา 20 กรัม (1-2 ถ้วย)',
#   'น้ำมันรำข้าวสำหรับทอด',
#   'ตักข้าว ผัดใส่จาน โรยปลาสลิดทอดและใบกระเพราทอดก่อนเสิร์ฟ'],
#  'ปริมาณสำหรับ 1 ที่?_https://food.mthai.com/food-recipe/87073.html': ['ปลาสลิด 30 กรัม',
#   'ข้าวผัด 200 กรัม'],
#  '_https://food.mthai.com/food-recipe/86767.html': ['พาสต้าต้มสุก?????????????? 300? กรัม',
#   'เนื้อไก่หั่นสี่เหลี่ยมเล็ก?? 300? กรัม',
#   'พริกแกงเขียวหวาน?????????? 2? ช้อนโต๊ะ',
#   'กะทิ???????????????????????????? 1-2? ช้อนโต๊ะ',
#   'มะเขือพวง??????????????????? 1-4? ถ้วย',
#   'ใบมะกรูดฉีก???????????????????? 2? ใบ',
#   'ใบโหระพา???????????????????? 1-4? ถ้วย',
#   'พริกชี้ฟ้าแดงและเหลืองหั่นแฉลบ? อย่างละ? 1? เม็ด',
#   'น้ำปลา????????????????????? 1? 1-2? ช้อนโต๊ะ',
#   'น้ำตาลปี๊บ???????????????????????? 1? ช้อนโต๊ะ',
#   'น้ำมันพืช?????????????????????????? 2? ช้อนโต๊ะ'],
#  '?แกงไก่ทอดใส่ฟักทอง_https://food.mthai.com/food-recipe/86694.html': ['ปีกบนไก่???????????? ? ? ? ? ? ? 300? กรัม',
#   'เกลือป่น???????????????????????????? 1? ช้อนชา',
#   'พริกไทยป่น???????????????????? 1-2? ช้อนชา',
#   'แป้งชุบทอดสำเร็จรูป?????????? 3? ช้อนโต๊ะ',
#   'น้ำมันพืชสำหรับทอด',
#   'ไก่ทอด',
#   'ฟักทองหั่นชิ้นสี่เหลี่ยม? 200? กรัม',
#   'แครอตหั่นชิ้นสี่เหลี่ยม? 200? กรัม',
#   'พริกแกงเผ็ด? 3? ช้อนโต๊ะ',
#   'กะทิ?? 3? ถ้วย',
#   'ใบมะกรูดซอย? 3 – 4 ใบ',
#   'ใบโหระพา?? 1? ถ้วย',
#   'พริกชี้ฟ้าแดงหั่นแฉลบ? 1? เม็ด',
#   'น้ำปลา? 4? ช้อนโต๊ะ',
#   'น้ำตาลปี๊บ? 1 – 2 ช้อนโต๊ะ',
#   'น้ำมันพืช? 2? ช้อนโต๊ะ'],
#  'หมูอบซอสน้ำแดง_https://food.mthai.com/food-recipe/84985.html': ['สะโพกหมูหั่นชิ้นสี่เหลี่ยมพอคำ?? 500 กรัม',
#   'หอมหัวใหญ่สับละเอียด????????????????? 2 ช้อนโต๊ะ',
#   'กระเทียมสับละเอียด????????????????????? 1 ช้อนโต๊ะ',
#   'น้ำส้มสายชู?????????????????????????????? 1-2 ช้อนโต๊ะ',
#   'ซอสมะเขือเทศ???? ? ? ? ? ? ? ? ? ? ?? 1-4 ถ้วย',
#   'ซอสปรุงรส?????????????????????????????????? 1 ช้อนโต๊ะ',
#   'มัสตาร์ด????? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ?? 1 ช้อนชา',
#   'พริกไทยป่น????????????????????????????????? 1 ช้อนชา',
#   'เกลือป่น??????????????????????????????????? 1-2 ช้อนชา',
#   'น้ำตาลทราย???????????????????????????????? 1 ช้อนโต๊ะ',
#   'เนยสดชนิดเค็ม???????????????????????????? 1 ช้อนโต๊ะ',
#   'น้ำเปล่า??????????????????????????????????? 1-2 ช้อนโต๊ะ',
#   'ผักชีสำหรับตกแต่ง',
#   'ใส่เนื้อหมูที่เตรียมไว้ลงผัดให้เข้ากัน ปิดฝาแล้วตั้งไฟอ่อน อบไว้นานประมาณ 20 นาที หรือจนหมูสุกนุ่ม ตักใส่จาน ตกแต่งด้วยฟักชี เสิร์ฟได้ทันที'],
#  'หอยแมลงภู่ผัดพริกเผา_https://food.mthai.com/food-recipe/86476.html': ['หอยแมลงภู่นิวซีแลนด์? (แกะผ่าด้านที่ไม่ติดกับเนื้อหอยออก)???????? 300? กรัม',
#   'กระเทียมสับหยาบ??????????????????????????????????????????????????????????????????????? 1? ช้อนโต๊ะ',
#   'พริกขี้หนูสับหยาบ??????????????????????????????????????????????????????????????????????? 1? ช้อนโต๊ะ',
#   'พริกหยวกหั่นแฉลบ?????????????????????????????????????????????????????????????????? 1-4? ถ้วย',
#   'หอมหัวใหญ่หั่นตามยาว???????????????????????????????????????????????????????????? 1-4? ถ้วย',
#   'แครอตหั่นท่อน???????????????????????????????????????????????????????????????????????? 1-4? ถ้วย',
#   'ต้นหอมซอย???????????????????????????????????????????????????????????????????????????????? 1? ต้น',
#   'น้ำพริกเผา?????????????????????????????????????????????????????????????????????????????????? 3? ช้อนโต๊ะ',
#   'น้ำปลา??????????????????????????????????????????????????????????????????????????????????????? 1? ช้อนโต๊ะ',
#   'น้ำมันหอย??????????????????????????????????????????????????????????????????????????????????? 2? ช้อนโต๊ะ',
#   'น้ำตาลทราย???????????????????????????????????????????????????????????????????????????????? 1? ช้อนโต๊ะ',
#   'น้ำตาลพืช??????????????????????????????????????????????????????????????????????????????????? 2? ช้อนโต๊ะ'],
#  ' “?หอยแมลงภู่อบชีส?”_https://food.mthai.com/food-recipe/81898.html': ['? หอยแมลงภู่นิวซีแลนด์??????????????????? 10???? ตัว',
#   '? เนยสดชนิดเค็ม ? ? ? ? ? ? ? ? ? ? ? ? ?? ? 3????? ช้อนโต๊ะ',
#   '? พาร์สลียืสับละเอียด ? ? ? ? ? ? ? ? ? ?? ? 1????? ช้อนโต๊ะ',
#   '? กระเทียมสับละเอียด??????????????????????? 2???? ช้อนโต๊ะ',
#   '? เกลือป่น??????????????????????????????????????? 1/4?? ช้อนชา',
#   '? พริกไทยป่น?????????????????????????????????? 1/2?? ช้อนชา',
#   '? มอซซาเรลลาชีสขูด?????????????????????? 1/2?? ช้อนชา',
#   '? ผักสลัดใบเล็กสำหรับตกแต่งตามชอบ',
#   'ยกออกจากเตา? จัดใส่จาน? ตกแต่งด้วยผักสลัดใบเล็ก? เสิร์ฟได้ทันที'],
#  'ผัดคะน้าหมูกรอบ_https://food.mthai.com/food-recipe/84381.html': ['หมูกรอบหั่นชิ้นพอคำ 1-2 ถ้วย',
#   'ก้านคะน้า หั่นท่อนยาว 2 นิ้ว 1 ถ้วย',
#   'ใบคะน้าหั่นชิ้นใหญ่ 2 ถ้วย',
#   'กระเทียมบุบหยาบ 1 ช้อนโต๊ะ',
#   'พริกขี้หนูแดงบุบหั่นแฉลบ 5-6 เม็ด',
#   'น้ำมันหอย 2 ช้อนโต๊ะ',
#   'เต้าเจียวดำ 1 ช้อนโต๊ะ',
#   'น้ำปลา 1 ช้อนชา',
#   'น้ำตาลทราย 1 – 2 ช้อนชา',
#   'พริกไทยป่น 1 – 4 ช้อนชา',
#   'น้ำเปล่า 2 – 3 ช้อนโต๊ะ',
#   'น้ำมันพืช 3 ช้อนโต๊ะ',
#   'ตักใส่จาน เสิร์ฟได้ทันที',
#   'หากต้องการผัดคะน้าให้สุกพร้อมกันในครั้งเดียว ให้นำก้านคะน้าไปลวกให้สุกเสียก่อน และแช่น้ำเย็นจัดให้หายร้อนทันทีเพียงเท่านี้ก็ช้วยให้ก้านและใบคะน้าสุกพร้อมกันแล้ว',
#   'การผัดคะน้าต้องผัดด้วยไฟแรงและเร็วไม่เช่นนั้นผักจะสลดและไม่กรอบอร่อย'],
#  'หมูกรอบผัดพริกขิง_https://food.mthai.com/food-recipe/84545.html': ['หมูกรอบหั่นชิ้นพอคำ? 1 – 2 กิโลกรัม',
#   'ถั่วฝักยาวหั่นท่อน? 300 กรัม',
#   'พริกแกงเผ็ด?? 250 กรัม',
#   'น้ำตาลปี๊บ? 3? ช้อนโต๊ะ',
#   'น้ำปลา? 1 – 4 ถ้วย',
#   'ใบมะกรูดฉีก?? 3? ช้อนโต๊ะ',
#   'น้ำมันพืช? 3? ช้อนโต๊ะ',
#   'น้ำเปล่า (ไม่ใส่ก็ได้)? 2 – 3 ช้อนโต๊ะ',
#   'ใส่ใบมะกรูด? ผัดเข้ากัน? ยกลงจากเตา ตักเสิร์ฟได้ทันที',
#   'หมูสามชั้น? 1? กิโลกรัม',
#   'พริกไทยเม็ด? 15? เม็ด',
#   'กระเทียมกลีบเล็ก? 10 กลีบ',
#   'รากผักชี? 2? ราก',
#   'น้ำส้มสายชู? 1 – 4 ถ้วย',
#   'แกลือแกง? 2? ช้อนชา',
#   'น้ำเปล่าสำหรับต้ม? 8? ถ้วย',
#   'น้ำมันพืชสำหรับทอด'],
#  'แกงส้มชะอมไข่ใส่กุ้ง_https://food.mthai.com/food-recipe/84403.html': ['กุ้งสดแกะเปลือกไว้หางผ่าหลังชักเส้นดำออก? 7? ตัว',
#   'ไข่ไก่??????????????????????????? 1? ฟอง',
#   'ชะอมเด็ดใบ?????????????????? 1? ถ้วย',
#   'พริกแกงส้ม???????????? 1? 1-2? ช้อนโต๊ะ',
#   'น้ำเปล่า????????????????? 1? 1-2? ถ้วย',
#   'น้ำมะขามเปียก? ? ? ? ? ? ? ? 3? ช้อนโต๊ะ',
#   'น้ำตาลปี๊บ????????????????????? 1? ช้อนโต๊ะ',
#   'น้ำปลา???????????????? 1??? 1-2? ช้อนโต๊ะ',
#   'น้ำมันสำหรับทอดชะอมเล็กน้อย',
#   'พริกแห้งเม็ดใหญ่แช่น้ำเอาเมล็ดออกหั่นท่อนสั้น???????? 10? เม็ด',
#   'หอมเล็กหั่นหยาบ???????????????????????????????????????? ? ???? 1 – 4? ถ้วย',
#   'กะปิอย่างดี???????????????????????????????????????????????????????? 1 – 2? ช้อนโต๊ะ',
#   'ตอกไข่ใส่ชาม? ตีให้เข้ากัน? ใส่ชะอมคนให้เข้ากันดี? นำไปทอดในน้ำมันร้อนด้วยไฟกลางจนเหลืองหอม? ตักขึ้นพักไว้ให้สะเด็ดน้ำมัน? แล้วหั่นเป็นชิ้นใสชามเตรียมไว้',
#   'เทน้ำใส่หม้อ? แล้วนำไปต้มให้เดือดใส่เครื่องแกงลงไปปรุงรสด้วยน้ำมะขามน้ำตาลปี๊บ? และน้ำปลา?? ชิมรสตามชอบเมื่อน้ำเดือดจัดให้ใส่กุ้งลงต้มพอสุกแล้วปิดเตา',
#   'ตักแกงส้มใส่ชามไข่ชะอมทอดที่เตรียมไว้? เสิร์ฟขณะร้อนๆ'],
#  'ข้าวปั้นปลาทูพะโล้_https://food.mthai.com/food-recipe/82509.html': ['ปลาทูสดแล่ชิ้นฟิลเลต์?????????????????????????????????? 3? ตัว',
#   'รากผักชีหั่นหยาบ?????????????????????????????????????????? 2? ช้อนโต๊ะ',
#   'กระเทียมหั่นหยาบ????????????????????????????????????????? 2 ช้อนโต๊ะ',
#   'พริกไทยเม็ด????????????????????????????????????????????? 1/2? ช้อนโต๊ะ',
#   'อบเชยแท่ง ????????????????????????????????????????????????? 1? แท่ง',
#   'โป๊ยกั้ก ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ?? 5 ดอก',
#   'น้ำเปล่า??????????????????????????????????????????????????????? 4? ถ้วย',
#   'ต้ำตาลปี๊บ????????????????????????????????????????????????? 1/2? ช้อนโต๊ะ',
#   'ซอสปรุงรส???????????????????????????????????????????????? 1/2? ช้อนโต๊ะ',
#   'เกลือป่น???????????????????????????????????????????????????? 1/2? ช้อนโต๊ะ',
#   'ข้าวญี่ปุ่นหุงสุก???????????????????????????????????????? 1 1/2? ถ้วย',
#   'สาหร่ายสำหรับพันข้าวปั้น',
#   'โชยุและวาซาบิตามชอบ'],
#  'ทอดมันกุ้ง_https://food.mthai.com/food-recipe/84704.html': ['เนื้อกุ้งสับหยาบ 250 กรัม',
#   'เนื้อกุ้งบดละเอียด 250 กรัม',
#   'เนื้อหมูสับ 200 กรัม',
#   'ซีอิ๋วขาว 2 ช้อนโต๊ะ',
#   'น้ำตาลทราย 1 – 2 ช้อนชา',
#   'แป้งข้าวโพด 2 ช้อนโต๊ะ',
#   'เกลือป่น 1- 2 ช้อนชา',
#   'น้ำมันงา 1 ช้อนชา',
#   'พริกไทยป่น 1 ช้อนชา',
#   'ไข่ไก่ตีให้เข้ากัน 2 ฟอง',
#   'เกล็ดขนมปังป่น 2 ถ้วย',
#   'นำมันพืชสำหรับทอด',
#   'ผักสลัดและน้ำจิ้มบ๊วยตามชอบสำหรับเสิร์ฟคู่กัน',
#   'ปรุงรสด้วยน้ำตาล ซีอิ๊วขาว น้ำมันงา เกลือ และพริกไทยใส่แป้งข้าวโพดลงนวดให้เข้ากัน นำไปแช่เย็นนานประมาณ 20 นาที',
#   'ปั้มส่วนผสมที่เตรียมไว้เป็นก้อนกลมขนาดเส้นผ่านศูนย์กลางประมาณ 1.5 นิ้ว กดให้แบน จากนั้นชุบไข่ให้ทั่ว ตามด้วยเกล็ดขนมปัง (ทำเช่นนี้จนหมด)',
#   'ทอดส่วนผสมที่เตรียมไว้ในน้ำมันร้อน (ใช้ไฟกลาง) จนสุกเหลืองตักขึ้นพักให้สะเด็ดน้ำมัน จัดใส่จาน เสิร์ฟคู่กับน้ำจิ้มบ๊วยและผักสลัด'],
#  'หอยลายผัดน้ำพริกเผา_https://food.mthai.com/food-recipe/84590.html': ['หอยลาย????????????????????????? 2 กิโลกรัม',
#   'กระเทียมสับละเอียด???? 1 – 2 ถ้วย',
#   'พริกขี้หนูบุบ???????????????????? 2 ช้อนโต๊ะ',
#   'พริกชี้ฟ้าแดงหั่นแฉลบ 1 – 2? ถ้วย',
#   'ใบโหระพา?????????????????????? 2? ถ้วย',
#   'น้ำพริกเผา ? ? ? ? ? ? ??? 1 – 2? ถ้วย',
#   'น้ำมันหอย????????????????? 1 – 4? ถ้วย',
#   'น้ำปลา??????????????????????????? 3 ช้อนโต๊ะ',
#   'น้ำตาลทราย??????????????????? 1? ช้อนโต๊ะ',
#   'น้ำมันพืช??????????????????? 1 – 3? ถ้วย'],
#  'พิซซ่าหน้าปลาทู_https://food.mthai.com/food-recipe/82562.html': ['ปลาทูสดแร่เนื้อ??????????????????????????????????????????????????????????????? 3? ตัว',
#   'ผิวเลมอนขูด???????????????????????????????????????????????????????????????? 1/2? ช้อนชา',
#   'ไธม์สด??????????????????????????????????????????????????????????????????????????? 1? ช่อ',
#   'ไวน์ขาว?????????????????????????????????????????????????????????????????????????? 1? ช้อนโต๊ะ',
#   'เกลือป่น?????????????????????????????????????????????????????????????????????? 1/4? ช้อนชา',
#   'พริกไทยป่น????????????????????????????????????????????????????????????????? 1/4? ช้อนชา',
#   'น้ำมันมะกอก????????????????????????????????????????????????????????????? 1 1/2? ช้อนโต๊ะ',
#   'แป้งพิซซ่าสำเร็จรูป? เส้นผ่าศูนย์กลางประมาณ 10 นิ้ว?????????? 1? แผ่น',
#   'มอซซาเรลลาชีสขูด????????????????????????????????????????????????????????? 1? ถ้วย',
#   'พาร์มีซานชีส ขูดละเอียด?????????????????????????????????????????????????? 3? ช้อนโต๊ะ',
#   'ใบโหระพาสำหรับตกแต่ง',
#   'พริกหวานสามสีหั่นสี่เหลี่ยมเล็ก???????????????? 1/4? ถ้วย',
#   'หอมหัวใหญ่หั่นสี่เหลี่ยนมเล็ก?????????????????????? 2? ช้อนโต๊ะ',
#   'มะเขือเทศหั่นสีเหลี่ยมเล็ก???????????????????????? 1/4 ถ้วย',
#   'น้ำส้มสายชู ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ?? 2? ช้อนโต๊ะ',
#   'เกลือป่น????????????????????????????????????????????????? 1/2? ช้อนชา',
#   'น้ำตาลทราย?????????????????????????????????????????????? 1? ช้อนโต๊ะ',
#   'น้ำมันมะกอก??????????????????????????????????????? 1? 1/2? ช้อนโต๊ะ',
#   'นำเข้าอบประมาณ 10 นาที หรือจนกระทั่งปลาสุก? ยกออกจากเตา ตกแต่งด้วยใบโหระพาเสิร์ฟขณะร้อนๆ'],
#  'Conchiglie Regata_https://food.mthai.com/food-recipe/82450.html': ['เส้น Conchiglie Regata ต้มสุก ???????? 100? กรัม',
#   'ผักคอส?????????????????????????????????????????????? 10? ใบ',
#   'เบคอนทอดกรอบ??????????????????????????????????? 2? ช้อนโต๊ะ',
#   'กรูตอง??????????????????????????????????????????????? 1/4? ถ้วย',
#   'พาร์มีซานชีสขูดเป็นแผ่น????????????????? 15-20? กรัม',
#   'ไข่แดง???????????????????????????????????????????????????? 1 ฟอง',
#   'น้ำมันมะกอก????????????????????????????????????????? 1/2? ถ้วย',
#   'มัสตาร์ด??????????????????????????????????????????????????? 1 ช้อนชา',
#   'แอนโชวีสับหยาบ?????????????????????????????????????? 1? ช้อนโต๊ะ',
#   'กระเทียมสับละเอียด?????????????????????????????????? 1? ช้อนโต๊ะ',
#   'น้ำเลมอน????????????????????????????????????????????????? 2? ช้อนโต๊ะ',
#   'พาร์มีซานชีสขูดละเอียด???????????????????????????? 2? ช้อนโต๊ะ',
#   'เกลือป่น??????????????????????????????????????????????? 1/4?? ช้อนชา',
#   'พริกไทยป่น??????????????????????????????????????????? 1/4? ช้อนชา',
#   'นำพาสต้าที่ต้มไว้? ผักคอส? เบคอน? และกรูตองลงคลุกกับน้ำสลัดให้เข้ากัน',
#   'ตักใส่จาน? โรยพาร์มีซานชีส? จัดเสิร์ฟ'],
#  'สเต็กทีโบนโคขุนพริกไทยดำ_https://food.mthai.com/food-recipe/83436.html': ['เนื้อทีโบนโคขุนชาโรเลส์ (น้ำหนักประมาณ 350 – 380 กรัม)? 1 ชิ้น',
#   'ไวน์แดง?????????????????????????????????????????????????????????????????????????? 1 ช้อนชา',
#   'บรั่นดี???????????????????????????????????????????????????????????????????????? 1 – 2 ช้อนชา',
#   'ผงอโรมาต??????????????????????????????????????????????????????????????????? 1/4 ช้อนชา',
#   'ผงมัสตาร์ด?????????????????????????????????????????????????????????????????? 1/2? ช้อนช้า',
#   'พริกไทยป่น????????????????????????????????????????????????????????????????? 1/2? ช้อนชา',
#   'เนยสดชนิดจืด?????????????????????????????????????????????????????????? 1 – 2? ช้อนชา',
#   'น้ำมันมะกอกสำหรับย่างเนื้อ????????????????????????????????????????? 1 – 2 ช้อนโต๊ะ',
#   'ผักเคียงต่างๆ เช่น ดอกกะหล่ำหั่นช่อ แครอทหั่นขวาง? ก้านบรอกโครีหั่นแท่งและถั่วลันเตาหวาน? ลวกสุกตามชอบ',
#   'เฟรนช์ฟรายทอดกรอบตามชอบ',
#   'พาร์สลีย์อบแห้งสำหรับตกแต่ง',
#   'หอมหัวใหญ่หั่นละเอียด?????????????????????? 1? 1/2? ช้อนชา',
#   'ไวน์แดง??????????????????????????????????????????????????? 2 ช้อนโต๊ะ',
#   'บราวน์ซอส????????????????????????????????????????? 2 – 3 ช้อนโต๊ะ',
#   'วิปปิ้งครีม????????????????????????????????????????????????? 1 ช้อนช้า',
#   'นมข้นจืด????????????????????????????????????????????????? 1 ช้อนชา',
#   'ซอสทาบาสโก???????????????????????????????????? 2 – 3 หยด',
#   'ซอสพริกศรีราชา?????????????????????????????????????? 1? ช้อนชา',
#   'ซอสเปรี้ยวลีแอนด์เพอร์รินส์?????????????????? 2 -3 หยด',
#   'ซอสเปรี้ยวไก่งวง ??????????????????????????????? 2 – 3 หยด',
#   'ผงอโรมาต?????????????????????????????????????????????? 1 ช้อนชา',
#   'พริกไทยดำบดหยาบ???????????????????????????????? 2 ช้อนชา',
#   'พริกไทยป่น????????????????????????????????????????? 1/2 ช้อนชา',
#   'เนยสดชนิดจืด?????????????????????????????????? 1 – 2 ช้อนชา'],
#  'ลาซานญ่าทูน่าซอสขาว_https://food.mthai.com/food-recipe/82153.html': ['แผ่นลาซานญ่าต้มสุก?????????????????? 4? แผ่น',
#   'ปลาทูน่าในน้ำเกลือ???????????????????? 1? ประป๋อง',
#   'ผักโขมต้นสุก?????????????????????????? 100 กรัม',
#   'พาร์มีซานชีสขูด?????????????????????? 1/4? ถ้วย',
#   'มอซซาเรลลาชีสขูด???????????????????? 1? ถ้วย',
#   'เนยสดชนิดจืด???????????????????????????? 2? ช้อนโต๊ะ',
#   'แป้งสาลีอเนกประสงค์?????????????????? 2? ช้อนโต๊ะ',
#   'นมสดรสจืด??????????????????????????? 3-4/1 ถ้วย',
#   'เบย์ลีฟ???????????????????????????????????????? 2 ใบ',
#   'เกลือป่น??????????????????????????????????? 1-2 ช้อนชา',
#   'พริกไทยป่น?????????????????????????????? 1-4 ช้อนชา'],
#  '” แกงจืดฟองเต้าหู้ดอกไม้จีนเจ “_https://food.mthai.com/food-recipe/63405.html': ['ฟองเต้าหู้ 2 แผ่น',
#   'เห็ดนางฟ้า 4 ดอก',
#   'เห็ดหูหนู 1/4 ถ้วย',
#   'ดอกใม้จีน 1/4 ถ้วย',
#   'ขึ้นฉ่าย 1 ต้น',
#   'แครอท 1 หัว',
#   'วุ้นเส้น\xa0 1/2\xa0 ถ้วย',
#   'ซีอิ๊วขาว 2 ช้อนโต๊ะ',
#   'น้ำ 1 1/2 ถ้วย'],
#  'ก๋วยเตี๋ยวหลอดทรงเครื่อง เมนูง่ายๆ ของมื้อกลางวัน_https://food.mthai.com/food-recipe/30837.html': [' หมูสามชั้น 2 ขีด',
#   'เต้าหู้แข็ง 1 แผ่น',
#   'ปลาหมึกแห้งตัวเล็ก 1 ตัว',
#   'กุ้งแห้งขนาดกลาง 1/2 ขีด',
#   'น้ำตาล 2 ช้อนโต๊ะ',
#   'ซอสซีอิ๊วดำ 1 ช้อนโต๊ะ',
#   'เสี้นก๋วยเตี๋ยวหลอด (เส้นใหญ่) 1/2 กก.',
#   'ถั่วงอก 3 ขีด',
#   'ผักคะน้า 2 ต้น',
#   'ผักชี',
#   'ต้นหอม',
#   'พริกขี้หนูแดง',
#   'น้ำส้ม',
#   'กระเทียมเจียว'],
#  'ทำทานเองง่ายๆ กับเมนู “ข้าวห่อไข่ สู้น้ำท่วม”_https://food.mthai.com/food-recipe/14479.html': ['ข้าวสวย 1-2 ทัพพี',
#   'ไข่ไก่ 2 ฟอง',
#   'หอมใหญ่ หั่นเป็นลูกเต๋า 1 ช้อนโต๊ะ',
#   'กระเทียบ ทุบ 2 กลีบ',
#   'แครอทหรือผักที่มี หั่นเป็นลูกเต๋า 2 ช้อนโต๊ะ',
#   'กุ้ง หรือเนื้อหมู,ไก่ สักเล็กน้อย',
#   'น้ำมันหอย 1 ช้อนชา',
#   'ซอสแม๊กกี้ เล็กน้อย',
#   'พริกไทย',
#   'น้ำมันพืช 2 ช้อนโต๊']}

# %% [markdown]
# # Store crawling data to S3 for further utilization

# %%
store_data_on_s3(prefix="Mthai-recipe", source=BASE_URL, ext_data=ingredients, raw_data=raw_pages)
# Out:
# Storing the data is completed
