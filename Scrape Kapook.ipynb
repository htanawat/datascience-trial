# %% [markdown]
# # Import necessary libs

# %%
from datetime import datetime, timedelta
from bs4 import BeautifulSoup as bs
from dotenv import load_dotenv
import threading, queue
import pandas as pd
import numpy as np
import requests
import logging
import boto3
import json
import re
import os

# Get environment variable
load_dotenv('.env')
AWS_ACCESS_KEY_ID = os.getenv("AWS_ACCESS_KEY_ID")
AWS_SECRET_ACCESS_KEY = os.getenv("AWS_SECRET_ACCESS_KEY")

#initialize S3
S3 = boto3.resource('s3',
    aws_access_key_id=AWS_ACCESS_KEY_ID,
    aws_secret_access_key=AWS_SECRET_ACCESS_KEY
)

#initialize dynamodb
dynamodb = boto3.resource('dynamodb', region_name='ap-southeast-2',
  aws_access_key_id=AWS_ACCESS_KEY_ID,
  aws_secret_access_key=AWS_SECRET_ACCESS_KEY
)

table_scrape_hist = dynamodb.Table('ScrapingHistory')

last_refresh = datetime.now()

# %% [markdown]
# # Necessary functions

# %%
# Function for filter the urls
def include_url_lambda(x):
    url = x.get("href")
    if url == None:
        return False
    
    if not "view" in url:
        return False
    
    url = f"https://cooking.kapook.com/view{url.split('view')[1]}"
    
#     if url[:2] == "//":
#         url = "https://" + url[2:]
        
#     if "http://https://" in url:
#         url = url.replace("http://", "")
        
#     if "%3E//" in url:
#         url = url.replace("%3E//", "https://")
        
    if url in visited_links:
        return False
    visited_links.add(url)
    if not include_url.search(url):
        return False
    to_visits.put(url)
    return True

# Function for scraping data from urls
def scrape_fn(url):
    while True:
        try:
            resp = requests.get(url)
            html = bs(resp.text)
            _ = [x for x in filter(include_url_lambda, html.findAll("a"))]
            raw_pages[url] = resp.text
            raw_articles[url] = html.findAll("div", {"id": "container"})
            if len(raw_articles[url]) == 0:
                del raw_articles[url]
            else:
                raw_articles[url] = raw_articles[url][0]
            break
        except Exception as e:
            print(f"Error: {e} -- Trying to reconnect to url {url}.")
            
# Wrapper function for validate outdated of s3 credential and auto replacing
def validate_update(fn):
    def return_fn(*ar, **kw):
        global S3, last_refresh, refresh_time
        _now = datetime.now()
        if (last_refresh + refresh_time) <= _now:
            S3 = boto3.resource('s3', 
                aws_access_key_id=AWS_ACCESS_KEY_ID,
                aws_secret_access_key=AWS_SECRET_ACCESS_KEY
            )
            last_refresh = _now

        return fn(*ar, **kw)
    return return_fn

# Store the data to the S3 instance
@validate_update
def store_data_on_s3(prefix, source, ext_data, raw_data):
    try:
        now = datetime.now()
        filename = f"{prefix}-{now.strftime('%Y-%m-%d_%H:%M:%S')}.json"

        # Simple extracted recipes
        ext_s3 = S3.Object("eltrial", f"SCRAPING/SIMPLE_EXTRACTED/{filename}")

        # Save raw pages for debugging and correction
#         raw_s3 = S3.Object("eltrial", f"SCRAPING/RAW/{filename}")

        ext_json = json.dumps(ext_data)
#         raw_json = json.dumps(raw_data)

        ext_s3.put(Body=ext_json, ACL='public-read')
#         raw_s3.put(Body=raw_json, ACL='public-read')
        
        table_scrape_hist.put_item(
            Item={
                "source": source,
                "timestamp": now.strftime("%Y-%m-%d %H:%M:%S"),
            }
        )
        
        print("Storing the data is completed")
    except Exception as e:
        print(f"Error: {e}")

# %% [markdown]
# # Settings

# %%
MAX_THREAD = 200
include_url = re.compile("cooking.kapook.com/view")
# include_url = re.compile("\/food-recipe|\/food-recommend|\/easy-menu")
BASE_URL = "https://cooking.kapook.com/"
refresh_time = timedelta(hours=1)

# %% [markdown]
# # Crawl data from sources

# %%
# Main Thread

if __name__ == "__main__":
    
    visited_links = set()
    to_visits = queue.Queue()
    raw_pages = {}
    raw_articles = {}
    
    start_url = f"{BASE_URL}/menu"

    resp = requests.get(start_url)
    page_text = resp.text

    html = bs(page_text)
    _ = [x for x in filter(include_url_lambda, html.findAll("a"))]

    while True:
        threads = []

        if to_visits.empty():
            break

        qsize = to_visits.qsize()
        num_threads = min(MAX_THREAD, qsize)
        print(f"Generating {num_threads} threads ...")
        for _t in range(num_threads):
            _url = to_visits.get()
            _thread = threading.Thread(target=scrape_fn, args=(_url,))
            _thread.start()
            threads.append(_thread)

        for _t in threads:
            _t.join()
        print(f"finish run {num_threads} threads. {to_visits.qsize()} remaining urls")

        del threads
    print("finished.")
# Out:
# Generating 79 threads ...
# finish run 79 threads. 363 remaining urls
# Generating 200 threads ...
# finish run 200 threads. 429 remaining urls
# Generating 200 threads ...
# finish run 200 threads. 361 remaining urls
# Generating 200 threads ...
# finish run 200 threads. 353 remaining urls
# Generating 200 threads ...
# finish run 200 threads. 293 remaining urls
# Generating 200 threads ...
# finish run 200 threads. 227 remaining urls
# Generating 200 threads ...
# finish run 200 threads. 110 remaining urls
# Generating 110 threads ...
# finish run 110 threads. 24 remaining urls
# Generating 24 threads ...
# finish run 24 threads. 14 remaining urls
# Generating 14 threads ...
# finish run 14 threads. 7 remaining urls
# Generating 7 threads ...
# finish run 7 threads. 1 remaining urls
# Generating 1 threads ...
# finish run 1 threads. 9 remaining urls
# Generating 9 threads ...
# finish run 9 threads. 5 remaining urls
# Generating 5 threads ...
# finish run 5 threads. 2 remaining urls
# Generating 2 threads ...
# finish run 2 threads. 1 remaining urls
# Generating 1 threads ...
# finish run 1 threads. 0 remaining urls
# finished.

# %%
# Print number of pages
len(raw_pages), len(raw_articles)
# Out:
# (1452, 1412)

# %% [markdown]
# # Simple Extract Recipe From Pages

# %%
ingredients = {}
EXCLUDE_WORDS = set(["หมายถึง", "อาหารเจ", "เคล็ดลับความอร่อย"])
ingredient_word = re.compile("ส่วนผสม|วัตถุดิบ|เครื่องปรุง|ส่วนประกอบ|วัตุดิบ|อัตราส่วน")
how_to_word = re.compile("ขั้นตอนการทำ|วิธีทำ|วิธีการทำ")

process = 0
_include = 0
_not_include = []

for url, page in raw_articles.items():
    strong = page.findAll(["strong", "p", "h1", "h2", "h3", "li", "a"])
    
    header_exists = False
    title = ""
    for s in strong:
        text = s.text
        is_ingredient = ingredient_word.search(text)
        is_how_to = how_to_word.search(text)

        if (s.name in ["strong", "h3", "h1"]) and not (is_ingredient or is_how_to) and text not in EXCLUDE_WORDS:
            title = f"{text}_{url}"
        else:
            if not header_exists:
                if is_ingredient:
                    header_exists = True
            else:
                if is_how_to:
                    header_exists = False
                else:
                    if s.name == "li":
                        if title not in ingredients:
                            ingredients[title] = [text]
                        else:
                            ingredients[title].append(text)
         
    process += 1
    print("\r", end=f"{process}")
# Out:
# 1412

# %%
len(ingredients)
# Out:
# 336

# %%
ingredients
# Out:
# {'ไมโครเวฟพร้อมจ้า ! ชวนทำไดฟูกุสตรอว์เบอร์รี เมนูไมโครเวฟ แป้งสีสวยเหนียวนุ่ม สอดไส้ถั่วแดงกวนกับผลไม้สด ปั้นลูกโตน่าหม่ำ จับแช่เย็นยิ่งฟิน_https://cooking.kapook.com/view206822.html': ['แป้งข้าวเหนียว 1+1/2 ถ้วย',
#   'แป้งข้าวโพด 1 ช้อนโต๊ะ',
#   'น้ำตาลทรายทรายป่นละเอียด 5 ช้อนโต๊ะ',
#   'น้ำสะอาด 250 กรัม',
#   'สีผสมอาหารสีแดง (ใส่หรือไม่ใส่ก็ได้) \xa0',
#   'แป้งมันสำปะหลัง สำหรับทำแป้งนวล 100 กรัม (นำไปผัดด้วยไฟกลางค่อนข้างอ่อน 5 นาที)\n\t\xa0',
#   'สตรอว์เบอร์รี\n\t\xa0',
#   'เนยสดเค็ม 1/2 ช้อนโต๊ะ',
#   'ถั่วแดงกระป๋อง 200 กรัม',
#   'น้ำตาลทรายแดง 160 กรัม\n\t\xa0'],
#  ' ขนมหวานวันหยุด เมนูคัพเค้กไมโครเวฟ เมนูไมโครเวฟ อร่อยนุ่มนานแต่งหน้าตามชอบ ทำง่ายไม่ต้องใช้เตาอบเหมาะกับเด็กหอ\xa0\xa0_https://cooking.kapook.com/view202667.html': ['เนยสด 120 กรัม',
#   'น้ำตาลทราย 120 กรัม',
#   'กลิ่นวานิลลา 1/2 ช้อนชา',
#   'ไข่ 2 ฟอง',
#   'แป้งสาลีอเนกประสงค์ 120 กรัม',
#   'ครีมและเกล็ดน้ำตาลตกแต่งตามชอบ\n\t\xa0'],
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 สะบัดบ๊อบให้เมนูช็อกโกแลตบอลสุดเชย แล้วมาลองทำช็อกโกแลตบอลหนึบที่ฮิตกันทั่วบ้านทั่วเมืองกัน สูตรทำง่ายด้วยไมโครเวฟ เหมาะเป็นของฝากในเทศกาลปีใหม่นี้มาก\xa0 _https://cooking.kapook.com/view218549.html': ['นมข้นหวาน 200 กรัม',
#   'ผงโกโก้ 100 กรัม'],
#  'ข้าวน้ำพริกลงเรือ จานเดียวทำง่ายอร่อยได้ทุกมื้อ_https://cooking.kapook.com/view227987.html': ['กระเทียม 1 ช้อนโต๊ะ',
#   'กะปิเผา 1 ช้อนโต๊ะ',
#   'น้ำตาลปี๊บ 2 ช้อนโต๊ะ',
#   'เนื้อมะดันซอยบาง 2 ลูก (ถ้าไม่มีไม่ต้องใส่ก็ได้)',
#   'เนื้อมะอึกหั่นบาง 2 ลูก (ถ้าไม่มีไม่ต้องใส่ก็ได้)',
#   'พริกขี้หนูสวน 10-20 เม็ด',
#   'น้ำมะนาว 2 ช้อนโต๊ะ',
#   'น้ำมันพืชสำหรับผัด',
#   'ข้าวสวย\n\t\xa0',
#   'หอมแดงสับละเอียด 2 หัว',
#   'น้ำตาลปี๊บ 2 ช้อนโต๊ะ',
#   'น้ำปลา 3 ช้อนโต๊ะ',
#   'เนื้อหมูสามชั้นหั่นชิ้นเล็ก 200 กรัม',
#   'น้ำมันพืชสำหรับผัด\n\t\xa0',
#   'ปลาดุกย่าง 1 ตัว',
#   'น้ำมันพืชสำหรับทอด\n\t\xa0'],
#  '1. ไข่ตุ๋นหมูสับไมโครเวฟ_https://cooking.kapook.com/view204076.html': ['ไข่ไก่',
#   'หมูสับ',
#   'ซีอิ๊วขาว',
#   'เกลือ',
#   'พริกไทย',
#   'น้ำเปล่า',
#   'ต้นหอมซอย\n\t\xa0'],
#  '2. มันอบไมโครเวฟ_https://cooking.kapook.com/view204076.html': ['มันฝรั่ง',
#   'ส้อม\n\t\xa0'],
#  '3. มะกะโรนีอบชีสไมโครเวฟ_https://cooking.kapook.com/view204076.html': ['มะกะโรนี',
#   'ชีส',
#   'นม',
#   'พริกไทยดำ',
#   'น้ำเปล่า',
#   'เกลือ\n\t\xa0'],
#  '4. สุกี้แห้งโรลไมโครเวฟ_https://cooking.kapook.com/view204076.html': ['ผักกาดขาว',
#   'หมูสับ',
#   'เบกกิ้งโซดา',
#   'น้ำมันงา',
#   'พริกไทย',
#   'ซีอิ๊วขาว',
#   'ใบต้นหอม',
#   'น้ำจิ้มสุกี้\n\t\xa0'],
#  '5. กะหล่ำปลีผัดน้ำปลาไมโครเวฟ_https://cooking.kapook.com/view204076.html': ['กะหล่ำปลี',
#   'กระเทียม',
#   'น้ำมัน',
#   'ซีอิ๊วขาว',
#   'น้ำปลา',
#   'น้ำตาลทราย\n\t\xa0'],
#  '6. ข้าวผัดไมโครเวฟ_https://cooking.kapook.com/view204076.html': ['ข้าวสวย (เป็นข้าวแช่เย็นจะดีที่สุด)',
#   'ไข่',
#   'ผักสามสีแช่แข็ง',
#   'ไส้กรอก',
#   'น้ำมัน',
#   'ซีอิ๊วขาว',
#   'น้ำปลา',
#   'ซอสหอยนางรม',
#   'น้ำตาลทราย',
#   'พริกไทย',
#   'ต้นหอมซอย\n\t\xa0'],
#  '7. ติ่มซำหมูนึ่งไข่เค็มไมโครเวฟ_https://cooking.kapook.com/view204076.html': ['หมูสับ',
#   'ไข่เค็มดิบ',
#   'รากผักชี',
#   'กระเทียม',
#   'พริกไทย',
#   'ซีอิ๊วขาว',
#   'ซอสหอยนางรม',
#   'แป้งมัน',
#   'น้ำเปล่า\n\t\xa0'],
#  'เมนูที่ 1 สูตรทำอาหารเมนูจากไมโครเวฟ "ไข่เจียวแฮมหมู"_https://cooking.kapook.com/view206258.html': ['ไข่ไก่ 3-4 ฟอง',
#   'แฮมหมู',
#   'ซีอิ๊วขาว',
#   'พริกไทย'],
#  'เมนูที่ 2 สูตรทำอาหารเมนูจากไมโครเวฟ "หมูบดทรงเครื่อง"_https://cooking.kapook.com/view206258.html': ['เนื้อหมูบดละเอียด 1 กิโลกรัม',
#   'พริกไทย',
#   'ซีอิ๊วขาว',
#   'น้ำมันหอย',
#   'เมล็ดผักชีบด',
#   'น้ำตาลทราย',
#   'น้ำมันพืช',
#   'ผงปรุงรส\n\t\xa0'],
#  'เมนูที่ 3 สูตรทำอาหารเมนูจากไมโครเวฟ "ไก่อบหมักเหล้า"_https://cooking.kapook.com/view206258.html': ['น่องไก่ 1 กิโลกรัม',
#   'พริกไทยดำ',
#   'ซีอิ๊วขาว',
#   'เหล้าจีน',
#   'เมล็ดผักชีบด',
#   'น้ำตาลทราย',
#   'เกลือ',
#   'ผงปรุงรส\n\t\xa0'],
#  'เมนูที่ 4 สูตรทำอาหารเมนูจากไมโครเวฟ "หมูผัดกระเทียม"_https://cooking.kapook.com/view206258.html': ['เนื้อหมูสันใน',
#   'พริกไทย',
#   'ซอสถั่วเหลือง',
#   'น้ำปลา',
#   'น้ำมันหอย',
#   'เมล็ดผักชีบด',
#   'น้ำตาลทราย',
#   'ผงปรุงรส\n\t\xa0'],
#  'เมนูที่ 5 สูตรทำอาหารเมนูจากไมโครเวฟ "ต้มจืดสาหร่ายเต้าหู้ไข่"_https://cooking.kapook.com/view206258.html': ['สาหร่าย',
#   'ผักกาดขาว',
#   'เต้าหู้ไข่',
#   'ขึ้นฉ่าย',
#   'พริกไทย',
#   'ซีอิ๊วขาว',
#   'เมล็ดผักชีบด',
#   'ซอสหอยนางรม',
#   'ผงปรุงรส\n\t\xa0'],
#  'ข้อแนะนำ_https://cooking.kapook.com/view206258.html': ['ภาชนะสำหรับปรุงอาหารในไมโครเวฟ ต้องเป็นภาชนะทนความร้อนประเภทสามารถประกอบอาหารในไมโครเวฟได้เท่านั้น\n\t\xa0'],
#  'มื้อเที่ยงนี้จัดเลยกับเมนูข้าวผัดไข่ สูตรอาหารจานเดียว ผัดด้วยไฟแรงหน่อยกลิ่นหอมรัญจวนมาก ราดพริกน้ำปลาหน่อยอร่อยเหาะ_https://cooking.kapook.com/view227497.html': ['กระเทียมสับ',
#   'น้ำมันพืช',
#   'ไข่เป็ด 2 ฟอง',
#   'ข้าวสวยหุงสุก',
#   'ซอสปรุงรส',
#   'ซีอิ๊วขาว',
#   'น้ำตาลทราย',
#   'ต้นหอมซอย',
#   'พริกไทย',
#   'ต้นหอม',
#   'มะนาว'],
#  '1. ข้าวน้ำพริกลงเรือ_https://cooking.kapook.com/view227246.html': ['หอมแดงสับละเอียด 2 หัว',
#   'น้ำตาลปี๊บ 2 ช้อนโต๊ะ',
#   'น้ำปลา 3 ช้อนโต๊ะ',
#   'เนื้อหมูสามชั้นหั่นชิ้นเล็ก 200 กรัม',
#   'น้ำมันพืชสำหรับผัด',
#   'ปลาดุกย่าง 1 ตัว',
#   'น้ำมันพืชสำหรับทอด'],
#  '2. ข้าวน้ำพริกกะปิ_https://cooking.kapook.com/view227246.html': ['กะปิเผา 2 ช้อนโต๊ะ',
#   'กระเทียมไทย 10 กลีบ',
#   'กุ้งแห้งป่น 2 ช้อนโต๊ะ',
#   'พริกขี้หนูสวนตามชอบ',
#   'มะเขือพวงตามชอบ',
#   'น้ำตาลปี๊บ 2 ช้อนโต๊ะ',
#   'น้ำปลา 1 ช้อนโต๊ะ',
#   'น้ำมะนาว 3 ช้อนโต๊ะ',
#   'ข้าวสวย',
#   'กุ้งแห้งทอดกรอบ',
#   'มะม่วงซอย',
#   'ไข่เจียวซอย',
#   'กุนเชียงทอด',
#   'พริกขี้หนูสดหั่น',
#   'ถั่วฝักยาวซอย',
#   'มะนาวหั่นซีก',
#   'ข้าวสวย',
#   'หมูสามชั้นหั่นชิ้น',
#   'หอมแดงซอย',
#   'น้ำเปล่า',
#   'น้ำตาลปี๊บ',
#   'เกลือ',
#   'ซีอิ๊วดำ'],
#  '3. ข้าวน้ำพริกกะปิสามหอม_https://cooking.kapook.com/view227246.html': ['น้ำพริกกะปิ 2 ช้อนโต๊ะ',
#   'น้ำมันหมู 1 ช้อนโต๊ะ',
#   'กากหมูเจียว 1 ช้อนโต๊ะ',
#   'ไข่เป็ด 1 ฟอง',
#   'หมูสับลวก 1/4 ถ้วย',
#   'กุ้ง 4 ตัว',
#   'หมึกกล้วยหั่นแว่น 4-6 ชิ้น',
#   'วุ้นเส้นแช่น้ำ 1/2 ถ้วย',
#   'กระเทียมโทนดอง 10 เม็ด',
#   'น้ำกระเทียมดองเล็กน้อย',
#   'น้ำตาลปี๊บ',
#   'น้ำปลา',
#   'สะตอฝานเป็นชิ้นยาว',
#   'ชะอม',
#   'หอมแดงเจียว',
#   'เบคอนกรอบ'],
#  '4. ข้าวน้ำพริกกะปิซูชิ_https://cooking.kapook.com/view227246.html': ['ข้าวสวย 1+1/2 ถ้วยตวง',
#   'น้ำมันพืช 2 ช้อนโต๊ะ',
#   'ปลาทูทอดแกะเนื้อหั่นชิ้น 2 ตัว',
#   'น้ำพริกกะปิ 3 ช้อนโต๊ะ',
#   'ข้าวโพดอ่อนลวกหั่นครึ่ง 3 ฝัก',
#   'ถั่วฝักยาวหั่นเป็นท่อนลวก 6 ท่อน',
#   'แตงกวาหั่นแท่ง 6 แท่ง',
#   'ผัดกาดหางหงส์ลวก 6 ใบ',
#   'ต้นหอมลวกสำหรับมัด',
#   'กะปิห่อใบตองย่างไฟพอหอม 3 ช้อนโต๊ะ',
#   'กระเทียมไทย 5 กลีบ',
#   'พริกขี้หนูสวน 25 เม็ด',
#   'มะเขือพวง 2 ช้อนโต๊ะ',
#   'น้ำมะนาว 5 ช้อนโต๊ะ',
#   'น้ำตาลปี๊บ 3 ช้อนโต๊ะ',
#   'น้ำปลา 2 ช้อนโต๊ะ'],
#  '5. ข้าวน้ำพริกตาแดง_https://cooking.kapook.com/view227246.html': ['พริกแห้งเม็ดใหญ่ย่างไฟ 1 ถ้วย',
#   'กระเทียมย่างไฟ 20 กลีบ',
#   'หอมแดงย่างไฟ 5 หัว',
#   'กะปิย่างไฟ 1 ช้อนโต๊ะ',
#   'ปลาแห้ง 2\xa0 ถ้วย',
#   'มะขามเปียกแกะเม็ดออกสับละเอียด \xa0',
#   'น้ำตาลปี๊บ \xa0',
#   'น้ำปลา \xa0',
#   'น้ำมันพืช',
#   'ข้าวสวย'],
#  '6. ข้าวน้ำพริกปลาย่าง_https://cooking.kapook.com/view227246.html': ['ปลาช่อนย่างหรือปลากดย่างแกะเอาแต่เนื้อ 1 ถ้วย',
#   'พริกชี้ฟ้าแห้งคั่ว หรือพริกขี้หนูแห้งคั่ว 10 เม็ด',
#   'หอมแดงคั่ว 10 หัว',
#   'กระเทียมคั่ว 5 หัว',
#   'เกลือ 2 ช้อนโต๊ะ',
#   'มะขามเปียกสับละเอียด 2 ช้อนโต๊ะ',
#   'ข้าวสวย'],
#  '7. ข้าวน้ำพริกมะขาม_https://cooking.kapook.com/view227246.html': ['มะขามอ่อน',
#   'เกลือ สำหรับโขลกกับมะขาม',
#   'พริกขี้หนู',
#   'กระเทียม',
#   'หอมแดง',
#   'กะปิ',
#   'น้ำตาลปี๊บ',
#   'น้ำปลา',
#   'เกลือป่น',
#   'หมูสับ',
#   'น้ำมันพืช'],
#  '8. ข้าวน้ำพริกกุ้งเสียบ_https://cooking.kapook.com/view227246.html': ['ข้าวสวย 1 ถ้วย',
#   'กุ้งเสียบ 1+1/2 ช้อนโต๊ะ',
#   'ไข่เค็ม 1 ฟอง',
#   'กระเทียมกลีบกลางทุบพอแตก 7 กลีบ',
#   'หอมใหญ่หั่นตามยาว 1/4 หัว',
#   'พริกขี้หนูเม็ดใหญ่สีแดง (ซอยหนาประมาณ 1/2 เซนติเมตร) จำนวน 1-2 เม็ด',
#   'ต้นหอมซอย 1 ต้น',
#   'น้ำพริกเผา 1+1/2 ช้อนโต๊ะ',
#   'น้ำปลา (หรือซีอิ๊วขาว)',
#   'น้ำตาลทราย',
#   'น้ำมันพืช 2 ช้อนโต๊ะ',
#   'เครื่องเคียงตามชอบ เช่น แตงกวา ต้นหอม เป็นต้น',
#   'ต้นหอมซอย',
#   'ไข่เค็ม ตัดเป็น 4 ชิ้นตามยาว',
#   'มะนาว'],
#  '9. ข้าวน้ำพริกนรก_https://cooking.kapook.com/view227246.html': ['พริกขี้หนูแห้งคั่ว 10 เม็ด',
#   'กุ้งแห้งคั่ว 1 ถ้วย',
#   'กะปิ 1 ช้อนโต๊ะ',
#   'หอมแดงสับ 1 ถ้วย',
#   'กระเทียมสับ 1 ถ้วย',
#   'น้ำมะขามเปียก 1/2 ถ้วย',
#   'น้ำปลา',
#   'น้ำมันพืช',
#   'ข้าวสวย'],
#  '10. ข้าวน้ำพริกกากหมู_https://cooking.kapook.com/view227246.html': ['มันหมูหั่นชิ้น 1 กิโลกรัม',
#   'หอมแดงซอย 300 กรัม',
#   'กระเทียมสับ 150 กรัม',
#   'พริกป่น 3 ช้อนโต๊ะ',
#   'น้ำตาลทราย 3 ช้อนโต๊ะ',
#   'เกลือ 1 ช้อนชา',
#   'ข้าวสวย'],
#  '11. ข้าวน้ำพริกเผา_https://cooking.kapook.com/view227246.html': ['พริกชี้ฟ้าแดงแห้งคั่ว 15 เม็ด',
#   'พริกขี้หนูแห้งคั่ว 10 เม็ด',
#   'กระเทียมคั่ว 1 ช้อนโต๊ะ',
#   'หอมแดงคั่ว 3 ช้อนโต๊ะ',
#   'น้ำมะขามเปียก 1/2 ถ้วย',
#   'เกลือ 1 ช้อนชา',
#   'น้ำตาลปี๊บ 2 ช้อนโต๊ะ',
#   'น้ำปลา 1 ช้อนโต๊ะ',
#   'น้ำมันพืช'],
#  '12. ข้าวน้ำพริกเผาหอยลาย_https://cooking.kapook.com/view227246.html': ['เนื้อหอยลายสุก (แกะเปลือกแล้ว) 1/2 ถ้วย',
#   'กระเทียมสับละเอียด 1-2 ช้อนชา',
#   'หอมใหญ่ 1/2 หัวเล็ก',
#   'พริกชี้ฟ้า (หั่นแฉลบบาง ๆ) 1 เม็ด',
#   'น้ำพริกเผา',
#   'ซอสปรุงรส',
#   'น้ำมันหอย',
#   'น้ำตาลทราย',
#   'ใบโหระพา 2-3 ต้น',
#   'ข้าวสวยหุงสุก 1 ถ้วยตวง',
#   'น้ำมันพืช'],
#  '13. ข้าวน้ำพริกอ่อง_https://cooking.kapook.com/view227246.html': ['หมูสับติดมัน 300 กรัม',
#   'มะเขือเทศลูกเล็ก 30 ลูก \xa0',
#   'หอมแดงซอย 10 หัว',
#   'กระเทียมไทย 1 ช้อนโต๊ะ',
#   'พริกป่น 2 ช้อนโต๊ะ \xa0',
#   'กะปิหรือถั่วเน่าปิ้งไฟ 1 ช้อนโต๊ะ \xa0',
#   'เกลือป่น 1 ช้อนโต๊ะ',
#   'น้ำตาลทราย \xa0',
#   'น้ำมันพืช 2 ช้อนโต๊ะ',
#   'ต้นหอม',
#   'ผักชี'],
#  '1. สปาเกตตีผัดซอสเขียวหวาน_https://cooking.kapook.com/view229000.html': ['น้ำมันมะกอก',
#   'น้ำพริกแกงเขียวหวาน 2 ช้อนโต๊ะ',
#   'กะทิสำเร็จรูป 1/2 ถ้วยตวง',
#   'น้ำตาลปี๊บ 2 ช้อนชา',
#   'น้ำปลา 2 ช้อนชา',
#   'กุ้งสด (ปอกเปลือกเหลือหาง) 150 กรัม',
#   'เมล็ดถั่วลันเตา (หรือมะเขือพวง) 2 ช้อนโต๊ะ',
#   'ใบมะกรูด (ฉีกเอาก้านกลางออก) 3 ใบ',
#   'เส้นสปาเกตตีลวกสุก 300 กรัม',
#   'ใบโหระพา 20 กรัม',
#   'นมข้นจืด 1/4 ถ้วยตวง',
#   'พริกชี้ฟ้าแดงหั่นเฉียง และใบโหระพาสำหรับแต่ง'],
#  '2. สปาเกตตีผัดซอสกะปิ_https://cooking.kapook.com/view229000.html': ['รากผักชี 2 ราก',
#   'กระเทียม 4-5 กลีบ',
#   'พริกไทยดำเม็ด ตามชอบ',
#   'หมูสับ',
#   'ซีอิ๊วขาว',
#   'น้ำมันหอย',
#   'น้ำตาลทราย',
#   'ซีอิ๊วดำ',
#   'น้ำเปล่า',
#   'ไข่ 1 ฟอง',
#   'เส้นสปาเกตตี',
#   'น้ำเปล่า (สำหรับลวก)',
#   'เกลือ',
#   'พริกขี้หนู ตามชอบ (ไม่ใส่ก็ได้)',
#   'หอมแดง 3 หัว',
#   'มะม่วง 1 ลูก',
#   'มะนาว 1 ลูก',
#   'กะปิ 1 ช้อนกินข้าว',
#   'หอยลายอบกรอบ',
#   'น้ำมันมะกอก'],
#  '3. สปาเกตตีผัดซอสโคชูจัง_https://cooking.kapook.com/view229000.html': ['เส้นสปาเกตตีแบบโฮลวีต',
#   'น้ำมันงา',
#   'กระเทียมสับ',
#   'ก้านดอกกะหล่ำ',
#   'กิมจิ 1 ถ้วย',
#   'พริกหวานหั่นเส้น',
#   'พริกป่น',
#   'ปวยเล้ง (Spinach) หรือผักตามชอบ',
#   'น้ำมันงา 1/2 ช้อนโต๊ะ',
#   'โคชูจัง 1+1/2 ช้อนโต๊ะ',
#   'น้ำซุปก้อนแช่แข็ง หรือน้ำเปล่า 2 ช้อนโต๊ะ',
#   'น้ำผึ้ง หรือน้ำตาลทราย 1 ช้อนโต๊ะ',
#   'ซอสปรุงรส',
#   'น้ำแอปเปิลไซเดอร์ (หรือน้ำส้มสายชูหมัก) 1 ช้อนโต๊ะ',
#   'พริกป่นและพริกไทย ปริมาณตามชอบ'],
#  '4. สปาเกตตีผัดซอสต้มยำไก่ย่าง_https://cooking.kapook.com/view229000.html': ['เนื้ออกไก่',
#   'เกลือ',
#   'พริกไทย',
#   'น้ำมันมะกอก',
#   'น้ำเปล่า',
#   'หอมแดง (สำหรับโขลกและผัด)',
#   'ตะไคร้',
#   'ข่า',
#   'น้ำเปล่า (สำหรับลวก)',
#   'เกลือ',
#   'น้ำมันมะกอก',
#   'เส้นลิงกวินี (Linguine)',
#   'มะเขือเทศหั่นยาว',
#   'ใบมะกรูดฉีก',
#   'ต้นหอมหั่นท่อน',
#   'ตะไคร้ซอย',
#   'พริกแห้งหั่นครึ่งเม็ด',
#   'พริกขี้หนูสดเด็ดก้านหั่นครึ่งเม็ด',
#   'น้ำพริกเผา',
#   'น้ำปลา',
#   'น้ำตาลทราย',
#   'น้ำเปล่า หรือนมสด (สำหรับผัด)',
#   'ผักชี สำหรับตกแต่ง',
#   'ต้นหอมซอย สำหรับตกแต่ง',
#   'มะนาวผ่าซีก'],
#  '5. สปาเกตตีผัดซอสครีมเห็ด_https://cooking.kapook.com/view229000.html': ['แฮมหั่นชิ้นสี่เหลี่ยม 50 กรัม',
#   'เส้นสปาเกตตีต้มสุก 150 กรัม',
#   'กระเทียมสับ 1/2 ช้อนโต๊ะ',
#   'หอมหัวใหญ่สับ 2 ช้อนโต๊ะ',
#   'น้ำมันมะกอก 1 ช้อนโต๊ะ',
#   'แป้งสาลีอเนกประสงค์ 2 1/2 ช้อนชา',
#   'วิปครีมชนิดจืด 1/4 ถ้วยตวง',
#   'นมสด 1/2 ถ้วยตวง',
#   'ใบกระวาน 1 ใบ',
#   'เห็ดแชมปิญองสไลซ์ 50 กรัม',
#   'พริกไทยดำป่น 1/4 ช้อนชา',
#   'เกลือป่นละเอียด 1/8-1/4 ช้อนชา',
#   'พาร์สลีย์สับ สำหรับโรย',
#   'พาร์มีซานชีส สำหรับโรย'],
#  '6. สปาเกตตีผัดซอสพะแนงปลาหมึก_https://cooking.kapook.com/view229000.html': ['น้ำมันพืช 1 ช้อนโต๊ะ',
#   'น้ำพริกแกงพะแนง 1+1/2 ช้อนโต๊ะ',
#   'กะทิเข้มข้นปานกลาง 1/2 ถ้วยตวง',
#   'ปลาหมึกหั่นแว่น 150 กรัม',
#   'เส้นสปาเกตตีสีดำต้มสุก 150 กรัม',
#   'น้ำปลา 2+1/2 ช้อนชา',
#   'น้ำตาลปี๊บ 1 ช้อนโต๊ะ',
#   'พริกชี้ฟ้าสีแดงกับสีเหลืองหั่นแฉลบอย่างละ 1/2 เม็ด',
#   'ใบโหระพา 1/3 ถ้วยตวง'],
#  '7. สปาเกตตีผัดซอสต้มข่าไก่_https://cooking.kapook.com/view229000.html': ['เส้นสปาเกตตีโฮลวีต',
#   'น้ำเปล่า (สำหรับลวกเส้น)',
#   'เกลือ',
#   'ข่า',
#   'ตะไคร้',
#   'ใบมะกรูด',
#   'หอมแดง',
#   'รากผักชี',
#   'พริกไทยดำ',
#   'เห็ด',
#   'อกไก่ 1 ชิ้น',
#   'น้ำมันพืช',
#   'น้ำเปล่า',
#   'นมจืด',
#   'พริกขี้หนูสวน',
#   'พริกจินดา',
#   'น้ำตาลมะพร้าว',
#   'น้ำปลา',
#   'มะนาว',
#   'ต้นหอมและผักชี'],
#  '8. สปาเกตตีผัดซอสคาโบนารา_https://cooking.kapook.com/view229000.html': ['เบคอน หั่นชิ้น (ปริมาณตามชอบ)',
#   'นมสด 200 มิลลิลิตร',
#   'ไข่ไก่ 1 ฟอง',
#   'พาร์มีซานชีสขูด 1 ช้อนโต๊ะ',
#   'น้ำ สำหรับต้มเส้นสปาเกตตี',
#   'เส้นสปาเกตตี 25 กรัม',
#   'เกลือป่น',
#   'น้ำมันมะกอก',
#   'กระเทียมสับ',
#   'พริกไทยดำ'],
#  'สูตรจาก Easy food good health by Andy_https://cooking.kapook.com/view224304.html': ['ไข่ไก่หรือไข่เป็ดเท่าที่มี',
#   'เกลือป่น (ใส่เล็กน้อยให้มีรสเค็มช่วยประหยัดเครื่องปรุงชนิดอื่น)',
#   'น้ำเปล่า ถ้าตุ๋นนานใส่ 3/4 ของขนาดหม้อภาชนะ',
#   'ปีกบนไก่ (น่องหรือสะโพก) ปริมาณตามชอบ',
#   'แท่งอบเชย 2-3 แท่ง (ใส่ให้พอมีกลิ่น)',
#   'ดอกโป๊ยกั๊ก ตามชอบ',
#   'น้ำตาลปี๊บ ใส่ตามชอบ (ถ้าชอบหวานกลมกล่อมใส่เยอะหน่อย ไม่มีใช้น้ำตาลทรายแทนได้ค่ะ หรือจะใส่น้ำตาลปี๊บ 1/2 ส่วน น้ำตาลทราย 1/2 ส่วนก็ได้ค่ะ)',
#   'ซีอิ๊วขาว (ช่วยเพิ่มความหอมอร่อย ชิมรสหลังจากใส่เกลือป่นก่อนเติมนะคะ)',
#   'น้ำปลา (ใส่หรือไม่ใส่ก็ได้ค่ะ)',
#   'ซีอิ๊วดำ (ช่วยเพิ่มสีของไข่พะโล้ ถ้าชอบเข้มมากใส่เยอะหน่อยค่ะ)\n\t\xa0'],
#  '1. ผัดถั่วงอก_https://cooking.kapook.com/view228685.html': ['กระเทียมสับ 1 ช้อนโต๊ะ',
#   'เต้าหู้แข็ง (หั่นเป็นชิ้น) \xa0',
#   'ถั่วงอก',
#   'พริกขี้หนูทุบพอแตก (ใส่หรือไม่ใส่ก็ได้)',
#   'ซอสหอยนางรม 2 ช้อนโต๊ะ',
#   'ซีอิ๊วขาว 1 ช้อนโต๊ะ',
#   'น้ำตาลทราย 1 ช้อนโต๊ะ',
#   'น้ำเปล่า 1/2 ถ้วย',
#   'ขึ้นฉ่าย (หั่นท่อน)',
#   'น้ำมันพืช (สำหรับผัด)'],
#  '2. ก๋วยเตี๋ยวทรงเครื่อง_https://cooking.kapook.com/view228685.html': ['ก๋วยเตี๋ยวเส้นใหญ่',
#   'ปีกบนไก่และปีกกลางไก่',
#   'ปลาหมึกแห้ง (แช่น้ำให้นิ่มแล้วหั่นเป็นชิ้น)',
#   'รากผักชี',
#   'กระเทียม',
#   'พริกไทยดำ',
#   'เต้าหู้ทอด (หั่นเป็นชิ้นพอคำ)',
#   'น้ำตาลปี๊บ',
#   'เห็ดหอม (หั่นเป็นชิ้น)',
#   'ผงพะโล้',
#   'ซีอิ๊วดำ',
#   'ถั่วงอก',
#   'ต้นหอมซอย',
#   'ซีอิ๊วขาว',
#   'น้ำมันหอย',
#   'เกลือ',
#   'น้ำมัน',
#   'ตั้งฉ่ายเค็ม',
#   'ขึ้นฉ่าย',
#   'พริกน้ำส้ม',
#   'ไข่ต้มยางมะตูม',
#   'ซีอิ๊วดำ',
#   'ซีอิ๊วขาว',
#   'น้ำส้มสายชูหมัก หรือน้ำส้มสายชูธรรมดา',
#   'น้ำตาลปี๊บ',
#   'น้ำต้มเล็กน้อย'],
#  '3. ก๋วยเตี๋ยวหลอดทะเล_https://cooking.kapook.com/view228685.html': ['หมึกแห้ง',
#   'น้ำด่าง (ขี้เถ้ามาผสมกับน้ำเปล่า)',
#   'กุ้งสด',
#   'หน่อไม้ทะเลกระป๋อง',
#   'มันหมูแข็ง',
#   'กระเทียมสับ',
#   'ไชโป๊',
#   'เต้าหู้เหลือง',
#   'กุ้งแห้ง',
#   'กระเทียม พริกไทย และรากผักชีโขลก',
#   'ไชโป๊',
#   'ซีอิ๊วขาว',
#   'น้ำปู',
#   'ซอสปรุงรส',
#   'เต้าหู้',
#   'ถั่วงอก',
#   'เส้นใหญ่แบบไม่ตัดเส้น',
#   'กุ้งแห้งแดง',
#   'ซีอิ๊วดำ',
#   'น้ำเชื่อม',
#   'น้ำส้มสายชู',
#   'พริกแดงตำหรือสับ'],
#  '4. ก๋วยเตี๋ยวหลอด_https://cooking.kapook.com/view228685.html': ['กระเทียมกลีบใหญ่ทุบ',
#   'รากผักชีทุบ',
#   'หมูสามชั้นหั่นชิ้นเล็ก ๆ',
#   'น้ำมันหอย',
#   'ซีอิ๊วขาว',
#   'น้ำปลา',
#   'ซีอิ๊วดำ',
#   'น้ำตาลทราย',
#   'เต้าหู้เหลือง หั่นเป็นชิ้นเล็ก',
#   'เส้นก๋วยเตี๋ยวแผ่นใหญ่ (ที่ยังไม่ได้ตัด)',
#   'ถั่วงอก',
#   'ไชโป๊หวาน',
#   'กุ้งแห้งทอด',
#   'กระเทียมเจียว',
#   'พริกไทยป่น',
#   'ต้นหอมซอย',
#   'ผักชีซอย',
#   'น้ำ (สำหรับต้ม)'],
#  '5. ก๋วยเตี๋ยวน้ำซุปเห็ดหอมเจ_https://cooking.kapook.com/view228685.html': ['หัวไชเท้า',
#   'เห็ดหอมสด',
#   'ตั้งฉ่าย',
#   'พริกไทย',
#   'ซีอิ๊วขาว',
#   'ผักบุ้งไทย',
#   'ถั่วงอก',
#   'เส้นก๋วยเตี๋ยว',
#   'ลูกชิ้นพริกไทยเจ',
#   'เนื้อปลาเจ'],
#  '6. ก๋วยเตี๋ยวเนื้อตุ๋น_https://cooking.kapook.com/view228685.html': ['เนื้อวัว (ส่วนเนื้อน่อง)',
#   'ข่า',
#   'ตะไคร้',
#   'ใบมะกรูด',
#   'ซีอิ๊วดำ',
#   'ซีอิ๊วขาว',
#   'เม็ดพริกไทย',
#   'เกลือเม็ด \xa0',
#   'กระเทียมดอง',
#   'หัวกระเทียม',
#   'รากผักชี',
#   'โป๊ยกั๊ก',
#   'อบเชย',
#   'น้ำตาลกรวด',
#   'ลำไยอบแห้ง',
#   'เครื่องก๋วยเตี๋ยวอื่น ๆ เช่น เส้นก๋วยเตี๋ยว (ตามชอบ), ถั่วงอก ,ลูกชิ้นเนื้อ, กระเทียมเจียว, ผักสำหรับโรยหน้า และเครื่องปรุง'],
#  '7. หอยทอด_https://cooking.kapook.com/view228685.html': ['หอยแมลงภู่ 1 ถ้วย',
#   'ไข่ 2 ฟอง',
#   'ต้นหอมซอย 2 ช้อนโต๊ะ',
#   'ถั่วงอก 1 ถ้วย',
#   'แป้งทอดกรอบ 4 ช้อนโต๊ะ',
#   'แป้งข้าวเจ้า 2 ช้อนโต๊ะ',
#   'แป้งเท้ายายม่อม 3 ช้อนโต๊ะ',
#   'ผงปรุงรส 1 ช้อนชา',
#   'พริกไทย 1 ช้อนโต๊ะ',
#   'ซอสปรุงรส 1 ช้อนโต๊ะ',
#   'น้ำมันพืช 3 ช้อนโต๊ะ',
#   'น้ำเปล่า 1/2 ถ้วย',
#   'น้ำปูนใส 2 ช้อนโต๊ะ (ถ้าไม่มีไม่ต้องใส่)',
#   'น้ำจิ้มไก่ 4 ช้อนโต๊ะ',
#   'ซอสพริก 2 ช้อนโต๊ะ'],
#  '8. ผัดไทยมังสวิรัติ_https://cooking.kapook.com/view228685.html': ['ผงปรุงรสเห็ดหอม 1 ช้อนโต๊ะ',
#   'ซีอิ๊วขาว 1 ช้อนโต๊ะ',
#   'น้ำตาลปี๊บ 1 ช้อนโต๊ะ',
#   'น้ำมะขามเปียก 1 ช้อนโต๊ะ',
#   'น้ำมันพืช 2 ช้อนโต๊ะ',
#   'ก๋วยเตี๋ยวเส้นจันท์ หรือเส้นเล็ก ตามชอบ 100 กรัม',
#   'น้ำซุปผัก 1 ถ้วยตวง',
#   'เต้าหู้เหลืองหั่นชิ้นสี่เหลี่ยมเล็ก 100 กรัม',
#   'ไชโป๊เค็มสับหยาบ 2 ช้อนโต๊ะ',
#   'ถั่วงอกดิบ (เด็ดรากออก) 1 ถ้วยตวง',
#   'ถั่วลิสงคั่วบด 1 ช้อนโต๊ะ',
#   'พริกป่น 1 ช้อนชา',
#   'มะนาวผ่าซีก',
#   'ผักเคียงตามชอบ เช่น หัวปลี ใบบัวบก ถั่วงอกดิบ'],
#  '9. วุ้นเส้นผัดไทย_https://cooking.kapook.com/view228685.html': ['น้ำมันพืช 2 ช้อนโต๊ะ',
#   'หอมแดงสับหยาบ 2 ช้อนโต๊ะ',
#   'กระเทียมสับ 2 ช้อนโต๊ะ',
#   'ไชโป๊หวานสับ 3 ช้อนโต๊ะ',
#   'กุ้งสด (ปอกเปลือกผ่าหลัง) 5 ตัว',
#   'เต้าหู้เหลือง (หั่นชิ้นเล็ก) 1/2 ก้อน',
#   'น้ำมะขามเปียก 3 ช้อนโต๊ะ',
#   'น้ำตาลปี๊บ 2 1/2 ช้อนโต๊ะ',
#   'น้ำปลา 4 ช้อนโต๊ะ',
#   'พริกป่น 2 ช้อนชา',
#   'วุ้นเส้น (แช่น้ำจนนุ่ม) 200 กรัม',
#   'น้ำเปล่า 1/2 ถ้วย',
#   'ใบกุยช่าย (หั่นเป็นท่อน) 2 ต้น',
#   'ถั่วงอก',
#   'ถั่วลิสงคั่วบด',
#   'พริกป่น',
#   'มะนาว'],
#  '10. ผัดไทยเกี๊ยวกรอบ_https://cooking.kapook.com/view228685.html': ['แผ่นเกี๊ยวแบบหนา',
#   'เนื้อปู',
#   'หมูสับ',
#   'กุ้งสับ',
#   'กระเทียม',
#   'น้ำพริกแกงผัดไทย (เอามาจากทางใต้ ประกอบไปด้วย หอมแดง พริกชี้ฟ้าแห้ง และน้ำตาลปึก)',
#   'เต้าหู้ทอด',
#   'มะขามเปียก (สำหรับปรุงรส)',
#   'น้ำปลา (สำหรับปรุงรส)',
#   'ถั่วงอก'],
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ไข่เจียวหมูสับทำบ่อยก็เบื่อ ลองมาทำไข่เจียวดอกขจรกันหน่อยดีไหม ใส่ผักพื้นบ้านมีประโยชน์ เอาไปทอดแบบไร้น้ำมันก็ได้ กินกับข้าวสวยหรือข้าวต้มก็อร่อย_https://cooking.kapook.com/view218558.html': ['ไข่ไก่',
#   'ดอกขจร',
#   'ซอสปรุงรส',
#   'น้ำมันพืช'],
#  '1. ไข่แดงดองพริกน้ำปลา _https://cooking.kapook.com/view212391.html': ['น้ำ 125 มิลลิลิตร',
#   'น้ำปลา 125 มิลลิลิตร',
#   'พริกแดง 4 เม็ด',
#   'พริกเขียว 4 เม็ด',
#   'กระเทียม 2 กลีบ',
#   'น้ำกระเทียมดอง 2 ช้อนโต๊ะ',
#   'กระเทียมดอง 1 หัว',
#   'น้ำตาลทรายขาว 3 ช้อนโต๊ะ',
#   'น้ำตาลมะพร้าว 3 ช้อนโต๊ะ',
#   'ไข่ไก่ เปลือกสีขาว\n\t\xa0'],
#  '2. ไข่แดงดองน้ำปลา _https://cooking.kapook.com/view212391.html': ['ไข่ 10 ฟอง',
#   'น้ำเปล่า 1 ถ้วย',
#   'น้ำปลาอย่างดี 1 ถ้วย',
#   'น้ำตาลปี๊บ 50 กรัม',
#   'น้ำตาลทราย 50 กรัม',
#   'ขิงหั่นแว่น 1 แง่ง',
#   'พริก 5 เม็ด\n\t\xa0'],
#  '3. ไข่แดงดองซีอิ๊ว _https://cooking.kapook.com/view212391.html': ['ไข่แดง 1 ฟอง',
#   'ซอสแม็กกี้',
#   'ข้าวสวย\n\t\xa0'],
#  '4. ไข่ดองเกลือ (ไข่แดงเค็ม)_https://cooking.kapook.com/view212391.html': ['ไข่เป็ด (เบอร์ L)',
#   'เกลือ 1/2-1 ช้อนชา',
#   'เหล้า หรือไวน์ 1/2 ช้อนชา (ใช้เหล้าชนิดไหนก็ได้ที่มีในบ้าน หรือตามสะดวก)\n\t\xa0'],
#  'กะหรี่ปั๊บแป้งชั้นเดียวก็ดูทั่วไป ต้องนี่เลย กะหรี่ปั๊บไส้ไก่ สูตรแป้งสองชั้นโดดเด่น มาพร้อมไส้ผัดผงกะหรี่กลิ่นหอมจับใจ อร่อยกรอบมากแค่กัดคำแรกก็ติดใจแล้ว ! _https://cooking.kapook.com/view214357.html': ['แป้งสาลีเอนกประสงค์ (แป้งว่าว) 300 กรัม',
#   'น้ำ 145 มิลลิลิตร',
#   'น้ำตาลทราย 20 กรัม',
#   'เกลือป่น 1/8 ช้อนชา',
#   'ชอร์ตเทนนิ่งน้ำมันรำข้าว 70 กรัม\n\t\xa0',
#   'แป้งสาลีอเนกประสงค์ (แป้งว่าว) 175 กรัม',
#   'ชอร์ตเทนนิ่งน้ำมันรำข้าว 70 กรัม',
#   'น้ำมัน (สำหรับทอด) 1 ขวด\n\t\xa0',
#   'น้ำมันรำข้าว (สำหรับผัด) 2 ช้อนโต๊ะ',
#   'ผงกะหรี่ 2 ช้อนชา',
#   'หอมใหญ่ (หั่นเต๋าเล็ก) 100 กรัม',
#   'เนื้ออกไก่ 200 กรัม',
#   'น้ำตาลทราย 5 ช้อนโต๊ะ',
#   'น้ำปลา 2+1/2 ช้อนโต๊ะ',
#   'เกลือป่น 1/2 ช้อนชา',
#   'พริกไทยป่น 2-3 ช้อนชา',
#   'มันเทศหรือมันฝรั่ง (หั่นเต๋าเล็ก) 300 กรัม (นำไปต้มให้สุกแต่อย่าให้เละนะคะ ต้มประมาณ 5-7 นาที)'],
#  '1. ขนมปังหน้าชีสกุ้ง_https://cooking.kapook.com/view221945.html': ['ขนมปังโฮลวีต 2 แผ่น',
#   'ไข่ไก่ 1 ฟอง',
#   'มะเขือเทศ 1 ลูก (ผ่าครึ่งแล้วควักไส้ออก)',
#   'ชีส 4 แผ่น (หั่นเต๋า)',
#   'กุ้งขาว 2 ตัว (ปอกเปลือก)',
#   'ต้นหอมซอย'],
#  '2. ไข่ถ้วยเบคอนชีส_https://cooking.kapook.com/view221945.html': ['เบคอน 12 ชิ้น (ตามจำนวนชิ้น)',
#   'เนย หรือน้ำมันเล็กน้อย (สำหรับทาพิมพ์)',
#   'มอสซาเรลล่าชีสขูด 200 กรัม',
#   'ไข่ไก่ 5 ฟอง',
#   'นม 1/4 ถ้วย',
#   'น้ำมัน 1/2 ช้อนชา',
#   'ผงฟู 1/2 ช้อนชา',
#   'เกลือ และพริกไทยดำ (ตามชอบ)'],
#  '3. แซนด์วิชไส้ปูอัด_https://cooking.kapook.com/view221945.html': ['ปูอัด (ฉีกเป็นเส้น ๆ ) 120\xa0 กรัม',
#   'แตงกวา (หั่นละเอียด) 2 ช้อนโต๊ะ',
#   'แครอต (หั่นละเอียด) 2 ช้อนโต๊ะ',
#   'มายองเนส 100 กรัม',
#   'ขนมปัง (ตามชอบ)',
#   'น้ำตาลทราย 1/2 ช้อนโต๊ะ'],
#  '4. ขนมปังอบไข่ไส้กรอก_https://cooking.kapook.com/view221945.html': ['ขนมปังฉีก',
#   'ไส้กรอก',
#   'ไข่นกกระทา'],
#  '5. มูสลี่นมถั่วเหลือง_https://cooking.kapook.com/view221945.html': ['มูสลี่',
#   'เมล็ดเจีย',
#   'เมล็ดแฟลกซ์',
#   'นมถั่วเหลืองไม่เติมน้ำตาล',
#   'ผลไม้สดตามชอบ'],
#  '6. พุดดิ้งขนมปังโฮลวีต_https://cooking.kapook.com/view221945.html': ['ขนมปังโฮลวีต',
#   'ไข่ไก่',
#   'นมไขมันต่ำ หรือนมถั่วเหลือง',
#   'น้ำผึ้ง',
#   'กลิ่นวานิลลา',
#   'ผลไม้ตามชอบ'],
#  '7. ขนมปังอบชีส_https://cooking.kapook.com/view221945.html': ['ขนมปังแบบหนา 2 แผ่น',
#   'เนยสด เล็กน้อย',
#   'เชดดาร์ชีสแผ่น 2 แผ่น',
#   'เบคอนแบบยาว 4 เส้น',
#   'ไข่ไก่ 2 ฟอง',
#   'ต้นหอมซอย'],
#  '8. ไข่อบเต้าหู้ไข่_https://cooking.kapook.com/view221945.html': ['เต้าหู้ไข่',
#   'เห็ดหอม',
#   'บรอกโคลี',
#   'มะเขือเทศ',
#   'ไข่ไก่',
#   'นมถั่วเหลือง',
#   'พริกไทย',
#   'ซีอิ๊วขาวโซเดียมต่ำ'],
#  '9. ไข่อบอะโวคาโด_https://cooking.kapook.com/view221945.html': ['อะโวคาโด',
#   'ไข่',
#   'เบคอน',
#   'พาร์มีซานชีส',
#   'ขนมปังซาวร์โดว์มัฟฟิน (หรือขนมปังอะไรก็ได้)',
#   'พริกไทยดำ',
#   'เกลือ'],
#  '10. ขนมปังอะโวคาโคอบชีส_https://cooking.kapook.com/view221945.html': ['อะโวคาโด',
#   'ขนมปัง',
#   'ไข่ไก่ 1 ฟอง',
#   'เกลือป่น เล็กน้อย',
#   'พริกไทยป่น เล็กน้อย',
#   'มอสซาเรลล่าชีส',
#   'พาร์มีซานชีส (ใส่หรือไม่ใส่ก็ได้)'],
#  '11. แพนเค้กหมี_https://cooking.kapook.com/view221945.html': ['แป้งสาลีอเนกประสงค์ 1+1/2 ถ้วย',
#   'ผงฟู 1 ช้อนโต๊ะ',
#   'เกลือ 1/4 ช้อนชา',
#   'ไข่ 2 ฟอง',
#   'น้ำตาลทราย 2 ช้อนโต๊ะ',
#   'นมสด 1+1/3 ถ้วย',
#   'เนยสดละลาย 2 ช้อนโต๊ะ'],
#  '12. คัพเค้กไข่และผัก_https://cooking.kapook.com/view221945.html': ['ไข่ไก่ 4 ฟอง',
#   'แครอตหั่นเต๋าลวกสุก 6 ช้อนโต๊ะ',
#   'เนื้อมะเขือเทศหั่นเต๋า 6 ช้อนโต๊ะ',
#   'หอมหัวใหญ่หั่นเต๋า 1/2 ถ้วย',
#   'ผักโขมอ่อน 1 ถ้วย',
#   'พาร์มีซานชีสขูด 1/4 ถ้วย',
#   'เกลือป่น 1/2 ช้อนชา',
#   'พริกไทยป่น 1/2 ช้อนชา',
#   'ซีอิ๊วขาว 2 ช้อนชา',
#   'น้ำซุป 1 ถ้วย'],
#  '13. เครปไข่ดาว_https://cooking.kapook.com/view221945.html': ['แป้งสาลีอเนกประสงค์ 1/2 ถ้วย',
#   'น้ำตาลทราย 1/2 ช้อนโต๊ะ',
#   'เกลือป่น 1/4 ช้อนชา',
#   'นมสด 3/4 ถ้วย',
#   'ไข่ไก่ 2 ฟอง',
#   'เนยสดละลาย 1+1/2 ช้อนโต๊ะ',
#   'แฮมสไลซ์ หรือเบคอน 4-5 แผ่น',
#   'ไข่ไก่ 4-5 ฟอง',
#   'พริกไทยป่น เล็กน้อย',
#   'พาร์สลีย์ หรือใบผักชี สำหรับแต่ง'],
#  '14. เฟรนช์โทสต์โรล_https://cooking.kapook.com/view221945.html': ['ขนมปังแผ่น',
#   'ครีมชีส',
#   'ผลไม้ตามชอบ เช่น สตรอว์เบอร์รี บลูเบอร์รี ราสป์เบอร์รี',
#   'ไข่ไก่',
#   'เนย',
#   'น้ำตาลไอซิ่ง',
#   'นมข้นหวาน'],
#  '15. ขนมปังแซนด์วิชฮาวายเอี้ยน_https://cooking.kapook.com/view221945.html': ['เชอร์รีในน้ำเชื่อม (Maraschino Cherries)',
#   'ขนมปัง 2 แผ่น',
#   'เนยสด',
#   'สับปะรดกระป๋อง 2 ชิ้น',
#   'เชอร์รีในน้ำเชื่อม (Maraschino Cherries) 2 ลูก',
#   'แฮม ปริมาณตามชอบ',
#   'ชีสแผ่น ตามชอบ (แนะนำ ชีสกรูว์แยร์แผ่นกึ่งแข็ง จะทำให้แซนด์วิชอร่อยมาก)',
#   'ใบโรสแมรีสดหั่นละเอียด หรือออริกาโน่อบแห้ง',
#   'พริกป่น',
#   'พริกไทย'],
#  'ไข่ตุ๋นทรงเครื่อง เนื้อเนียน ๆ โดย คุณ Phorn_Kitchen สมาชิกเว็บไซต์พันทิปดอทคอม_https://cooking.kapook.com/view225566.html': ['ไข่ไก่ 2 ฟอง',
#   'ซีอิ๊วขาว 1 ช้อนชา',
#   'ผงปรุงรสหมู 1 ช้อนชา',
#   'น้ำ 200 มิลลิลิตร',
#   'หมูสับ 50 กรัม',
#   'ซอสปรุงรส 1 ช้อนชา',
#   'แครอตหั่นเต๋า 20 กรัม',
#   'พริกไทยป่น เล็กน้อย',
#   'กุ้ง 2 ตัว',
#   'ต้นหอมซอย'],
#  '“ข้าวต้มทรงเครื่อง สูตรแบบโบราณผัดเครื่องข้าวต้ม”_https://cooking.kapook.com/view214061.html': ['ข้าวหอมมะลิต้มสุก',
#   'หมูสับ',
#   'กระเทียมซอย (สำหรับโรยหน้าและสำหรับผัด)',
#   'ขิงอ่อนหั่นเส้น',
#   'รากผักชีซอย',
#   'ลูกผักชีบด',
#   'ผงปรุงรส',
#   'ซีอิ๊วขาว',
#   'น้ำมันหอย',
#   'น้ำตาลทราย',
#   'ขึ้นฉ่าย',
#   'พริกไทยขาวป่น',
#   'ผักชี',
#   'ต้นหอมซอย\n\t\xa0',
#   'สามารถใส่ผัก สมุนไพร เนื้อสัตว์อื่น ๆ เพิ่มเติมได้ตามความชอบ เช่น กระวาน ใบเตย กุ้งแห้ง ปลาหมึกกรอบ เป็นต้น\n\t\xa0'],
#  'คุณแขมร อินเตอร์ สมาชิกเว็บไซต์พันทิปดอทคอม_https://cooking.kapook.com/view220213.html': ['สาหร่ายแผ่น',
#   'ไข่',
#   'แผ่นเปาะเปี๊ยะ',
#   'น้ำมัน สำหรับทอด'],
#  'วันนี้ป้าทำแซนด์วิชคร็อกเมอซิเยอร์ บอกเลยว่าอร่อยมาก ๆ\nทำเป็นอาหารเช้าคู่กับกาแฟเข้ากันมากค่ะ โดย ครัวป้ามารายห์_https://cooking.kapook.com/view227998.html': ['เนยสด 25 กรัม',
#   'แป้งเค้ก 20 กรัม',
#   'นม 200 มิลลิลิตร',
#   'เกลือป่น 1/4 ช้อนชา',
#   'พริกไทย',
#   'ขนมปัง 4 แผ่น',
#   'เชดดาร์ชีส 2 แผ่น',
#   'แฮม 4 แผ่น',
#   'มอสซาเรลล่าชีสขูด',
#   'ออริกาโน่'],
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 แชร์ไปให้เพื่อนรู้ว่าเราก็สายมันนะ กับเมนูมันม่วงอบ ความพิเศษคือใส่เครื่องเทศและโรยชีสนี่แหละ จะกินเล่นเพลิน ๆ หรือกินเอาอิ่มก็ยังได้ ใครรู้สึกอยากกินขึ้นมาเข้าครัวเลย _https://cooking.kapook.com/view216786.html': ['มันม่วง 2 ลูก',
#   'แป้งข้าวโพด 2 ช้อนโต๊ะ',
#   'น้ำมัน 1 ช้อนโต๊ะ',
#   'ผงสโมกปาปริก้า 1 ช้อนชา',
#   'ผงกระเทียม 1+1/2 ช้อนชา',
#   'ออริกาโน่แห้ง 1 ช้อนชา',
#   'เกลือ ตามชอบ',
#   'พริกไทย ตามชอบ',
#   'โรสแมรี่สด 1 ช้อนโต๊ะ',
#   'ชีสพาร์มิจาโน่ เร็กจิอาโน่ (Parmigiano Reggiano) 2 ช้อนโต๊ะ\n\t\xa0'],
#  '1. ไข่กระทะ_https://cooking.kapook.com/view213126.html': ['ไข่ไก่ 2 ฟอง',
#   'กุนเชียง',
#   'ไก่รวน หรือหมูรวน',
#   'หมูยอ',
#   'ต้นหอม (สำหรับโรย)',
#   'ซอสปรุงรส',
#   'พริกไทย',
#   'เนยจืดหรือน้ำมัน\n\t\xa0'],
#  '2. ข้าวไข่เจียว_https://cooking.kapook.com/view213126.html': ['ไข่ไก่ 2 ฟอง',
#   'หมูสับ 2 ช้อนโต๊ะ',
#   'พริกขี้หนูซอย 1 ช้อนชา (ใส่หรือไม่ใส่ก็ได้)',
#   'ต้นหอมซอย 1 ช้อนโต๊ะ',
#   'ซอสหอยนางรม 1 ช้อนโต๊ะ',
#   'ซอสปรุงรส 1 ช้อนชา',
#   'พริกไทยป่น 1/4 ช้อนชา',
#   'น้ำมันพืช (สำหรับทอด)',
#   'ข้าวสวย\n\t\xa0'],
#  '3. ซุปฟักทองขนมปังกระเทียม_https://cooking.kapook.com/view213126.html': ['เนยสดชนิดจืดอ่อนตัว 50 กรัม',
#   'กระเทียมสับ 1 ช้อนโต๊ะ',
#   'เกลือป่น 1/4 ช้อนชา',
#   'พริกไทยป่น 1/2 ช้อนชา',
#   'น้ำตาลทราย 1 ช้อนชา',
#   'พาร์สลีย์สับละเอียด 1 ช้อนโต๊ะ',
#   'ขนมปังฝรั่งเศสหั่นตามขวาง 2 ชิ้น\n\t\xa0',
#   'ซุปฟักทอง 1 ถ้วย',
#   'ขนมปังกระเทียม สำหรับรับประทานคู่',
#   'เมล็ดดอกทานตะวันกะเทาะเปลือก',
#   'พริกไทยดำบดหยาบ\n\t\xa0'],
#  '4. สปาเกตตีซอสครีมเห็ด_https://cooking.kapook.com/view213126.html': ['เส้นสปาเกตตีต้มสุก 150 กรัม',
#   'กระเทียมสับ 1/2 ช้อนโต๊ะ',
#   'หอมใหญ่สับ 2 ช้อนโต๊ะ',
#   'น้ำมันมะกอก 1 ช้อนโต๊ะ',
#   'แป้งสาลีอเนกประสงค์ 2+1/2 ช้อนชา',
#   'วิปครีมชนิดจืด 1/4 ถ้วยตวง',
#   'นมสด 1/2 ถ้วยตวง',
#   'แฮมหั่นชิ้นสี่เหลี่ยม 50 กรัม',
#   'เห็ดแชมปิญองสไลซ์ 50 กรัม',
#   'ใบกระวาน 1 ใบ',
#   'พริกไทยดำป่น 1/4 ช้อนชา',
#   'เกลือป่นละเอียด 1/8-1/4 ช้อนชา',
#   'พาร์สลีย์สับสำหรับโรย',
#   'พาร์มีซานชีสสำหรับโรย\n\t\xa0'],
#  '5. แซนด์วิชขนมปังปิ้งหน้าผลไม้_https://cooking.kapook.com/view213126.html': ['ขนมปังโฮลวีต',
#   'คอตเทจชีส',
#   'เนยถั่ว',
#   'สตรอว์เบอร์รีสไลซ์',
#   'กล้วยหอม (สไลซ์เป็นแว่น)\n\t\xa0'],
#  '6. ข้าวผัดปู_https://cooking.kapook.com/view213126.html': ['กระเทียมสับ',
#   'ไข่เป็ด 2 ฟอง',
#   'หอมใหญ่หั่นเต๋า',
#   'กรรเชียงปูม้าแกะสำเร็จ',
#   'ข้าวสวย (แช่เย็น)',
#   'ซีอิ๊วขาว',
#   'ซอสหอยนางรม',
#   'น้ำตาลทราย',
#   'ต้นหอมซอย',
#   'แตงกวา',
#   'พริกน้ำปลาสามรส (สำหรับเสิร์ฟ)',
#   'น้ำมันพืช (สำหรับผัด)\n\t\xa0'],
#  '7. หมูย่าง_https://cooking.kapook.com/view213126.html': ['เนื้อสะโพกหมู หรือสันนอกหมู 1 กิโลกรัม',
#   'รากผักชี 25 กรัม',
#   'กระเทียมไทย (แกะเปลือก) 2 หัว',
#   'พริกไทยเม็ด 1+1/2 ช้อนชา',
#   'น้ำตาลมะพร้าว 180 กรัม',
#   'หัวกะทิ 1+1/2 ถ้วยตวง',
#   'ซีอิ๊วดำ 3 ช้อนชา',
#   'ซีอิ๊วขาว 8 ช้อนโต๊ะ',
#   'ซอสปรุงรสฝาเขียว 6 ช้อนโต๊ะ',
#   'แป้งข้าวโพด 1 ช้อนโต๊ะ',
#   'ไข่แดง 1 ฟอง',
#   'น้ำมันพืช 5 ช้อนโต๊ะ',
#   'ไม้สำหรับเสียบหมู\n\t\xa0',
#   'น้ำมะนาว',
#   'น้ำตาลมะพร้าว',
#   'น้ำปลา',
#   'พริกป่น',
#   'ข้าวคั่ว',
#   'ต้นหอมซอย',
#   'ผักชีฝรั่งซอย\n\t\xa0'],
#  '1. เมนูไข่ดาวจิ๋ว_https://cooking.kapook.com/view224203.html': ['ไข่ไก่ 2 ฟอง (แช่แข็ง)',
#   'น้ำมันมะพร้าว',
#   'กล้วยหอม 1 ลูก',
#   'เครื่องดื่ม (ชาร้อน)'],
#  '2. เมนูไข่คนชีส_https://cooking.kapook.com/view224203.html': ['ไข่ไก่ 2 ฟอง',
#   'มะเขือเทศสับ',
#   'ต้นหอมซอย',
#   'เกลือชมพู',
#   'มอสซาเรลล่าชีส',
#   'น้ำมันมะพร้าว',
#   'กล้วยหอม 1 ลูก',
#   'เครื่องดื่ม (ชาร้อน)'],
#  '3. เมนูเฟรนช์โทสต์_https://cooking.kapook.com/view224203.html': ['ขนมปังโฮลวีต 3 แผ่น',
#   'ไข่ไก่ 2 ฟอง',
#   'เกลือชมพู',
#   'พริกไทยดำ',
#   'นมสด 100 มิลลิลิตร',
#   'เนยเค็ม',
#   'ผลไม้',
#   'เครื่องดื่ม (น้ำส้ม)'],
#  '4. เมนูขนมปังไข่ดาว_https://cooking.kapook.com/view224203.html': ['ไข่ไก่ 1 ฟอง',
#   'ขนมปังโฮลวีต 2 แผ่น (หรือแบบแผ่นหนา 1 แผ่น)',
#   'แตงกวาญี่ปุ่น',
#   'เครื่องดื่ม (โกโก้ร้อน)',
#   'น้ำมันมะกอก',
#   'กีวี'],
#  '1. บูเดชิเก_https://cooking.kapook.com/view228342.html': ['ไส้กรอก (หรือผลิตภัณฑ์เนื้อสัตว์แปรรูปตามชอบ)',
#   'บะหมี่กึ่งสำเร็จรูปรสต้มยำกุ้ง หรือบะหมี่กึ่งสำเร็จรูปเกาหลี',
#   'ไข่ไก่',
#   'ผักตามชอบ (เช่น ต้นหอมญี่ปุ่นซอย, แครอตหั่นแว่น, เห็ด, ผักกาดขาว, กะหล่ำปลี เป็นต้น)',
#   'สาหร่าย',
#   'โคชูจัง',
#   'น้ำมันงา'],
#  '2. ไก่ทอดเกาหลี_https://cooking.kapook.com/view228342.html': ['น่องไก่และปีกไก่ 1.5 กิโลกรัม',
#   'เกลือป่น',
#   'พริกไทยป่น',
#   'ผงกระเทียมป่น',
#   'ไข่ไก่ 1 ฟอง',
#   'แป้งชุบทอด 1/2 ถ้วย',
#   'แป้งมัน 1/2 ถ้วย',
#   'ผงฟู 1 ช้อนชา',
#   'น้ำมันพืช (1 ลิตร) 1 ขวด',
#   'กระเทียม 3-4 กลีบ',
#   'ซอสมะเขือเทศ 1/3 ถ้วย',
#   'โคชูจัง 1/4 ถ้วย',
#   'น้ำผึ้ง 1/3 ถ้วย',
#   'น้ำส้มสายชูแอปเปิล 1 ช้อนโต๊ะ',
#   'งาขาว'],
#  '3. แกงกิมจิ_https://cooking.kapook.com/view228342.html': ['เบคอนหั่น หรือหมูสามชั้น (หั่นชิ้น) 100 กรัม',
#   'ผงกระเทียม 1 ช้อนชา (หรือกระเทียมสับ 3 กลีบ)',
#   'ขิงผง 1 ช้อนชา (หรือขิงสับ 1 ช้อนชา)',
#   'พริกป่น หรือพริกเกาหลี 1/4 ช้อนชา',
#   'กิมจิ 150-200 กรัม',
#   'น้ำเปล่า 2 ถ้วยตวง',
#   'ดาชิ (ผงซุปปลา) 2 ช้อนโต๊ะ (ซุปก้อนไก่หรือหมู 1/2 ก้อน หรือน้ำที่แช่ปลาแห้งปริมาณพอเหมาะ)',
#   'โคชูจัง (ซอสพริกเกาหลี) 1-2 ช้อนโต๊ะ',
#   'มิโซะ (เต้าเจี้ยวญี่ปุ่น) หรือเต้าเจี้ยวไทย 1 ช้อนโต๊ะ',
#   'เต้าหู้คินุ หรือเต้าหู้ใบตอง (หั่นเต๋าใหญ่) 1/2-1 ก้อน',
#   'ไข่ไก่ 1 ฟอง',
#   'ต้นหอมญี่ปุ่น หรือต้นหอมไทยหั่นท่อน'],
#  '4. กิมจิ_https://cooking.kapook.com/view228342.html': ['ผักกาดขาว 2 หัว',
#   'น้ำส้มสายชู',
#   'ไช้เท้า 1 หัว (หั่นเป็นแว่น)',
#   'เกลือ',
#   'แครอต',
#   'ต้นหอม (หั่นเป็นท่อน) 3 ต้น',
#   'ขิงบดละเอียด',
#   'กระเทียมโขลกละเอียด',
#   'พริกชี้ฟ้า',
#   'น้ำตาลทราย 3 ช้อนโต๊ะ',
#   'โคชูจัง 2 ช้อนโต๊ะพูน ๆ',
#   'น้ำปลา'],
#  '5. ข้าวผัดโคชูจัง_https://cooking.kapook.com/view228342.html': ['กระเทียมสับ',
#   'โคชูจัง',
#   'ข้าวสวย',
#   'เนื้อหมูหมัก',
#   'ซอสปรุงรส',
#   'น้ำตาลทราย',
#   'พริกไทยป่น',
#   'ไข่ไก่ 1 ฟอง',
#   'น้ำเปล่า',
#   'น้ำมันพืชสำหรับผัด',
#   'แตงกวาหรือผักลวก'],
#  '6. ข้าวผัดกิมจิ_https://cooking.kapook.com/view228342.html': ['กิมจิผักกาดขาว 1 ถ้วย',
#   'ข้าวสวย 2+1/2 ถ้วย',
#   'โคชูจัง (ซอสพริกเกาหลี) 1+1/2 ช้อนโต๊ะ',
#   'น้ำส้มสายชู 1 ช้อนโต๊ะ',
#   'ซีอิ๊วขาว 1/2 ช้อนโต๊ะ',
#   'เต้าหู้เนื้อแข็ง 1 ชิ้น',
#   'หอมหัวใหญ่สับ 1/2 หัว',
#   'กระเทียมสับ 2 กลีบ',
#   'เห็ดหอมซอย 1 ถ้วย',
#   'ต้นหอมซอย 2 ต้น',
#   'ไข่ดาว',
#   'น้ำมันพืช'],
#  'เต้าหู้ทอด+น้ำจิ้มรสเด็ด (เจ) ครัวบ้านทราย\nโดย คุณ sandy_sine สมาชิกเว็บไซต์พันทิปดอทคอม_https://cooking.kapook.com/view228022.html': ['น้ำตาลทราย 65 กรัม',
#   'น้ำตาลปี๊บ 65 กรัม',
#   'เกลือ 1 ช้อนชา',
#   'น้ำส้มสายชู 5 ช้อนโต๊ะ',
#   'น้ำเปล่า 3 ช้อนโต๊ะ',
#   'พริกแดง 1 เม็ด',
#   'ถั่วลิสงคั่ว 2 ช้อนโต๊ะ',
#   'เต้าหู้ขาว 2 แผ่น',
#   'น้ำมัน'],
#  'พายไก่สูตรง่ายอร่อย by ครัวตุ๊กตา\nโดย คุณ tukata001 สมาชิกเว็บไซต์พันทิปดอทคอม (ครัวตุ๊กตา)_https://cooking.kapook.com/view223389.html': ['เนย 2 ช้อนโต๊ะ',
#   'หอมหัวใหญ่ 1/2 ลูก',
#   'ไก่สับ 250 กรัม',
#   'มันฝรั่ง 1 ลูก',
#   'ผงกะหรี่ 2 ช้อนโต๊ะ',
#   'ซีอิ๊วขาว 3 ช้อนโต๊ะ',
#   'น้ำตาลทราย 5 ช้อนโต๊ะ',
#   'แป้งข้าวโพด 1 ช้อนโต๊ะ',
#   'แป้งพายชั้น 1 กล่อง',
#   'ไข่ไก่ 1 ฟอง'],
#  '1. น้ำจิ้มกุยช่าย_https://cooking.kapook.com/view227493.html': ['น้ำส้มสายชู 120 กรัม',
#   'ซีอิ๊วดำหวาน 35 กรัม',
#   'ซีอิ๊วขาว 1.5 ช้อนโต๊ะ',
#   'น้ำตาลทรายแดง 120 กรัม',
#   'เกลือป่น 1 ช้อนชา',
#   'พริกแดงสับตามชอบ'],
#  '2. น้ำจิ้มซอสมะขาม_https://cooking.kapook.com/view227493.html': ['น้ำต้มสุก',
#   'น้ำมะขามเปียก',
#   'น้ำตาลปี๊บ',
#   'ซีอิ๊วขาว'],
#  '3. น้ำจิ้มซีฟู้ด_https://cooking.kapook.com/view227493.html': ['น้ำตาลปี๊บ 500 กรัม',
#   'เกลือ 2 ช้อนโต๊ะ',
#   'น้ำร้อน 3+1/2 ถ้วย',
#   'น้ำมะนาว 4 ถ้วย',
#   'พริกขี้หนู 200 กรัม',
#   'กระเทียมไทย 200 กรัม',
#   'ผักชี 200 กรัม'],
#  '4. น้ำจิ้มซีฟู้ดถั่วตัด_https://cooking.kapook.com/view227493.html': ['พริกขี้หนูสวน',
#   'กระเทียม',
#   'รากผักชี',
#   'น้ำตาลปี๊บ',
#   'เกลือ',
#   'ถั่วตัด',
#   'น้ำมะนาว'],
#  '5. น้ำจิ้มแจ่วหอมแดง_https://cooking.kapook.com/view227493.html': ['พริกป่น',
#   'น้ำปลา',
#   'น้ำตาลทราย',
#   'น้ำมะนาว',
#   'หอมแดงซอย',
#   'ต้นหอมซอย',
#   'ผักชี'],
#  '6. น้ำจิ้มแจ่วมะขาม_https://cooking.kapook.com/view227493.html': ['น้ำมะขามเปียก',
#   'น้ำตาลปี๊บ',
#   'ซีอิ๊วขาว',
#   'พริกป่น',
#   'ข้าวคั่ว',
#   'ตะไคร้ซอย',
#   'ผักชีฝรั่งซอย'],
#  '7. น้ำจิ้มแจ่วซอสแม็กกี้_https://cooking.kapook.com/view227493.html': ['ซอสแม็กกี้ 2 ช้อนโต๊ะ',
#   'น้ำตาลทราย 1 ช้อนชา',
#   'พริกป่น 2 ช้อนชา (ปริมาณเพิ่ม-ลดได้ตามชอบ)',
#   'น้ำมะนาว 2 ช้อนโต๊ะ',
#   'ผักชีฝรั่งซอยละเอียด 1 ช้อนโต๊ะ'],
#  '8. น้ำจิ้มลูกชิ้นทอด_https://cooking.kapook.com/view227493.html': ['น้ำมะขามเปียก 400 มิลลิลิตร',
#   'น้ำตาลปี๊บ 400 กรัม',
#   'น้ำตาลทราย 80 กรัม',
#   'เกลือ 2 ช้อนชา',
#   'น้ำเปล่า 200 มิลลิลิตร',
#   'พริกแห้งป่น ปริมาณตามชอบ',
#   'ถั่วคั่วป่น ปริมาณตามชอบ (ไม่ใส่ก็ได้)',
#   'ผักชี ปริมาณตามชอบ'],
#  '9. น้ำจิ้มเปาะเปี๊ยะทอด_https://cooking.kapook.com/view227493.html': ['น้ำมะขามเปียกเข้มข้น 1 ซอง',
#   'น้ำตาลปี๊บ 100 กรัม',
#   'น้ำ 60 มิลลิลิตร',
#   'เกลือป่นไทย 1 ช้อนชา',
#   'พริกขี้หนูแดงโขลก 1 ช้อนโต๊ะ',
#   'ผักชีซอยและถั่วลิสงคั่วโขลก สำหรับโรยหน้า'],
#  '10. น้ำจิ้มหอยทอด_https://cooking.kapook.com/view227493.html': ['น้ำจิ้มไก่ 4 ช้อนโต๊ะ',
#   'ซอสพริก 2 ช้อนโต๊ะ'],
#  '11. น้ำจิ้มข้าวโพดทอด_https://cooking.kapook.com/view227493.html': ['น้ำตาลทราย 1/2 ถ้วยตวง',
#   'น้ำส้มสายชู 1/4 ถ้วยตวง',
#   'เกลือป่น 1 ช้อนชา',
#   'พริกขี้หนูซอย หรือตำละเอียด 5 เม็ด',
#   'น้ำจิ้มไก่ 2 ช้อนโต๊ะ',
#   'ถั่วลิสงคั่วป่น (ใส่หรือไม่ใส่ก็ได้)'],
#  '12. น้ำจิ้มอาจาดเจ_https://cooking.kapook.com/view227493.html': ['น้ำส้มสายชู 1 ถ้วยตวง',
#   'น้ำตาลทราย 1+1/4 ถ้วยตวง',
#   'เกลือป่นหยาบ 1 ช้อนชา',
#   'พริกชี้ฟ้าสีแดงซอยตามขวาง',
#   'แตงกวาซอย'],
#  '13. น้ำจิ้มเต้าหู้ทอด_https://cooking.kapook.com/view227493.html': ['น้ำตาลทราย 1/2 ถ้วยตวง',
#   'น้ำส้มสายชู 1/2 ถ้วยตวง',
#   'เกลือป่น 1 ช้อนชา',
#   'พริกชี้ฟ้าซอย 1 เม็ด',
#   'งาขาวคั่วบด 1 ช้อนโต๊ะ'],
#  'ยำไข่เค็มแดง ทำน้ำยำรสเข้มข้น โดย คุณ Kitty Chef สมาชิกเว็บไซต์พันทิปดอทคอม_https://cooking.kapook.com/view212552.html': ['ไข่แดงเค็มสุก (ไข่ไก่)',
#   'กุ้งสดลวกสุก',
#   'ขึ้นฉ่าย',
#   'หอมแขก',
#   'เม็ดมะม่วงหิมพานต์\n\t\xa0',
#   'น้ำตาลเคี่ยว 4 ช้อนโต๊ะ',
#   'น้ำปลา 2 ช้อนโต๊ะ',
#   'น้ำมะนาวคั้นสด ๆ 2 ช้อนโต๊ะ',
#   'น้ำปลาร้าต้มสุก 2 ช้อนโต๊ะ',
#   'มะนาวผ่าซีก',
#   'พริกจินดาโขลกละเอียด ประมาณ 15 เม็ด\n\t\xa0'],
#  'อาซาอี โบลว์ (Acai Breakfast Bowl)_https://cooking.kapook.com/view205111.html': ['อาซาอีเบอร์รี (Acai Berry)',
#   'นมอัลมอนด์',
#   'ผลไม้ตามฤดูกาล หรือผลไม้ตามชอบ เช่น แก้วมังกร กล้วยหอม กีวี มะม่วง สตรอว์เบอร์รี ทับทิม ลูกฟิกส์ บลูเบอร์รี\xa0',
#   'โกจิเบอร์รี',
#   'มะพร้าวอบแห้ง',
#   'กราโนลา',
#   'อัลมอนด์อบ',
#   'เมล็ดแฟลกซ์'],
#  'สูตรจาก คุณแขมร อินเตอร์ สมาชิกเว็บไซต์พันทิปดอทคอม_https://cooking.kapook.com/view226139.html': ['บลูเบอร์รี 300 กรัม',
#   'น้ำตาลทราย 200 กรัม',
#   'น้ำเปล่า (1) 200 กรัม',
#   'แป้งข้าวโพด 40 กรัม',
#   'น้ำเปล่า (2) 80 กรัม',
#   'น้ำมะนาว (ใส่หรือไม่ใส่ก็ได้)'],
#  '1. กล้วยปิ้ง_https://cooking.kapook.com/view225557.html': ['กล้วยน้ำว้า'],
#  '2. หัวกุ้ง คางกุ้งอบกรอบ_https://cooking.kapook.com/view225557.html': ['หัวกุ้ง (ตัดส่วนปาก ตา และหนวดออก)',
#   'คางกุ้ง (ส่วนที่เป็นขาแข็งอยู่ติดกับหัว ล้างให้สะอาด เอาขี้สีแดง ๆ สิ่งสกปรกออก ผึ่งแห้งค่ะ)',
#   'เกลือ',
#   'พริกไทย',
#   'แป้งมัน',
#   'น้ำมันงา (หรือน้ำมันอื่น ๆ ที่ชอบ)'],
#  '3. หมูแดดเดียว_https://cooking.kapook.com/view225557.html': ['หมูหั่นเส้น 500 กรัม',
#   'พริกไทยป่น 1 ช้อนชา',
#   'น้ำมันหอย 2 ช้อนโต๊ะ',
#   'ซอสปรุงรส 2 ช้อนโต๊ะ',
#   'นมสด 2 ช้อนโต๊ะ',
#   'น้ำมันงา 1 ช้อนโต๊ะ',
#   'เม็ดผักชี (ใส่หรือไม่ใส่ก็ได้)'],
#  '4. หมูกรอบ_https://cooking.kapook.com/view225557.html': ['หมูสามชั้น',
#   'น้ำส้มสายชู',
#   'เกลือป่น'],
#  '5. เฟรนช์ฟรายส์_https://cooking.kapook.com/view225557.html': ['เฟรนช์ฟรายส์',
#   'เกลือ'],
#  '6. นักเก็ต_https://cooking.kapook.com/view225557.html': ['นักเก็ต (สูตรที่ชอบ)'],
#  '7. ไข่เจียวหมูสับ_https://cooking.kapook.com/view225557.html': ['ไข่ไก่ 2 ฟอง',
#   'หมูสับ หรือเครื่องเคราอื่น ๆ ตามชอบ',
#   'ซอสปรุงรส'],
#  '8. ไก่ทอดน้ำปลา_https://cooking.kapook.com/view225557.html': ['ปีกกลางไก่ 500 กรัม',
#   'น้ำปลา 2 ช้อนโต๊ะ',
#   'พริกไทย'],
#  '9. สเต๊กปลา_https://cooking.kapook.com/view225557.html': ['ปลาแซลมอน หรือปลาอื่น ๆ',
#   'พริกไทย',
#   'เกลือ'],
#  '10. ผัดกะเพราหมู_https://cooking.kapook.com/view225557.html': ['หมูชิ้นหรือหมูสับ',
#   'พริก',
#   'กระเทียม',
#   'ซอสปรุงรส',
#   'ซอสหอยนางรม',
#   'ใบกะเพรา'],
#  'ชวนทำมันฝรั่งทอดคั่วพริกกระเทียม เปลี่ยนรสชาติธรรมดาให้จัดจ้านแบบคนไทย\nโดย คุณแขมร อินเตอร์ สมาชิกเว็บไซต์พันทิปดอทคอม_https://cooking.kapook.com/view223864.html': ['มันฝรั่งลูกเล็ก 250 กรัม',
#   'พริกสด 5-10 เม็ด',
#   'กระเทียม 5 กลีบ',
#   'ต้นหอม 1-2 ต้น',
#   'น้ำตาลทราย 1 ช้อนชา',
#   'เกลือ 1/4 ช้อนชา',
#   'งาขาวคั่ว 1-2 ช้อนโต๊ะ',
#   'น้ำมันพืช 1+1/2 ช้อนโต๊ะ'],
#  'กุ้งอบวุ้นเส้น หอมอร่อยมันเยิ้มทำง่าย ๆ ด้วยกระทะใบเดียว_https://cooking.kapook.com/view205267.html': ['กุ้งก้ามกราม',
#   'วุ้นเส้น 80 กรัม',
#   'น้ำตาลทราย 2 ช้อนโต๊ะ',
#   'ซีอิ๊วดำ 2 ช้อนชา',
#   'ซอสหอยนางรม 2 ช้อนโต๊ะ',
#   'ซีอิ๊วขาว 2 ช้อนโต๊ะ',
#   'น้ำซุป 1 ถ้วย',
#   'เบคอน',
#   'ขิงแก่',
#   'กระเทียม',
#   'พริกไทยดำ',
#   'พริกไทยขาว',
#   'ขึ้นฉ่าย',
#   'ต้นหอม\n\t\xa0'],
#  '1.  เห็ดเข็มทองทอด_https://cooking.kapook.com/view221349.html': ['เห็ดเข็มทอง',
#   'แป้งทอดกรอบ 1/2 ถ้วย',
#   'น้ำเย็นจัด 1/2 ถ้วย',
#   'น้ำมะขามเปียก 3 ช้อนโต๊ะ',
#   'น้ำตาลปี๊บ 1 ช้อนโต๊ะ',
#   'ซีอิ๊วขาว 2 ช้อนโต๊ะ'],
#  '2. ยำเห็ดทอดกรอบ_https://cooking.kapook.com/view221349.html': ['เห็ดตามชอบ 200 กรัม (เห็ดเข็มทอง เห็ดนางฟ้า หรือเห็ดชิเมจิ)',
#   'ไข่ไก่ 1 ฟองเล็ก',
#   'แป้งทอดกรอบ 2+1/2 ช้อนโต๊ะ',
#   'พริกไทยป่นเล็กน้อย',
#   'เกลือป่นเล็กน้อย',
#   'น้ำเย็นจัด 2+1/2 ช้อนโต๊ะ',
#   'น้ำมันสำหรับทอด',
#   'หมูสับรวนสุก 60 กรัม',
#   'น้ำที่ได้จากการรวนหมูประมาณ 1-2 ทัพพี',
#   'น้ำมะนาว 3 ช้อนโต๊ะ',
#   'น้ำปลา 2 ช้อนโต๊ะ',
#   'น้ำตาลทราย 1+1/2 ช้อนโต๊ะ (หรือน้ำตาลปี๊บ)',
#   'หอมแดงซอย 4 หัว',
#   'พริกขี้หนูแดงหั่น 6-7 เม็ด',
#   'ขึ้นฉ่ายซอย 1 ต้น'],
#  '3. เห็ดนางฟ้าทอดฝอย_https://cooking.kapook.com/view221349.html': ['เห็ดนางฟ้า',
#   'น้ำมันพืช (สำหรับทอด)',
#   'น้ำเปล่า',
#   'น้ำตาลปี๊บ 1 ช้อนโต๊ะพูน ๆ',
#   'ซีอิ๊วขาว',
#   'งาขาว 1/2 ช้อนโต๊ะ'],
#  '4. เทมปุระเห็ด_https://cooking.kapook.com/view221349.html': ['แป้งข้าวโพด 200 กรัม',
#   'เกลือป่น',
#   'พริกไทยป่น',
#   'น้ำเย็นจัด 250 มิลลิลิตร',
#   'น้ำมันพืช สำหรับทอด',
#   'เห็ดหอมสด ผ่าครึ่ง 50 กรัม',
#   'เห็ดเข็มทอง 50 กรัม',
#   'เห็ดออรินจิ ผ่าครึ่งตามยาว 50 กรัม',
#   'เห็ดนางรม 50 กรัม',
#   'เห็ดโคนญี่ปุ่น 50 กรัม',
#   'เกล็ดขนมปัง 200 กรัม',
#   'ซอสพริกสูตรเจ'],
#  '5. เห็ดนางฟ้าชุบแป้งทอด_https://cooking.kapook.com/view221349.html': ['เห็ดนางฟ้า',
#   'แป้งทอดกรอบ 1/2 ถ้วย',
#   'น้ำเย็นจัด 1/2 ถ้วย',
#   'เกลือป่น เล็กน้อย',
#   'พริกไทยป่น เล็กน้อย',
#   'น้ำมันพืช (สำหรับทอด)',
#   'น้ำมะขามเปียก',
#   'น้ำตาลปี๊บ',
#   'ซีอิ๊วขาว'],
#  '\xa0 \xa0 \xa0 \xa0 \xa0 วันนี้ป้าลองทำ “โดนัทใบเตย” จากโดนัทสีเดิม ๆ ลองเปลี่ยนกลิ่นเปลี่ยนสี เพิ่มทางเลือกความอร่อยไปอีก โดย ครัวป้ามารายห์_https://cooking.kapook.com/view203204.html': ['แป้งสาลีอเนกประสงค์ 500 กรัม',
#   'น้ำตาลทราย 60 กรัม',
#   'เกลือป่น 1 ช้อนชา',
#   'ยีสต์ 7 กรัม',
#   'ไข่ขาวเบอร์ 2 1 ฟอง',
#   'น้ำใบเตยคั้น 225 กรัม',
#   'สีผสมอาหารสีเขียว',
#   'เนยสด 60 กรัม\n\t\xa0'],
#  '1. ผัดซีอิ๊วหมู _https://cooking.kapook.com/view212521.html': ['น้ำมันพืช 2 ช้อนโต๊ะ',
#   'กระเทียมสับ 1 ช้อนโต๊ะ',
#   'เนื้อหมู หั่นเป็นชิ้นบาง 100 กรัม',
#   'ก๋วยเตี๋ยวเส้นใหญ่ (แยกออกเป็นเส้นบาง ๆ ) 200 กรัม',
#   'ซีอิ๊วดำ 1/2 ช้อนโต๊ะ',
#   'ซอสปรุงรส 2 ช้อนโต๊ะ',
#   'น้ำตาลทราย 1/2 ช้อนโต๊ะ',
#   'ไข่ไก่ 1 ฟอง',
#   'คะน้าหั่นแฉลบ 1 ต้น',
#   'แครอตหั่นบาง 50 กรัม',
#   'พริกไทยป่นสำหรับโรยหน้า\n\t\xa0'],
#  '2. ข้าวผัดปู_https://cooking.kapook.com/view212521.html': ['กระเทียมสับ',
#   'ไข่เป็ด 2 ฟอง',
#   'หอมใหญ่หั่นเต๋า',
#   'กรรเชียงปูม้าแกะสำเร็จ',
#   'ข้าวสวย (แช่เย็น)',
#   'ซีอิ๊วขาว',
#   'ซอสหอยนางรม',
#   'น้ำตาลทราย',
#   'ต้นหอมซอย',
#   'แตงกวา',
#   'พริกน้ำปลาสามรส',
#   'น้ำมันพืช\n\t\xa0'],
#  '3. ข้าวผัดทะเล_https://cooking.kapook.com/view212521.html': ['เนยสด หรือน้ำมันพืช สำหรับผัด',
#   'หอมใหญ่ซอย 1 ช้อนโต๊ะ',
#   'ไข่เป็ด หรือไข่ไก่ 1 ฟอง',
#   'กุ้งสด ปอกเปลือกผ่าหลัง 2 ตัว',
#   'ปลาหมึก หั่นแว่น 1 ตัว',
#   'ข้าวสวยหุงสุก (พักทิ้งไว้จนเย็นสนิท) 1 ถ้วย',
#   'เกลือป่น 1/4 ช้อนชา',
#   'พริกไทยป่น 1/4 ช้อนชา',
#   'น้ำส้มสายชู 1 ช้อนโต๊ะ',
#   'น้ำตาลทราย 1/2 ช้อนโต๊ะ',
#   'ต้นหอมซอย\n\t\xa0'],
#  '4. ข้าวผัดต้มยำ _https://cooking.kapook.com/view212521.html': ['พริกขี้หนูสับ',
#   'กระเทียมสับ',
#   'น้ำมันพืช (สำหรับผัด)',
#   'กุ้งสด (ล้างสะอาด แกะเปลือก ผ่าหลังให้เรียบร้อย)',
#   'ข่าสับ',
#   'ตะไคร้สับ',
#   'ใบมะกรูดซอย',
#   'หอมแดงซอย',
#   'มะเขือเทศ',
#   'เห็ดฟาง',
#   'ซีอิ๊วขาว',
#   'ซุปก้อน (คนอร์)',
#   'ซอสหอยนางรม',
#   'น้ำตาลทราย',
#   'มะนาว',
#   'น้ำพริกเผา',
#   'ข้าวสวย (ใช้ข้าวเย็นที่หุงมาแล้ว 1 คืน)',
#   'พริกไทยป่น เล็กน้อย',
#   'ต้นหอมซอย\n\t\xa0'],
#  '5. ข้าวผัดกุ้ง_https://cooking.kapook.com/view212521.html': ['ข้าวหอมมะลิหุงสุก',
#   'ผงรสดี 1 ช้อนชา',
#   'น้ำตาลทราย',
#   'ซอสถั่วเหลือง',
#   'กุ้งสด',
#   'ต้นหอมซอย\n\t\xa0'],
#  '6. ข้าวผัดหมูยอ_https://cooking.kapook.com/view212521.html': ['เนยสด หรือน้ำมันพืช',
#   'หอมใหญ่ซอย 1 ช้อนโต๊ะ',
#   'ไข่เป็ด หรือไข่ไก่ 1 ฟอง',
#   'หมูยอ หั่นชิ้นเล็ก',
#   'ข้าวสวยหุงสุก (พักทิ้งไว้จนเย็นสนิท) 1 ถ้วย',
#   'เกลือป่น 1/4 ช้อนชา',
#   'พริกไทยป่น 1/4 ช้อนชา',
#   'น้ำส้มสายชู 1 ช้อนโต๊ะ',
#   'น้ำตาลทราย 1/2 ช้อนโต๊ะ',
#   'ต้นหอมซอย\n\t\xa0'],
#  '7. ข้าวผัดมันกุ้ง_https://cooking.kapook.com/view212521.html': ['กระเทียมสับ',
#   'กุ้งสด (ปอกเปลือก ผ่าหลัง ดึงเส้นดำออก)',
#   'น้ำพริกมันกุ้ง 2 ช้อนโต๊ะ',
#   'ไข่ไก่ 1 ฟอง',
#   'ข้าวสวยหุงสุก (แช่เย็นหรือข้าวเก่า) 1 ถ้วย',
#   'น้ำมันหอย 1 ช้อนโต๊ะ',
#   'ซีอิ๊วขาว 2 ช้อนชา',
#   'น้ำปลา 2 ช้อนชา',
#   'น้ำตาลทราย 2 ช้อนชา',
#   'น้ำมันพืช (สำหรับผัด)\n\t\xa0'],
#  '8. สุกี้น้ำ_https://cooking.kapook.com/view212521.html': ['น้ำซุป',
#   'หมูหมักหรือเนื้ออื่น ๆ หมักตามชอบ',
#   'ผักต่าง ๆ',
#   'ไข่ไก่ 1 ฟอง',
#   'วุ้นเส้น แช่น้ำ',
#   'น้ำจิ้มสุกี้\n\t\xa0'],
#  '9. สุกี้แห้ง_https://cooking.kapook.com/view212521.html': ['ไข่ไก่ 3 ฟอง',
#   'น้ำมันหอย 2 ช้อนโต๊ะ',
#   'ซีอิ๊วขาว 2 ช้อนโต๊ะ',
#   'น้ำมันงา 2 ช้อนโต๊ะ',
#   'พริกไทยป่น 1 ช้อนโต๊ะ',
#   'หมูนุ่มหมัก 200 กรัม',
#   'ลูกชิ้นปลา 200 กรัม',
#   'เต้าหู้ปลา 200 กรัม',
#   'ปูอัด 200 กรัม',
#   'กุ้งสด 200 กรัม',
#   'น้ำมันพืช 2 ช้อนโต๊ะ',
#   'กระเทียมสับ',
#   'ผักตามชอบ',
#   'เห็ดตามชอบ',
#   'ขึ้นฉ่าย',
#   'ผักกาดขาว',
#   'บ๊อกฉ่อย',
#   'ต้นหอม',
#   'น้ำซุปไก่ 3 ถ้วย',
#   'วุ้นเส้น 2 ห่อเล็ก',
#   'น้ำจิ้มสุกี้\n\t\xa0'],
#  '10. ข้าวหมูกระเทียม_https://cooking.kapook.com/view212521.html': ['เนื้อหมูหั่นเป็นชิ้นพอคำ',
#   'กระเทียม',
#   'พริกไทยดำ',
#   'เกลือทะเล',
#   'น้ำมันสำหรับทอดหมู',
#   'ซีอิ๊วขาว',
#   'น้ำตาลทราย เล็กน้อย',
#   'น้ำมันสำหรับหมักหมู',
#   'แตงกวา',
#   'พริกน้ำปลา\n\t\xa0'],
#  '11. กุ้งผัดกระเทียมราดข้าว_https://cooking.kapook.com/view212521.html': ['มันหมู 3 ช้อนโต๊ะ',
#   'กระเทียม 2 ช้อนโต๊ะ\n\t\xa0',
#   'กุ้งขาว 16 ตัว (ขนาดกลาง 40 ตัวกิโล)',
#   'มันกุ้ง (จากกุ้ง 16 ตัว)',
#   'น้ำมันหอย ซีอิ๊วขาว และซอสปรุงรส อย่างละ 1/2 ช้อนโต๊ะ',
#   'กระเทียม ประมาณ 1 ช้อนโต๊ะ',
#   'รากผักชี ประมาณ 1 ช้อนชา',
#   'พริกไทยเม็ด ประมาณ 1 ช้อนชา\n\t\xa0'],
#  '12. ข้าวผัดพริกแกงหมู_https://cooking.kapook.com/view212521.html': ['ถั่วฝักยาว หั่นเป็นท่อนสั้น จำนวน 1 ถ้วย',
#   'น้ำมันพืช สำหรับผัด',
#   'น้ำพริกแกงเผ็ด 1 ช้อนโต๊ะ',
#   'น้ำปลา 1 ช้อนโต๊ะ',
#   'น้ำตาลปี๊บ หรือน้ำตาลทราย 1/2 ช้อนโต๊ะ',
#   'เนื้อหมูสามชั้น หรือหมูสับ หรือหมูกรอบ ตามชอบ 1 ถ้วย',
#   'ใบมะกรูดซอย 3 ใบ',
#   'พริกชี้ฟ้าแดง สำหรับแต่ง\n\t\xa0'],
#  '13. ราดหน้าหมู (หมี่กรอบ)_https://cooking.kapook.com/view212521.html': ['บะหมี่เหลือง',
#   'ยอดคะน้า',
#   'หมูหมัก (สูตรที่ชอบ)',
#   'น้ำซุป (หรือใช้ซุปก้อน)',
#   'เต้าเจี้ยว',
#   'น้ำตาลทราย',
#   'น้ำปลา',
#   'แป้งมันฮ่องกง (ถ้าไม่มีก็ใช้แป้งมันธรรมดา)',
#   'พริกไทย',
#   'กระเทียมเจียว',
#   'น้ำมันสำหรับทอด\n\t\xa0'],
#  '14. ผัดกะเพราเนื้อไข่ดาว_https://cooking.kapook.com/view212521.html': ['เนื้อสับ หรือเนื้อหั่นชิ้น',
#   'น้ำเปล่า',
#   'น้ำมันหอย',
#   'น้ำปลา',
#   'น้ำตาลทราย',
#   'กระเทียม',
#   'พริกสด',
#   'ใบกะเพรา',
#   'ไข่ดาว\n\t\xa0'],
#  '15. ก๋วยเตี๋ยวคั่วไก่ _https://cooking.kapook.com/view212521.html': ['เส้นก๋วยเตี๋ยว',
#   'สันในไก่',
#   'ปลาหมึกกรอบ',
#   'ไข่',
#   'น้ำมันหอย',
#   'ซีอิ๊วขาว',
#   'น้ำตาลทราย',
#   'พริกไทย',
#   'แป้งข้าวโพด',
#   'น้ำมันงา',
#   'ต้นหอมซอย',
#   'ผักกาดหอม',
#   'พริกไทย',
#   'ปาท่องโก๋ตัวเล็กทอดกรอบ',
#   'น้ำมัน\n\t\xa0'],
#  '16. ข้าวไข่เจียว_https://cooking.kapook.com/view212521.html': ['ไข่ไก่',
#   'น้ำมันหอย',
#   'ซอสปรุงรส',
#   'ต้นหอม\n\t\xa0'],
#  '17. เกี๊ยวน้ำ_https://cooking.kapook.com/view212521.html': ['น้ำมันงา 1 ช้อนชา',
#   'กระเทียมสับละเอียด 1 ช้อนชา',
#   'ขิงสดสับ 1 ช้อนชา',
#   'เห็ดหอมหั่นหรือสับ 150 กรัม',
#   'ซอสถั่วเหลือง 1/2 ช้อนโต๊ะ',
#   'ต้นหอมซอย 1 ช้อนโต๊ะ',
#   'น้ำเปล่า',
#   'แผ่นเกี๊ยวสำหรับห่อ\n\t\xa0',
#   'น้ำมันงา 2 ช้อนชา',
#   'กระเทียมสับละเอียด 1 ช้อนชา',
#   'ขิงสดขูด 1 ช้อนชา',
#   'หอมหัวใหญ่สับ 2 ช้อนโต๊ะ',
#   'น้ำซุปผัก 3 ถ้วยตวง',
#   'ซีอิ๊วขาว 1 ช้อนโต๊ะ',
#   'เกลือป่น 1/2 ช้อนโต๊ะ',
#   'กะหล่ำปลีหั่นชิ้น 50 กรัม',
#   'เห็ดหอมหั่นชิ้นบาง 30 กรัม',
#   'ต้นหอมซอย 1 ช้อนชา\n\t\xa0'],
#  '18. มะกะโรนีผัดซอส_https://cooking.kapook.com/view212521.html': ['มะกะโรนี 1 ถ้วย',
#   'เนื้อสัตว์ตามชอบ 200 กรัม',
#   'หอมใหญ่หั่น 1/2 หัว',
#   'มะเขือเทศหั่น 1 ลูก',
#   'ไข่ไก่ 3 ฟอง',
#   'ซอสมะเขือเทศ 1/2 ถ้วย',
#   'เกลือป่น เล็กน้อย',
#   'ต้นหอมหั่นท่อน\n\t\xa0'],
#  '19. มาม่าผัดขี้เมาหมูกรอบ_https://cooking.kapook.com/view212521.html': ['มาม่ารสชาติตามชอบ 1 ซอง',
#   'กระเทียม 3-5 กลีบ',
#   'พริกขี้หนูแดง ปริมาณตามชอบ',
#   'น้ำมันพืชสำหรับผัด',
#   'หมูกรอบ 100 กรัม',
#   'ข้าวโพดอ่อน (หั่นเฉียง) 50 กรัม',
#   'ผักคะน้า (หั่นเฉียง) 1 ต้น',
#   'พริกหยวกสีเขียว-แดง (หั่นเฉียง) อย่างละ 1 เม็ด',
#   'ซอสปรุงรส 1 ช้อนโต๊ะ',
#   'น้ำมันหอย 1 ช้อนโต๊ะ',
#   'น้ำตาลทราย 1 ช้อนชา',
#   'ใบกะเพราเด็ดเป็นใบ 1 ต้น\n\t\xa0'],
#  '20. ข้าวคะน้าหมูกรอบ_https://cooking.kapook.com/view212521.html': ['คะน้า 1 ต้น',
#   'หมูกรอบ (หั่นชิ้น) ตามชอบ',
#   'พริกขี้หนูทุบ ตามชอบ',
#   'กระเทียมสับ 1 ช้อนโต๊ะ',
#   'น้ำมันหอย 2 ช้อนชา',
#   'เต้าเจี้ยว 1 ช้อนโต๊ะ',
#   'น้ำตาลทราย 1 ช้อนชา',
#   'น้ำมันพืช (สำหรับผัด)\n\t\xa0'],
#  '1. น่องไก่ทอดน้ำปลา_https://cooking.kapook.com/view228132.html': ['น่องไก่ 1/2 กิโลกรัม',
#   'น้ำปลา 2 ช้อนโต๊ะ',
#   'น้ำมันพืช'],
#  '2. น่องไก่ทอดวิงส์แซ่บ (ผงลาบ)_https://cooking.kapook.com/view228132.html': ['น่องไก่',
#   'น้ำผสมเกลือเข้มข้น',
#   'แป้งโกกิ',
#   'แป้งสาลีอเนกประสงค์',
#   'ผงลาบ (รสดี)',
#   'พริกป่น',
#   'ไขไก่ 1 ฟอง',
#   'น้ำมันพืช'],
#  '3. น่องไก่ทอดกระเทียม_https://cooking.kapook.com/view228132.html': ['รากผักชี',
#   'กระเทียม',
#   'น่องไก่ (ล้างให้สะอาด)',
#   'พริกไทย',
#   'เกลือ',
#   'น้ำปลา',
#   'ซอสปรุงรส (ภูเขาทอง)',
#   'น้ำมันพืช'],
#  '4. น่องไก่ทอดน้ำปลา_https://cooking.kapook.com/view228132.html': ['น้ำปลา',
#   'พริกไทย',
#   'น่องไก่',
#   'น้ำมันพืช'],
#  '5. น่องไก่ทอดหาดใหญ่_https://cooking.kapook.com/view228132.html': ['น่องไก่',
#   'เม็ดผักชี 1+1/2 ช้อนชา',
#   'ยี่หร่า 1+1/2 ช้อนชา',
#   'กระเทียมไทย 1 หัว',
#   'น้ำผึ้ง 1 ช้อนชา',
#   'เหล้าจีน 2 ช้อนชา',
#   'เกลือป่น เล็กน้อย',
#   'น้ำมันถั่วเหลือง (สำหรับทอด)',
#   'หอมเจียว (โรยหน้า)'],
#  '6. น่องไก่วิงส์แซ่บ (ผงแซ่บ)_https://cooking.kapook.com/view228132.html': ['น่องไก่ 4 น่อง (หรือปริมาณตามชอบ)',
#   'เกลือป่น 1 ช้อนชา',
#   'น้ำตาลทราย 1 ช้อนชา',
#   'ไข่ไก่ 1 ฟอง',
#   'แป้งสาลีอเนกประสงค์ 1/2 ถ้วยตวง',
#   'พริกป่นละเอียด 1 ช้อนโต๊ะ',
#   'ผงมะนาว 1 ช้อนโต๊ะ',
#   'ผงปรุงรส (รสดี) 1 ช้อนโต๊ะ'],
#  '7. น่องไก่ทอดเกาหลี_https://cooking.kapook.com/view228132.html': ['น่องไก่ 1 กิโลกรัม',
#   'ไข่ไก่ 1 ฟอง',
#   'กระเทียมสับ 1 ช้อนโต๊ะ (ประมาณ 3-4 กลีบ)',
#   'งาขาวคั่ว 2 ช้อนโต๊ะ',
#   'ผงกระเทียม 1 ช้อนชา',
#   'เกลือ 1/2 ช้อนชา',
#   'พริกไทยดำบดหยาบ 1/2 ช้อนชา',
#   'แป้งทอดกรอบ 1 ถ้วยตวง',
#   'แป้งมัน 1 ถ้วยตวง',
#   'ผงฟู 1 ช้อนชา',
#   'น้ำมันพืช 1/2 ถ้วยตวง',
#   'น้ำส้มสายชูหมักจากแอปเปิล 1 ช้อนโต๊ะ',
#   'ซอสมะเขือเทศ 1/2 ถ้วยตวง',
#   'โคชูจัง 4 ช้อนโต๊ะ',
#   'น้ำผึ้ง 6 ช้อนโต๊ะ (1/4 ถ้วยตวง + 2 ช้อนโต๊ะ)'],
#  '8. น่องไก่ทอดซอสเทอริยากิ_https://cooking.kapook.com/view228132.html': ['น่องไก่เล็ก',
#   'เกลือป่น',
#   'พริกไทยป่น',
#   'แป้งสาลีอเนกประสงค์ (หรือแป้งทอดกรอบ)',
#   'ซอสเทอริยากิ',
#   'งาขาวคั่ว',
#   'น้ำมันพืชสำหรับทอด',
#   'ซีอิ๊วญี่ปุ่น 1/2 ถ้วย',
#   'สาเก 1/2 ถ้วย',
#   'มิริน 1/2 ถ้วย',
#   'น้ำตาลทราย 1 ช้อนโต๊ะ',
#   'ขิงแก่หั่นแว่น 2-3 ชิ้น'],
#  '9. น่องไก่ทอดลาบแซ่บ_https://cooking.kapook.com/view228132.html': ['ปีกไก่บน 600 กรัม',
#   'ซอสปรุงรส 2 ช้อนโต๊ะ',
#   'น้ำมันหอย 1 ช้อนโต๊ะ',
# ...
#   'อะโวคาโด หั่นเต๋า',
#   'ดอกเกลือ',
#   'น้ำมันมะกอก Extra Virgin',
#   'มะนาว\n\t\xa0'],
#  '5. ผัดขี้เมาอกไก่สับ_https://cooking.kapook.com/view205521.html': ['น้ำมันคาโนลา',
#   'กระเทียมสับ',
#   'เครื่องแกงผัดพริกขิง',
#   'อกไก่สับ',
#   'หน่อไม้',
#   'พริกแดงหั่นเฉียง',
#   'น้ำสะอาด',
#   'ดอกเกลือ',
#   'น้ำตาลหญ้าหวาน',
#   'ใบกะเพรา\n\t\xa0'],
#  '6. อกไก่คั่วตะไคร้_https://cooking.kapook.com/view205521.html': ['ตะไคร้',
#   'ใบมะกรูด',
#   'หอมแดง',
#   'น้ำมันคาโนลา',
#   'อกไก่สับ',
#   'หอมแขกสไลซ์',
#   'ต้นหอมหั่นท่อน',
#   'พริกแดง',
#   'ดอกเกลือ\n\t\xa0'],
#  '7. ลาบอกไก่_https://cooking.kapook.com/view205521.html': ['อกไก่',
#   'น้ำสะอาด',
#   'เห็ดหูหนูดำซอย',
#   'ดอกเกลือ',
#   'มะนาว',
#   'พริกป่น',
#   'ข้าวคั่ว',
#   'ต้นหอมซอย',
#   'ข่าสับละเอียด',
#   'สะระแหน่\n\t\xa0'],
#  '8. อกไก่ผัดพริกหยวก _https://cooking.kapook.com/view205521.html': ['อกไก่',
#   'น้ำมันงา',
#   'น้ำมันคาโนลา เล็กน้อย',
#   'กระเทียมสับ',
#   'หอมหัวใหญ่',
#   'เห็ดหูหนูดำ',
#   'พริกหยวก',
#   'น้ำสะอาด',
#   'ดอกเกลือ',
#   'น้ำตาลหญ้าหวาน\n\t\xa0'],
#  '9. อกไก่ผัดเห็ดชิเมจิดำ _https://cooking.kapook.com/view205521.html': ['อกไก่',
#   'น้ำมันงา',
#   'น้ำมันคาโนลา เล็กน้อย',
#   'กระเทียมสับ',
#   'เห็ดชิเมจิดำ',
#   'พริกหวานสีแดง',
#   'น้ำสะอาด',
#   'ดอกเกลือ',
#   'น้ำตาลหญ้าหวาน\n\t\xa0'],
#  '10. ยำไข่ขาว_https://cooking.kapook.com/view205521.html': ['ไข่ขาวพาสเจอร์ไรส์ (ใช้ของ CP)',
#   'ไก่สับ',
#   'เห็ดเข็มทอง',
#   'น้ำสะอาด',
#   'ดอกเกลือ',
#   'น้ำตาลหญ้าหวาน \xa0',
#   'มะนาว',
#   'หอมแขกซอย',
#   'ขึ้นฉ่าย\n\t\xa0'],
#  '11. ปีกไก่ทอดรีดน้ำมัน_https://cooking.kapook.com/view205521.html': ['ปีกไก่',
#   'ดอกเกลือ',
#   'น้ำมันรำข้าว\n\t\xa0'],
#  '12. ลาบไข่ขาว_https://cooking.kapook.com/view205521.html': ['ไข่ขาวพาสเจอร์ไรส์ (ใช้ของ CP)',
#   'ไก่สับ',
#   'เห็ดูหนูดำ',
#   'น้ำสะอาด',
#   'หอมแขกซอย',
#   'ข่าสับ (เล็กน้อย)',
#   'ต้นหอมซอย',
#   'สะระแหน่\n\t\xa0'],
#  '13. ผัดฟักทองใบโหระพา_https://cooking.kapook.com/view205521.html': ['น้ำมันคาโนลาเล็กน้อย',
#   'กระเทียมสับ',
#   'ฟักทอง',
#   'น้ำสะอาด',
#   'ไก่สับ',
#   'ไข่ไก่',
#   'ใบโหระพา\n\t\xa0'],
#  '14. กะเพราไข่ขาว_https://cooking.kapook.com/view205521.html': ['ไข่ขาวพาสเจอร์ไรส์ (ใช้ของ CP)',
#   'น้ำมันคาโนลาเล็กน้อย',
#   'กระเทียม',
#   'หอมใหญ่',
#   'พริก',
#   'ไก่สับ',
#   'แครอตหั่นเต๋า',
#   'เห็ดเข็มทอง',
#   'น้ำสะอาด',
#   'ดอกเกลือ',
#   'น้ำตาลหญ้าหวาน',
#   'ใบกะเพรา\n\t\xa0'],
#  '15. พะแนงอกไก่ขลุกขลิก _https://cooking.kapook.com/view205521.html': ['น้ำมันคาโนลา',
#   'พริกแกงพะแนง',
#   'หอมใหญ่',
#   'พริกหยวกสไลซ์',
#   'อกไก่ (หมักน้ำมันงา)',
#   'นมถั่วเหลือง',
#   'ดอกเกลือ',
#   'น้ำตาลหญ้าหวาน',
#   'ใบมะกรูดหั่นฝอย\n\t\xa0'],
#  '16. เขียวหวานอกไก่ผัดแห้ง_https://cooking.kapook.com/view205521.html': ['น้ำมันคาโนลา',
#   'พริกแกงเขียวหวาน',
#   'มะเขือเปราะ',
#   'อกไก่',
#   'นมถั่วเหลือง',
#   'ดอกเกลือ',
#   'น้ำตาลหญ้าหวาน',
#   'พริกแดง',
#   'ใบโหระพา\n\t\xa0'],
#  '17. น้ำพริกอ่องไก่สับ_https://cooking.kapook.com/view205521.html': ['น้ำมันคาโนลาเล็กน้อย',
#   'พริกแกง',
#   'ไก่สับ',
#   'มะเขือเทศปั่น (สีดา+ลูกท้อ)',
#   'กุ้งเคยตากแห้งไม่ฟอกสี',
#   'ดอกเกลือ',
#   'น้ำตาลหญ้าหวาน',
#   'มะเขือเทศเชอร์รี\n\t\xa0'],
#  '18. อกไก่ผัดเห็ดสามอย่าง_https://cooking.kapook.com/view205521.html': ['น้ำมันคาโนลาเล็กน้อย',
#   'กระเทียมสับ',
#   'อกไก่หมักน้ำมันงา',
#   'เห็ดเข็มทอง',
#   'เห็ดหอมแห้ง (แช่น้ำจนนิ่มแล้ว)',
#   'เห็ดชิเมจิดำ',
#   'แครอต',
#   'ดอกเกลือ',
#   'น้ำตาลหญ้าหวาน\n\t\xa0'],
#  '19. ผัดอกไก่ไข่ขาวใส่ใบโหระพา_https://cooking.kapook.com/view205521.html': ['ไข่ขาวพาสเจอร์ไรส์ (ใช้ของ CP)',
#   'น้ำมันคาโนลา',
#   'กระเทียมสับ',
#   'พริกสับ',
#   'น้ำสะอาด',
#   'ดอกเกลือ',
#   'น้ำตาลหญ้าหวาน',
#   'ใบโหระพา\n\t\xa0'],
#  '20. อกไก่ผัดผงกะหรี่_https://cooking.kapook.com/view205521.html': ['อกไก่',
#   'ผงกะหรี่ Nize',
#   'ไข่ไก่',
#   'น้ำมันคาโนลาเล็กน้อย',
#   'กระเทียมสับ',
#   'หอมใหญ่สไลซ์',
#   'แครอต',
#   'นมถั่วเหลือง',
#   'ดอกเกลือ',
#   'น้ำตาลหญ้าหวาน\n\t\xa0'],
#  '21. อกไก่กระเทียม_https://cooking.kapook.com/view205521.html': ['อกไก่',
#   'กระเทียมสับ',
#   'ผงพริกไทยดำ Nize',
#   'น้ำมันคาโนลา',
#   'น้ำตาลหญ้าหวาน',
#   'น้ำสะอาด',
#   'ดอกเกลือ',
#   'กระเทียมสับ\n\t\xa0'],
#  '22. ผัดพริกแกงอกไก่_https://cooking.kapook.com/view205521.html': ['น้ำมันคาโนลาเล็กน้อย',
#   'กระเทียมสับ',
#   'พริกแกงแดง',
#   'อกไก่',
#   'ถั่วฝักยาวที่ลวก',
#   'นมถั่วเหลือง',
#   'ดอกเกลือ',
#   'น้ำตาลหญ้าหวาน',
#   'พริกชี้ฟ้าแดง',
#   'ใบโหระพา\n\t\xa0'],
#  '23. ผัดกะเพราปลาทูน่า_https://cooking.kapook.com/view205521.html': ['น้ำมันคาโนลาเล็กน้อย',
#   'กระเทียม',
#   'พริก',
#   'หอมหัวใหญ่',
#   'ใบกะเพรา',
#   'แครอต',
#   'เห็ดเข็มทอง',
#   'ปลาทูน่าในน้ำแร่',
#   'ดอกเกลือ',
#   'น้ำตาลหญ้าหวาน',
#   'ถั่วฝักยาว\n\t\xa0'],
#  '24. อกไก่ผัดขิง_https://cooking.kapook.com/view205521.html': ['น้ำมันคาโนลา',
#   'กระเทียม',
#   'อกไก่หมักน้ำมันงา',
#   'เห็ดหูหนูดำซอย',
#   'แครอต',
#   'พริกหยวก',
#   'ขิงซอย',
#   'ต้นหอม',
#   'น้ำสะอาด',
#   'ดอกเกลือ',
#   'น้ำตาลหญ้าหวาน\n\t\xa0'],
#  '25. ปลาดอรี่ผัดฉ่า_https://cooking.kapook.com/view205521.html': ['พริกแกงผัดพริกขิง',
#   'กระชาย',
#   'เห็ดออรินจิ',
#   'ปลาดอรี่',
#   'พริกไทยอ่อน',
#   'ใบมะกรูด',
#   'ดอกเกลือ',
#   'น้ำตาลหญ้าหวาน',
#   'ใบโหระพา',
#   'กระชาย',
#   'โหระพา',
#   'ใบมะกรูด\n\t\xa0'],
#  '26. ปลาดอรี่นึ่งมะนาว_https://cooking.kapook.com/view205521.html': ['กะหล่ำปลีซอย',
#   'เห็ดเข็มทอง',
#   'เห็ดออรินจิ',
#   'ปลาดอรี่',
#   'ขึ้นฉ่าย\n\t\xa0',
#   'กระเทียมสด',
#   'กระเทียมดอง',
#   'พริกแดง',
#   'รากผักชี',
#   'ดอกเกลือ',
#   'มะนาว',
#   'น้ำตาลหญ้าหวาน\n\t\xa0'],
#  '27. ห่อหมกปลาดอรี่_https://cooking.kapook.com/view205521.html': ['นมถั่วเหลือง',
#   'พริกแกงแดง',
#   'ไข่ไก่',
#   'ปลาดอรี่',
#   'ดอกเกลือ',
#   'น้ำตาลหญ้าหวาน',
#   'กะหล่ำปลี',
#   'ใบโหระพา',
#   'พริกแดง',
#   'ใบมะกรูดหั่นฝอย\n\t\xa0'],
#  '28. ผัดเปรี้ยวหวานอกไก่_https://cooking.kapook.com/view205521.html': ['น้ำมันคาโนลา',
#   'กระเทียม',
#   'หอมใหญ่',
#   'เห็ดออรินจิ',
#   'อกไก่หมักน้ำมันงา',
#   'สับปะรด',
#   'แตงกวา',
#   'น้ำมะเขือเทศปั่น',
#   'ดอกเกลือ',
#   'น้ำตาลหญ้าหวาน',
#   'มะเขือเทศ\n\t\xa0'],
#  '29. สเต๊กหมูสันนอก_https://cooking.kapook.com/view205521.html': ['หมูสันนอกสไลซ์',
#   'นมสด',
#   'สับปะรด',
#   'ดอกเกลือ',
#   'พริกไทย',
#   'เนยจืด',
#   'กระเทียมจีนบุบ',
#   'น้ำมันมะกอก Extra Virgin',
#   'โรสแมรี่\n\t\xa0'],
#  '30. เต้าหู้ไข่ทรงเครื่อง_https://cooking.kapook.com/view205521.html': ['เต้าหู้ไข่',
#   'น้ำมันคาโนลาเล็กน้อย',
#   'กระเทียมสับ',
#   'หอมแขกหั่นเต๋า',
#   'อกไก่สับ',
#   'แครอต',
#   'พริกหวานสีเหลือง',
#   'เห็ดหอมแห้งหั่นเต๋า',
#   'ถั่วแระญี่ปุ่น',
#   'ข้าวโพดอ่อน',
#   'มะเขือเทศปั่น',
#   'ดอกเกลือ',
#   'น้ำตาลหญ้าหวาน\n\t\xa0'],
#  '31. อกไก่ Spicy_https://cooking.kapook.com/view205521.html': ['อกไก่',
#   'ผงฟู',
#   'ดอกเกลือ',
#   'ผงปาปริก้า',
#   'เห็ดเข็มทอง',
#   'กระเทียมสับ',
#   'พริกซอย\n\t\xa0'],
#  '32. กะเพราผักรวมแซลมอนบด _https://cooking.kapook.com/view205521.html': ['น้ำมันคาโนลาเล็กน้อย',
#   'กระเทียม',
#   'พริกสดตำ',
#   'พริกแกงผัดพริกขิง',
#   'เห็ดออรินจิ',
#   'เห็ดเข็มทอง',
#   'ข้าวโพดอ่อน',
#   'แครอต',
#   'ดอกเกลือ',
#   'หญ้าหวาน',
#   'ถั่วฝักยาว',
#   'ใบกะเพรา',
#   'พริกชี้ฟ้าแดง',
#   'กะเพราทอด\n\t\xa0'],
#  '33. อกไก่ผัดไข่แดงเค็ม_https://cooking.kapook.com/view205521.html': ['อกไก่',
#   'ผงฟู',
#   'น้ำมัน',
#   'พริกหวานสีเหลือง',
#   'อกไก่',
#   'หอมใหญ่',
#   'กระเทียมสับ',
#   'หอมใหญ่',
#   'พริกหวานสีเหลือง',
#   'นมถั่วเหลือง',
#   'ไข่ไก่',
#   'ไข่แดงเค็ม',
#   'ดอกเกลือกับหญ้าหวาน',
#   'พริกชี้ฟ้าแดง',
#   'ขึ้นฉ่ายซอย\n\t\xa0'],
#  '34. ถั่วงอกผัดน้ำ_https://cooking.kapook.com/view205521.html': ['กุ้งเคยไม่ฟอกสีลงไป',
#   'กระเทียมสับ',
#   'น้ำมันคาโนลาเล็กน้อย',
#   'ถั่วงอก',
#   'แครอตซอย',
#   'ปลาข้าวสารอบ',
#   'ต้นหอมหั่นท่อน',
#   'น้ำสะอาด',
#   'ดอกเกลือ\n\t\xa0'],
#  '1. มาม่าต้มยำแห้ง _https://cooking.kapook.com/view214500.html': ['บะหมี่กึ่งสำเร็จรูปรสต้มยำน้ำข้น (ลวกเส้นพอสุก)',
#   'ผักกาดหอม',
#   'หมูสับ (นำไปรวนให้มีน้ำขลุกขลิก ใส่น้ำปลาลงไปนิดหน่อยให้ตัวหมูมีรสชาติ)',
#   'เบคอนทอดกรอบ',
#   'มะนาว 1 ซีก',
#   'ใบมะกรูด',
#   'พริกขี้หนูทุบ 4-5 เม็ด',
#   'ถั่วลิสงคั่วป่น',
#   'พริกป่นตามชอบ\n\t\xa0'],
#  '2. ผัดไทยกุ้งสด_https://cooking.kapook.com/view214500.html': ['ซอสผัดไทย',
#   'กุ้งสด (แกะเปลือกผ่าหลังเอาเส้นดำออก) 3-5 ตัว (ตามชอบ)',
#   'เต้าหู้เหลือง (หั่นเต๋า) 3 ช้อนโต๊ะ',
#   'ไชโป๊ (สับละเอียด) 2 ช้อนโต๊ะ',
#   'ก๋วยเตี๋ยวเส้นเล็ก (หรือเส้นจันท์) แช่น้ำจนนิ่ม',
#   'ถั่วงอกดิบ',
#   'ใบกุยช่าย (หั่นท่อน)',
#   'ไข่ไก่ 1 ฟอง',
#   'น้ำมันพืช (สำหรับผัด)',
#   'ถั่วลิสงคั่วบด (ตามชอบ)',
#   'ผักสด (สำหรับทานคู่)\n\t\xa0',
#   'น้ำตาลปี๊บ 2 ช้อนโต๊ะ',
#   'น้ำมะขามเปียก 2 ช้อนโต๊ะ',
#   'น้ำปลา 2 ช้อนโต๊ะ',
#   'พริกป่น 1 ช้อนชา (หรือความเผ็ดตามชอบ)\n\t\xa0'],
#  '3. กวยจั๊บญวน_https://cooking.kapook.com/view214500.html': ['ซี่โครงหมู 500 กรัม',
#   'ผงปรุงรสหมู สำหรับหมักหมู 1/2 ช้อนโต๊ะ',
#   'น้ำเปล่า 1 ลิตร',
#   'เส้นกวยจั๊บญวน 1 ห่อ',
#   'หมูยอหั่นเป็นเส้น 200 กรัม',
#   'ผงปรุงรสหมู สำหรับปรุงรส 1 ช้อนโต๊ะ',
#   'หอมเจียว 1 ช้อนชา',
#   'ต้นหอมซอย 1 ช้อนชา\n\t\xa0'],
#  '4. บะหมี่เกี๊ยวหมูแดง_https://cooking.kapook.com/view214500.html': ['อบเชย 2 แท่ง',
#   'ดอกโป๊ยกั๊ก 2 ดอก',
#   'กระเทียมสับละเอียด 1 ช้อนโต๊ะ',
#   'พริกไทยป่น 1 ช้อนชา',
#   'น้ำตาลทราย 2 ช้อนโต๊ะ',
#   'น้ำผึ้ง 2 ช้อนโต๊ะ',
#   'ซอสมะเขือเทศ 3 ช้อนโต๊ะ',
#   'น้ำมันหอย 2 ช้อนโต๊ะ',
#   'ซีอิ๊วขาว 2 ช้อนโต๊ะ',
#   'เกลือป่น 1/2 ช้อนโต๊ะ',
#   'สีผสมอาหารสีส้มเล็กน้อย',
#   'น้ำเปล่า',
#   'หมูสันใน ใช้ส้อมจิ้มให้ทั่วชิ้น (น้ำหนักประมาณ 500 กรัม) 1 ชิ้น\n\t\xa0',
#   'รากผักชี 2 ราก',
#   'กระเทียม 1 ช้อนโต๊ะ',
#   'พริกไทยเม็ด 1 ช้อนชา',
#   'เนื้อหมูสับ 200 กรัม',
#   'เนื้อกุ้งสับ 100 กรัม',
#   'แป้งข้าวโพด 1 ช้อนชา',
#   'ซีอิ๊วขาว 1 ช้อนโต๊ะ',
#   'แผ่นเกี๊ยว 1 ห่อ',
#   'น้ำซุปกระดูกหมู (ใส่น้ำลงในหม้อ นำขึ้นตั้งไฟ ใส่กระดูกหมูลงต้มจนเดือด เคี่ยวด้วยไฟอ่อนไปเรื่อย ๆ )',
#   'ผักกวางตุ้ง หั่นท่อนสั้น 100 กรัม',
#   'บะหมี่ไข่ 1 ห่อ',
#   'หมูแดงหั่นเป็นชิ้น',
#   'กระเทียมเจียว',
#   'ต้นหอมซอย',
#   'พริกไทยป่น\n\t\xa0'],
#  '5. เส้นหมี่กะทิสีชมพู_https://cooking.kapook.com/view214500.html': ['ไข่ 2 ฟอง',
#   'กะทิ 2 ถ้วย',
#   'หอมแดงสับ 1/2 ถ้วย',
#   'หมูสับ 200 กรัม',
#   'กุ้งสับ 200 กรัม',
#   'เต้าเจี้ยว 4 ช้อนโต๊ะ',
#   'น้ำมะขามเปียก 4 ช้อนโต๊ะ',
#   'พริกป่น 1 ช้อนโต๊ะ',
#   'น้ำตาลปี๊บ 3 ช้อนโต๊ะ',
#   'เต้าหู้แข็งหั่นเต๋า 1/2 ถ้วย',
#   'ซอสมะเขือเทศ 3 ช้อนโต๊ะ',
#   'ซอสเย็นตาโฟ 3 ช้อนโต๊ะ',
#   'เส้นหมี่ 200 กรัม',
#   'กุยช่าย 1 ถ้วย',
#   'ถั่วงอก 1 ถ้วย',
#   'กุยช่าย สำหรับแต่ง',
#   'ถั่วงอก สำหรับแต่ง',
#   'พริกชี้ฟ้าแดง สำหรับแต่ง',
#   'ถั่วลิสงคั่วบด 4 ช้อนโต๊ะ',
#   'พริกป่น\n\t\xa0'],
#  '6. เส้นใหญ่ผัดซีอิ๊วกุ้งไก่_https://cooking.kapook.com/view214500.html': ['เส้นใหญ่ 100 กรัม (ลอกเป็นแผ่นออกจากกัน)',
#   'กุ้งสด (ปอกเปลือกผ่าหลังดึงเส้นดำออก) 3 ตัว',
#   'อกไก่หั่นชิ้น 100 กรัม',
#   'ไข่ไก่ 1 ฟอง',
#   'คะน้าหั่นพอดีคำ 2 ต้น',
#   'กระเทียมสับ 1 ช้อนโต๊ะ',
#   'ซีอิ๊วดำหวาน 1 ช้อนชา',
#   'ซีอิ๊วขาว 1-2 ช้อนโต๊ะ',
#   'น้ำตาลทราย 1/2 ช้อนโต๊ะ',
#   'น้ำมันพืช 1 ช้อนโต๊ะ\n\t\xa0'],
#  '7. กวยจั๊บโบราณ_https://cooking.kapook.com/view214500.html': ['กระเทียมทุบ',
#   'รากผักชีทุบ',
#   'กระดูกหมู (สำหรับต้มซุป)',
#   'เกลือ',
#   'หมูสามชั้น',
#   'ไส้ใหญ่หมู',
#   'ม้ามหมูหั่นชิ้น',
#   'เต้าหู้ทอดกรอบ',
#   'ใบกุยช่าย (หั่นเป็นท่อนประมาณ 1 นิ้ว)',
#   'กระเทียมสับ',
#   'ถั่วงอก (เด็ดหาง)',
#   'ผงพะโล้',
#   'ซีอิ๊วขาว',
#   'น้ำมันหอย',
#   'ซีอิ๊วดำหวาน',
#   'เลือดไก่ (หั่นเป็นชิ้น ๆ)',
#   'ไข่ไก่หรือไข่เป็ดต้ม (แกะเปลือก)',
#   'แป้งมันหรือแป้งข้าวโพด (ละลายน้ำ)',
#   'เส้นกวยจั๊บ',
#   'เกลือป่น\n\t\xa0'],
#  '8. เส้นใหญ่ราดหน้า_https://cooking.kapook.com/view214500.html': ['เนื้อหมู 300 กรัม',
#   'ซีอิ๊วขาว 1 ช้อนโต๊ะ',
#   'น้ำมันหอย 1 ช้อนโต๊ะ',
#   'น้ำตาลทรายแดง 1 ช้อนชา\xa0\xa0 \xa0',
#   'แป้งข้าวโพด 1+1/2 ช้อนโต๊ะ',
#   'น้ำมันพืช และพริกไทยป่นเล็กน้อย สำหรับหมักหมู',
#   'ก๋วยเตี๋ยวเส้นใหญ่ 30 กรัม',
#   'ซีอิ๊วดำเล็กน้อยสำหรับผัดเส้น',
#   'กระเทียมสับ 1 ช้อนชา',
#   'เต้าเจี้ยว 1 ช้อนชา',
#   'น้ำ 1 ถ้วยตวง',
#   'ซีอิ๊วขาว',
#   'แป้งมันละลายน้ำ 2 ช้อนโต๊ะ',
#   'ผักคะน้า 150 กรัม',
#   'พริกไทยป่น\n\t\xa0'],
#  '9. ก๋วยเตี๋ยวเย็นตาโฟ_https://cooking.kapook.com/view214500.html': ['เส้นก๋วยเตี๋ยวตามชอบ',
#   'ผักบุ้งจีน หั่นเป็นท่อนสั้น ๆ',
#   'ลูกชิ้นรักบี้, ลูกชิ้นกุ้ง หรือลูกชิ้นอื่น ๆ ตามชอบ',
#   'ปลาเส้น หั่นเป็นชิ้นบาง ๆ',
#   'ปลาหมึกกรอบ',
#   'เลือดหมู (หั่นชิ้น)',
#   'เต้าหู้ทอด',
#   'น้ำซุปกระดูกหมู',
#   'เกลือ',
#   'น้ำตาลกรวด',
#   'รากผักชี',
#   'พริกไทยเม็ด (ทุบพอแตก)',
#   'กระเทียม (ทุบพอแตก)',
#   'หอมใหญ่',
#   'ซีอิ๊วขาว',
#   'หัวไช้เท้า\n\t\xa0'],
#  '10. ก๋วยเตี๋ยวหมูสับต้มยำ_https://cooking.kapook.com/view214500.html': ['กระดูกหมู 500 กรัม',
#   'หัวไช้เท้าหั่นเป็นชิ้นหนา 1 หัว',
#   'น้ำเปล่า',
#   'รากผักชีทุบ 2 ต้น',
#   'น้ำตาลกรวด 2 ช้อนโต๊ะ',
#   'เกลือป่น สำหรับปรุงรส\n\t\xa0',
#   'เต้าหู้ขาวแบบแข็งหั่น 4 ส่วน 1 ก้อน',
#   'น้ำมันพืช สำหรับทอดเต้าหู้',
#   'หมูสับ 300 กรัม',
#   'ตับหมู 200 กรัม',
#   'ก๋วยเตี๋ยวเส้นเล็ก (หรือเส้นตามชอบ) 1 ห่อ',
#   'ถั่วงอกเด็ดหาง',
#   'น้ำมันกระเทียมเจียว',
#   'กระเทียมเจียว',
#   'ตั้งฉ่าย',
#   'ถั่วลิสงคั่วบด',
#   'ต้นหอมซอย',
#   'ผักชีซอย',
#   'น้ำมะนาว',
#   'พริกไทย สำหรับโรยหน้า',
#   'พริกป่น\n\t\xa0'],
#  '11. ก๋วยเตี๋ยวเย็นตาโฟต้มยำ _https://cooking.kapook.com/view214500.html': ['พริกแดงสด 2 กำมือ',
#   'กระเทียมสด (แกะเปลือก) 1 ทัพพี',
#   'กระเทียมดอง (แบบแกะเปลือก) 1 ทัพพี (ใช้แบบแกะเปลือกเพื่อไม่ให้น้ำซอสมีเปลือกกระเทียมอยู่)',
#   'เต้าหู้ยี้ 10 ก้อน',
#   'เต้าเจี้ยว 1/2 ถ้วย',
#   'น้ำกระเทียมดอง 1/2 ถ้วย',
#   'น้ำส้มสายชู 1/2 ถ้วย',
#   'น้ำเปล่า 2 ถ้วย',
#   'เกลือป่น ปลายทัพพี',
#   'น้ำตาลทราย 1 ทัพพี',
#   'น้ำตาลปี๊บ\xa0 1 ทัพพี',
#   'สีผสมอาหารสีแดงเล็กน้อย',
#   'แป้งเท้ายายม่อม\n\t\xa0',
#   'น้ำซุปกระดูกหมู',
#   'เกลือ',
#   'น้ำตาลกรวด',
#   'รากผักชี',
#   'พริกไทยเม็ด (ทุบพอแตก)',
#   'กระเทียม (ทุบพอแตก)',
#   'หอมใหญ่ 1-2 หัว',
#   'ซีอิ๊วขาว',
#   'หัวไช้เท้า',
#   'ปลาหมึกแห้งย่างไฟ 2 ตัว (เพื่อให้ซุปหอมกลมกล่อม)\n\t\xa0',
#   'เกี๊ยวทอดกรอบ',
#   'ไก่กรอบ (ไก่ชุบแป้งสำเร็จรูปพร้อมปรุง)',
#   'พริกป่น',
#   'ถั่วป่น',
#   'น้ำตาลทราย',
#   'น้ำปลา',
#   'น้ำพริกเผา',
#   'พริกดอง',
#   'เส้นก๋วยเตี๋ยว',
#   'กุ้งลวก ลูกชิ้น เต้าหู้ปลา และอื่น ๆ ตามชอบ\n\t\xa0'],
#  '12. ผัดไทยไชยา_https://cooking.kapook.com/view214500.html': ['น้ำพริกเครื่องก๋วยเตี๋ยว 1 กิโลกรัม',
#   'หอมแดง 2 กิโลกรัม',
#   'มะขามเปียก 1/2 กิโลกรัม',
#   'กะทิ 4 กิโลกรัม',
#   'น้ำตาลปี๊บอย่างดี 5 กิโลกรัม',
#   'น้ำตาลทราย 1 กิโลกรัม',
#   'กะปิ',
#   'เกลือเม็ด',
#   'น้ำมันพืช\n\t\xa0',
#   'พริกแห้งเม็ดใหญ่ 1 กิโลกรัม',
#   'หอมแดง 3 กิโลกรัม',
#   'เกลือเม็ด\n\t\xa0',
#   'ก๋วยเตี๋ยวเส้นเล็กและเส้นหมี่ (ยี่ห้อที่นิยมคือ ตราดอกบัว)',
#   'ถั่วงอกดิบ หรือกะหล่ำปลีซอย',
#   'ใบกุยช่าย\n\t\xa0'],
#  '13. ผัดหมี่โคราช_https://cooking.kapook.com/view214500.html': ['หมูสามชั้น หั่นชิ้นพอคำ 150 กรัม',
#   'น้ำมันพืช',
#   'หอมแดงสับ 1 ช้อนโต๊ะ',
#   'กระเทียมสับ 1 ช้อนโต๊ะ',
#   'เต้าเจี้ยวอย่างดี 2 ช้อนโต๊ะ',
#   'น้ำมะขามเปียก 2 ช้อนโต๊ะ',
#   'ซีอิ๊วดำ 2 ช้อนชา',
#   'น้ำตาลมะพร้าว 1 ช้อนโต๊ะ',
#   'น้ำปลาอย่างดี 1 ช้อนโต๊ะ',
#   'น้ำสะอาด',
#   'เส้นหมี่โคราช ลวกน้ำร้อน 250 กรัม',
#   'ไข่เป็ด 2 ฟอง',
#   'ถั่วงอก 50 กรัม',
#   'ใบกุยช่ายหั่น 50 กรัม',
#   'แคบหมู ตามชอบ',
#   'พริกป่น ตามชอบ\n\t\xa0'],
#  '14. ผัดหมี่ฮ่องกงเจ_https://cooking.kapook.com/view214500.html': ['น้ำมันพืช 2 ช้อนโต๊ะ',
#   'เห็ดหอมสด หั่นเป็นชิ้น 100 กรัม',
#   'เต้าหู้เหลืองหั่นเป็นชิ้นเล็ก 100 กรัม',
#   'โปรตีนเกษตรแช่น้ำจนนุ่ม 100 กรัม',
#   'กะหล่ำปลีหั่นเป็นเส้น 100 กรัม',
#   'แครอตหั่นเป็นเส้น 1 ช้อนโต๊ะ',
#   'เส้นหมี่ฮ่องกงลวกสุก 300 กรัม',
#   'น้ำซุปผัก 1/4 ถ้วย',
#   'น้ำตาลทราย 1 ช้อนชา',
#   'ซีอิ๊วขาว 1 ช้อนโต๊ะ',
#   'ซอสเห็ดหอม 1 ช้อนโต๊ะ',
#   'พริกไทยป่นเล็กน้อย สำหรับปรุงรส\n\t\xa0'],
#  '15. เส้นหมี่ผัดผักกระเฉดทะเล_https://cooking.kapook.com/view214500.html': ['มันกุ้ง',
#   'น้ำเปล่า (สำหรับผสมซอส)',
#   'น้ำปลา',
#   'มะนาว',
#   'เส้นหมี่ขาวแช่น้ำพอนิ่ม',
#   'น้ำเปล่า (สำหรับลวกเส้น)',
#   'น้ำมันพืช',
#   'กระเทียมตำหยาบ',
#   'พริกขี้หนูตำหยาบ',
#   'น้ำตาลปี๊บ',
#   'กุ้ง',
#   'ปลาหมึก',
#   'ยอดอ่อนผักกระเฉด\n\t\xa0'],
#  'เคล็ดลับ_https://cooking.kapook.com/view196569.html': ['ใช้ไฟอ่อนในการย่าง สามารถย่างบนกระทะหรือเตาถ่านได้ทั้งสองแบบ ไม่ควรย่างจนสุกมากเพราะเนื้อปลาหมึกจะแห้ง เหนียว',
#   'เป็นเมนูที่ทำง่ายลองนำไปทำไว้กินเล่นยามว่าง หากใครไม่มีเตาถ่านก็ใช้กระทะเปิดไฟอ่อนค่อย ๆ ย่างจนสุก\n\t\xa0'],
#  'โดย คุณ Kitty Chef สมาชิกเว็บไซต์พันทิปดอทคอม_https://cooking.kapook.com/view202208.html': ['หมูบด',
#   'แป้งข้าวโพด',
#   'น้ำปลา',
#   'พริกป่น',
#   'มะนาว',
#   'ข้าวคั่ว',
#   'ต้นหอม',
#   'ผักชี',
#   'หอมแดง',
#   'ใบมะกรูด\n\t\xa0'],
#  'ปูไข่นึ่งนมสด โดย คุณ NUTCHANART_CH สมาชิกเว็บไซต์พันทิปดอทคอม_https://cooking.kapook.com/view195577.html': ['ปูไข่ 3 ตัว \xa0 \xa0',
#   'นมข้นจืด 5 ช้อนโต๊ะ \xa0',
#   'พริกขี้หนูสวน 25 เม็ด \xa0',
#   'กระเทียม 10 กลีบ \xa0',
#   'รากผักชี 3 ราก \xa0',
#   'น้ำตาลปี๊บ 1 ช้อนโต๊ะ\xa0',
#   'น้ำปลา 3 ช้อนโต๊ะ \xa0',
#   'น้ำมะนาว 4 ช้อนโต๊ะ \xa0',
#   'ผักชีสับ 1 ช้อนโต๊ะ \xa0',
#   'พริกขี้หนู',
#   'กระเทียม',
#   'รากผักชี',
#   'น้ำตาลปี๊บ',
#   'น้ำปลา',
#   'น้ำมะนาว',
#   'ผักชี']}

# %% [markdown]
# # Store crawling data to S3 for further utilization

# %%
store_data_on_s3(prefix="Kapook-recipe", source=BASE_URL, ext_data=ingredients, raw_data=raw_pages)
# Out:
# Storing the data is completed
