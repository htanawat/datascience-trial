# %%
# %%writefile app.py
from flask import Flask, Response, render_template, make_response, jsonify, request as req
from flask_cors import CORS
from boto3.dynamodb.conditions import Key, Attr
from dotenv import load_dotenv
import pandas as pd
import numpy as np
import psycopg2
import boto3
import json
import re
import os

load_dotenv('.env')
AWS_ACCESS_KEY_ID = os.getenv("AWS_ACCESS_KEY_ID")
AWS_SECRET_ACCESS_KEY = os.getenv("AWS_SECRET_ACCESS_KEY")

dynamodb = boto3.resource('dynamodb', region_name='ap-southeast-2',
  aws_access_key_id=AWS_ACCESS_KEY_ID,
  aws_secret_access_key=AWS_SECRET_ACCESS_KEY
)

table_prices = dynamodb.Table('IngredientPrices')

conn = psycopg2.connect(
    "dbname=eltrial user=top password=1234"
)

app = Flask(__name__)
CORS(app)

includes = re.compile("หมู|ไก่|วัว|^ไข่$|ไข่ไก่|^นม")
excludes = re.compile("นมข้นหวาน|ผง|คนอร์|มาม่า|คาร์เนชั่น|หมูกรอบ|กระดูก|ปู|^ซอส|^เครื่องเทศ|^เต้าหู้|อินทผาลัม|ลูกชิ้น|หมูแฮม|ไข่แดงเค็ม|น้ำมัน|คอร์|ไส้กรอก|หัวใจ|กระเพาะ|ปอด|รสดี|คนอ|น้ำซุป|หมูยอ|น้ำ|ซีอิ๊ว|ชุด|^พริกไทย|ซีอิ้ว|สต๊อก|แป้ง|^พริก|เลือด|ชุป|รากผักชี|บะหมี่กึ่งสำเร็จรูป|ข้นหวาน|กากหมู|นมข้น|หมูแดง|แคปหมู|มันหมู|^ซอส|นมถั่วเหลือง|\*\*|^เหล้าจีน|อัลมอนด์|หมูหยอง|สูตร|ซุปก้อน|^เครื่อง|ส่วนผสม|แคบหมู")
excludes_units = re.compile("สำหรับ|ครึ่1/2|ปริมานตามใจชอบ")

ingredient_kws = re.compile('pork_ขาหมู|pork_ซี่โครงหมู|pork_ตับหมู|pork_เนื้อก้อน|\
pork_เนื้อแดง|pork_เนื้อไหล่|pork_สะโพกหมู|pork_สันนอก|pork_สันใน|\
pork_สามชั้น|pork_ไส้ตันหมู|pork_ไส้ใหญ่หมู|pork_ไส้อ่อนหมู|pork_หมูบด|\
beef_ขอบกระด้ง|beef_ขี้ริ้ว|beef_เครื่องใน|beef_ดอกจอก|beef_น่อง|beef_ซี่โครง|\
beef_เนื้อแดง|beef_เนื้อปลีก|beef_เศษเนื้อ|beef_สันคอ|beef_เนื้อวัวบด|beef_เนื้อก้อน|\
beef_สันใน|beef_สันนอก|chicken_ไก่บ้าน|chicken_ไก่ทั้งตัว|chicken_ไก่ผ่าซีก|\
chicken_อกไก่|chicken_ซี่โครงไก่|chicken_ปีกบนไก่|chicken_ปีกกลางไก่|\
chicken_ปีกไก่เต็ม|chicken_น่องไก่|chicken_สะโพกไก่|chicken_เครื่องในไก่|\
chicken_ตีนไก่|chicken_เนื้อไก่บด|chicken_ไก่มีชีวิตหน้าฟาร์ม|eggs_ไข่ไก่เบอร์ 0|\
eggs_ไข่ไก่เบอร์ 1|eggs_ไข่ไก่เบอร์ 2|eggs_ไข่ไก่เบอร์ 3|eggs_ไข่ไก่เบอร์ 4|\
eggs_ไข่ไก่เบอร์ 5|eggs_ไข่ไก่ต้ม|eggs_ไข่ไก่คละหน้าฟาร์ม|นม')

ingredient_translate = {
    "หมูสับ": "pork_เนื้อก้อน",
    "เนื้อหมูบด": "pork_หมูบด",
    "หมูบด": "pork_หมูบด",
    "ไข่ไก่": "eggs_ไข่ไก่เบอร์ 2",
    "ไขไก่": "eggs_ไข่ไก่เบอร์ 2",
    "หมูสามชั้น": "pork_สามชั้น",
    "เนื้อหมู": "pork_เนื้อก้อน",
    "ปีกไก่บน": "chicken_ปีกบนไก่", 
    "นมสด": "นม",
    "สันในไก่": "chicken_อกไก่",
    "อกไก่": "chicken_อกไก่",
    "มันไก่": "chicken_น่องไก่",
    "ไก่สด": "chicken_อกไก่",
    "สะโพกไก่": "chicken_สะโพกไก่",
    "สันคอหมู": "pork_เนื้อก้อน",
    "คอหมู": "pork_เนื้อก้อน",
    "ซี่โครงหมู": "pork_ซี่โครงหมู",
    "ปีกไก่กลาง": "chicken_ปีกกลางไก่",
    "ไก่อก": "chicken_อกไก่",
    "หมูสันนอก": "pork_สันนอก",
    "ตับไก่": "chicken_เครื่องในไก่",
    "เนื้อไก่": "chicken_อกไก่",
    "ปีกไก่": "chicken_ปีกไก่เต็ม",
    "หมูส่วนสะโพก": "pork_สะโพกหมู",
    "หมูสันใน": "pork_สันใน",
    "เนื่อหมู": "pork_เนื้อก้อน",
    "เนื้อสันในวัว": "beef_สันใน",
    "เนื้อวัว": "beef_เนื้อก้อน",
    "โครงไก่": "chicken_ซี่โครงไก่",
    "สันนอกหมู": "pork_สันนอก",
    "น่องไก่": "chicken_น่องไก่",
    "ไก่บด": "chicken_เนื้อไก่บด",
    "ปีกบนไก่": "chicken_ปีกบนไก่",
    "หมูบก": "pork_หมูบด",
    "หมูสามชั้น": "pork_สามชั้น",
    "ใส้หมู": "pork_ไส้อ่อนหมู",
    "ไส้หมู": "pork_ไส้อ่อนหมู",
    "หนังไก่": "chicken_น่องไก่",
    "ไส้ใหญ่หมู": "pork_ไส้ใหญ่หมู",
    "เอ็นข้อไก่": "chicken_ตีนไก่",
    "สันในหมู": "pork_สันใน",
    "ตีนไก่": "chicken_ตีนไก่",
    "ตับหมู": "pork_ตับหมู",
    "ปีกกลางไก่": "chicken_ปีกกลางไก่",
    "ไก่สับ": "chicken_น่องไก่",
    "หนังหมู": "pork_สามชั้น",
}

default_ingredient = {
    "นม": "นม",
    "ไข่": "eggs_ไข่ไก่เบอร์ 2",
    "หมู": "pork_เนื้อก้อน",
    "ไก่": "chicken_น่องไก่",
    "วัว": "beef_เนื้อก้อน",
}

frac_pattern = re.compile("\d+\/\d+")
num_pattern = re.compile("\d+")

ingd_patterns = []
for u in ingredient_translate:
        ingd_patterns.append(u)
        
ingd_pattern = re.compile("|".join(ingd_patterns))

ingd_default_patterns = []
for u in default_ingredient:
        ingd_default_patterns.append(u)
        
ingd_default_pattern = re.compile("|".join(ingd_default_patterns))

units = {
    "กรัม": (0.001, "กก."),
    "g": (0.001, "กก."),
    "grams": (0.001, "กก."),
    "กระม": (0.001, "กก."),
    "กิโล": (1., "กก."),
    "ฟอง": "ฟอง",
    "ชิ้นใหญ่": "unknown",
    "มิลลิลิตร": (0.001, "ลิตร"),
    "ก้อน": "unknown",
    "ถ้วย": "unknown",
    "ช้อนโต๊ะ": (0.015, "ลิตร"),
    "ชิ้น": "unknown",
    "กร้ม": (0.001, "กก."),
    "ml": (0.001, "ลิตร"),
    "kg": (1, "กก."),
    "กก": (1, "กก."),
    "ขีด": (0.1, "กก."),
    "กิโลกรัม": (1, "กก."),
    "กรม": (0.001, "กก."),
    "ท่อน": "unknown",
    "โครง": "unknown",
    "ใบ": "ฟอง",
    "แพ็ค": "unknown",
    "mg": (0.000001, "กก."),
    "ก$": (0.001, "กก."),
    "เส้น": "unknown",
    "น่อง": "unknown",
    "ปีก": "unknown",
    "ขา": "unknown",
    "วง": "unknown",
    "ตัว": "unknown",
    "ขึด": "unknown",
    "ซอง": "unknown",
    "อก": "unknown",
    "จาน": "unknown",
    "โล": (1, "กก."),
    "แท่ง": "unknown",
    "บาท": "baht",
    "ไม้": "unknown",
    "ดุ้นสั้น": "unknown",
    "ตีน": "unknown",
    "Kg": (1, "กก."),
    "ทัพพี": "unknown",
    "ฟอว": "unit",
    "ถาด": "unknown",
    "ช้ินโต๊ะ": (0.015, "กก."),
    "ห่อ": "unknown",
    "ลูก": "unit",
    "KG": (1., "กก."),
    "แผ่น": "unknown",
    "G": (0.001, "กก."),
    "ตามสะดวก": "unknown",
    "ชต": (0.015, "กก."),
    "pack": "unknown",
    "พวง": "unknown",
    "ถุง": "unknown",
    "pcs": "ฟอง",
    "สไลด์": "unknown",
    "โคร": "unknown",
    "ฟ$": "ฟอง",
    "ชาม": "unknown",
    "แพค": "unknown",
    "ขีเ": (0.1, "กก."),
    "ช้อน$": "unknown",
    "อัน": "unknown",
    "แพ๊ค": "unknown",
    "ครึ่งโล": (0.5, "กก."),
    "หม้อ": "unknown",
    "กล่อง": "unknown",
    "กรีม": (0.001, "กก."),
    "กนัม": (0.001, "กก."),
    "สะโพก": "unknown",
    "ซีก": "unknown",
    "ขรด": "unknown",
    "ชีด": "unknown",
    "หยิบมือ": "unknown",
    "โคลง": "unknown",
    "มือ": "unknown",
    "ถต": (0.14, "กก."),
    "กรับ": (0.001, "กก."),
    "แ$": (0.001, "กก."),
    "กม": (0.001, "กก."),
    "ชุด": "unknown",
    "ช้อนโตณะ": (0.015, "กก."),
    "หอง": "ฟอง",
    "หาง": "unknown",
    "ช้อนโตํะ": "unknown",
    "ที่": "unknown",
}

patterns = [
    "\d+ - \d+\ *{}",
    "\d+-\d+\ *{}",
    "\d+\ *{}",
    "\d+\t*{}",
]

unit_patterns = []
for u in units:
    for p in patterns:
        unit_patterns.append(p.format(u))
        
unit_pattern = re.compile("|".join(unit_patterns))
unit_type_pattern = re.compile("|".join(list(units.keys())))

@app.route('/')
def search():
    kw = req.args.get('keyword')
    cursor = conn.cursor()
    cursor.execute(f"SELECT menu_name, ingredient_json FROM ingredients where menu_name ilike '%{kw}%';")
    result = cursor.fetchall()
    cursor.close()
    
    if len(result) == 0:
        return '{"msg": "not found."}'
    else:
        menus = {f"{i+1} {k}": json.loads(l) for i, (k, l) in enumerate(result)}
#         print(menus)
        
    queried_prices = {}
    menu_prices = {}
    show_str = {}
    ingd_prices = {}

    for m in menus:
        date_price = None
        show_str[m] = []
        for ig in menus[m]:
            _use_to_cal = False
            _ig = ig.split(" ")[0].replace("\u200b", "").replace("(", "").replace(")", "")
            if includes.search(_ig) and not excludes.search(_ig) and not excludes_units.search(menus[m][ig]):
                ingd_type = ingd_pattern.search(_ig)
                ingd_default_type = ingd_default_pattern.search(_ig)
                if ingd_type or ingd_default_type:
                    if ingd_type:
                        str_ingd_type = ingredient_translate[ingd_type.group()]
                    else:
                        str_ingd_type = default_ingredient[ingd_default_type.group()]

                    unit_type = unit_pattern.search(menus[m][ig])
                    if unit_type:
                        str_unit_type = unit_type.string
                        unit_type_p = unit_type_pattern.search(menus[m][ig]).group()
    #                     print(unit_type_p)
                        try:
                            common_unit_type = units[unit_type_p]
                        except:
                            common_unit_type = units[unit_type_p+"$"]

                        if common_unit_type == "unknown":
                            show_str[m].append(f"*{_ig} {menus[m][ig]} (unknown unit type)")
                        else:
                            _frac = frac_pattern.search(menus[m][ig])
                            _num = num_pattern.search(menus[m][ig])
                            if _frac or _num:

                                _use_to_cal = True

                                if _frac:
                                    fr = _frac.group()
                                    magn = float(fr.split("/")[0])/float(fr.split("/")[1])
                                else:
                                    magn = float(_num.group())

                                if str_ingd_type not in queried_prices:
                                    prices = pd.DataFrame(dict(table_prices.query(KeyConditionExpression=Key("type").eq(str_ingd_type) & Key("date").between("2020-07-23", "2020-08-22")).items())["Items"])
                                    prices["price"] = prices["price"].astype(float)
                                    queried_prices[str_ingd_type] = prices
                                else:
                                    prices = queried_prices[str_ingd_type]

                                if not isinstance(date_price, np.ndarray):
                                    date_price = np.zeros([prices.shape[0]])

                                if isinstance(common_unit_type, tuple):
                                    show_str[m].append(f"*{_ig} {menus[m][ig]} ({common_unit_type[1]})")
                                    magn *= common_unit_type[0]
                                    date_price += (prices["price"] * magn).values
                                else:
                                    show_str[m].append(f"*{_ig} {menus[m][ig]} ({common_unit_type})")
                                    if common_unit_type == "บาท":
                                        date_price += magn
                                    else:
                                        date_price += (prices["price"] * magn).values

            if not _use_to_cal:
                show_str[m].append(f"{_ig} {menus[m][ig]}")


    #                             if str_ingd_type == "นม":
    #                             print(prices)
    #                             print(str_ingd_type, magn, common_unit_type)

        
#         print(type(date_price))
        if isinstance(date_price, np.ndarray) and not np.sum(date_price) == 0:
            menu_prices[m] = date_price.tolist()
        else:
            menu_prices[m] = 0
        
    if len(queried_prices) == 0:
        qdate = []
    else:
        k = list(queried_prices.keys())[0]
        qdate = queried_prices[k]["date"].values.tolist()
        
    return {
        "menu_prices": menu_prices,
        "queried_prices": {k:queried_prices[k]["price"].values.tolist() for k in queried_prices},
        "date": qdate,
        "show_str": show_str,
    }

if __name__ == '__main__':
    app.debug = True
    app.run(host='0.0.0.0', port=8000)
# Out:
# Overwriting app.py

# %%
# !python3 app.py
# Out:
#  * Serving Flask app "app" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
#  * Running on http://0.0.0.0:8000/ (Press CTRL+C to quit)
#  * Restarting with stat
#  * Debugger is active!
#  * Debugger PIN: 257-460-940
# 49.230.13.211 - - [26/Jul/2020 11:56:55] "GET /?keyword=วุ้นเส้นหมูกรอบคั่วพริกเกลือ HTTP/1.1" 200 -
# 49.230.13.211 - - [26/Jul/2020 11:57:05] "GET /?keyword=หมี่กรอบผัดซีอิ๊ว HTTP/1.1" 200 -

# %%
# import subprocess as sp

# server = sp.Popen("FLASK_APP=app.py flask run", shell=True)
# server

# %%
from flask import Flask, Response, render_template, make_response, jsonify, request as req
from boto3.dynamodb.conditions import Key, Attr
from dotenv import load_dotenv
import pandas as pd
import numpy as np
import psycopg2
import boto3
import json
import re
import os

load_dotenv('.env')
AWS_ACCESS_KEY_ID = os.getenv("AWS_ACCESS_KEY_ID")
AWS_SECRET_ACCESS_KEY = os.getenv("AWS_SECRET_ACCESS_KEY")

dynamodb = boto3.resource('dynamodb', region_name='ap-southeast-2',
  aws_access_key_id=AWS_ACCESS_KEY_ID,
  aws_secret_access_key=AWS_SECRET_ACCESS_KEY
)

table_prices = dynamodb.Table('IngredientPrices')

conn = psycopg2.connect(
    "dbname=eltrial user=top password=1234"
)

kw = ""
cursor = conn.cursor()
cursor.execute(f"SELECT menu_name, ingredient_json FROM ingredients where menu_name ilike '%{kw}%';")
result = cursor.fetchall()
cursor.close()

# %%
includes = re.compile("หมู|ไก่|วัว|^ไข่$|ไข่ไก่|^นม")
excludes = re.compile("นมข้นหวาน|ผง|คนอร์|มาม่า|คาร์เนชั่น|หมูกรอบ|กระดูก|ปู|^ซอส|^เครื่องเทศ|^เต้าหู้|อินทผาลัม|ลูกชิ้น|หมูแฮม|ไข่แดงเค็ม|น้ำมัน|คอร์|ไส้กรอก|หัวใจ|กระเพาะ|ปอด|รสดี|คนอ|น้ำซุป|หมูยอ|น้ำ|ซีอิ๊ว|ชุด|^พริกไทย|ซีอิ้ว|สต๊อก|แป้ง|^พริก|เลือด|ชุป|รากผักชี|บะหมี่กึ่งสำเร็จรูป|ข้นหวาน|กากหมู|นมข้น|หมูแดง|แคปหมู|มันหมู|^ซอส|นมถั่วเหลือง|\*\*|^เหล้าจีน|อัลมอนด์|หมูหยอง|สูตร|ซุปก้อน|^เครื่อง|ส่วนผสม|แคบหมู")
excludes_units = re.compile("สำหรับ|ครึ่1/2|ปริมานตามใจชอบ")

# %%
menus = {k: json.loads(l) for k, l in result}

# %%
ingredient_kws = re.compile('pork_ขาหมู|pork_ซี่โครงหมู|pork_ตับหมู|pork_เนื้อก้อน|\
pork_เนื้อแดง|pork_เนื้อไหล่|pork_สะโพกหมู|pork_สันนอก|pork_สันใน|\
pork_สามชั้น|pork_ไส้ตันหมู|pork_ไส้ใหญ่หมู|pork_ไส้อ่อนหมู|pork_หมูบด|\
beef_ขอบกระด้ง|beef_ขี้ริ้ว|beef_เครื่องใน|beef_ดอกจอก|beef_น่อง|beef_ซี่โครง|\
beef_เนื้อแดง|beef_เนื้อปลีก|beef_เศษเนื้อ|beef_สันคอ|beef_เนื้อวัวบด|beef_เนื้อก้อน|\
beef_สันใน|beef_สันนอก|chicken_ไก่บ้าน|chicken_ไก่ทั้งตัว|chicken_ไก่ผ่าซีก|\
chicken_อกไก่|chicken_ซี่โครงไก่|chicken_ปีกบนไก่|chicken_ปีกกลางไก่|\
chicken_ปีกไก่เต็ม|chicken_น่องไก่|chicken_สะโพกไก่|chicken_เครื่องในไก่|\
chicken_ตีนไก่|chicken_เนื้อไก่บด|chicken_ไก่มีชีวิตหน้าฟาร์ม|eggs_ไข่ไก่เบอร์ 0|\
eggs_ไข่ไก่เบอร์ 1|eggs_ไข่ไก่เบอร์ 2|eggs_ไข่ไก่เบอร์ 3|eggs_ไข่ไก่เบอร์ 4|\
eggs_ไข่ไก่เบอร์ 5|eggs_ไข่ไก่ต้ม|eggs_ไข่ไก่คละหน้าฟาร์ม|นม')

ingredient_translate = {
    "หมูสับ": "pork_เนื้อก้อน",
    "เนื้อหมูบด": "pork_หมูบด",
    "หมูบด": "pork_หมูบด",
    "ไข่ไก่": "eggs_ไข่ไก่เบอร์ 2",
    "ไขไก่": "eggs_ไข่ไก่เบอร์ 2",
    "หมูสามชั้น": "pork_สามชั้น",
    "เนื้อหมู": "pork_เนื้อก้อน",
    "ปีกไก่บน": "chicken_ปีกบนไก่", 
    "นมสด": "นม",
    "สันในไก่": "chicken_อกไก่",
    "อกไก่": "chicken_อกไก่",
    "มันไก่": "chicken_น่องไก่",
    "ไก่สด": "chicken_อกไก่",
    "สะโพกไก่": "chicken_สะโพกไก่",
    "สันคอหมู": "pork_เนื้อก้อน",
    "คอหมู": "pork_เนื้อก้อน",
    "ซี่โครงหมู": "pork_ซี่โครงหมู",
    "ปีกไก่กลาง": "chicken_ปีกกลางไก่",
    "ไก่อก": "chicken_อกไก่",
    "หมูสันนอก": "pork_สันนอก",
    "ตับไก่": "chicken_เครื่องในไก่",
    "เนื้อไก่": "chicken_อกไก่",
    "ปีกไก่": "chicken_ปีกไก่เต็ม",
    "หมูส่วนสะโพก": "pork_สะโพกหมู",
    "หมูสันใน": "pork_สันใน",
    "เนื่อหมู": "pork_เนื้อก้อน",
    "เนื้อสันในวัว": "beef_สันใน",
    "เนื้อวัว": "beef_เนื้อก้อน",
    "โครงไก่": "chicken_ซี่โครงไก่",
    "สันนอกหมู": "pork_สันนอก",
    "น่องไก่": "chicken_น่องไก่",
    "ไก่บด": "chicken_เนื้อไก่บด",
    "ปีกบนไก่": "chicken_ปีกบนไก่",
    "หมูบก": "pork_หมูบด",
    "หมูสามชั้น": "pork_สามชั้น",
    "ใส้หมู": "pork_ไส้อ่อนหมู",
    "ไส้หมู": "pork_ไส้อ่อนหมู",
    "หนังไก่": "chicken_น่องไก่",
    "ไส้ใหญ่หมู": "pork_ไส้ใหญ่หมู",
    "เอ็นข้อไก่": "chicken_ตีนไก่",
    "สันในหมู": "pork_สันใน",
    "ตีนไก่": "chicken_ตีนไก่",
    "ตับหมู": "pork_ตับหมู",
    "ปีกกลางไก่": "chicken_ปีกกลางไก่",
    "ไก่สับ": "chicken_น่องไก่",
    "หนังหมู": "pork_สามชั้น",
}

default_ingredient = {
    "นม": "นม",
    "ไข่": "eggs_ไข่ไก่เบอร์ 2",
    "หมู": "pork_เนื้อก้อน",
    "ไก่": "chicken_น่องไก่",
    "วัว": "beef_เนื้อก้อน",
}

ingd_patterns = []
for u in ingredient_translate:
        ingd_patterns.append(u)
        
ingd_pattern = re.compile("|".join(ingd_patterns))

ingd_default_patterns = []
for u in default_ingredient:
        ingd_default_patterns.append(u)
        
ingd_default_pattern = re.compile("|".join(ingd_default_patterns))

units = {
    "กรัม": (0.001, "กก."),
    "g": (0.001, "กก."),
    "grams": (0.001, "กก."),
    "กระม": (0.001, "กก."),
    "กิโล": (1., "กก."),
    "ฟอง": "ฟอง",
    "ชิ้นใหญ่": "unknown",
    "มิลลิลิตร": (0.001, "ลิตร"),
    "ก้อน": "unknown",
    "ถ้วย": "unknown",
    "ช้อนโต๊ะ": (0.015, "ลิตร"),
    "ชิ้น": "unknown",
    "กร้ม": (0.001, "กก."),
    "ml": (0.001, "ลิตร"),
    "kg": (1, "กก."),
    "กก": (1, "กก."),
    "ขีด": (0.1, "กก."),
    "กิโลกรัม": (1, "กก."),
    "กรม": (0.001, "กก."),
    "ท่อน": "unknown",
    "โครง": "unknown",
    "ใบ": "ฟอง",
    "แพ็ค": "unknown",
    "mg": (0.000001, "กก."),
    "ก$": (0.001, "กก."),
    "เส้น": "unknown",
    "น่อง": "unknown",
    "ปีก": "unknown",
    "ขา": "unknown",
    "วง": "unknown",
    "ตัว": "unknown",
    "ขึด": "unknown",
    "ซอง": "unknown",
    "อก": "unknown",
    "จาน": "unknown",
    "โล": (1, "กก."),
    "แท่ง": "unknown",
    "บาท": "baht",
    "ไม้": "unknown",
    "ดุ้นสั้น": "unknown",
    "ตีน": "unknown",
    "Kg": (1, "กก."),
    "ทัพพี": "unknown",
    "ฟอว": "unit",
    "ถาด": "unknown",
    "ช้ินโต๊ะ": (0.015, "กก."),
    "ห่อ": "unknown",
    "ลูก": "unit",
    "KG": (1., "กก."),
    "แผ่น": "unknown",
    "G": (0.001, "กก."),
    "ตามสะดวก": "unknown",
    "ชต": (0.015, "กก."),
    "pack": "unknown",
    "พวง": "unknown",
    "ถุง": "unknown",
    "pcs": "ฟอง",
    "สไลด์": "unknown",
    "โคร": "unknown",
    "ฟ$": "ฟอง",
    "ชาม": "unknown",
    "แพค": "unknown",
    "ขีเ": (0.1, "กก."),
    "ช้อน$": "unknown",
    "อัน": "unknown",
    "แพ๊ค": "unknown",
    "ครึ่งโล": (0.5, "กก."),
    "หม้อ": "unknown",
    "กล่อง": "unknown",
    "กรีม": (0.001, "กก."),
    "กนัม": (0.001, "กก."),
    "สะโพก": "unknown",
    "ซีก": "unknown",
    "ขรด": "unknown",
    "ชีด": "unknown",
    "หยิบมือ": "unknown",
    "โคลง": "unknown",
    "มือ": "unknown",
    "ถต": (140, "g"),
    "กรับ": (0.001, "กก."),
    "แ$": (0.001, "กก."),
    "กม": (0.001, "กก."),
    "ชุด": "unknown",
    "ช้อนโตณะ": (0.015, "กก."),
    "หอง": "ฟอง",
    "หาง": "unknown",
    "ช้อนโตํะ": "unknown",
    "ที่": "unknown",
}

patterns = [
    "\d+ - \d+\ *{}",
    "\d+-\d+\ *{}",
    "\d+\ *{}",
    "\d+\t*{}",
]

unit_patterns = []
for u in units:
    for p in patterns:
        unit_patterns.append(p.format(u))
        
unit_pattern = re.compile("|".join(unit_patterns))
unit_type_pattern = re.compile("|".join(list(units.keys())))

# %%
unit_type_pattern
# Out:
# re.compile(r'กรัม|g|grams|กระม|กิโล|ฟอง|ชิ้นใหญ่|มิลลิลิตร|ก้อน|ถ้วย|ช้อนโต๊ะ|ชิ้น|กร้ม|ml|kg|กก|ขีด|กิโลกรัม|กรม|ท่อน|โครง|ใบ|แพ็ค|mg|ก$|เส้น|น่อง|ปีก|ขา|วง|ตัว|ขึด|ซอง|อก|จาน|โล|แท่ง|บาท|ไม้|ดุ้นสั้น|ตีน|Kg|ทัพพี|ฟอว|ถาด|ช้ินโต๊ะ|ห่อ|ลูก|KG|แผ่น|G|ตามสะดวก|ชต|pack|พวง|ถุง|pcs|สไลด์|โคร|ฟ$|ชาม|แพค|ขีเ|ช้อน$|อัน|แพ๊ค|ครึ่งโล|หม้อ|กล่อง|กรีม|กนัม|สะโพก|ซีก|ขรด|ชีด|หยิบมือ|โคลง|มือ|ถต|กรับ|แ$|กม|ชุด|ช้อนโตณะ|หอง|หาง|ช้อนโตํะ|ที่',
# re.UNICODE)

# %%
frac_pattern = re.compile("\d+\/\d+")
num_pattern = re.compile("\d+")

# %%
dict(prices())
# Out:
# {'Items': [{'price': Decimal('182.01702163319416'),
#    'date': '2020-07-23',
#    'type': 'pork_สามชั้น'},
#   {'price': Decimal('181.8467674206031'),
#    'date': '2020-07-24',
#    'type': 'pork_สามชั้น'},
#   {'price': Decimal('181.994167428968'),
#    'date': '2020-07-25',
#    'type': 'pork_สามชั้น'},
#   {'price': Decimal('182.24495456567672'),
#    'date': '2020-07-26',
#    'type': 'pork_สามชั้น'},
#   {'price': Decimal('182.30987309635077'),
#    'date': '2020-07-27',
#    'type': 'pork_สามชั้น'},
#   {'price': Decimal('182.3756543486512'),
#    'date': '2020-07-28',
#    'type': 'pork_สามชั้น'},
#   {'price': Decimal('182.4579703953696'),
#    'date': '2020-07-29',
#    'type': 'pork_สามชั้น'},
#   {'price': Decimal('182.5827306438472'),
#    'date': '2020-07-30',
#    'type': 'pork_สามชั้น'},
#   {'price': Decimal('182.69303899636168'),
#    'date': '2020-07-31',
#    'type': 'pork_สามชั้น'},
#   {'price': Decimal('182.7896671459574'),
#    'date': '2020-08-01',
#    'type': 'pork_สามชั้น'},
#   {'price': Decimal('182.89034042846907'),
#    'date': '2020-08-02',
#    'type': 'pork_สามชั้น'},
#   {'price': Decimal('182.9980219796872'),
#    'date': '2020-08-03',
#    'type': 'pork_สามชั้น'},
#   {'price': Decimal('183.10856227805832'),
#    'date': '2020-08-04',
#    'type': 'pork_สามชั้น'},
#   {'price': Decimal('183.21709703043777'),
#    'date': '2020-08-05',
#    'type': 'pork_สามชั้น'},
#   {'price': Decimal('183.32610346361446'),
#    'date': '2020-08-06',
#    'type': 'pork_สามชั้น'},
#   {'price': Decimal('183.43721819013393'),
#    'date': '2020-08-07',
#    'type': 'pork_สามชั้น'},
#   {'price': Decimal('183.55012343005782'),
#    'date': '2020-08-08',
#    'type': 'pork_สามชั้น'},
#   {'price': Decimal('183.66389549120817'),
#    'date': '2020-08-09',
#    'type': 'pork_สามชั้น'},
#   {'price': Decimal('183.77842004926032'),
#    'date': '2020-08-10',
#    'type': 'pork_สามชั้น'},
#   {'price': Decimal('183.89408685041906'),
#    'date': '2020-08-11',
#    'type': 'pork_สามชั้น'},
#   {'price': Decimal('184.01095153516448'),
#    'date': '2020-08-12',
#    'type': 'pork_สามชั้น'},
#   {'price': Decimal('184.12885787598265'),
#    'date': '2020-08-13',
#    'type': 'pork_สามชั้น'},
#   {'price': Decimal('184.24769907447373'),
#    'date': '2020-08-14',
#    'type': 'pork_สามชั้น'},
#   {'price': Decimal('184.36749513379525'),
#    'date': '2020-08-15',
#    'type': 'pork_สามชั้น'},
#   {'price': Decimal('184.48826435562071'),
#    'date': '2020-08-16',
#    'type': 'pork_สามชั้น'},
#   {'price': Decimal('184.60997249382612'),
#    'date': '2020-08-17',
#    'type': 'pork_สามชั้น'},
#   {'price': Decimal('184.73257636076335'),
#    'date': '2020-08-18',
#    'type': 'pork_สามชั้น'},
#   {'price': Decimal('184.85605237447785'),
#    'date': '2020-08-19',
#    'type': 'pork_สามชั้น'},
#   {'price': Decimal('184.9803871957358'),
#    'date': '2020-08-20',
#    'type': 'pork_สามชั้น'},
#   {'price': Decimal('185.10556115534752'),
#    'date': '2020-08-21',
#    'type': 'pork_สามชั้น'},
#   {'price': Decimal('190.29408755272866'),
#    'date': '2020-08-22',
#    'type': 'pork_สามชั้น'}],
#  'Count': 31,
#  'ScannedCount': 31,
#  'ResponseMetadata': {'RequestId': 'P7N64383DIO9TJQMK4L0A0DQ3NVV4KQNSO5AEMVJF66Q9ASUAAJG',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'server': 'Server',
#    'date': 'Sun, 26 Jul 2020 09:22:36 GMT',
#    'content-type': 'application/x-amz-json-1.0',
#    'content-length': '3286',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': 'P7N64383DIO9TJQMK4L0A0DQ3NVV4KQNSO5AEMVJF66Q9ASUAAJG',
#    'x-amz-crc32': '1555208092'},
#   'RetryAttempts': 0}}

# %%
prices
# Out:
#                  price        date                type
# 0    2.835654172231381  2020-07-23  eggs_ไข่ไก่เบอร์ 2
# 1   2.8416331494672877  2020-07-24  eggs_ไข่ไก่เบอร์ 2
# 2   2.8475087490903706  2020-07-25  eggs_ไข่ไก่เบอร์ 2
# 3    2.853282758518512  2020-07-26  eggs_ไข่ไก่เบอร์ 2
# 4   2.8589569342648127  2020-07-27  eggs_ไข่ไก่เบอร์ 2
# 5   2.8645330024719384  2020-07-28  eggs_ไข่ไก่เบอร์ 2
# 6    2.870012659437233  2020-07-29  eggs_ไข่ไก่เบอร์ 2
# 7   2.8753975721287466  2020-07-30  eggs_ไข่ไก่เบอร์ 2
# 8   2.8806893786923475  2020-07-31  eggs_ไข่ไก่เบอร์ 2
# 9   2.8858896889500607  2020-08-01  eggs_ไข่ไก่เบอร์ 2
# 10   2.891000084889794  2020-08-02  eggs_ไข่ไก่เบอร์ 2
# 11  2.8960221211465926  2020-08-03  eggs_ไข่ไก่เบอร์ 2
# 12  2.9009573254755785  2020-08-04  eggs_ไข่ไก่เบอร์ 2
# 13  2.9058071992167065  2020-08-05  eggs_ไข่ไก่เบอร์ 2
# 14  2.9105732177514883  2020-08-06  eggs_ไข่ไก่เบอร์ 2
# 15  2.9152568309518188  2020-08-07  eggs_ไข่ไก่เบอร์ 2
# 16   2.919859463621042  2020-08-08  eggs_ไข่ไก่เบอร์ 2
# 17  2.9243825159273915  2020-08-09  eggs_ไข่ไก่เบอร์ 2
# 18  2.9288273638299342  2020-08-10  eggs_ไข่ไก่เบอร์ 2
# 19   2.933195359497153  2020-08-11  eggs_ไข่ไก่เบอร์ 2
# 20  2.9374878317182893  2020-08-12  eggs_ไข่ไก่เบอร์ 2
# 21  2.9417060863075757  2020-08-13  eggs_ไข่ไก่เบอร์ 2
# 22  2.9458514065014767  2020-08-14  eggs_ไข่ไก่เบอร์ 2
# 23   2.949925053349063  2020-08-15  eggs_ไข่ไก่เบอร์ 2
# 24  2.9539282660956356  2020-08-16  eggs_ไข่ไก่เบอร์ 2
# 25  2.9578622625597175  2020-08-17  eggs_ไข่ไก่เบอร์ 2
# 26  2.9617282395035254  2020-08-18  eggs_ไข่ไก่เบอร์ 2
# 27  2.9655273729970384  2020-08-19  eggs_ไข่ไก่เบอร์ 2
# 28   2.969260818775769  2020-08-20  eggs_ไข่ไก่เบอร์ 2
# 29   2.972929712592353  2020-08-21  eggs_ไข่ไก่เบอร์ 2
# 30    2.72591065490559  2020-08-22  eggs_ไข่ไก่เบอร์ 2

# %%
queried_prices = {}
menu_prices = {}
show_str = {}
ingd_prices = {}

for m in menus:
    date_price = None
    show_str[m] = []
    for ig in menus[m]:
        _use_to_cal = False
        _ig = ig.split(" ")[0].replace("\u200b", "").replace("(", "").replace(")", "")
        if includes.search(_ig) and not excludes.search(_ig) and not excludes_units.search(menus[m][ig]):
            ingd_type = regex_pattern.search(_ig)
            ingd_default_type = ingd_default_pattern.search(_ig)
            if ingd_type or ingd_default_type:
                if ingd_type:
                    str_ingd_type = ingredient_translate[ingd_type.group()]
                else:
                    str_ingd_type = default_ingredient[ingd_default_type.group()]
                    
                unit_type = unit_pattern.search(menus[m][ig])
                if unit_type:
                    str_unit_type = unit_type.string
                    unit_type_p = unit_type_pattern.search(menus[m][ig]).group()
#                     print(unit_type_p)
                    try:
                        common_unit_type = units[unit_type_p]
                    except:
                        common_unit_type = units[unit_type_p+"$"]
                        
                    if common_unit_type == "unknown":
                        show_str[m].append(f"*{_ig} {menus[m][ig]} (unknown unit type)")
                    else:
                        _frac = frac_pattern.search(menus[m][ig])
                        _num = num_pattern.search(menus[m][ig])
                        if _frac or _num:
                            
                            _use_to_cal = True
                            
                            if _frac:
                                fr = _frac.group()
                                magn = float(fr.split("/")[0])/float(fr.split("/")[1])
                            else:
                                magn = float(_num.group())
                                
                            if str_ingd_type not in queried_prices:
                                prices = pd.DataFrame(dict(table_prices.query(KeyConditionExpression=Key("type").eq(str_ingd_type) & Key("date").between("2020-07-23", "2020-08-22")).items())["Items"])
                                prices["price"] = prices["price"].astype(float)
                                queried_prices[str_ingd_type] = prices
                            else:
                                prices = queried_prices[str_ingd_type]
                                
                            if not isinstance(date_price, np.ndarray):
                                date_price = np.zeros([prices.shape[0]])
                                
                            if isinstance(common_unit_type, tuple):
                                show_str[m].append(f"*{_ig} {menus[m][ig]} ({common_unit_type[1]})")
                                magn *= common_unit_type[0]
                                date_price += prices["price"] * magn
                            else:
                                show_str[m].append(f"*{_ig} {menus[m][ig]} ({common_unit_type})")
                                if common_unit_type == "บาท":
                                    date_price += magn
                                else:
                                    date_price += prices["price"] * magn
                                    
        if not _use_to_cal:
            show_str[m].append(f"{_ig} {menus[m][ig]}")
                                    
                            
#                             if str_ingd_type == "นม":
#                             print(prices)
#                             print(str_ingd_type, magn, common_unit_type)
        
    if isinstance(date_price, np.ndarray):
        menu_prices.append(date_price)
    else:
        menu_prices.append(0)
#     print(date_price)
#                         show_str[m].append(f"*{_ig} {menus[m][ig]} (unknown unit type)")
#                     print(str_ingd_type, common_unit_type)
                    
#                 show_str[m].append(f"*{_ig} {menus[m][ig]}")
                
#                 ingd_prices.append()
#         else:
# #             print(ig, includes.search(ig), excludes.search(ig))
#             show_str[m].append(f"{ig} {menus[m][ig]}")

# %%
show_str
# Out:
# {'ไข่เจียว': ['*ไข่ 2 ฟอง (ฟอง)', 'น้ำ 1 ถ้วยตวง', 'น้ำปลา นิดหน่อย'],
#  'ไข่เจียวทูน่าพริกสับ': ['ปลาทูน่า 1 กระป๋อง',
#   'พริกขี้หนู 6 เม็ด',
#   '*ไข่ไก่ 2 ฟอง (ฟอง)',
#   'น้ำปลา เล็กน้อย',
#   'น้ำมันพืช พอประมาณ'],
#  'วุ้นเส้นหมูกรอบคั่วพริกเกลือ': ['วุ้นเส้น 2 ห่อ\xa0\xa0',
#   '*หมูสามชั้น 400 กรัม\xa0 (กก.)',
#   'เกลือ 1 ช้อนโต๊ะ ',
#   'น้ำส้มสายชู 2 ช้อนโต๊ะ',
#   'พริกแดงจินดาสับ 1½ ช้อนโต๊ะ',
#   'กระเทียมสับ 1½ ช้อนโต๊ะ',
#   'เกลือ 1 ช้อนชา',
#   'น้ำตาล 1 ช้อนชา\xa0',
#   'ซีอิ๊วขาวต้นหอม 1 ช้อนโต๊ะ\xa0'],
#  'ขนมผิง🌟': ['แป้งมัน 2 ถ้วยตวง',
#   'น้ำตาลทราย 150 กรัม',
#   'กะทิอบควันเทียน 1/2 ถ้วยตวง',
#   'ไข่แดง 1 ฟอง',
#   'น้ำเปล่า 2 ช้อนโต๊ะ'],
#  'หมี่กรอบผัดซีอิ๊ว': ['บะหมี่ไข่ 2 1/2 ก้อน',
#   'น้ำมันพืช พอประมาณ',
#   '*ไข่ไก่ 2 ฟอง (ฟอง)',
#   '*เนื้อหมู 1 ชิ้นใหญ่ (unknown unit type)',
#   'เนื้อหมู 1 ชิ้นใหญ่',
#   'คะน้า 3 ต้น',
#   'น้ำตาลทราย ตามชอบ',
#   'ผงปรุงรส ตามชอบ',
#   'ซีอิ๊วดำ เล็กน้อย',
#   'พริกไทยขาวป่น ตามชอบ'],
#  'ไก่ทอดเกาหลีซอสส้ม': ['แป้งมันสำปะหลัง 2 ช้อนโต๊ะ',
#   'น้ำสะอาด 30 มิลลิลิตร',
#   'น้ำตาล 4 ช้อนโต๊ะ',
#   'น้ำส้ม 200 มิลลิลิตร',
#   'ขิงสับละเอียด 1 ช้อนโต๊ะ',
#   'ซอสปรุงรส 1 ช้อนโต๊ะ',
#   'งาขาว ',
#   'พาร์สลีย์ ',
#   'ส้มหั่นชิ้น ',
#   '*ปีกไก่บน 500 กรัม\xa0\xa0  (กก.)',
#   'เกลือ 2 ช้อนชา\xa0',
#   'พริกไทย 2 ช้อนชา',
#   'แป้งทอดกรอบ 300 กรัม',
#   'น้ำ 200 มิลลิลิตร',
#   'น้ำมัน '],
#  'ขนมโตเกียวไส้กรอกพันเบคอน': ['สโมคเบค่อน 1 แพ็ค',
#   'สโมคพ็อคซอสเซสมินิ 1 แพ็ค',
#   'ซอสมะเขือเทศ 100 กรัม',
#   'กระเทียม 1 ช้อนโต๊ะ',
#   'พริกไทย 1 ช้อนชา',
#   'น้ำตาล ½ ช้อนชา',
#   'ซอสปรุงรส 1 ช้อนโต๊ะ',
#   'น้ำสต๊อก ½ ถ้วยตวง',
#   '*ไข่ไก่ 2 ฟอง (ฟอง)',
#   'น้ำตาลป่น 80 กรัม\xa0',
#   '*นมสด 100 มิลลิลิตร\xa0 (ลิตร)',
#   'น้ำปูนใส 80 มิลลิลิตร\xa0',
#   'กลิ่นวานิลลา 1 ช้อนชา',
#   'แป้งสาลีอเนกประสงค์ 140 กรัม',
#   'แป้งมันสำปะหลัง 30 กรัม',
#   'ผงฟู 1 ช้อนชา',
#   'เกลือ 1/2 ช้อนชา',
#   'น้ำมัน 15 กรัม\xa0'],
#  'ไข่ขยี้กุ้งพริกน้ำปลาโลว์โซเดียม 🥚🦐': ['กุ้งสด 10 ตัว',
#   '*ไข่ไก่ 4-5 ฟอง (ฟอง)',
#   'ซีอิ๊วขาว 1 ช้อนโต๊ะ',
#   'น้ำตาล 1/2 ช้อนชา',
#   'พริกไทยป่น ครึ่งช้อนชา',
#   'น้ำปลาโลว์โซเดียม ตามชอบ',
#   'กระเทียม ตามชอบ',
#   'มะนาว 2 ลูก',
#   'น้ำตาลโตนด ตามชอบ',
#   'พริกขี้หนูสวน ตามชอบ'],
#  'อะไรเอ่ยใช้เวลา 9 เดือน... เนื้อเค็มต้มกะทิจ้าาา': ['เนื้อเค็มติดมันสไลด์เป็นชิ้นพอคำ 500 กรัม',
#   'หอมแดง/หอมแขกซอย 1 ถ้วยตวง',
#   'พริกขี้หนู 20 เม็ด',
#   'ใบมะกรูดฉีก 10-15 ใบ',
#   'กะทิขวด 500 กรัม',
#   'น้ำเปล่า 2-3 ช้อนโต๊ะ',
#   'น้ำตาลปี๊ป 1 ช้อนโต๊ะ',
#   'น้ำมะขามเปียก 1 ช้อนโต๊ะ',
#   'น้ำปลา 1 ช้อนโต๊ะ'],
#  'แกงจืดตำลึงเต้าหู้หมูสับ 🐷': ['ตำลึง ตามชอบ',
#   '*หมูสับ 250 กรัม (กก.)',
#   'ซุปก้อนคนอร์หมู 1 ก้อน',
#   'ซีอิ้วขาว 1 ช้อนโต๊ะ',
#   'น้ำปลา ครึ่ง ช้อนโต๊ะ',
#   'น้ำตาล 1 ช้อนชา',
#   'พริกไทยป่น ครึ่งช้อนชา',
#   'เกลือ นิดหน่อย'],
#  'คีช อาหารเช้า': ['เชดด้าชีส 2 +1/2 ถ้วย',
#   'แป้งเอนกประสงค์ 2ถ้วย',
#   'น้ำเย็น 5 ช้อนโต๊ะ',
#   'เนย 1ถ้วย',
#   'ใส้คีส ',
#   '*นม 1ถ้วย (unknown unit type)',
#   'นม 1ถ้วย',
#   '*ไข่ 6ฟอง (ฟอง)',
#   'ผักขม 2ถ้วย',
#   'เห็ด 1ถ้วย',
#   'เกลือ,พริกไทดำ '],
#  'เมอแรงค์อัลมอน': ['ไข่ขาว 120 กรัม',
#   'น้ำตาล 120กรัม',
#   'อัลมอนสไลด์ ตามชอบ',
#   'กลิ่นวนิลา 1/2 ช้อนชา',
#   'ครีมออฟทาทาร์ 1/4ช้อนชา'],
#  'มะม่วงหาวมะนาวโห่แช่อิ่ม': ['1.มะม่วงหาวมะนาวโห่ 1กิโลกรัม',
#   '2.น้ำตาลทราย 500กรัม',
#   '3.เกลือป่น 1/2ช้อนชา',
#   '4.ปูนแดง 1ช้อนโต๊ะ',
#   '5.น้ำสะอาด 1-1 1/2ลิตร'],
#  'ข้าวราดไข่ข้นกุ้ง 🥚🦐': ['*ไข่ไก่ 2 ฟอง (ฟอง)',
#   'กุ้งสด 3-4 ตัว',
#   '*นมสด 1 ช้อนโต๊ะ (ลิตร)',
#   'ซีอิ๊วขาว 1/2 ช้อนโต๊ะ',
#   'พริกไทยขาวป่น นิดหน่อย'],
#  'ไข่ดาวกรอบนอกฉ่ำใน': ['*ไข่ไก่ 1 ฟอง (ฟอง)', 'น้ำมันพืช '],
#  'มะม่วงหาวมะนาวโห่ครั้งแรกของน้องง': ['มะม่วงหาวมะนาวโห่ 2 ถุง',
#   'น้ำตาลทราย 300 กรัม',
#   'เกลือ 1 ช้อนโต๊ะ'],
#  'มะม่วงหาวมะนาวโห่กับน้ำจิ้ม': ['มะม่วงหาวมะนาวโห่ 200 กรัม',
#   'น้ำต้มสุกที่เย็นแล้ว ',
#   'เกลือ ',
#   '🍴 ',
#   'น้ำตาลทราย 3 ชต.',
#   'น้ำปลา 3 ชต.',
#   'ผงปรุงรสที่ชอบ 1/2 ชต.',
#   'พริกป่น 1 ชต.'],
#  'มะม่วงหาวมะนาวโห่ลอยแก้ว': ['มะม่วงหาวมะนาวโห่ 1 โล',
#   'น้ำตาลทรายขาง 7 ชต.',
#   'น้ำตาลทรายไม่ขัดสี 2 ชต.',
#   'เกลือใส่กับน้ำเชื่อม 1/2 ชช',
#   'น้ำเปล่า 1 1/2 ถต.'],
#  'สลัดโรลซอสพีนัทบัตเตอร์ ': ['*ส่วนผสม ',
#   'จิฟ 110\tกรัม',
#   'ซอสฮอยซิน 1 ½\tช้อนโต๊ะ',
#   'น้ำพริกเผา 1 ช้อนโต๊ะ',
#   'คิคโคแมน 2 ช้อนชา',
#   'น้ำมันงา 1/4 ช้อนชา',
#   'น้ำมะนาว 1 ½ \tช้อนโต๊ะ',
#   'น้ำสะอาด 1/4 ถ้วยตวง',
#   'งาขาวคั่ว สำหรับเสิร์ฟ',
#   '*สลัดโรล ',
#   'กุ้งลวก 12 ตัว',
#   'แผ่นแป้งเปาะเปี๊ยะ 8 แผ่น',
#   'แตงกวาญี่ปุ่นซอย 1 ผล',
#   'แครอท 1/4 ผล',
#   'ไควาเระ 1 กำ',
#   'มิซูน่า 1 กำ',
#   'พริกหวานสีแดงซอย 1 ผล',
#   'เห็ดเข็มทอง 1 กำ'],
#  'กาแฟดำมะม่วงหาวมะนาวโห่': ['มะม่วงหาวมะนาวโห่ 6 ลูก',
#   'มะม่วงเบา 1 ลูก',
#   'น้ำผึ้ง 2 ช้อนโต๊ะ',
#   'น้ำเปล่า 80 ออนซ์',
#   'กาแฟ 20 ออนซ์',
#   'น้ำแข็ง เต็มแก้ว'],
#  'กะเพราไก่ไข่สองใจ 💕': ['*ไข่ 2 ฟอง (ฟอง)',
#   '*สันในไก่ 300 กรัม (กก.)',
#   'กะเพรา 1 กำ',
#   'พริก 10 เม็ด ',
#   'กระเทียม 5 กลีบ ',
#   'ซอสหอยนางรม 2 ช้อนโต๊ะ ',
#   'น้ำปลา 1/2 ช้อนโต๊ะ ',
#   'ซีอิ้วขาว 1/2 ช้อนโต๊ะ ',
#   'ซีอิ้วดำ 1/2 ช้อนโต๊ะ '],
#  'ยำไข่ต้ม 🥚': ['*ไข่ไก่ 8 ฟอง  (ฟอง)',
#   'ต้นหอม 2 ต้น',
#   'ผักชี 2 ต้น',
#   'หอมแดง 5 หัว',
#   'พริกจินดา 15 เม็ด',
#   'มะนาว 1 ลูก',
#   'น้ำปลา 2 ช้อนโต๊ะ ',
#   'น้ำตาล 1/2 ช้อนโต๊ะ ',
#   '*หมูบด 4 ช้อนโต๊ะ  (ลิตร)'],
#  'ยำมะม่วงหาวมะนาวโห่': ['มะม่วงหาวมะนาวโห่ 1 ถ้วย',
#   'น้ำตาลทราย 3 ช้อนโต๊ะ',
#   'พริกป่น 1/2 ช้อนโต๊ะ',
#   'น้ำปลา 2 ช้อนโต๊ะ'],
#  'ข้าวมันไก่ (ฉบับกล่องข้าวสาวออฟฟิต)': ['*อกไก่ 200 กรัม (กก.)',
#   'รากผักชี 2 ราก',
#   'หัวไชเท้า 1/3 ส่วน',
#   'พริกไทย ',
#   'เกลือ ',
#   'คนอร์ ',
#   'ข้าว ',
#   'น้ำเปล่า ',
#   'น้ำมันพืช ',
#   'ขิงฝาน ',
#   'น้ำจิ้มข้าวมันไก่เราใช้ตราก่วงเฮง '],
#  '“ยำ 3 ไข่”': ['น้ำตาลทราย 2-3 ช้อนชา',
#   'ผงปรุงรส 1/2 ช้อนชา',
#   'น้ำปลา  1-2 ช้อนโต๊ะ',
#   'มะนาว 1-2 ลูก',
#   'พริกขี้หนูซอย 6 เม็ด',
#   'หอมแดงซอย 3 หัว',
#   'ตั้งโอ๋ซอย 2 ต้น',
#   'ไข่ดาว 2 ฟอง',
#   'ไข่เค็ม 2 ฟอง',
#   'ไข่เยี่ยวม้า 2 ฟอง'],
#  'ข้าวมันไก่': ['ไก่สด ',
#   'มันไก่ ',
#   'ข้าวสาร ',
#   'ขิงสด ',
#   'รากผักชี ',
#   'พริกไทยเม็ด ',
#   'พริกขี้หนูสด ',
#   'เต้าเจี้ยว ',
#   'ซีอิ้วดำ ',
#   'น้ำส้มายชู ',
#   'น้ำตาล ',
#   'ฟักเขียว ',
#   'มะนาวดอง '],
#  'ผัดมาม่าไข่เค็มโรยเลย์': ['มาม่ารสไข่เค็ม 1 ซอง',
#   'เลย์รสบาร์บีคิว 1 ซอง',
#   'กระเทียมสับ 3 กลีบ',
#   'ไส้กรอก/หมูสับ แล้วแต่ชอบ',
#   'ไข่เค็ม 1 ฟอง'],
#  'ขนมจีบหมูไข่เค็ม': ['*หมูสับปรุงรส 500 กรัม (กก.)',
#   'น้ำมันงา 1 ชต',
#   'พริกไทย 1 ชช',
#   'กระเทียมบด 1 ชต',
#   'ไข่เเดงเค็ม 5 ฟอง'],
#  'ราดหน้าฮ่องกง + สอนเทคนิคผัดเส้นระดับโปร  ♥️': ['*เนื้อวัว 100 g (กก.)',
#   'คะน้า 100 g',
#   'เส้นใหญ่ 100g',
#   'เห็ดฟาง 6 ลูก',
#   'แป้งมันฮ่องกง 2 ช้อน',
#   'น้ำมันหอย 2-3 เหยาะ',
#   'ซีอิ้วขาว 2-3 เหยาะ',
#   'ซีอิ๊วดำ 4-5 เหยาะ'],
#  'มะม่วงหาวมะนาวโห่ น้ำปลาหวาน โรยพริกเกลือ': ['มะม่วงหาวมะนาวโห่ ตามชอบ',
#   'น้ำปลาน้ำปลาหวาน 150 มล',
#   'น้ำตาลปี๊บน้ำปลาหวาน ครึ่ง กก',
#   'พริกป่นใส่ในน้ำปลาหวาน 1 ชต',
#   'หอมแดงซอย 5 หัว',
#   'พริกป่นทำพริกเกลือ 2 ชต',
#   'เกลือทำพริกเกลือ 3 ชต',
#   'น้ำตาลพริกเกลือ 5 ชต',
#   'ผงชูรส 1 ช้อนชา'],
#  'Surprise eggs 🥚': ['*ไข่ไก่ 2 ฟอง (ฟอง)',
#   'ซอส 4 เหยาะ ',
#   'พริกไทย เหยาะๆ ลงไป',
#   'มะเขือเทศราชินี 5 ลูก'],
#  '🌈ข้าวมันไก่หม้อหุงข้าว': ['*อกไก่ลอกหนัง 2 ชิ้น (unknown unit type)',
#   'อกไก่ลอกหนัง 2 ชิ้น',
#   'ขิง 1หัว',
#   'กระเทียม 6-7 กีบ',
#   'เกลือ ',
#   'คนอร์ ',
#   'สำหรับทำน้ำจิ้มข้าวมันไก่ขิง ',
#   'ข้าวสาร 1 กระป๋อง'],
#  'มะม่วงไม่รู้หาว มะนาวไม่รู้โห่': ['ผลมะม่วงหาวมะนาวโห่สุก 1 กก.',
#   'น้ำตาลทรายแดง 500 กรัม',
#   'เกลือผงเสริมไอโอดีน 1 ช้อนชา',
#   'น้ำเปล่า 6 ลิตร',
#   'ใบเตย 4 ใบ '],
#  'ข้าวมันไก่ (สูตรหม้อหุงข้าว)': ['*สะโพกไก่ 2 ชิ้น (unknown unit type)',
#   'สะโพกไก่ 2 ชิ้น',
#   'ขิง 1-2 ชิ้น',
#   'กระเทียมไทย 1 กำมือ',
#   'ข้าวสาร 1.5 ถ้วย',
#   'น้ำปลาอย่างดี ',
#   'น้ำมันสำหรับผัด ',
#   'กระเทียมจีนสับ 1 ส่วน',
#   'หอมเเดงสับ 2 ส่วน',
#   'ขิงอ่อนสับ 2 ส่วน',
#   'เต้าเจี้ยว 2 ส่วน',
#   'น้ำเต้าเจี้ยว 2 ส่วน',
#   'น้ำตาล 0.5 ส่วน',
#   'น้ำมะนาว 1 ส่วน',
#   'น้ำเปล่าต้มสุก 1 ส่วน',
#   'ต้นหอม ',
#   'พริกสดซอย ',
#   'ซีอิ้วหวาน '],
#  'ไข่เค็มหมูสับ หมูสับผัดไข่เค็ม': ['*หมูสับ 200กรัม (กก.)',
#   'ไข่เค็ม 2ฟอง',
#   'ต้นหอม 3ต้น',
#   'กระเทียม 5กลีบ',
#   'น้ำมันหอย 2ชต.',
#   'น้ำตาล 2ช้อนชา',
#   'ซีอิ้วขาว 1ชต.'],
#  '🎎🎎🎎🎎🎎': [',,, 1919191919', 'apapa ', '~~~ '],
#  'ข้าวมันไก่หม้อหุงข้าว': ['ข้าวสาร 2-3 ถ้วย',
#   '*อกไก่ 2 ชิ้น (unknown unit type)',
#   'อกไก่ 2 ชิ้น',
#   'กระเทียม ตามชอบ',
#   'รากผักชี ตามชอบ',
#   'ขิง ตามชอบ',
#   'น้ำมัน 2 ช้อนโต๊ะ',
#   'เกลือ 1/4 ช้อนชา',
#   'ส่วนผสมน้ำจิ้ม ',
#   'เต้าเจี้ยว ครึ่งถ้วยตวง',
#   'น้ำตาลทราย 2 ช้อนโต๊ะ',
#   'มะนาวหรือน้ำส้มสายชู\xa0 2 ช้อนโต๊ะ',
#   'ซีอิ้วดำ 1-2 ช้อนชา',
#   'ขิง+พริกสด+กระเทียม ตามชอบ'],
#  'ข้าวมันไก่อบหม้อหุงข้าว': ['*สะโพกไก่ 2ชิ้น (unknown unit type)',
#   'สะโพกไก่ 2ชิ้น',
#   'คนอร์ซอสข้นรสไก่ ',
#   'เห็ดหอม 3-4ดอก',
#   'ต้นหอม 2ต้น',
#   'แครอท 1/2ถ้วยตวง',
#   'ข้าว 2ถ้วย',
#   'น้ำมันพืช '],
#  'ไก่ทอดคอนเฟคไร้น้ำมัน': ['*ปีกไก่กลาง 7-8 ชิ้น (unknown unit type)',
#   'ปีกไก่กลาง 7-8 ชิ้น',
#   'น้ำปลา 1 ช้อนโต๊ะ',
#   'น้ำมันหอย 1 ช้อนโต๊ะ',
#   'พริกไทย 1 ช้อนชา',
#   'คอนเฟคชนิดจืด 3 ถ้วยตวง',
#   '*ไข่ไก่ 1 ฟอง (ฟอง)',
#   'คนอร์ขวดปรุงรส 1 ช้อนโต๊ะ'],
#  'Microwave Bread Pudding (Sugar-free)': ['egg 1',
#   'milk 1/4 cup',
#   'banana 1/2 banana',
#   'cinnamon ',
#   'honey (optional)'],
#  'ตำข้าวโพดไข่เค็ม': ['กระเทียม 2 กลีบ',
#   'พริก 3-5 เม็ด',
#   'น้ำปลา 1/2 ช้อนโต๊ะ',
#   'น้ำตาลปีบ 1/2 ช้อนโต๊ะ',
#   'มะขามเปียก 1/2 ช้อนโต๊ะ',
#   'มะนาว 1/2 - 1 ซีก',
#   'ถัวฝักยาว 1 ฝัก',
#   'ข้าวโพดต้มแล้ว 1 ฝัก',
#   'ไข่เค็ม 1 ฟอง',
#   'ถั่วลิสง/กุ้งแห้ง 1 ช้อนโต๊ะ',
#   'มะเขือเทศ 1-2 ลูก'],
#  'ดองไข่เค็มแบบง่ายๆ Salted duck eggs': ['ไข่เป็ด ',
#   'เกลือทะเล ',
#   'น้ำเปล่า ',
#   'น้ำส้มสายชูแบบถูก '],
#  'บะจ่างใบบัว': ['ข้าวเหนียว  500 กรัม ',
#   '*หมูสามชั้น 1 ถ้วย (unknown unit type)',
#   'หมูสามชั้น 1 ถ้วย',
#   'กุ้งแห้ง 1 ถ้วย',
#   'ถั่วลิสงดิบ 1 ถ้วย',
#   'เห็ดหอมแห้งแช่น้ำ 1ถ้วย',
#   'ไข่แดงเค็มดิบ 7-14 ฟอง',
#   'แปะก๊วย 1/2 ถ้วน',
#   'กุนเชียง 1 ถ้วย ',
#   'ผงพะโล้ 2ชช.',
#   'ซีอิ๊วขาว 1ถ้วย ',
#   'น้ำตาลปีบ 1/2ถ้วย',
#   'พริกไทย 1/4 ถ้วย '],
#  'ปลาซาบะย่างซีอิ๊ว': ['ปลาซาบะ 1 ตัว',
#   'ซีอิ๊วดำหวาน 2 ช้อนโต๊ะ',
#   'น้ำตาลทราย 1 ช้อนโต๊ะ',
#   'ซอสทอริยากิ 4 ช้อนโต๊ะ',
#   'น้ำมันงา 1 ช้อนโต๊ะ'],
#  'ชาเขียว': ['ผงชาเขียวตราช้างทอง 5 ช้อนโต๊ะ',
#   'นมข้นหวาน 1กระป๋อง (388กรัม)',
#   'น้ำตาลทรายแดง 1 1/2 ทัพพี',
#   'ครีมเทียม 1 1/2 ทัพพี',
#   'น้ำร้อน 1.2 ลิตร'],
#  'ข้าวมันไก่แบบเร่งด่วน': ['ผงสำเร็จรูปข้าวมันไก่ 1 ซอง',
#   'ข้าวสาร 2 ถ้วย',
#   'น้ำเปล่า กะตามชอบให้ข้าวลักษณะใด',
#   '*ไก่อก 2 ชิ้น (unknown unit type)',
#   'ไก่อก 2 ชิ้น'],
#  'แกงปลาซาบะย่างใบชะพลู': ['ปลาซาบะย่าง 2 ตัว',
#   'พริกแกงใต้ 3 ชต.',
#   'ใบชะพลู 2 กำมือ',
#   'คนอร์ผงรสหมู 1 ชช.',
#   'เกลือ 1/2 ชช.',
#   'น้ำตาล 2 ชช.',
#   'กะทิกล่อง 250 มล.',
#   'น้ำเปล่า '],
#  'ข้าวมันไก่ - หุงในหม้อหุงข้าว': ['*ไก่สด 500-700 กรัม (กก.)',
#   'ข้าวหอมมะลิ 2 ถ้วยตวง',
#   'ขิง 1 แง่ง (50 กรัม)',
#   'ผักชี 2-3 ต้น',
#   'กระเทียม 1 หัว',
#   'เกลือ, '],
#  'แพรเค้กหมูสับไข่ดาว': ['*เนื้อหมูบด 50กร้ม (กก.)',
#   '*ไข่ไก่ 2 ฟอง (ฟอง)',
#   'ซอสปรุงรส 1ช้อนชา',
#   'พริกไทยดำ, ',
#   'แป้งแพนเค้ก 70 กรัม',
#   'เนยจืดละลาย 1ก้อนเล็ก',
#   '*นมสด 50ml (ลิตร)'],
#  'ผัดวุ้นเส้นกระเทียมดอง ไข่เค็มทำเอง': ['วุ้นเส้น  30 กรัม (ก่อนแช่)',
#   'ไข่เค็มดิบ  2 ฟอง',
#   'เนื้อเชียง 1 ชิ้น',
#   'กระเทียมดอง  4 หัว',
#   'กระเทียมเม็ดใหญ่ 3 กลีบ',
#   'หอมใหญ่ ครึ่งหัว',
#   'มะเขือเทศ 1 ลูก',
#   'ต้นหอม 1 ต้น',
#   'คื่นช่าย 1 ต้น',
#   'ซอสถั่วเหลือง  2 ช้อนโต๊ะ',
#   'น้ำมันหอย 3 ช้อนโต๊ะ',
#   'ชีอิ๊วดำ 1 ช้อนชา'],
#  'ฉ่าเต่าแง้เตากัวตือบะ ผัดเต้าหู้ถั่วงอกหมูสับ': ['เต้าหู้ไข่สีขาว 2ก้อน',
#   'ถั่วงอก 2ขีด',
#   'น้ำมันรำข้าว 1ทัพพี',
#   'ซอสฝาเหลือง 3ช้อนโต๊ะ',
#   'กระเทียมไท 3กีบ',
#   'พริกไทยป่น 1ช้อนชา',
#   'พริกชี้ฟ้า ตามใจชอบ',
#   'ต้นหอม ตามใจชอบ',
#   '*เนื้อหมูสับ 300กรัม (กก.)'],
#  'สปาเก็ตตี้ซอสไข่เค็ม': ['แอคเนซี 200 กรัม',
#   'หอมใหญ่ 10 กรัม',
#   'เนื้อกุ้งสับ 50 กรัม',
#   'เห็ดนางรมหลวงหั่นเต๋า 15 กรัม',
#   'ส่วนผสมซอสไข่เค็ม ',
#   'ไข่แดง 2 ฟอง',
#   'มันกุ้ง 60 กรัม',
#   'ไข่แดงเค็ม 1 ช้อนโต๊ะ',
#   'ซอสปรุงรส 2 ช้อนชา',
#   'วิปปิ้งครีม 3 ช้อนโต๊ะ',
#   'เนยและน้ำมัน สำหรับผัด',
#   'เกลือและพริกไทย สำหรับปรุงรส',
#   'ไข่กุ้งและผักชี สำหรับตกแต่ง'],
#  'กระเพราหมูไข่ลูกเขย': ['*หมูบด 200กรัม (กก.)',
#   'กระเทียมตำ 1ช้อนโต๊ะ',
#   'พริกสดตำ 2 ช้อนโต๊ะ',
#   '*ไข่ไก่ 5 ฟอง (ฟอง)',
#   'น้ำมันพืช ',
#   'น้ำมันหอย ',
#   'น้ำปลา ',
#   'น้ำตาล ',
#   'ซีอิ้วขาว ',
#   'ใบกะเพราะ 1 กำ'],
#  'ยอดมะพร้าวอ่อนผัดไข่': ['*ไข่ไก่ 4 ฟอง (ฟอง)',
#   'ยอดมะพร้าวอ่อนหั่นชิ้นตามชอบ 500 กรัม',
#   'หัวหอมใหญ่ซอย 1 หัว',
#   'น้ำมันพืช 2 ชต',
#   'คนอร์ซอสข้นหมู 1 ชต',
#   'น้ำมันหอย 1 + 1/2 ชต'],
#  'อเมริกาโน่สับปะรด 🍍☕️': ['สับปะรดภูแล 80-100 กรัม',
#   'น้ำดื่ม 2 ชต',
#   'กาแฟแคปซูล 1 แคปซูล',
#   'น้ำร้อน 2 ขีด',
#   'น้ำแข็ง '],
#  'ซาบะย่างสูตรคลีน': ['ปลาซาบะแล่สำเร็จ 1ชิ้น(150g)',
#   'ไข่ต้ม 2ฟอง',
#   'ถั่วฝักยาวลวก 1กำมือ',
#   'แครอทลวก 3ชิ้น'],
#  'ข้าวมันไก่ หม้อหุงข้าว': ['*สะโพกไก่ 2 ชิ้น (ใหญ่ ) (unknown unit type)',
#   'สะโพกไก่ 2 ชิ้น (ใหญ่ )',
#   'ขิง ',
#   'รากผักชี ',
#   'กระเทียม ',
#   'พริกไทย ',
#   'หัวไชเท้า ',
#   'ข้าวหอมมะลิ ',
#   'เกลือ ',
#   'ซีอิ๊วขาว ',
#   'ซีอิ๊วดำหวาน ',
#   'น้ำตาล ',
#   'ผงปรุงรส ',
#   'เต้าเจี้ยว ',
#   'มะนาวหรือน้ำส้มสายชู ',
#   'พริกขี้หนู '],
#  'ข้าวเหนียวเปียกดอกอัญชันทรงเครื่อง ': ['ข้าวเหนียวเขี้ยวงู 200 กรัม ',
#   'น้ำตาล 100 กรัม',
#   'น้ำเปล่า 1 ลิตร',
#   'น้ำดอกอัญชัน 1/2 ถ้วย',
#   'ข้าวโพดต้ม 150 กรัม',
#   'เผือกนึ่ง 150 กรัม',
#   'มะพร้าวอ่อน 150 กรัม',
#   'หน้า 250 มิลลิลิตร',
#   'หน้า 1 ช้อนโต๊ะ ',
#   'หน้า 1/4 ช้อนชา'],
#  'ต้มยำกุ้งมะพร้าวน้ำหอม(น้ำข้น)': ['กุ้งขาว ตามชอบ',
#   'น้ำพริกเผา 1 ชต',
#   'น้ำมะพร้าวหอม 2 ลูก',
#   'ผงต้มยำน้ำข้นมาม่า 3 ซอง',
#   'น้ำมันพริกเผามาม่า 1 ซอง',
#   'ชุดทำต้มยำข่า,ตะไคร้,มะกรูด,พริก,มะนาว 1 ชุด',
#   'กระเทียมบุบ 3 กลีบ',
#   'น้ำปลา 2 ชต',
#   'รากผักชีบุบ 4 ราก'],
#  'ไข่ลูกเขย ไข่นกกะทา': ['ไข่นกกะทาต้มพร้อมแกะ 35-40ฟอง',
#   'หอมแดง 6หัว',
#   'มะขามเปียก 1ปั้น',
#   'พริกแดงแห้ง 10เม็ด',
#   'น้ำมันพืช 1/2ขวด',
#   'น้ำตาลปึก 2ก้อน',
#   'น้ำตาลทราย 2 ชน',
#   'น้ำปลา 5 ชต'],
#  'ลาเต้น้ำตาลสด': ['กาแฟดริป 1 ซอง',
#   'นมสด 40 ',
#   'น้ำร้อน 50 มล.',
#   'น้ำตาลสด 40 มล.',
#   'น้ำแข็ง -'],
#  'ข้าวปลาซาบะย่างเกลือ': ['ปลาซาบะเเช่เเข็งเเมคโคร 1 ชิ้น',
#   'เกลือ นิดหน่อย',
#   'เนย/น้ำมัน '],
#  'ไข่ลูกเขย': ['ไข่ต้ม ', 'หอมเจียว ', 'น้ำตาลปี๊บ ', 'น้ำมะขาม ', 'ผักชี '],
#  'ขนมปังหน้าหมูและน้ำอาจาด': ['3 ขีด',
#   'ผงปรุงรสหมูคนอร์ 2 ช้อนชา',
#   '*ไข่ไก่ 1ฟอง (ฟอง)',
#   'แป้งมัน 2ช้อนโต๊ะ',
#   'ขนมปัง ',
#   'แตงกวา ',
#   'หอมแดง ',
#   'พริกชี้ฟ้าแดง ',
#   'น้ำส้มสายชู 2 ช้อนโต๊ะ',
#   'น้ำตาลทราย 4 - 5ช้อนโต๊ะ',
#   'เกลือ 2 ช้อนช้า',
#   'น้ำต้มสุก '],
#  'หมูสันคอผัดพริกเผาสะตอ': ['พริกสด+กระเทียมตำ ตามชอบ',
#   '*สันคอหมู 200 กรัม (กก.)',
#   'สะตอ ',
#   'ซอสปรุงรสฝาเขียว 1/2 ชต',
#   'น้ำมันหอยหรือซอสเห็ดหอม 1 ชต',
#   'น้ำตาล 1/2 ชต',
#   'น้ำพริกเผา 2 ชต'],
#  'ขนมปังฝรั่งเศสหน้าเนยกระเทียม หม้อทอดไร้มัน': ['เนย 50 กรัม',
#   'กระเทียม 2 หัว',
#   'พาสลีย์ 1 ชช',
#   'ขนมปังฝรั่งเศส '],
#  'Dalgona\u200b Coffee\u200b': ['กาแฟ 2 ช้อนโต๊ะ',
#   'น้ำตาลทรายไม่ฟอกสี 2 ช้อนโต๊ะ',
#   'น้ำร้อน 2 ช้อนโต๊ะ',
#   'นมตราหมี ',
#   'น้ำแข็ง '],
#  'กาแฟบ๊วยซ่าส์💥': ['กาแฟสด 2 ช็อต',
#   'บ๊วยดองเค็ม 2 เม็ด',
#   'น้ำผึ้ง 30 กรัม ',
#   'โซดา 100 ml',
#   'น้ำแข็ง 1 แก้ว'],
#  'Strawberry summer fresh 🍓🌊': ['น้ำสตรอเบอร์รี่เข่มข้น 40 ml',
#   'โซดา 1/2 ขวด',
#   'น้ำแข็ง 1 แก้ว'],
#  'โจ๊กนะคะ': ['*เนื้อหมูสับ 500กรัม (กก.)',
#   'ข้าวปลายหอมมะลิ 200กรัม',
#   'เกลือป่น 1|2ช้อนชา',
#   'ตับ 200กรัม',
#   'ผักชี ตามใจชอบ',
#   'น้ำสะอาด ครึ่งลิตร',
#   'สี่อิ๋วขาวสูตร1 5ช้อนโต๊ะ',
#   'พริกไทยป่น ตามใจชอบ',
#   'ถั่วคั่ว ตามใจชอบ',
#   'ขิงดอง ตามใจชอบ'],
#  'ไข่ลูกเขยหรรษา': ['ไข่ต้ม ',
#   'หอมเจียว ',
#   'น้ำตาลปี๊บ ',
#   'มะขามเปรียก ',
#   'ผงปรุงรส '],
#  'คอหมูย่าง': ['*สันคอหมู 500 g (กก.)',
#   '*คอหมู 500 g (กก.)',
#   'น้ำผึ้ง 1 ช้อนโต๊ะ',
#   'ซีอิ๋วขาว 1 ช้อนโต๊ะ',
#   'ซอสหอย 1 ช้อนโต๊ะ',
#   'ผงปรุงรส 1 ช้อนโต๊ะ',
#   'พริกไทยขาว 1 ช้อนโต๊ะ'],
#  'ไก่ต้มน้ำปลา': ['ไก่ ครึ่งตัว',
#   'ข่า ',
#   'รากผักชี ',
#   'น้ำปลา ',
#   'ซอสปรุงรส ',
#   'น้ำตาล ',
#   'น้ำเปล่า '],
#  'น้ำดอกอัญชันเข้มข้น สำหรับทำขนม ': ['ดอกอัญชัน 15 ดอก', 'น้ำร้อน 1/2 ถ้วย '],
#  'ตุ๋นกระดูกหมูน้ำดำ': ['กระดูกหมู 1kg',
#   'ต้นหอม 2ต้น',
#   'น้ำตาล 2ช้อนโต๊ะ',
#   'น้ำปลา 1ช้อนโต๊ะ',
#   'เกลือ 1ช้อนชา',
#   'รากผักชี 1ช้อนโต๊ะ',
#   'พริกไทยดำ 1ช้อนโต๊ะ',
#   'กระเทียม 1ช้อนโต๊ะ',
#   'น้ำมันหอย 2ช้อนโต๊ะ',
#   'ซีอิ้วขาว 2ช้อนโต๊ะ',
#   'ซีอิ้วดำ 1ช้อนโต๊ะ',
#   'ไข่ต้ม 3ฟอง'],
#  'บ๊ะจ่าง ทำไหว้ ทำกินเองก็ได้จ้า': ['ข้าวเหนียวดิบ 1 kg',
#   'กุ้งแห้ง 1 ถ้วยตวง',
#   'ถั่วลิสง 1 ถ้วยตวง',
#   'เห็ดหอม 1/2 kg',
#   '*หมูหมัก 1/2 kg (กก.)',
#   'พริกไทย 3 ช้อนโต๊ะ',
#   'น้ำมันพืช 3 ช้อนโต๊ะ',
#   'ซีอิ๊วขาว 3 ช้อนโต๊ะ',
#   'น้ำตาลทราย 1 ช้อนโต๊ะ',
#   'ซอสหอยนางรม 4 ช้อนโต๊ะ',
#   'ไข่แดงหั่นครึ่ง 1/2 kg',
#   'ใบไผ่ ',
#   'เชือกสำหรับมัด ',
#   'กระเทียม 1 ถ้วยตวง'],
#  'กาแฟหางแดง': ['กาแฟ 1 แคปซูล',
#   'น้ำแดง 1 ชต',
#   'น้ำดื่มแช่เย็น 25 มล.',
#   'น้ำแข็ง ',
#   'น้ำร้อน 1 ขีด 30 มล.'],
#  'Beef Rotie': ['แป้งโรตี 1 แผ่น', 'ไส้เนื้อสับ 2 ช้อนโต๊ะ'],
#  'บะจ่าง8เซียน': ['ข้าวเหนียวเขี้ยวงู 3 กิโล',
#   'เห็ดหอม 2 ขีด',
#   'ไข่เค็มแดง 15 ฟอง',
#   '*หมูสามชั้น 1/2 กิโล (กก.)',
#   'แปะก๊วย 2 ขีด',
#   'ถั่วซีก 1 ขีด',
#   'กุนเชียง 1 เส้น',
#   'เกาลัด 2 ขีด',
#   'ถั่วลิสง 1/2 กิโล',
#   'กุ้งแก้ง 3 ขีด',
#   'พริกป่น 3 ช้อนโต๊ะ',
#   'เกลือ 1 ช้อนโต๊ะ',
#   'น้ำมันหอย 2 ช้อนโต๊ะ',
#   'ซีอิ๊วขาว 5 ช้อนโต๊ะ',
#   'ผงปรุงรสคอร์นหมู 2 ช้อนโต๊ะ',
#   'น้ำตาลทรายขาว 3 ช้อนโต๊ะ'],
#  'ไก่ทอดเนยโชยุ (Butter Shoyu Chicken)': ['*สะโพกไก่ 2 - 4 ชิ้น (unknown unit type)',
#   'สะโพกไก่ 2 - 4 ชิ้น',
#   'เกลือโคเชอร์ ',
#   'พริกไทยดำป่นสดๆ ',
#   'น้ำมันที่มีรสชาติเป็นกลาง 1 ช้อนโต๊ะ',
#   'สาเก 3 ช้อนโต๊ะ',
#   'เนยรสจืด 1 ช้อนโต๊ะ',
#   'ส่วนผสมซอส ',
#   'โชยุ 2 ½ ช้อนโต๊ะ',
#   'สาเก 2 ช้อนโต๊ะ',
#   'มิริน 1 ช้อนโต๊ะ',
#   'น้ำตาล 1 ช้อนโต๊ะ'],
#  'ปลากระพงขาวลวก-จิ้ม': ['ปลากระพงขาว ',
#   'ขิง 2-4 เเว่น',
#   'เกลือนิดหน่อย ',
#   '~น้ำจิ้มเต้าเจี้ยว~ ',
#   'เต้าเจี้ยว 1ชต',
#   'พริก ตามชอบ',
#   'มะนาว 1 ชต',
#   'น้ำตาล 1/4 ชต'],
#  'ปลาซาบะย่างซอสโชยุ': ['ปลาซาบะเเร่เอาเนื้อออก ',
#   'ผักเเต่งจาน ',
#   'โชยุ ',
#   'น้ำตาล ',
#   'คาราเมล '],
#  'หุงข้าวเหนียวด้วยไมโครเวฟแค่ 7 นาที': ['ข้าวเหนียว 3 ถ้วย', 'น้ำร้อน '],
#  'ซุปเห็ดแชมปิญองกับอกไก่ย่าง': ['คิวพี 1 ถ้วย',
#   '*อกไก่ย่าง 1 ชิ้น (unknown unit type)',
#   'อกไก่ย่าง 1 ชิ้น',
#   'ขนมปังกระเทียม 2 ชิ้น',
#   'มะเขือเทศ ตามชอบ'],
#  'ไข่ตุ๋นแฮมชีส': ['*ไข่ไก่ 2ฟอง (ฟอง)',
#   'หมูบด ',
#   'แฮม ',
#   'เห็ดแชมปิยอง ',
#   'ชีสแผ่น 1แผ่น',
#   'นมคาร์เนชั่น 4ช้อน',
#   'น้ำเปล่า 4ช้อน',
#   'ซอสปรุงรสฝาเขียว 1ช้อน',
#   'ซอสหอยนางรม 1ช้อน'],
#  'ซาลาเปาไส้ถั่วแดงกวนไร้น้ำตาล สูตรนุ่มนวดมือ และไม่ใช้เนยขาว': ['แป้งเค้ก ',
#   'นมสด ',
#   'ยีสต์ผง ',
#   'น้ำตาล ',
#   'ผงฟู ',
#   'น้ำมันรำข้าว/น้ำมันคาโนล่า ',
#   'ถั่วแดงต้ม ',
#   'อิริทิทอล ',
#   'น้ำมันคาโนล่า ',
#   'น้ำตาลลดเพิ่มได้ตามชอบ '],
#  'ข้าวหน้าหมูบลูโกกิไข่ออนเซน ': ['ข้าว 1 ชาม',
#   '*หมูบลูโกกิ 4 ช้อนโต๊ะ  (ลิตร)',
#   '*ไข่ไก่ 1 ฟอง  (ฟอง)'],
#  'ซาลาเปาไส้หมูสับ': ['*เนื้อหมูบด 400g (กก.)',
#   'แครอท 20g',
#   'เห็ดหอม 2หัว',
#   'หอมใหญ่ ครึ่งลูก',
#   'ต้นหอม 2ต้น',
#   'ผงปรุงรส ',
#   'แป้งซาลาเปา ',
#   'แป้งอเนกประสงค์ 375g',
#   'เกลือ 1ชช',
#   'น้ำตาล 20g',
#   'ผงฟู 2ชต',
#   'น้ำมันพืช 2ชต',
#   'ยีสต์ 4g',
#   '*นม 260g (กก.)'],
#  'ข้าวต้มหมูสับ': ['ข้าวสวย 1 จาน',
#   '*หมูสับ 1 ถ้วย (unknown unit type)',
#   'หมูสับ 1 ถ้วย',
#   'ต้นหอมคื่นช่าย 1 กำ',
#   'ซีอิ๊วเห็ดหอม ',
#   'น้ำปลา ',
#   'พริกไทย '],
#  'ขนมปังซุปหอมใหญ่โบโลน่าอบชีส 🧀': ['หอมใหญ่ซอย 1/2 หัว',
#   'โบโลน่าหั่นเต๋า ตามชอบ',
#   'มายองเนส ตามชอบ',
#   'อโรมาต 1/4 ชช',
#   'มาการีน ทาขนมปัง',
#   'ขนมปังแผ่นหนา 2 แผ่น',
#   'น้ำมันพืช 1 ชช',
#   'อลาวรี่ ตามชอบ'],
#  'แซนวิชปลาซาบะอโวคาโด 🐟🥑\U0001f96a': ['ขนมปัง 4 แผ่น',
#   'ปลาซาบะในน้ำเกลือ 1 กระป๋อง',
#   'มัสตาร์ด ตามชอบ',
#   'ซอสมะเขือเทศ ตามชอบ',
#   'มายองเนส ตามชอบ',
#   'อโวคาโด 1/2 ลูก ',
#   'พริกไทย เล็กน้อย',
#   'ไข่แดงต้มสุก 4 ฟอง',
#   'น้ำมันงา 1/2 ชช',
#   'โคชูจัง 1 ชช'],
#  'บราวนี่ไมโครเวฟจากผงไมโล': ['แป้งอเนกประสงค์ 50g',
#   'น้ำมันพืช 50g',
#   'น้ำตาลปรับได้ตามชอบ 55g.',
#   'ผงไมโลลดน้ำตาล 50g',
#   '*ไข่ไก่ 1 ฟอง (ฟอง)',
#   'เกลือป่น เล็กน้อย',
#   'ถั่ว ตามชอบ'],
#  'เฮลท์ตี้ มิกซ์สลัดมันฝรั่ง\U0001f96a': ['คิวพี 3 ช้อนโต๊ะ',
#   'ขนมปังโฮลวีท 1 แผ่น',
#   '*อกไก่ต้ม 1 ช้อนโต๊ะ (ลิตร)',
#   'พริกไทย เล็กน้อย',
#   'พาสลีย์ เล็กน้อย'],
#  'แคบหมู': ['หมู ', 'น้ำมัน ', 'เกลือ '],
#  'มาม่าแล้วแต่': ['กุ้ง 2-3 ตัว',
#   'ปลาหมึก 2-3 ตัว ',
#   '*หมูสับก้อน 50 กรัม  (กก.)',
#   'หมูกรอบ 1 แผ่น',
#   '*ไข่ไก่ 2-3 ฟอง  (ฟอง)',
#   'มาม่า 2-3ห่อ ',
#   'ชุดต้มยำ 1 ชุด',
#   'คนอร์ 1/2 ก้อน ',
#   'น้ำพริกเผา 2 ชต',
#   'พริกตำ 2-3 ชต',
#   'มะนาว 2 ลูก'],
#  'ขนมจีนน้ำเงี้ยว': ['กระดูกหมู 1/2 กก',
#   'พริกแกงน้ำเงี้ยว 1 ถ้วย',
#   'ถั่วเน่า 1 แผ่น',
#   'มะเขือเทศหั่น 1 ถ้วย',
#   'ซุปก้อน 1 ก้อน',
#   'เกลือ 1/2 ช้อนชา',
#   'น้ำปลาอย่างดี 2 ช้อนโต๊ะ',
#   'หอมแดงซอย 1 ถ้วย',
#   'ผักกาดดองซอย 1 ถ้วย',
#   'แคปหมู 1 ถ้วย',
#   'เลือดไก่ 1 ก้อน',
#   'ดอกงิ้ว 4-5 ต้น',
#   '*หมูบดติดมัน 1 ถ้วย (unknown unit type)',
#   'หมูบดติดมัน 1 ถ้วย'],
#  'อาหารสด จานด่วนน': ['แป้ง 100 กรัม', '*หมู 5 กรัม (กก.)', 'ผักสด 3 กรัม'],
#  'ข้าวต้มปลาหอย': ['ข้าวสวย 2ทัพพี',
#   'ปลาอินทรีย์ ',
#   'หอยนางรม ',
#   'ข่า ',
#   'ขึ้นช่าย ',
#   'คนอร์หมูก้อนสูตรไม่ใช่ชูรส ',
#   'ซีอิ๊วขาว ',
#   'พริกไทย ',
#   'ไข่ไก่ '],
#  'แกงคั่วซี่โครงหมู': ['*ซี่โครงหมู 1กิโล (กก.)',
#   'พริกแกงใต้ 2ขีด',
#   'กะทิ 250มิลลิลิตร',
#   'น้ำปลา 1ช้อนโต๊ะ',
#   'น้ำตาลปี๊บ 2ช้อนโต๊ะ',
#   'ใบมะกรูด 4ใบ',
#   'พริกชี้ฟ้าแดง 3เม็ด',
#   'คนอร์ 1ก้อน',
#   'น้ำซุป ตามชอบ'],
#  'แกงคั่วเนื้อใส่หน่อไม้': ['*เนื้อสันในวัว 300กรัม (กก.)',
#   'กะทิสด 2ขีด',
#   'หน่อไม้ต้มสุก 1ถุง',
#   'พริกแกงกะทิใต้ 2ช้อนโต๊ะ',
#   'พริกแกงเผ็ดใต้ 1ช้อนโต๊ะ',
#   'กะปิกุ้งอย่างดี 1ช้อนโต๊ะ',
#   'เครื่องปรุงรสตามชอบ 1ส่วน'],
#  'สปาเก็ตตี้เขียวหวาน ปลาสลิด': ['ปลาสลิด 2ตัว',
#   'พริกแกงเขียวหวาน 2ช้อนโต๊ะ',
#   'สปาเก็ตตี้ 250กรัม',
#   'ใบโหระพา 3-4ต้น',
#   'มะเขือพวง 2พวง',
#   'พริกชี้ฟ้า 1เม็ด',
#   'มะเขือเปาะ 1ลูก',
#   'กะทิชาวเกาะ 1 กล่อง',
#   'น้ำตาล 1ช้อนโต๊ะ',
#   'ซีอิ๊วขาว ครึ่งช้อนโต๊ะ',
#   'น้ำมันหอย 2ช้อนโต๊ะ',
#   'ผงปรุงรสคนอร์ 1ช้อนชา'],
#  'ขนมปังชุบไข่ไส้กรอก 🌭': ['ขนมปัง 4 แผ่น',
#   'มาการีนหรือเนยสด ทาขนมปัง',
#   'ไส้กรอกค็อกเทลผัก3สี 1 ห่อ',
#   '*ไข่ไก่ 1 ฟอง (ฟอง)',
#   'พริกไทย เล็กน้อย'],
#  'สลัดปูสไตล์ญี่ปุ่น (Japanese Kani Salad)': ['เนื้อปู 5 ออนซ์ (140 กรัม)',
#   'แตงกวา ½ ลูก',
#   'เมล็ดข้าวโพดเหลือง ½ ถ้วย',
#   'น้ำสลัดมายองเนสพอนซึ ',
#   'มายองเนสญี่ปุ่น 2 ช้อนโต๊ะ',
#   'พอนซึ 1 ช้อนโต๊ะ',
#   'งาขาวคั่ว 1 ช้อนโต๊ะ',
#   'โชยุ ½ ช้อนชา'],
#  'น้ำสลัดบีทรูท❤️': ['apple 5 ช้อนโต๊ะ',
#   'น้ำตาลทราย 1 ช้อนโต๊ะ ',
#   'น้ำมันมะกอก 3 ช้อนโต๊ะ',
#   'น้ำมะนาว 3 ช้อนโต๊ะ',
#   'เกลือป่น 1/2 ช้อนชา',
#   'บีทรูทต้มสุก 1/2 หัว',
#   'พริกไทยป่น 1/2 ช้อนชา',
#   'น้ำผึ้ง 2 ช้อนโต๊ะ',
#   'มัสตาร์ด 1 ช้อนโต๊ะ '],
#  'ไข่อบมันฝรั่งและชีส  baked egg and potatoes with cheese ': ['มันฝรั่งตามชอบ ',
#   'พาเมซานชีสตามชอบ ',
#   'ไส้กรอกตามชอบ ',
#   'เกลือป่นเล็กน้อย ',
#   'พริกไทยป่นเล็กน้อย ',
#   'ซอสมะเขือเทศตามชอบ ',
#   'มัสตาร์ดตามชอบ ',
#   'วิปปิ้งครีมหรือนมสด ',
#   'ไข่ไก่ ',
#   'ชีสโรยหน้า ',
#   'พาสลีย์โรยหน้า ',
#   'เบค่อนทอดกรอบโรยหน้า '],
#  'Coffee mojito': ['เอสเปรสโซ่ 1ชอท',
#   'น้ำส้ม 3/4ถ้วย',
#   'ใบสะระแหน่ 10ใบ',
#   'โซดา ตามชอบ',
#   'เหล้าส้ม ตามชอบ'],
#  'คะน้าฮ่องกง+เนื้อน้ำมันหอย': ['เนื้อ 1 ถ้วย',
#   'กระเทียมตำ 1 ลูก',
#   'คะน้าฮ่องกง 2 ต้น',
#   'น้ำมันหอย 1 ช้อนโต๊ะ',
#   'ซีอิ๊วขาว สามสี่เหยาะ',
#   'แป้งมัน 1 ช้อนโต๊ะ'],
#  'มะม่วงแช่อิ่ม ไม่มีสี ไม่มีสาร': ['มะม่วงสด 2 กก.',
#   'เกลือหมักดอก 200 กรัม',
#   'น้ำตาลทราย 500 กรัม'],
#  'ขนมเบื้องโบราณ ไส้ครีม': ['ถั่วเขียวเราะเปลือก 300กรัม',
#   'ไข่เป็ด 1ฟอง',
#   'น้ำตาลปี๊บ1 1ชต.',
#   'เกลือ 1/4ชช.',
#   'ต้นหอม 2ต้น',
#   'งาขาวคั่วไว้โรยหน้า ',
#   'ไข่ขาวไข่เป็ด 1ฟอง',
#   'น้ำตาลปีบ2หรือน้ำเชื่อมร้อนๆ ปีบ1ชต. น้ำเชื่อม 2ชต.',
#   'น้ำปูนใส 2 ชต.',
#   'แป้งเอนกประสงค์ 1ชต.'],
#  'อกไก่ สโมคปาปริก้า': ['*ส่วนผสม ',
#   '*อกไก่ 400 กรัม (กก.)',
#   'น้ำมันมะกอก 1 ช้อนชา',
#   'แม็คคอร์มิค 1 ช้อนชา',
#   'แม็คคอร์มิค 1/4 ช้อนชา',
#   '*ส่วนผสม ',
#   'แครอท 450 กรัม',
#   'นมถั่วเหลือง 2 ช้อนโต๊ะ',
#   'แม็คคอร์มิค หยิบมือ',
#   'แม็คคอร์มิค หยิบมือ',
#   'เกลือ สำหรับปรุงรส',
#   'พริกไทย สำหรับปรุงรส',
#   '*ส่วนผสม ',
#   'ผักสลัด 50 กรัม',
#   'ถั่วขาวต้มสุก 2 ช้อนโต๊ะ',
#   'ข้าวโพดต้มสุก 2 ช้อนโต๊ะ',
#   'ลูกเดือยต้มสุก 2 ช้อนโต๊ะ',
#   'งาขาวคั่ว 1/2 ช้อนชา',
#   'เมล็ดทานตะวัน 2 ช้อนชา',
#   'น้ำมันมะกอก 1 ช้อนโต๊ะ',
#   'ผิวมะนาวเลมอน 1/2 ช้อนชา',
#   'น้ำมะนาวเลมอน 1/4 ผล'],
#  'ฟักทองแกงบวด': ['ฟักทองเนื้อแน่น ', 'น้ำตาลมะพร้าว ', 'เกลือ ', 'กะทิ '],
#  'Orange coffee dalgona 🍊': ['ผงกาแฟสำเร็จรูป 4 ช้อนโต๊ะ',
#   'น้ำตาล 4 ช้อนโต๊ะ',
#   'น้ำเปล่า 4 ช้อนโต๊ะ',
#   'น้ำส้ม 3/4 แก้ว',
#   'สะระแหน่ 1 ยอด '],
#  'jejeje': ['猪 1'],
#  'หมูย่างเกาหลีสลัดต้นหอม': ['*หมูสันนอกติดมัน￼ 1 กก   (กก.)',
#   'งาขาวสำหรับหมัก 3 ช้อนโต๊ะ',
#   'ซอสพริกเกาหลีหมักหมู 2 ชต ',
#   'เกลือ 1 ชช',
#   'น้ำตาล 1 ชช',
#   'โชยุ 3 ชต  ',
#   'น้ำส้มสายชู 1 ชต  ',
#   'น้ำมันงา 1 ชต ',
#   'น้ำตาลทรายแดง 1ชต',
#   'กระเทียมสับ ตามชอบ',
#   'พริกสับ ตรมชอบ',
#   'มะนาว 1ชต',
#   'น้ำสลัดต้นหอม 3ชต',
#   'ต้นหอมยักษ์หั่นฝอย 1ต้น',
#   'ผักสลัดหั่นเล็ก ตามชอบ',
#   'น้ำเชื่อม 1ชต',
#   'งาขาว 1 ชต',
#   'น้ำส้มสายชูหมักทำซูชิ 1 ชต',
#   'สาหร่ายโรยข้าว 1หยิบ'],
#  'น้ำตกเนื้อ': ['*เนื้อวัวติดมัน 300 กรัม (กก.)',
#   'ต้นหอม 1 ช้อนโต๊ะ',
#   'ผักชีฝรั่ง 1 ช้อนโต๊ะ',
#   'หอมแดง 2 ช้อนโต๊ะ',
#   'สาระแหน่ 2 ช้อนโต๊ะ',
#   'ข้าวคั่ว 1 ช้อนโต๊ะ',
#   'ผงปรุงรส 1 ช้อนชา',
#   'น้ำตาล 1 ช้อนชา',
#   'น้ำปลา 1 ช้อนโต๊ะ',
#   'พริกป่น 1 ช้อนโต๊ะ',
#   'มะนาว 1 ลูกใหญ่',
#   'น้ำเปล่า 100 มล'],
#  'ต้มจืดลูกเงาะเห็ดเยื่อไผ่': ['หมูสับ ตามชอบ',
#   'วุ้นเส้น ตามชอบ',
#   'หัวไชเท้า 1 หัว',
#   'แครอท 1 หัว',
#   'เห็ดเยื่อไผ่ ตามชอบ',
#   'พริกไทยขาว ตามชอบ',
#   'เกลือ ปลายช้อนชา',
#   'ซีอิ๊วขาว ปลายช้อนชา',
#   'หัวหอม 1 หัว',
#   'เม็ดเก๋ากี้ 4-5 เม็ด',
#   'กระเทียมสับ '],
#  'ผัดบวบใส่ไข่🥒': ['บวบ 1 ลูก',
#   'กระเทียมสับ 2 กลีบ',
#   'น้ำปลา 1 ช้อนโต๊ะ',
#   'น้ำตาล 1 ช้อนโต๊ะ',
#   'ซอสหอยนางรม 1 ช้อนโต๊ะ',
#   'แครอทหั่นเส้น 2 ช้อนโต๊ะ',
#   '*ไข่ไก่ 2 ฟอง (ฟอง)'],
#  'สลัดโซบะ น้ำสลัดญี่ปุ่น': ['เส้นโซบะ 120 กรัม',
#   'แตงกวาญี่ปุ่น 1/4 ลูก',
#   'มะเขือเทศราชินี 3 ลูก',
#   'ส้มวาเลนเซีย 1/2  ลูก',
#   'ผักร็อกเก็ต 1 ถ้วยตวง',
#   'เห็ดชิเมจิ 6  ดอก',
#   'ไข่ต้ม 1/2 ฟอง',
#   'ต้มหอมซอย,งาขาวคั่วสำหรับโรย ตามชอบ',
#   'ส่วนผสมน้ำสลัดญี่ปุ่น ',
#   'คิคโคแมน 2 ช้อนโต๊ะ',
#   'น้ำส้มสายชู 2 ช้อนโต๊ะ',
#   'น้ำตาลทราย 1 ช้อนชา',
#   'พริกไทยดำป่น ตามชอบ'],
#  'น้ำพั้นซ์ผลไม้สด': ['น้ำเเดงเฮลส์บลูบอยสีแดง 500\u200b ml.',
#   'น้ำส้มซันควิกรสผลไม้รวม 350\u200b ml.',
#   'ซันควิก 150\u200b ml.',
#   'น้ำเปล่าเย็นจัด 1,250 ml.',
#   'ผลไม้ลอย ตามชอบ',
#   'ใบสะระแหน่ ',
#   'ดอกเกลือ 1\u200b ช้อนชา',
#   'อื่นๆ '],
#  'แกงเขียวหวานเนื้อซี่โครงกับเนื้อสามชั้นพริกขี้หนูสวน': ['เนื้อซี่โครง 10 กิโล',
#   'เนื้อสามชั้น 10 กิโล',
#   'พริกแกงเขียวหวาน 4 กิโล',
#   'กะทิ 25 กิโล',
#   'น้ำตาลปี๊บ ',
#   'น้ำปลาดี ',
#   'ดอกเกลือ 2 กำมือ',
#   'เครื่องเทศต้มเนื้อเปื่อย 4 ถุง',
#   'ซอสปรุงรสฝาเขียว ',
#   'กระดูกเนื้อ 5 กิโล',
#   'ยี่หร่าคั่ว ',
#   'ลูกผักชีคั่ว ',
#   'กระเทียมไทยเม็ดเล็ก ',
#   'พริกไทยเม็ด ',
#   'พริกขี้หนูสวน ',
#   'มะเขือเปราะ ',
#   'ใบโหระพา ',
#   'รากผักชี ',
#   'เกลือ '],
#  'ซุปเนื้อวัวน้ำใส☺️ ': ['*เนื้อวัวสันใน 500 กรัม (กก.)',
#   'หัวหอมใหญ่ 2 หัว',
#   'มะเขือเทศ 1 ลูก ',
#   'มันเทศ 1 หัว',
#   'แครอท 2 หัว ',
#   'คื่นช่าย 1 ขีด',
#   'หัวไชเท้า 1/2 หัว ',
#   'อบเชย 1 ก้าน',
#   'ลูกกระวาน 4-5 ลูก',
#   'โป๊ยกั๊ก 1 ดอก',
#   'เกลือ 1 ช้อนชา',
#   'น้ำเปล่า 1.5 ลิตร'],
#  'น้ำสลัดมะเขือเทศ': ['มะเขือเทศ 1 ลูก',
#   'มายองเนส 1 1/2 ช้อนโต๊ะ',
#   'น้ำมันมะพร้าว 1/2 ช้อนชา',
#   'น้ำผึ้ง 1 ช้อนชา'],
#  'สลัดเวียดนาม': ['**ส่วนผสม ',
#   '*ไก่ 600 กรัม (กก.)',
#   'ตะไคร้ซอยละเอียด 1 หัว',
#   'กระเทียมสับละเอียด 1 ชต.',
#   'น้ำมะนาว 1 ชต.',
#   'น้ำปลา 1 ชต.',
#   'ซอสถั่วเหลือง/ซอสปรุงรส 1 ซต.',
#   'น้ำตาลทรายแดง 2 ชต.',
#   'น้ำมันสำหรับทำอาหาร 1 ชต.',
#   'ฮอยซินซอส 2 ชต.',
#   '**ชามสลัด** ',
#   'ไก่ย่าง ',
#   'เส้นขนมจีน/เส้นหมี่แห้ง/วุ้นเส้นลวกแล้ว 200 กรัม',
#   'แตงกวาหั่นเส้น 1 ลูกใหญ่',
#   'แครอทขูดเส้น 1 หัวใหญ่',
#   'ถั่วงอก 2  ถต.',
#   'กระหล่ำปลีซอย 2 ถต.',
#   'ผักต่างๆตามชอบ ',
#   'ผักชีตามชอบ ',
#   'ใบโหระพาตามชอบ ',
#   'ถั่วลิสงคั่วบดตามชอบ ',
#   '**น้ำสลัด** ',
#   'น้ำปลาอย่างดี 1/4 ถต',
#   'น้ำส้มสายชูข้าว 2 ชต.',
#   'น้ำตาลทราย 3 ชต.',
#   'น้ำอุ่น 1/2 ถต.',
#   'น้ำมะนาว 1 ชต.',
#   'กระเทียมสับ 1 ชต.',
#   'พริกแดง 2 เม็ด',
#   '**ทาไก่ระหว่างอบ** ',
#   'ซอสฮอยซิน 2 ชต.'],
#  'ขนมปังปิ้งพาเมซานชีส': ['พาเมซานชีส 1 ช้อน', 'เนยสด 1 ช้อน'],
#  'Air fryer Taro Custard Thai  Dessert ❌no sugar / ขนมหม้อแกงเผือก ด้วย ': ['เผือกนึ่งหรือต้ม ',
#   'กะทิ ',
#   'ไข่ไก่ ',
#   'อิริทิทอล ',
#   'แป้งข้าวจ้าว ',
#   'เกลือ ',
#   'หมายเหตุ '],
#  'สลัดมันฝรั่งไข่ต้ม 🥔🥚': ['มันฝรั่งต้มสุกหั่นเต๋า 1 หัว',
#   'แครอทหั่นเต๋า 1/2 หัว',
#   'หอมใหญ่หั่นเต๋า 1 หัวเล็ก',
#   'ไข่ต้มสุกเอาเฉพาะไข่ขาว 2 ฟอง',
#   'น้ำสลัดครีม ตามชอบ'],
#  'Peach tea 💛🍊🥃': ['ชาพีช 6 ช้อนชา',
#   'น้ำร้อน 75 ml.',
#   'น้ำแข็ง 1 แก้ว',
#   'Topping '],
#  'Triple Rose Gimlette ': ['Triple 90 ml.',
#   'Green 30 ml.',
#   'Elderflower 30 ml.',
#   'Ice 1/2 cup'],
#  'ไข่ตุ๋นร้อนๆยามเช้า': ['*ไข่ไก่ 2ฟอง (ฟอง)',
#   'กระเทียม 2กลีบ',
#   'น้ำมัน 2ช้อนชา',
#   'ซีอิ้วขาว 1/2ช้อนชา',
#   'น้ำมันหอย 1/2ช้อนชา',
#   'น้ำตาลทราย เล็กน้อย',
#   'หอมใหญ่สับ 1ช้อนโต้ะ',
#   'น้ำเปล่า 2ช้อนชา'],
#  '#มาดามมะม่วงเข้าครัว ชวนทำ Sangria น้ำผลไม้เพื่อสุขภาพ ^^': ['ไวน์แดง 1 ขวด',
#   'ส้มวาเลนเซีย 1 ลูก',
#   'แอปเปิ้ล 1/2 ลูก',
#   'ผลไม้อื่นๆ ',
#   'โซดา '],
#  'ซีซาร์สลัด': ['ผักสลัด ',
#   'ขนมปังกรอบ ',
#   'น้ำสลัดซีซ่า/น้ำสลัดงา ',
#   'เบค่อนทอดกรอบ ',
#   'พาเมซานชีสละเอียด '],
#  'มันฝรั่งทอดกรอบโฮมเมด': ['มันฝรั่งผิวเรียบๆ 2-3\u200b หัว',
#   'เกลือสำหรับล้าง ',
#   'แป้งเค้ก ',
#   'น้ำมันสำหรับทอดเช่นรำข้าว ',
#   'เกลือหรือผงปาปริก้า '],
#  'น้ำสลัดสตรอเบอร์รี่ (Strawberry Dressing)': ['สตรอเบอร์รี่ 1 ถ้วย (ประมาณ 5.5 ออนซ์)',
#   'น้ำมันมะกอก ⅓ ถ้วย',
#   'น้ำส้มสายชูบัลซามิก 1 ช้อนชา',
#   'น้ำเลมอน ½ ลูก (1 ช้อนโต๊ะ)',
#   'สลัด ',
#   'ผักสลัดใบเขียว ตามชอบ',
#   'สตรอเบอร์รี่สไลด์ 2 - 3 ลูก',
#   'ถั่ววอลนัทคั่ว '],
#  'เกล็ดหิมะเสาวรสเบอรี่❄️': ['เสาวรส 6 ลูก ',
#   'น้ำส้มเข้มข้น 2 ช้อนโต๊ะ',
#   'น้ำเขื่อม 3 ช้อนโต๊ะ ',
#   'น้ำแข็ง 300 กรัม ',
#   'เบอรี่ 70 กรัม ',
#   'เกลือ 1/2 ช้อนชา '],
#  'สลัดปลาย่าง🥗 เพื่อสุขภาพ': ['คิวพี 1 ถ้วย',
#   'เนื้อปลากะพง 200 กรัม',
#   'อัลมอนด์สไลด์ เล็กน้อย',
#   'พริกไทย เล็กน้อย',
#   'เลมอน เล็กน้อย'],
#  'สูตรรักษา ฝ้า จุดด่างดำจากสิว หมองคล้ำ ให้ขาว ใส สุดยอดครีมรักษาฝ้า': ['สูตรรักษา 640 บาท'],
#  'น้ำส้มคั้นสด': ['ส้มเขียวหวาน 1\u200b กิโลกรัม',
#   'น้ำตาลทราย 2\u200b ช้อนโต๊ะ',
#   'เกลือ 1\u200b ช้อนชา'],
#  '!\nj': ['see ', 'e3 ', 'hg '],
#  'องุ่นเคียวโฮแครอทม่วงสมูทตี้ 🍇': ['องุ่นเคียวโฮแช่ฟรีซ ตามชอบ',
#   'แครอทม่วง 1 หัวเล็ก',
#   'น้ำดื่มแช่เย็น 50 มล.',
#   'สาระแหน่ ตามชอบ'],
#  'สับปะรดแครอทโยเกิร์ตสมูทตี้ ': ['แครอท 1/2 หัว',
#   'สับปะรดแช่แข็ง ตามชอบ',
#   'โยเกิร์ตรสธรรมชาติไขมัน 1 ถ้วย',
#   'น้ำดื่ม 1 ถ้วยโยเกิร์ต'],
#  'Keto coconut-flour bread /ขนมคีโต :  ขนมปัง ทำจากแป้งมะพร้าว   ': ['ไข่ ',
#   'น้ำมันมะพร้าว ',
#   'แป้งมะพร้าว ',
#   'เกลือ ',
#   'ผงฟู '],
#  'สับปะรดมิกซ์เบอร์รี่โยเกิร์ตสมูทตี้': ['โยเกิร์ตมิกซ์เบอร์รี่และธัญญาหาร 1 ถ้วย',
#   'สับปะรดแช่แข็ง ตามชอบ',
#   'น้ำชาเขียวดอกหอมหมื่นลี้แช่เย็น 1 ถ้วยโยเกิร์ต'],
#  'สับปะรดอโวคาโดปั่น 🥑🍍': ['สับปะรดแช่แข็ง ตามชอบ',
#   'อโวคาโด 1 ลูก',
#   'น้ำดื่ม กะเอา'],
#  'ต้มยำไข่แซ่บ': ['*ไข่ไก่ 3 ฟอง (ฟอง)',
#   'หอมแดงซอย 1 ช้อนโต๊ะ',
#   'กระเทียม 1/2 ช้อนโต๊ะ',
#   'น้ำปลา 1ช้อนโต๊ะ',
#   'น้ำมะนาว 2ช้อนโต๊ะ',
#   'น้ำตาล 1ช้อนโต๊ะ',
#   'ข่า 1ช้อนโต๊ะ',
#   'ตะไคร้ 2ต้น',
#   'ใบมะกรูด นิดหน่อย',
#   '*นมสด 1กล่อง (unknown unit type)',
#   'นมสด 1กล่อง',
#   'น้ำพริกเผา 1ช้อนโต๊ะ',
#   'พริกสด 10เม็ด'],
#  'ปีกไก่กลางทอดกรอบ': ['*ปีกไก่กลาง 1 กก (กก.)',
#   'รสดีเเป้งชุบทอด 1 ซอง',
#   'น้ำ 160 มล'],
#  'คั่วหน่อไม้': ['*หมูสามชั้น 1 ขีด (กก.)',
#   'หน่อไม้หวาน 6 หน่อเล็ก',
#   'หอมแดง 3 หัว',
#   'พริกหนุ่ม 2 เม็ด',
#   'กระเทียม 5 กลีบ',
#   'นำ้มันหอย '],
#  'กระเพราไส้กรอกหมูสับ 🐷': ['ไส้กรอก 1 แพค',
#   '*หมูสับ 150-200 กรัม (กก.)',
#   'ใบกระเพรา ตามชอบ',
#   'พริก 3 เม็ด',
#   'พริกแห้ง 2 เม็ด',
#   'น้ำปลา 2 ช้อนชา',
#   'ซีอิ๊วขาว 2 ช้อนชา',
#   'น้ำตาล 1 ช้อนชา',
#   'ซอสเห็ดหรือน้ำมันหอย 1 ช้อนโต๊ะ',
#   'พริกไทยขาวป่น '],
#  'ชาเขียวนมสด': ['ชาเขียว 2 ช้อนโต๊ะ',
#   'น้ำร้อนจัด 200 ml.',
#   'นมข้นหวาน 2 ช้อนโต๊ะ',
#   'น้ำตาลทราย 1 ช้อนชา',
#   '*นมสดรสจืด 50 ml. (ลิตร)',
#   'น้ำแข็ง เต็มแก้ว'],
#  'ไก่ผัดพริกหน่อไม้': ['*สะโพกไก่ 150 กรัม (กก.)',
#   '*ตับไก่ 50 กรัม (กก.)',
#   'ซอสปรุงรส 1 ช้อนโต๊ะ',
#   'ซอสน้ำมันหอยหรือซอสเห็ดหอม 2 ช้อนโต๊ะ',
#   'น้ำตาล 1 ช้อนโต๊ะ',
#   'หน่อไม้สดหั่นชิ้นเเช่เกลือจนนิ่มเเล้วบีบน้ำออก ตามชอบ',
#   'พริก '],
#  'อโวคาโดกล้วยหอมสมูทตี้🥑🍌': ['นมนด ตามชอบ',
#   'อโวคาโดไทย 1 1/2 ลูก',
#   'กล้วยหอมแช่แข็ง 1 ลูก'],
#  'วุ้นนมสดคุ้กกี้แอนด์ครีม': ['นมตราหมีสีเหลือง 1 กระป๋อง',
#   'คุ้กกี้ช็อกโกแลตสอดไส้ครีม 6 ชิ้น',
#   'ผงวุ้น 1 ช้อนชา',
#   'น้ำเปล่า 75 มิลลิลิตร',
#   'น้ำตาล ตามชอบ'],
#  'แครอทม่วงสับปะรดส้มปั่น 🥕🍊🍆': ['แครอทม่วงหั่นชิ้น 1 หัวเล็ก',
#   'น้ำส้มแมนดารินแช่เย็น 1 กล่อง',
#   'สับปะรดแช่แข็ง ตามชอบ',
#   'น้ำดื่มแช่เย็น กะเอา'],
#  'แกงเผ็ดปัตตานี จากตำราโบราณ พ.ศ. 2509': ['ไก่บ้านใช้ไก่ห้างก็ได้นะ ครึ่งตัว',
#   'ขมิ้น 1 แง่ง',
#   'หอมแดง 2 หัว',
#   'กระเทียม 15 กลีบ',
#   'ตะไคร้ 5-6 ต้น',
#   'ใบแมงลัก 1 มัด',
#   'กะปิ 1 ช้อนโต๊ะ',
#   'น้ำปลา 2/3 ทัพพี',
#   'น้ำมะขามเปียก 3 ช้อนโต๊ะ'],
#  'นมกีวี่ 🥝': ['*นมจืด 1 กล่อง (unknown unit type)',
#   'นมจืด 1 กล่อง',
#   'กีวี่ 2 ลูก',
#   'น้ำตาลทราย 2 ช้อนโต๊ะ'],
#  'อะโวคาโดนมสด | Avocado Milk Shake ': ['นมสด 500 cc',
#   'น้ำผึ้ง 3 ช้อนโต๊ะ',
#   'อะโวคาโด 1 ลูก'],
#  'กุยช่ายขาวผัดเต้าหู้ไข่หมูสับ 🐷': ['กุยช่ายขาว 1 แพค',
#   'หมูสับ ตามชอบ',
#   'เต้าหู้ไข่ 1 หลอด',
#   'ซีอิ๊วขาว 1 ช้อนโต๊ะ',
#   'ซอสเห็ดหอม 1 ช้อนโต๊ะ',
#   'น้ำตาล 1 ช้อนชา',
#   'พริก 2-4 เม็ด',
#   'กระเทียม ครึ่งหัว',
#   'พริกไทยขาวป่น 1/2 ช้อนชา',
#   'รากผักชี 2-3ราก',
#   'ซีอิ๊วขาว 1/2 ช้อนโต๊ะ',
#   'ซอสเห็ดหอมหรือหอยนางรม 1/2 ช้อนโต๊ะ',
#   'พริกไทยขาวป่น นิดหน้อย'],
#  'ฉู่ฉี่ปลาทู': ['ปลาทูสด  4 ตัว',
#   'น้ำพริกแกงเผ็ด 80 กรัม',
#   'ใบมะกรูดฉีกแล้วซอยละเอียด 1-2 ช้อนโต๊ะ',
#   'พริกชี้ฟ้าซอยละเอียด 1-2 ช้อนโต๊ะ ',
#   'กะทิ 250 มล',
#   'น้ำตาลปี๊บ 1 1/2 ช้อนโต๊ะ ',
#   'น้ำปลา  3 ช้อนโต๊ะ'],
#  'กล้วยทับน้ำกะทิ ': ['กล้วยน้ำว้า 1 หวี',
#   'น้ำตาลทราย ตามชอบ',
#   'เนยสดจืด ',
#   'น้ำกะทิ ',
#   'น้ำตาลมะพร้าว ',
#   'เกลือป่น เล็กน้อย'],
#  'เคบับไก่ (กะบับ) สูตรเร่งด่วนใน 10 นาที': ['*เนื้อไก่ 400 g (กก.)',
#   'หัวหอมแขก 1 หัว',
#   'มะเขือเทศ 1ลูก',
#   'ผงมาซาล่า 2 ช้อนโต๊ะ',
#   'ผงปาปริก้า 1 ช้อนโต๊ะ',
#   'เมล็ดยี่หร่า ครึ่งช้อนโต๊ะ',
#   'พริกไทยดำ ครึ่งช้อนโต๊ะ',
#   'เกลือ 2 ช้อนชา',
#   'กระเทียม 1 หัว',
#   'เนยแท้ 1 ช้อน',
#   'ผักหรือสลัดตามชอบ ตามชอบ'],
#  'แกงเขียวหวานเนื้อ(ยอดมะพร้าว&มะเขือ)': ['เนื้อโคขุน 3 ขีด',
#   'ยอดมะพร้าว 1 ถุง',
#   'มะเขือเปราะ 1 ตะกร้า',
#   'พริกแดงสด 2-3 เม็ด',
#   'โหระพา 1 กำ',
#   'พริกแกงเขียวหวาน 1 ซอง',
#   'กะทิ 1 ขวด',
#   'น้ำปลา ปรุงรสตามใจ',
#   'น้ำตาล ปรุงรสตามใจ'],
#  'น้ำผักผลไม้รวม': ['แครอทม่วง 1 หัวเล็ก',
#   'น้ำส้มเขียวหวานแช่เย็น 1 กล่อง',
#   'ขึ้นฉ่ายไทย ตามชอบ',
#   'เนื้ออินทผาลัมสด 4 เม็ด',
#   'น้ำแข็ง 6 ก้อน'],
#  'ขนมปังปิ้งเนยนม': ['ขนมปังหั่นหนา 2 แผ่น',
#   'เนย/มาร์การีน 2-3 ชต',
#   'น้ำตาล 2ชต หรือตามชอบ',
#   'นมข้นหวาน 2ชต หรือตามชอบ'],
#  'อกไก่พริกแกง': ['*เนื้ออกไก่หั่น 200 g (กก.)',
#   'กระชายซอยฝอย 1 หยิบมือ',
#   'พริกไทยอ่อน 1-2 ช่อ',
#   'โหระพาเด็ดเอาแต่ใบ 1 ถ้วย',
#   'พริกขี้หนู/ชี้ฟ้า 10 เม็ด',
#   'หอมแดง 2 หัว',
#   'กระเทียม 2 หัว',
#   'พริกแกงแดง 1 ช้อนโต๊ะ',
#   'น้ำปลา 6-7 เหยาะ'],
#  'สุกี้ยากี้ญี่ปุ่น': ['เนื้อสไลด์ 150 กรัม',
#   'ผักต่างๆ ตามชอบ',
#   '*ไข่ไก่ 1 ฟอง (ฟอง)',
#   'เต้าหู้ 40 กรัม',
#   '*ส่วนผสมน้ำซุป ',
#   'คิคโคแมน 1/4 ถ้วย',
#   'คิคโคแมน 1/2 ถ้วย',
#   'คิคโคแมน 1/3 ถ้วย',
#   'สาเก 1/4 ถ้วย',
#   'น้ำตาล 2 ช้อนโต๊ะ'],
#  'สตรอเบอร์รี่ชีสเค้ก ไม่ง้อเตาอบ': ['*ส่วนผสม ',
#   'สตรอเบอร์รี่แช่แข็ง 200 กรัม',
#   'น้ำตาล 65 กรัม',
#   'น้ำมะนาว 5 มล.',
#   '*ส่วนผสม ',
#   'แมคไวตี้ส์ไดเจสทิฟบิสกิต 100 กรัม',
#   'เนยละลาย 40 กรัม',
#   '*ส่วนผสม ',
#   'ครีมชีส 200 กรัม',
#   'น้ำตาล 200 กรัม',
#   'โยเกิร์ต 35 กรัม',
#   'น้ำมะนาว 5 มล.',
#   'เจลาตินแผ่น 3 แผ่น',
#   'วิปปิ้งครีม 120 กรัม',
#   'สตรอเบอร์รี 65 กรัม',
#   '*ส่วนผสม ',
#   'สตรอเบอร์รีซอส 100 กรัม',
#   'เจลาตินแผ่น 2 แผ่น',
#   'วิปปิ้งครีม 50 กรัม'],
#  'ข้าวเกรียบปากหม้อ': ['แป้งข้าวเจ้า 300 กรัม',
#   'แป้งมันสำปะหลัง 100 กรัม',
#   'แป้งท้าวยายม่อม 50 กรัม',
#   'เกลือป่น 3 กรัม',
#   'น้ำเปล่า 1 1/2 ถ้วยตวง',
#   'ใช้ไส้ร่วมกับม้าฮ่อ 30 ก้อน',
#   'ผักชี ',
#   'ผักกาดหอม ',
#   'พริกขี้หนูสวน ',
#   'กระเทียมเจียว ',
#   'พริกชี้ฟ้าแดงซอย ',
#   'สีผสมอาหารตามชอบ ',
#   'น้ำเดือด 3 ถ้วยตวง'],
#  'บะหมี่ผัดพริกกระเทียมชะอมหมูสับและไส้กรอก': ['บะหมี่ชวนชิม 1 ห่อ',
#   'พริกจินดาแดงซอย 10 เม็ด',
#   'กระเทียมฝานบาง 4 กลีบ',
#   'ชะอม ตามชอบ',
#   'ซอสผัดปรุงรสแม็กกี้ 4 ชต',
#   'น้ำตาลทราย 1 ชช',
#   '*หมูสับ 250 กรัม (กก.)',
#   'ไส้กรอกรมควันหั่นชิ้น 4 แท่ง',
#   'น้ำเปล่า เล็กน้อย',
#   'น้ำมันพืช 1 ชต'],
#  'ขนมปังปิ้งเตาถ่าน': ['ขนมปัง 2 แผ่น',
#   'เนยจืด 20 กรัม',
#   'น้ำตาล 1/2 ช้อนโต๊ะ',
#   'นมข้นหวาน ตามชอบ'],
#  'ขนมปังปิ้งหอมๆ': ['เนย 1 ชต', 'พาเมซานชีส 2 ชต'],
#  'แซนวิชแฮมพริกเผาหมูหยอง': ['ขนมปังโฮลวีท 3 แผ่น',
#   'น้ำพริกเผา ตามชอบ',
#   'หมูหยอง ตามชอบ',
#   'มายองเนส ตามชอบ',
#   'แฮม 2 แผ่น'],
#  'นมสดทอด ': ['*นมสด 3 ถ้วย (unknown unit type)',
#   'นมสด 3 ถ้วย',
#   'น้ำตาล 1/2 ถ้วย',
#   'แป้งข้าวโพด 1/2 ถ้วย',
#   'เนย 1 ช้อนโต๊ะ',
#   'เนย 3 ช้อนโต๊ะ',
#   '*ไข่ไก่ 2 ฟอง (ฟอง)',
#   'เกล็ดขนมปัง ',
#   'น้ำมันพืช '],
#  'ปีกไก่สไปซี่ หม้อทอดไร้มัน AirFryer': ['*ปีกไก่ 500 กรัม (กก.)',
#   'ผงฮอทเเอนด์สไปซี่ 1 ช้อนโต๊ะ',
#   'น้ำมันงา 1 ช้อนโต๊ะ'],
#  'ทาโก้เครป': ['แม็คคอร์มิค 1 ซอง',
#   '*หมูบด 350 กรัม (กก.)',
#   'หัวหอมใหญ่ 50 กรัม',
#   'ซอสมะเขือเทศ 20 กรัม',
#   'น้ำเปล่า 20 กรัม',
#   'แผ่นตอติญ่า 7 แผ่น',
#   'มะเขือเทศ 2 ลูก',
#   'ชีสมอสซาเรลลา 20 กรัม',
#   'ชีสเชดด้า 20 กรัม',
#   'ชีสพาเมซาน 5 กรัม',
#   'น้ำมันพืช สำหรับผัด',
#   'ผักกาดแก้ว ตามชอบ',
#   'มัสตาร์ด ตามชอบ'],
#  'แซนวิชไข่พริกเผา': ['ขนมปัง 2 แผ่น',
#   '*ไข่ไก่ 1 ฟอง (ฟอง)',
#   'โบโลน่า 2 แผ่น',
#   'น้ำพริกเผา ',
#   'ผักตามชอบ '],
#  'สะตอผัดกะปิหมูสามชั้น': ['*หมูสามชั้นหั่นชิ้นพอคำ 3 ขีด (กก.)',
#   'สะตอ 2 ขีด',
#   'กะปิอย่างดี 2 ช้อนโต๊ะ',
#   'พริกขี้หนู 10-20 เมล็ด (ตามชอบ)',
#   'กระเทียม 10 กลีบ',
#   'น้ำตาลปี๊บ 1 ช้อนชา',
#   'น้ำปลาอย่างดี 1 ช้อนชา',
#   'ผงปรุงรสคนอร์ 1 ช้อนชา',
#   'น้ำมันสำหรับผัด 2 ช้อนโต๊ะ',
#   'น้ำเปล่าเล็กน้อย '],
#  'ขนมปังแซนวิช': ['แป้งขนมปัง 350กรัม ',
#   'แป้งสาลีพิเศษ 150 กรัม',
#   'น้ำตาล 45 กรัม',
#   'เกลือ 5 กรัม',
#   'ยีสต์ 11 กรัม',
#   'น้ำเปล่า 350 มล.',
#   'เนยสด 35กรัม ',
#   'นมผง 30กรัม',
#   'กลิ่นนมเนย 1ชช.',
#   'ผงนิ่ม 5กรัม'],
#  'น้ำพริกแกงส้ม สูตรเพิ่มพริกสด': ['พริกชี้ฟ้าแห้ง 10เม็ด',
#   'พริกขี้หนูแห้ง 7 เม็ด',
#   'พริกจินดาแดงสด 10 เม็ด',
#   'หอมแดง 3 หัว',
#   'กระเทียม 3 กลีบ',
#   'กระชาย 7 แง่ง',
#   'เกลือ 1/2 ช้อนชา',
#   'กะปิ 1 ช้อนชา'],
#  'แกงไตปลา': ['พริกเครื่องแกงเผ็ด 400 กรัม',
#   'ไตปลาปลาทูหรือปลาจวดก็ได้ 50 cc',
#   'หน่อไม้หั่นสี่เหลี่ยมต้มสุกทิ้งน้ำไปแล้ว 1 กก.',
#   'สะตอ 200 กรัม',
#   'ฟักทองหั่น 200 กรัม',
#   'มะเขือเปาะ 200 กรัม',
#   'เนื้อปลาแห้ง 300 กรัม',
#   'กะปิ 1 ช้อนชา',
#   'ซอสปรุงรส 1 ช้อนโต๊ะ',
#   'น้ำตาลทราย 1 ช้อนโต๊ะ',
#   'น้ำมะขามเปียก 2/3 ถ้วย',
#   'ชะอม 100 กรัม',
#   'ข่า 50 กรัม',
#   'ตะไคร้ซอย 50 กรัม',
#   'ใบมะกรูดฉีก 10 ใบ',
#   'หอมแดงบุบ 50 กรัม',
#   'ขมิ้นบุบ 30 กรัม'],
#  'แซนวิชพริกเผาปูอัดหมูหยอง': ['ขนมปัง 3 แผ่น',
#   'หมูหยอง ตามชอบ',
#   'ปูอัด 4 แท่ง',
#   'น้ำพริกเผา ตามชอบ',
#   'เนย 1 ก้อน'],
#  'ต้มแซ่บเนื้อตุ๋น': ['เศษเนื้อ 1 กิโล\u2028',
#   'รากผักชี, ',
#   'พริกแห้ง, ',
#   'ซอสถั่วเหลือง 4 ช้อนโต๊ะ\u2028',
#   'น้ำปลา, ',
#   'ผักชีใปเลื่อย, ',
#   'มะเขือเทศ\u2028 '],
#  'ขนมปังปิ้งเนยทาแยมกระเจี๊ยบพุทราจีน ': ['ขนมปังทานตะวัน 1 ชิ้น',
#   'เนย 1 ช้อนโต๊ะ',
#   'แยมกระเจี๊ยบ 2 ช้อนโต๊ะ'],
#  'ปีกกลางไก่ทอด': ['*ปีกกลางไก่ 1 กิโลกรัม (กก.)',
#   'น้ำมันหอย 2 ช้อนชา',
#   'ผงปรุงรส 1 ช้อนโต๊ะ',
#   'แป้งชุบทอด พอประมาณ',
#   'น้ำมันพืช 500 กรัม',
#   'หอมเจียว ตามชอบ'],
#  'ขนมปังปิ้งเนยนมVsขนมปังปิ้งช๊อคโก้กล้วยหอม': ['ขนมปังปอนด์ 1 แถว',
#   'เนยสด 1 ถ้วย',
#   'นมข้นหวาน 1 หลอด',
#   'กล้วยหอม 2 ลูก',
#   'ผงไมโล 2 ห่อ'],
#  'ขนมต้ม': ['แป้งข้าวเหนียว 300 g',
#   'มะพร้าวทึนทึก 2 ลูก',
#   'น้ำตาลมะพร้าว 200 g',
#   'มะพร้าวสำหรับคลุก '],
#  'ขนมต้มขาว': ['แป้งข้าวเหนียว 2 ชต',
#   'น้ำเปล่า 250 กรัม',
#   'มะพร้าวทึนทึกขูดเส้นเคล้าเกลือป่นนึงสุก 200 กรัม',
#   'กลิ่นมะลิ 4 หยด',
#   'น้ำตาลปี๊บ 250 กรัม',
#   'มะพร้าวทึนทึกขูดเส้น 200 กรัม'],
#  'ขนมต้มอบควันเทียน': ['มะพร้าวขูดเป็นเส้น 2 ถ้วย',
#   'น้ำตาลปี๊บ 200 กรัม',
#   'น้ำลอยดอกมะลิ 1/3 ถ้วย',
#   'แป้งข้าวเหนียว 2 ถ้วย',
#   'หัวกะทิ 1/3 ถ้วย',
#   'มะพร้าวขูดเป็นเส้นสำหรับคลุก 1 ถ้วย',
#   'เกลือป่น 1/2 ช้อนชา',
#   'ควันเทียน 1 อัน'],
#  'บะหมี่เย็น โซเมนแตงกวา': ['คิคโคแมน 120 มิลลิลิตร',
#   'เส้นโซเมน 100 กรัม\xa0',
#   'แตงกวา 30 กรัม',
#   'วาซาบิ 10 กรัม\xa0',
#   'มะเขือเทศ ',
#   'มะนาว 2-3 แผ่น',
#   'ต้นหอมญี่ปุ่น 15 กรัม'],
#  'แกงจืดหมูสับวุ้นเส้น': ['*หมูสับ 300 กรม (กก.)',
#   'วุ้นเส้น 100 กรัม',
#   'แครอท 1 ',
#   'เต้าหู้ไข่ 2 หลอด',
#   'ผักชี 2 ต้น',
#   'กระเทียมทุบ 2 กลีบ',
#   'ผักกาดขาว 200 กรัม',
#   'น้ำตาล 1 ช้อนโต๊ะ',
#   'ซีอิ้วขาวฝาเขียว 3 ช้อนโต๊ะ',
#   'พริกไทย 1 ช้อนโต๊ะ',
#   'เกลือ 1/2 ช้อนโต๊ะ',
#   'น้ำเปล่า 3 ถ้วยถวง'],
#  'บาร์บีคิว สูตรทำขาย และทำกิน': ['*หมูสันคอ 1 กิโลกรัม (กก.)',
#   '*หมูส่วนสะโพก 3กิโลกรัม (กก.)',
#   'กระเทียมโขลกละเอียด 2 ช้อนโต๊ะ',
#   'ผักชีซอย 2 ต้น',
#   'พริกไทยดำ.ขาว 3 ช้อนโต๊ะ',
#   'นมสดคาเนชั่น ครึ่ง กระป๋อง',
#   'น้ำมันพืช 1 ช้อนโต๊ะ',
#   'รสดี 2 ช้อนโต๊ะ',
#   'น้ำตาลทราย 6 ช้อนโต๊ะ',
#   'น้ำตาลปีบ 3 ช้อนโต๊ะ',
#   'เกลือ 1 ช้อนโต๊ะ',
#   'ซอสบาร์บีคิวที่ผสมเรียบร้อย 12 ช้อนโต๊ะ',
#   'ซีอิ้วดำ 3 ช้อนโต๊ะ',
#   'ซอสฝาเขียว 2 ช้อนโต๊ะ',
#   'สับปะรดเนื้อแน่น 2 ลูก ใหญ่',
#   'พริกหยวก.พริกชีฟ้าแดง ครึ่ง กิโลกรัม',
#   'หอมใหญ่.หรือ 3 หัว',
#   'มะเขือเทศราชินี 200 กรัม',
#   'ซอสบาร์บีคิว 1 ถ้วยตวง',
#   'ซอสมะเขือเทศ 1 ถ้วยตวง ครึ่ง',
#   'ซอสพริก 1 ถ้วยตวง',
#   'น้ำเปล่า 1 ถ้วยตวง',
#   'พริกป่นละเอียด 1 ช้อนโต๊ะ',
#   'ผงพะโล้ ครึ่งช้อนโต๊ะ',
#   'กระเทียมสับละเอียด 1 ช้อนโต๊ะ',
#   'เนย 1 ช้อนโต๊ะ'],
#  'ไข่แดงดองน้ำปลากวน': ['*ไข่ไก่ 10 ฟอง (ฟอง)',
#   'น้ำปลาเมกาเชฟ 1 ถ้วยตวง',
#   'น้ำตาลมะพร้าว 50 กรัม',
#   'น้ำตาลทราย 50 กรัม',
#   'น้ำเปล่า 1 ถ้วยตวง'],
#  'ต้มจืดผักกาดดอง ใส่กระดูกหมู': ['กระดูกหมู 300 กรัม',
#   'ผักกาดดอง 500 กรัม',
#   'คนอร์ซุปหมูก้อน 1 ก้อน',
#   'กระเทียม 5 กลีบ',
#   'น้ำเปล่า 1 ลิตร',
#   'น้ำตาล 1 ช้อนชา'],
#  'ผัดเปรี้ยวหวานหมู ': ['*เนื้อหมูสไลด์ 250 กรัม (กก.)',
#   'หอมหัวใหญ่ 1 หัว',
#   'แตงกวาลูกเล็ก 5 ลูก',
#   'มะเขือเทศ 1 ลูก',
#   'กระเทียมสับ 1 ช้อนโต๊ะ',
#   'ต้นหอม 2 ต้น ',
#   'ซอสปรุงรส ตามชอบ',
#   'น้ำตาล ตามชอบ',
#   'ซอสมะเขือเทศ 3 ช้อนโต๊ะ',
#   'น้ำมันหอย ตามชอบ'],
#  'ขนมปังปิ้งหน้าชีส': ['เนยเค็ม ', 'ชีสพาเมซานประมาณ ', 'ขนมปัง '],
#  'ข้าวไข่ข้นกุ้ง เนื้อนุ่มละมุนลิ้น ': ['*ไข่ไก่เบอร์ 1 ฟอง (ฟอง)',
#   'ซีอิ๊วขาว 1 /2ช้อนชา',
#   '*นมสด 1 ช้อนโต๊ะ (ลิตร)',
#   'น้ำมัน 1/2 ช้อนชา',
#   'กุ้งลวกสุกแล้ว 5 ตัว'],
#  'ชานมวุ้นปีโป้': ['ชาdilmah 1 ซอง',
#   'ครีมเทียมพร่องไขมัน 1/4 ถ้วย',
#   'นมข้นหวาน 1/2 ช้อนโต๊ะ',
#   'วุ้นปีโป้ 1 ถ้วยเล็ก'],
#  'ชานม': ['ชาแดงอัสสัม 15 กรัม',
#   'น้ำร้อน 300 กรัม',
#   'คอฟฟี่เมท 2 ชต',
#   'นมข้นหวาน ตามชอบ',
#   'น้ำตาลทรายออร์แกนิค 1 ชต'],
#  'ขนมปังกรอบเนยชาไทยนมเย็น': ['นมข้นหวานชาไทย ',
#   'นมข้นหวานนมเย็น ',
#   'ขนมปัง 3 แผ่น',
#   'เนย 37\u200b กรัม',
#   'น้ำตาล 22\u200b กรัม\u200b',
#   'น้ำตาลไอซิ่ง 22\u200b กรัม\u200b',
#   '*ไข่ 1 ฟอง\u200b (ฟอง)',
#   'แป้งสาลี 18 กรัม\u200b',
#   'ผงฟู 1/8\u200b ช้อนชา\u200b',
#   'นมผง 12\u200b กรัม\u200b'],
#  'ทำสเต็กกินเองไม่ยาก 2': ['*สะโพกไก่ติดน่อง 300\tกรัม (กก.)',
#   'แม็คคอร์มิค สำหรับหมัก',
#   'น้ำมันมะกอก 3 ช้อนโต๊ะ + 1 ช้อนโต๊ะ',
#   'แครอท ตามชอบ',
#   'เนย 2\tช้อนโต๊ะ',
#   '*นมสด 1\tถ้วย (unknown unit type)',
#   'นมสด 1\tถ้วย',
#   'มะแขว่น 1\tช้อนโต๊ะ',
#   'แม็คคอร์มิค 1\tซอง',
#   'เกลือ/พริกไทยดำ สำหรับปรุงรส'],
#  'ชานม ชาใต้ นมเจ': ['ผงชา 1 ช้อนโต๊ะ', 'นมถั่วเหลือง 1 แก้ว', 'น้ำ 1 แก้ว'],
#  'วิธีทำ “ต้มยำไข่เจียว” เมนูต้มยำแซ่บถึงเครื่อง พร้อมไข่เจียวเนื้อนุ่ม ': ['คนอร์ 2 ก้อน',
#   '*ไข่ไก่ 4-5 ฟอง (ฟอง)',
#   'น้ำปลา 2 ช้อนโต๊ะ',
#   'น้ำ 1 ลิตร',
#   'ตะไคร้ทุบหั่นท่อน 1 ต้น',
#   'ใบมะกรูด 5 ใบ',
#   'ข่าหั่นแว่น 2 แว่น',
#   'ผักชีใบเลื่อย 10 กรัม',
#   'เห็ดชิเมจิ 50 กรัม',
#   'พริกขี้หนูบุบหยาบ 10 เม็ด',
#   'นมข้นจืด 2 ช้อนโต๊ะ',
#   'ผักชี '],
#  'ต้มแซ่บกระดูกอ่อนใบกะเพรา': ['กระดูกอ่อนหมู 500 กรัม',
#   'ข่าหั่นแว่น 4 ชิ้น',
#   'ตะไคร้บุบ 1 ต้น',
#   'ใบมะกรูดฉีก 4 ใบ',
#   'หอมแดงบุบ 5 หัว',
#   'คนอร์ซุปก้อน 1 ก้อน',
#   'น้ำปลา 2 ช้อนชา',
#   'น้ำตาล 1 ช้อนชา',
#   'พริกป่น 1/2 ช้อนโต๊ะ',
#   'พริกขี้หนูสับ ',
#   'มะนาว ',
#   'เห็ดฟาง 80 กรัม',
#   'ใบกะเพราะ 1 กำมือ',
#   'ผักชีฝรั่ง ',
#   'พริกแห้ง '],
#  'แซนด์วิชเนยถั่วกับสมูทตี้': ['*ส่วนผสมแซนด์วิช ',
#   'ขนมปัง 6 แผ่น',
#   'Jif 1/2 ถ้วย',
#   'เซเลอรี่ 2 ก้าน',
#   'ลูกเกดดำ ตามชอบ',
#   'แอปเปิล 1/2 ลูก',
#   'แม็คคอร์มิค ตามชอบ',
#   'กล้วยหอม 1/2 ลูก',
#   'น้ำผึ้ง ตามชอบ',
#   'เนยจืด ',
#   '*ส่วนผสมสมูทตี้ ',
#   'กล้วยหอม 2 ลูก',
#   '*นมสด 2 ถ้วย (unknown unit type)',
#   'นมสด 2 ถ้วย',
#   'น้ำผึ้ง 2 ช้อนโต๊ะ',
#   'น้ำแข็ง 2 ถ้วย',
#   'Jif 1/2 ถ้วย',
#   'Jif 2 ช้อนโต๊ะ'],
#  'แซนด์วิชผักโขมผัดไข่': ['คนอร์ 1 ช้อนชา',
#   'ผักโขม 200 กรัม',
#   '*ไขไก่ 2 ฟอง (ฟอง)',
#   'กระเทียม 1/2 ช้อนโต๊ะ',
#   'เกลือ 1 ช้อนชา',
#   'พริกไทย 2 ช้อนชา',
#   'ขนมปัง 2-3 แผ่น',
#   'เนย '],
#  'มาม่าทรงเครื่องเล้งแซ่บ': ['บะหมี่กึ่งสำเร็จรูป 3  ห่อ',
#   'คนอร์ซุปก้อน 1 ก้อน\xa0',
#   'กระดูกสันหลังหมู 500 กรัม',
#   'หมูสับปรุงรส ',
#   'กุ้งขาว ',
#   'ไข่แดง 5 ฟอง\xa0',
#   'หมูกรอบ ',
#   'เนื้อปูก้อน ',
#   'มะนาวหั่นฝาน ',
#   'ผักชีฝรั่ง '],
#  'ชานมเย็นสูตรหญ้าหวาน': ['ชาไทยผงปรุงสำเร็จ 1 ช้อนโต๊ะ',
#   'นมจืด ครึ่งกล่อง',
#   'น้ำตาลหญ้าหวาน 2 ซอง',
#   'น้ำแข็ง '],
#  'นมสดสตรอว์เบอร์รี': ['สมัคเกอร์ส 2 ช้อนโต๊ะ\xa0',
#   '*นมสด 300 มิลลิลิตร (ลิตร)',
#   'สตรอว์เบอร์รี ',
#   'น้ำสะอาด 2 ช้อนโต๊ะ',
#   'น้ำแข็ง 1 แก้ว'],
#  'Apple French Toast': ['*ส่วนผสมแอปเปิ้ล ',
#   'แอปเปิ้ล 2 ลูก',
#   'เนย 1/4 ถ้วย',
#   'น้ำตาลทรายแดง 1/4 ถ้วย',
#   'แม็คคอร์มิค ตามชอบ',
#   'แม็คคอร์มิค ตามชอบ',
#   '*ส่วนผสมคาราเมล ',
#   'น้ำตาลทราย 80  กรัม',
#   'วิปปิ้งครีม 100 กรัม',
#   'เนยเย็น 1 ถ้วย',
#   'แม็คคอร์มิค 1 ช้อนชา',
#   '*ส่วนผสมขนมปัง ',
#   '*นมสด 1/2 ถ้วย (unknown unit type)',
#   'นมสด 1/2 ถ้วย',
#   'แม็คคอร์มิค 1 ช้อนชา',
#   'เนยสำหรับทอด ',
#   'ขนมปังแซนวิช ',
#   'ลูกเกด สำหรับตกแต่ง',
#   'อัลมอนด์สไลด์ สำหรับตกแต่ง',
#   'ไอซิ่ง สำหรับตกแต่ง'],
#  'บราวนี่เนยถั่ว': ['Unsweetened 55 กรัม',
#   'Lindt 140 กรัม',
#   'ผงโกโก้ 30 กรัม',
#   'เนย 125 กรัม',
#   'จิฟ 30 กรัม',
#   '*ไข่ไก่ 3 ฟอง (ฟอง)',
#   'น้ำตาลทราย 275 กรัม',
#   'เกลือ 1/2 ช้อนชา',
#   'กลิ่นวานิลลา 2 ช้อนชา',
#   'แป้งสาลี 140 กรัม',
#   'พิมพ์ขนาด '],
#  'ต้มยำปลาหมึกยัดไส้': ['คนอร์ 2 ก้อน',
#   'ปลาหมึก 600 กรัม',
#   '*หมูสับ 300 กรัม (กก.)',
#   'พริกไทย 1 ช้อนชา',
#   'ซอสปรุงรส 1 ช้อนชา',
#   'ตะไคร้ 15 กรัม',
#   'ข่า 15 กรัม',
#   'ใบมะกรู 4-5 ใบ',
#   'นมข้นจืด 15 มิลลิลิตร',
#   'พริกขี้หนู 15 กรัม',
#   'มะนาว ',
#   'เกี๊ยวกรอบ '],
#  'ก๋วยเตี๋ยวต้มยำกุ้ง จากชุดทำก๋วยเตี๋ยวต้มยำสำเร็จรูป GRAB THAI GO': ['ชุดทำก๋วยเตี๋ยวต้มยำ 1 กล่อง',
#   'กุ้งสด 5-6 ตัว ตามชอบ',
#   'เห็ดฟาง 40 กรัม',
#   '*นมสด 100 ml. (ลิตร)'],
#  'ชาบูญี่ปุ่นจักรพรรดิ': ['โชยุ 1 ถ้วยตวง\xa0',
#   '"คิคโคแมน 2 ช้อนโต๊ะ',
#   'น้ำตาล 3 ช้อนโต๊ะ',
#   'น้ำเลมอน 3 ช้อนโต๊ะ',
#   'มิริน 2 ช้อนโต๊ะ',
#   '"คิคโคแมน ½ ถ้วยตวง',
#   'น้ำสะอาด 4 ถ้วยตวง',
#   'ชุดเนื้อสัตว์ทะล ',
#   '*เนื้อหมูสไลซ์ 200 กรัม (กก.)',
#   'เนื้อวากิวสไลซ์ 200 กรัม\xa0',
#   'ชุดผักรวม ',
#   'เส้นอูด้ง '],
#  'หมูสะเต๊ะ': ['เนื้อหมูหมัก ',
#   '*เนื้อหมูสันใน 600กรัม (กก.)',
#   'สูตรหมักหมู '],
#  'ก๋วยเตี๋ยวต้มยำ': ['เนื้อหมู 2'],
#  'สเต็ก\u200bอกไก่ซอสบัลซามิก': ['*อกไก่ 1 ชิ้น (unknown unit type)',
#   'อกไก่ 1 ชิ้น',
#   'เกลือ ปรุงรส',
#   'พริกไทยดำ ปรุงรส',
#   'น้ำส้มสายชูบัลซามิก 2 ช้อนชา',
#   'น้ามันรำข้าว 2 ช้อนชา',
#   'แครอท 1/3 หัว',
#   'น้ำเปล่า 2 ช้อนโต๊ะ'],
#  'จิ้มจุ่ม': ['*เนื้อหมู 3 ขีด (กก.)',
#   '*เนื้อไก่ 3 ขีด (กก.)',
#   'สามชั้นสไลด์ 3 ขีด',
#   'น้ำมันหอย 3 ช.ต.',
#   'น้ำมันหอย 2 ช.ต.',
#   'คนอร์ผง 3 ช.ต.',
#   'พริกป่นเกาหลี ตามชอบ',
#   'น้ำจิ้มสุกี้ ตามชอบ',
#   'ผักบุ้ง ตามชอบ',
#   'วุ้นเส้น ตามชอบ'],
#  'ยำขนมจีน': ['ขนมจีน 1/2 กก.',
#   'หมูยอ 1 ท่อน',
#   'ปลาทู 2 ตัว',
#   'ผักชีฝรั่ง 5 ต้น',
#   'หอมหัวแดง 5 หัว',
#   'พริกสดแดง 5 เม็ด',
#   'พริกป่น ตามชอบ',
#   'น้ำปลา/น้ำปลาร้า/มะนาว/น้ำตาล ตามชอบ'],
#  'ก๋วยเตี๋ยวต้มยำตามใจ': ['*หมู 1/2kg (กก.)', 'ผักช 2ต้น'],
#  'เค้กกล้วยหอมเจ': ['แป้งเค้ก 180 กรัม',
#   'น้ำตาลป่น 100 กรัม',
#   'น้ำมันรำข้าว 100 กรัม',
#   'กล้วยหอมงอมๆ 300 กรัม',
#   'ผงฟู 1 ชช',
#   'เบคกิ้งโซดา 1/2 ชช',
#   'กลิ่นวานิลลา 1 ชช',
#   'เกลือ หยิบมือ'],
#  'ก๋วยเตี๋ยวลุยสวน': ['ปลาทูนึ่งแกะเนื้อหั่นเป็นชิ้นตามยาว 2 ตัว',
#   'แผ่นก๋วยเตี๋ยว 2 แผ่น',
#   'หมูยอ 100 กรัม',
#   'แครอทลวกหั่นแท่ง 1/2 หัว',
#   'ผักชีฝรั่ง ',
#   'ใบโหระพา ',
#   'ใบสาระแหน่ ',
#   'แตงกวาหั่นแท่งปาดเมล็ดออก 1/2 ผล',
#   'ผักกาดหอม 4 ใบ',
#   'พริกขี้หนูแดง 15 ดอก',
#   'น้ำปลา 1 ช้อนโต๊ะ',
#   'น้ำต้มสุก 50 มล.',
#   'น้ำมะนาวคั้นสด 1 ช้อนโต๊ะ',
#   'รากผักชี 2 ราก',
#   'กระเทียม 6 กลีบ',
#   'น้ำสลัดงาญี่ปุ่น 20 มล.',
#   'ผักชี '],
#  'ก๋วยเตี๋ยวเรือ ': ['น้ำซุป ',
#   'ผงปรุงรสน้ำก๋วยเตี๋ยวเรือ 1ซอง',
#   'กระเทียมดอง+น้ำดอง 2-3หัว',
#   'กะทิ 1กล่อง',
#   'กระดูกเล้ง 1/2กก',
#   'รากผักชี 4ราก',
#   'กระเทียม 5กลีบ',
#   'พริกไทเม็ด 2ชช',
#   'น้ำตาลปึก 2ก้อน',
#   'เครื่องเนื้อสัตว์ ',
#   '*หมูหมักนุ่ม 400กรัม (กก.)',
#   'ตับ 150กรัม',
#   'ลูกชิ้น 1/2กก',
#   'ถั่วงอก 10บาท',
#   'ผักบุ้งไท 2กำ',
#   'ผักชีฝรั่ง 1กำ',
#   'กระเทียมเจียว ',
#   'เส้นต่างๆตามชอบ '],
#  'ก๋วยเตี๋ยวต้มยำหมูสับไข่เยิ้ม': ['ไข่ไก่ ',
#   'เส้นหมี่ขาว ',
#   'หมูสับ ',
#   'น้ำพริกเผา ',
#   'ถั่วป่น ',
#   'น้ำตาล ',
#   'น้ำมะนาว ',
#   'ผักชี '],
#  'หมูย่างสเต็ก': ['*เนื้อหมูสันนอก 100กรัม (กก.)',
#   '*นมสด 1ถ้วยตวง (unknown unit type)',
#   'นมสด 1ถ้วยตวง',
#   'ซอสปรุงรส 2ช้อนโต๊ะ',
#   'พริกไทยดำ 1ช้อนชา',
#   'ใบไทม์ 1ช้อนชา',
#   'น้ำตาลทราย 1ช้อนโต๊ะ'],
#  'เค้กกล้วยหอม': ['แป้งสาลีเอกประสงค์ ไ180กรัม',
#   'ผงฟู 2ช้1/2ช้อนชา',
#   'โซดาไบคาร์บอเนต 3/4ช้อนชา',
#   'เนท้อกล้วยหอมสุดงอม 220กรัม',
#   '*นมจืด 100กรัม (กก.)',
#   'กลิ่นวนิลา 1ช้อนชา',
#   'มะนาว 1ซีก',
#   'น้ำมันถั่วเหลือง 170กรัม',
#   '*ไข่ไก่เบอร์ศูนย์ 2ฟอง (ฟอง)',
#   'เกลือ 1/2ช้อนชา',
#   'น้ำตาลทราย 150กรัม'],
#  'ก๋วยเตี๋ยวต้มยำรสเด็ด': ['น้ำซุปกระดูกหมู ตามชอบ',
#   'บะหมี่ลวกแล้ว 4 ก้อน',
#   'ไข่ต้ม 2 ฟอง',
#   'ลูกชิ้นกุ้ง ตามชอบ',
#   '✅เครื่องปรุงน้ำยำ หัวข้อสูตร',
#   'ถั่วลิสงป่น 1 ช้อนโต๊ะ',
#   'ปริกป่น 1 ช้อนชา',
#   'พริกเผา 1 ช้อนชา',
#   'น้ำปลา 1 ช้อนโต๊ะ',
#   'น้ำตาลทราย 1 ช้อนโต๊ะ',
#   'มะนาว 2 ซีก',
#   'ต้นหอมซอย 1 ช้อนโต๊ะ'],
#  'ก๋วยเตี๋ยวห่อหมูสับ': ['ก๋วยเตี๋ยวเส้นใหญ่ 0.5 KG',
#   '*หมูสับ 8 ขีด (กก.)',
#   'ผักกาดแก้ว 2 หัว',
#   'กระเทียม 1 แพค',
#   'ผักชี 1 แพค',
#   'หอมหัวใหญ่ 2 หัว',
#   'เครื่องปรุงรส ',
#   'คนอร์อร่อยชัวร์ ',
#   'น้ำจิ้มซีฟู้ด '],
#  'ก๋วยเตี๋ยวหมูต้มยำ': ['เนื้อหมู -',
#   'กระดูกเล้ง -',
# ...
#  'สุกี้ญี่ปุ่นน้ำดำ': ['น้ำซุป ',
#   'โชยุ ',
#   'มิริน ',
#   'น้ำมันพืช สำหรับผัด',
#   'หอมใหญ่ 1 ลูก',
#   'ต้นหอมญี่ปุ่น 1 ต้น',
#   'เต้าหู้ 1 กล่อง',
#   'หมูสไลด์ ตามชอบ',
#   'เห็ดหอม 3 ชิ้น',
#   'เห็ดเข็มทอง 1 ห่อ',
#   'ผักกาดขาว ตามชอบ',
#   'เส้นบุก ตามชอบ'],
#  'อกไก่ผัดหน่อไม้ดอง': ['เนื้ออกไก่ 220 ก.',
#   'หน่อไม้ดอง 120 ก.',
#   'พริกแดงจินดา 12 เม็ด',
#   'กระเทียมไทย 15 กลีบ',
#   'น้ำตาลโตนด 1/4 ชช.',
#   'ซีอิ๊วขาว 2 ชช.',
#   'ใบมะกรูด 4 ใบ',
#   'พริกชี้ฟ้า 3 ฝัก'],
#  'อกไก่คั่วสมุนไพร': ['*อกไก่ 2 ชิ้นใหญ่ (unknown unit type)',
#   'อกไก่ 2 ชิ้นใหญ่',
#   'แป้งชุบทอด 2 ทัพพี',
#   'ใบมะกรูด 4,5 ใบ',
#   'พริกแห้ง 10 เม็ด',
#   'เกลือ เล็กน้อย',
#   'พริกไทย เล็กน้อย',
#   'ถั่วลิสง ตามชอบ',
#   'พริกป่น 1 ช้อนโต๊ะ',
#   'อร่อยชัวร์ 2 ช้อนชา'],
#  'หมูทอดตำครก สูตรเร่งด่วน': ['เนื้อหมู ครึ่งกิโล',
#   'กระเทียม 1หัว',
#   'รากผักชี 1ต้น',
#   'น้ำปลา/พริกไทย ตามชอบ'],
#  'สตอว์เบอร์รี่กีวี่ปั่น 🍓🥝': ['กีวี่สด 3 ลูก',
#   'สตรอว์เบอร์รี่ 12 ลูก',
#   'น้ำผึ้ง 6-8 ช้อนชา',
#   'น้ำแข็ง 2 ถ้วยตวง',
#   'เกลือ หยิบมือ',
#   'น้ำต้มสุก 1 ถ้วยตวง'],
#  'กระชอนนึ่งข้าวเหนียว ไม่ง้อหวด ไม่ง้อซึ้ง ': ['ข้าวเหนียว 2 ถ้าวย',
#   'น้ำหม่า 1 ถ้วย '],
#  'ขนมปังปิ้ง น้ำสลัดหมูหยอง': ['ขนมปังแผ่นหนา 1 แผ่น',
#   'เนย 1 ช้อนชา',
#   'น้ำสลัด 2 ช้อนชา',
#   'หมูหยอง 3 ช้อนโต๊ะ'],
#  'กุยช่ายขาวผัดเต้าหู้ไข่': ['เต้าหู้ไข่ 2 หลอด',
#   'กุยช่ายข่าว 300 กรัม',
#   'น้ำปลา 3 ช้อนชา',
#   'ผงคนอร์ 1 ช้อนชา',
#   'น้ำมันหอย 2 ช้อนชา'],
#  'น้ำผลไม้รวม': ['ฝรั่งผลเล็ก 2 ผล', 'ส้ม 2 ผล', 'แครอท 1 หัว'],
#  'ไก่ผัดเม็ดมะม่วงหินมะพาน': ['อกไก่ ',
#   'น้ำพริกเผาเสฉวนไม่มีให้ใช้น้ำพริกเผา ',
#   'เม็ดมะม่วงหิมพาน ',
#   'น้ำเปล่า ',
#   'น้ำมันงา ',
#   'น้ำมันพืช ',
#   'พริกไทยดำป่น ',
#   'น้ำตาล ',
#   'น้ำพริกเผา ',
#   'น้ำพริกเผาเสฉวน ',
#   'ซอสปรุงรส ',
#   'ซีอิ๊วขาว ',
#   'น้ำมันหอย ',
#   'กระเทียมสับ ',
#   'พริกชี้ฟ้าแห้ง ',
#   'พริกชี้ฟ้าแดงใหญ่ ',
#   'หอมใหญ่หั่นเต๋า ',
#   'พริกหวานสีเขียวหั่นเต๋า ',
#   'พริกหวานสีเหลืองหั่นเต๋า ',
#   'พริกหวานสีแดงหั่นเต๋า ',
#   'แป้งทอดกรอบ '],
#  'แกงป่าอกไก่': ['*อกไก่เลาะหนัง 200 กรัม (กก.)',
#   'มะเขือเปราะ 7 ลูก',
#   'ถั่วฝักยาว 3 ฝัก',
#   'กระชาย 7 ราก',
#   'ใบมะกรูดฉีก 3 ใบ',
#   'ใบกะเพรา ',
#   'พริกแกงป่าสำเร็จรูป 2 ช้อนโต๊ะ',
#   'น้ำปลา 1 ช้อนโต๊ะ'],
#  'รวมแกงใบย่านาง (สูตรปลาย่าง no-ร้า) แกงหน่อไม้ แกงเปรอะ แกงเห็ด ฯลฯ': ['น้ำซุป 1 หม้อ',
#   'ใบย่านาง 1 มัด',
#   'พริก 1 ถ้วย',
#   'หอมแดง 1 ถ้วย',
#   'ตะไคร้ 5-6 ต้น',
#   'เนื้อปลา 1 ถ้วย',
#   'ปลาย่าง 1 ตัว'],
#  'ปากหนามทอด สุดแซ่บสูตรพ่อ': ['ปากหนาม 300 กรัม',
#   'รสดี 2 ช้อนชา',
#   'พริกไทยเม็ด ตามชอบ'],
#  'ผัดชะอมวุ้นเส้นหมูสับ': ['วุ้นเส้น ',
#   'ชะอมเด็ดยอดอ่อน 500 กรัม',
#   '*เนื้อหมูสับ 500 กรัม (กก.)',
#   'กระเทียมสับ 5 กลีบ',
#   'น้ำตาลทราย 2 ช้อนโต๊ะ',
#   'ซอสปรุงรส 2 ช้อนโต๊ะ',
#   'ซอสหอยนางรม 1 ช้อนโต๊ะ'],
#  'เค้กสตรอเบอร์รี่หน้ากรอบ': ['แป้งสาลีเอนกประสงค์ 165 กรัม',
#   'น้ำตาลทราย ตามสูตร 155 (ใส่แค่130)',
#   '*ไข่ไก่ 1 ฟอง (ฟอง)',
#   'เนยจืด 75 กรัม',
#   'เกลือป่น 1/2 ช้อนชา',
#   'ผงฟู 1+1/2 ช้อนชา',
#   'กลิ่นวานิลลา 1 ช้อนชา',
#   '*นมสด 70 กรัม (กก.)',
#   'สตรอเบอร์รี่สด ตามชอบ'],
#  'Jeera Rice ข้าวผัดยี่หร่า (บาสมาติหุงด้วยหม้อหุงข้าว)': ['ข้าวบาสมาติอย่างดีและใหม่ 2 ถ้วย',
#   'น้ำเปล่า 3 ถ้วย',
#   'กีห์ 2 - 3 tbsp',
#   'jeera 3-4 tsp'],
#  'เยลลี่สตรอเบอร์รี่': ['ผงทำเยลลี่สำเร็จรูป 1 ซอง',
#   'น้ำเดือด 8 ออนซ์ (1 ถ้วยตวง)',
#   'น้ำเย็น 8 ออนซ์ (1 ถ้วยตวง)',
#   'สตรอเบอร์รี่สด ตามชอบ',
#   'วิปปิ้งครีม ตามชอบ'],
#  'จีบไทย จีบนก 🐤': ['แป้งข้าวเจ้า 1/2 ถ้วย',
#   'แป้งข้าวเหนียว 1 ช.ต.',
#   'แป้งมันสำปะหลัง 2 ช.ช.',
#   'แป้งเท้ายายม่อม 2 ช.ช.',
#   'น้ำมันพืช 1 ช.ต.',
#   'หางกะทิ 1/2 ถ้วย',
#   'แป้งนวล 3 ช.ต.',
#   'ตัวไส้ ',
#   '*หมูสับ 1/2 ถ้วย (unknown unit type)',
#   'หมูสับ 1/2 ถ้วย',
#   'สามเกลอ 1 ช.ต.',
#   'หอมใหญ่หั่นเต๋าเล็ก 1 หัว',
#   'น้ำมันพืชสำหรับผัด 1 ช.ต.',
#   'กระเทียมสับ 2 ช.ต.',
#   'น้ำมันพืชสำหรับเจียว 1/4 ถ้วย',
#   'น้ำปลา 3 ช.ต.',
#   'น้ำตาลมะพร้าว 1 ช.ต.',
#   'แครอทสำหรับทำปาก ',
#   'งาดำสำหรับทำตา '],
#  'ต้มแซ่บเนื้อ แซ่บๆ': ['*เนื้อวัว 2 ขีด (กก.)',
#   'น้ำเปล่า 2-3 ถ้วย',
#   'พริกขี้หนูทุบ ตามชอบ',
#   'ตะไคร้ 5 ต้น',
#   'ผงรสดี 1 ซอง',
#   'น้ำมะนาว 3 ชต',
#   'น้ำปลา 2 ชต',
#   'ข่าหั่น 3 แง่ง'],
#  'ผัดหมี่กระเฉดหมูสับไส้กรอกไก่': ['เส้นหมี่ขาว 100 กรัม',
#   '*หมูสับ 150 กรัม (กก.)',
#   'ผักกระเฉด 1 กำ',
#   'ไส้กรอกไก่ 2 แท่ง',
#   '*ไข่ไก่ 1 ฟอง (ฟอง)',
#   'น้ำตาล 1/2 ช้อนชา',
#   'ชีอิ๊วขาว 1/2 ช้อนโต๊ะ',
#   'น้ำมันหอย 1/2 ช้อนโต๊ะ',
#   'ชีอิ๊วดำ 1/4 ช้อนชา',
#   'น้ำเปล่า 3 ช้อนโต๊ะ',
#   'พริกขี้หนู 7 เม็ด',
#   'กระเทียม 7 กลีบ'],
#  'ขนมปัง หอมกรุ่นจากเตา (เครื่องทำขนมปังอัตโนมัติ)': ['แป้งขนมปัง 190 g.',
#   'ยีสต์ 6 g.',
#   'นมผง 10 g.',
#   'เกลือ ครึ่งช้อนชา',
#   'เนย 1 ช้อนโต๊ะ',
#   '*นมสด 100 g. (กก.)',
#   'ไข่แดงเบอร์ 1 ฟอง',
#   'น้ำตาล 20 g.'],
#  'แซนด์วิชพริกเผา หมูหยอง ไข่': ['ขนมปัง 3 แผ่น',
#   'หมูหยอง ',
#   'ไข่ดาวนึ่ง ',
#   'พริกเผา '],
#  'พุดดิ้งน้ำทับทิมผลไม้รวม': ['น้ำทับทิมผสมน้ำผลไม้รวม 1 ลิตร',
#   'เจลาตินผง 2 ช้อนโต๊ะ',
#   'โยเกิร์ตรสธรรมชาติสำหรับแต่งหน้า ',
#   'ผลไม้สดตามชอบ '],
#  'บะหมี่ผัดขี้เมาไส้กรอก': ['บะหมี่กึ่งสำเร็จรูป 4 ห่อ',
#   'ไส้กรอก 250 กรัม ',
#   'คะน้าฮ่องกง 400 กร้ม ',
#   'กะเพรา 5 กิ่ง',
#   'กระเทียม 5 กลีบ',
#   'พริกจินดา 10 เม็ด',
#   'ซอสหอยนางรม 2 ช้อนโต๊ะ ',
#   'ซีอิ้วขาว 1 ช้อนโต๊ะ',
#   'น้ำปลา 1 ช้อนโต๊ะ ',
#   'น้ำตาล 1/2 ช้อนโต๊ะ',
#   'น้ำมัน 1 ช้อนโต๊ะ '],
#  'ขนมปังปิ้งกับคอทเทจชีส ทำง่าย ไม่ต้องกลัวอ้วน! ': ['ขนมปังปิ้ง 2 แผ่น',
#   'คอทเทจชีส 2 ช้อนโต๊ะ',
#   'น้ำผึ้ง 1 ช้อนโต๊ะ',
#   'กราโนล่า 2 ช้อนโต๊ะ',
#   'ผลไม้ตัดแต่ง '],
#  'แซนวิช\u200bทูน่าพริกเผาชีสสส': ['ขนมปัง 1 แผ่น',
#   'ทูน่า 1/2 กระป๋อง',
#   'พริกเผา 1 ช้อนชา',
#   'มายองเนส 2 ช้อนชา',
#   'เกลือ, ',
#   'ชีสตามชอบ ',
#   'ผักตามชอบ '],
#  'ไก่ทอด ฮอต แอนด์ สไปซี่': ['*ปีกบนไก่ 10 ปีก (unknown unit type)',
#   'ปีกบนไก่ 10 ปีก',
#   'ผงปรุงรสคนอร์รสไก่ 1 ช้อนโต๊ะ',
#   'น้ำปลา 1 ช้อนโต๊ะ',
#   'แป้งทอดกรอบคนอร์ 1 ช้อนโต๊ะ',
#   'น้ำมัน สำหรับทอด',
#   'ผงปรุงรส 1 1/2 ช้อนโต๊ะ'],
#  'หมูหยองแซนวิชสเปรด': ['ขนมปังโฮลวีท 1 คู่',
#   'หมูหยอง 2 ช้อนโต๊ะ',
#   'แซนวิชสเปรด 1 ช้อนโต๊ะ'],
#  'ป่นเห็ดเจ ครัวคุณหลี': ['เห็ดนางฟ้า 200 กรัม',
#   'ปลาร้าเจหมักจากถั่วเหลือง ',
#   'ซีอิ้วต้ากี่สูตร4 ',
#   'พริกสดสีเขียวแดง '],
#  'น้ำกะทิทุเรียน': ['เนื้อทุเรียนหมอนทองเนื้อสุกกำลังดี 2 พลู',
#   'กะทิอร่อยดีกล่องเล็ก 1 กล่อง',
#   'น้ำตาลโตนด 2 ชต.',
#   'เกลือ 1/4 ชช.'],
#  'ขนมบ้าบิ่นแบบอบ': ['แป้งข้าวเหนียว 100 กรัม',
#   'แป้งท้าวยายม่อม 25  กรัม',
#   'น้ำตาล 100 กรัม',
#   'มะพร้าวขูดขาว 150 กรัม',
#   'กระทิหรือน้ำเปล่า 120  กรัม',
#   '*ไข่ไก่ 1 ฟอง (ฟอง)',
#   'กลิ่นมะลิหรือกลิ่นวนิลา ',
#   'น้ำมันสำหรับทาภาชนะก่อนนำขนมเข้าอล '],
#  'ไก่ทอดเกลือ ด้วยหม้อทอดไร้มัน Philip AirFryer': ['*ปีกไก่กลาง 300 กรัม (กก.)',
#   'เกลือ นิดหน่อย',
#   'พริกไทย นิดหน่อย',
#   'น้ำมัน 1/2 ชต',
#   'แป้งโกกิ 1/2 ชต'],
#  'ขาหมูพะโล้ทำขายรวย': ['*ขาหมู 2ขา (unknown unit type)',
#   'ขาหมู 2ขา',
#   'ชุดพะโล้ 2ชุด',
#   'รากผักชี 2ขีด',
#   '*ไข่ 10ฟอง (ฟอง)',
#   'น้ำตาลโตนด 500กรัม',
#   'กระเทียมกลีบเล็ก 10กลีบ',
#   'ซอสง่วนเชียงฝาเขียว 2ทัพพี',
#   'ซีอิ๊วขาว 1ทัพพี',
#   'น้ำตาลทราย 1ช้อนโต๊ะ',
#   'ซีอิ๊วดำ 3ช้อนโต๊ะ',
#   'รสดี 2ช้อนโต๊ะ'],
#  'ปีกไก่ทอดเกลือ': ['*ปีกกลางไก่ผ่าครึ่ง 1 กิโลกรัม (กก.)',
#   'แป้งโกกิ 3 ช้อนโต๊ะ',
#   'น้ำเปล่า 6 ช้อนโต๊ะ',
#   'เกลือป่น 2.5 ช้อนชา',
#   'พริกไทยป่น 0.5 ช้อนชา',
#   'ใบมะกรูด 5-6 ใบ',
#   'น้ำมันสำหรับทอด '],
#  'ขนมปังปิ้งปาดแยมบลูเบอร์รี่คลีนๆง่ายสุดๆ': ['บลูเบอร์รี่แช่แข็ง 2 ช้อนโต๊ะ',
#   'น้ำหวานดอกมะพร้าว 1 ช้อนชา',
#   'ขนมปังโฮลวีท 1 แผ่น',
#   'buckwheat 1 ช้อนชา'],
#  'ลาบอีสานสูตรทำง่าย': ['*หมูบด 20บาท (baht)',
#   'หอมแดงซอย 3หัว',
#   'สาระแหน่เด็ดใบ 1กำ',
#   'คนอร์ทำลาบ 1ช้อนโต๊ะ',
#   'มะนาวตามชอบ 1-2ลูก'],
#  'ขนมช่อผกากรอง': ['แป้งพัดโพกหรือแป้งสาลีชนิดเบา 1 ถ้วย',
#   'กะทิ 200 ml ',
#   'น้ำลอยดอกมะลิหรือน้ำเปล่า 100 ml',
#   'น้ำตาลทรายละเอียด 1/4 ถ้วย',
#   'สีผสมอาหาร ตามชอบ',
#   'ไส้ขนมวันนี้ใช้ '],
#  '“ขนมปังปิ้ง กับ ชาไทยร้อน"': ['ขนมปัง 4 แผ่น',
#   'Thai 2 ช้อนชา',
#   'Thai 3 ช้อนชา',
#   'น้ำร้อน 1 แก้ว',
#   'นมข้น 2 ช้อนชา'],
#  'ทาโกะยากิสไตล์บ้านๆ ': ['แป้งอเนกประสงค์ ',
#   'ไข่ไก่ ',
#   'ปลาหมึก ',
#   'ผักโขม ',
#   'พริกไท ',
#   'ปลาแห้ง ',
#   'น้ำจิ้มทาโกะ ',
#   'มายองเนส '],
#  'หลนเต้าเจี้ยวหมูสับ': ['เต้าเจี้ยวขาว 300กรัม',
#   'หัวหอมแดง 250กรัม',
#   'พริกชี้ฟ้าเขียว-แดง 120กรัม',
#   'หางกะทิ 3ถ้วยตวง',
#   'น้ำตาลปี๊บ 2ช้อนโต๊ะ',
#   'มะขามเปียก 1ถ้วยตวง',
#   'เกลือป่น 1ช้อนชา'],
#  'สปาเก็ตตี้ผัดพริกแห้งกระเทียมพามีซานชีส': ['เส้นสปาเก็ตตี้ต้มสุก 140 กรัม',
#   'เบคอน ตามชอบ',
#   'ไส้กรอก ตามชอบ',
#   'พริกแห้ง 4 เม็ด',
#   'กระเทียมจีน 2 กลีบใหญ่',
#   'พามีซานชีส 1 ช้อนชา',
#   'น้ำมันรำข้าว ',
#   'ออริกาโน่แห้ง ',
#   'พาสลี่ย์แห้ง ',
#   'เกลือ ',
#   'พริกไทยดำ ',
#   'ผงอโรมาตคนอร์ '],
#  'ขนมปังกล้วยหอมทอด': ['ขนมปังตัดขอบ 1 ปอนด์เล็ก',
#   'กล้วยหอม 5 ลูก',
#   '*ไข่ไก่ 3 ฟอง (ฟอง)',
#   'น้ำมันพืช 5 ชต.',
#   'นมข้นหวาน ตามชอบ'],
#  'ขนมจีนน้ำพริก': ['กะทิ 750 มล',
#   'ไตปลา 3 ชต',
#   'กุ้ง ½ โล',
#   'พริกแกงแดง 1 ขีด',
#   'หอมเจียว 1 ถ้วย',
#   'กระเทียมเจียว 1 ถ้วย',
#   'ถั่วป่น 1 ถ้วย',
#   'ระกำ ตามชอบ',
#   'น้ำตาลปี๊บ 2 ชต',
#   'ผักชี ตามชอบ'],
#  'ปีกกลางทอดซีอิ้ว': ['*ปีกไก่กลาง 1 กล่อง (unknown unit type)',
#   'ปีกไก่กลาง 1 กล่อง',
#   'เกลือ ครึ่งช้อนชา',
#   'ซีอิ้วขาว 1 ช้อนโต๊ะ',
#   'น้ำตาลทราย 2 ช้อนโต๊ะ',
#   'น้ำเปล่า 1 ช้อนโต๊ะ',
#   'คนอร์ผงรสหมู 1 ช้อนชา',
#   'น้ำมันเหลือทอด 1 ช้อนชา',
#   'แป้งทอดกรอบ 1 ช้อนโต๊ะ'],
#  'ขนมปังหน้าพาเมซานชีส': ['ขนมปังแบบหั่นหนาๆ 1แถว',
#   'เนยสด 100กรัม',
#   'พาร์เมซานชีสแบบผง 100กรัม'],
#  'สเต็กเนื้อสันในพริกไทยดำ หม้อทอดAirflyer': ['เนื้อสันในอย่างดี 200กรัม',
#   'เกลือป่น ',
#   'พริกไทยดำ ',
#   'กระเทียม ',
#   'น้ำมันมะกอก '],
#  'แซนวิชเนยแยม': ['ขนมปังขาว 2 แผ่น',
#   'เนยเค็ม 1 ก้อน',
#   'แยมบลูเบอร์รี่ ตามชอบ'],
#  'แซนวิสปูอัด ฉบับเร่งรีบ': ['มายองเนส ',
#   'ปูอัดสีส้ม 5 อัน',
#   'ขนมปัง 5 คู่',
#   'ผักสลัด ตามชอบ'],
#  'แกงกะหรี่ทงคัตสึ': ['เนื้อหมู ',
#   'แป้งทอดกรอบ ',
#   'ไข่ไก่ ',
#   'เกล็ดขนมปัง ',
#   'แกงกะหรี่พร้อมทาน ',
#   'คนอร์ปรุงรสซอสขวด '],
#  'แกงส้มเปลือกแตงโมกุ้งสด': ['กุ้งสด 2 ขีด',
#   'น้ำสะอาด 4 ถ้วย',
#   'เปลือกแตงโม 300 กรัม ',
#   'น้ำปลาดี  3 - 4 ช้อนโต๊ะ',
#   'น้ำตาลปี๊บ 3 ช้อนโต๊ะ',
#   'น้ำมะขามเปียก 3/4 ถ้วย',
#   '**เครื่องน้ำพริกแกงส้ม ',
#   'หอมแดง 7 หัว ',
#   'พริกแห้งเม็ดใหญ่ 8-9 เมล็ด',
#   'เกลือ 1/2 ช้อนชา',
#   'กะปิ  1 ช้อนชา',
#   'เนื้อปลาต้มหรือเนื้อกุ้งต้ม 1/4 ถ้วย'],
#  'กล้วยอบ': ['กล้วยน้ำหว้าห่ามๆ 1 หวี'],
#  'เป็ดพะโล้ต้มแซ่บ': ['เนื้อเป็ด 3ขีด',
#   'เครื่องเทศพะโล้ 1 ซอง',
#   'น้ำตาลปีบ 1ช้อนชา',
#   'เกลือป่น ครึ่งช้อนชา',
#   'ซีอิ้วดำหวาน 1ช้อนโต๊ะ',
#   'ซีอิ้วขาว 1ช้อนโต๊ะ',
#   'รากผักชี 2-3ราก',
#   'พริกไทยขาวเม็ด 10เม็ด',
#   'กระเทียม 4-5กลีบ',
#   'พริกขี้หนู ',
#   'มะนาว 1-2ลูก',
#   'ผักชี 2-3ต้น',
#   'น้ำเปล่า 5 - 6ถ้วยตวง',
#   'ผักกาดหอม ',
#   'ผงปรุงรสถ้ามี '],
#  'สามชั้นผัดสะตอ': ['*หมูสามชั้น 1 เส้น (unknown unit type)',
#   'หมูสามชั้น 1 เส้น',
#   'สะตอ 100 กรัม',
#   'พริกชี้ฟ้า 10 เม็ด',
#   'หอมแดง 5 หัว',
#   'น้ำตาลอ้อย ตามชอบ',
#   'น้ำเปล่า ',
#   'กะปิ ครึ่งช้อนโต๊ะ'],
#  'มะม่วงเบาดองเกลือ ไม่ใส่สาร ': ['มะม่วงเบา ', 'เกลือ ', 'น่ำตาล ', 'ปูน '],
#  'สะตอผัดกะปิพริกชี้ฟ้าหมูบะช่อ': ['น้ำมันถั่วเหลือง 3 ช้อนโต๊ะ',
#   'สะตอ 50\u200b เม็ด',
#   'กะปิ 1\u200b ช้อนโต๊ะ',
#   'เกลือป่น 1/2\u200b ช้อนชา',
#   'น้ำปลาอย่างดี 1/2\u200b ช้อนชา',
#   'หมูสันคอ 200\u200b กรัม',
#   'พริกชี้ฟ้า 3\u200b เม็ด'],
#  'ขนมปังปิ้ง': ['ขนมปังแผ่นหนา 1 แผ่น',
#   'เนยหรือมาการีน ตามชอบ',
#   'น้ำตาล ตามชอบ'],
#  'ขนมปังชีสสสสส': ['ขนมปังแผ่นหนา 1 แผ่น',
#   'มอสซาเรลล่าชีสแบบแผ่น 1 แผ่น',
#   'พาร์เมซานชีสแบบผง 1 ช้อนโต๊ะ',
#   'เนยสดละลาย 2 ช้อนโต๊ะ'],
#  'แกงจืดไชเท้าหมูสับ': ['ไชเท้า 1 กิโลกรัม',
#   '*หมูสับ 1/2 กิโลกรัม (กก.)',
#   'ต้นหอม/ผักชี ',
#   '3 ',
#   'ซีอิ้วขาว 4 ช้อนโต๊ะ',
#   'พริกไทยป่น 1 ช้อนโต๊ะ'],
#  'หมูสามชั้นทอดน้ำปลา ด้วยหม้อทอดไร้มัน Philips AirFryer': ['*หมูสามชั้น 500 กรัม (กก.)',
#   'น้ำปลา 1 ชต',
#   'น้ำมันงา 1 ชต',
#   'น้ำตาลทรายนิดหน่อย ',
#   'เเป้งทอดกรอบ 1-2 ชต'],
#  'แกงส้มไข่เจียวกิมจิกุ้งสด': ['น้ำซุป 1 ถ้วย',
#   'พริกแกงส้ม 50 กรัม',
#   'น้ำปลา 1 ช้อนโต๊ะ',
#   'น้ำมะขามเปียก 2 ช้อนโต๊ะ',
#   'น้ำตาลปีป 40 กรัม',
#   'กุ้งสด 100 กรัม',
#   '*ไข่ 2 ฟอง (ฟอง)',
#   'กิมจิ 150 กรัม'],
#  'แซนวิชไส้กรอกหมู': ['ไส้กรอกหมู 1 ชิ้น',
#   'ผัดสลัด ตามชอบ',
#   'ขนมปัง 1 คู่',
#   'แซนวิชสเปรด 1 ช้อนโต๊ะ'],
#  'ชอกโก้คิทแคทแฟรบเป้': ['ไมโล3in1 1ซอง', 'คิทแคท 1ชิ้น', 'น้ำแข็ง 10ก้อน'],
#  'ทอดมันแฮมชีส': ['ทอดมันแบบสำเร็จรูป ', 'ham ', 'น้ำมันพืช '],
#  'แกงจืดผักกาดขาวหมูสับวุ้นเส้น': ['*หมูสับ 2 ขีด (กก.)',
#   'ผักกาดขาว 5 ใบ',
#   'แครอท 1/2 หัว',
#   'น้ำเปล่า 1 ลิตร',
#   'ผงปรุงรสคนอร์ 2 ช้อนชา',
#   'น้ำมันหอย 1/2 ช้อนชา',
#   'วุ้นเส้น 1/2 ซอง'],
#  'สะตอผัดหมูกะปิ': ['สะตอ ',
#   'เนื้อหมูหั่นชิ้น ',
#   'กะปิ ',
#   'กระเทียมสับ ',
#   'พริกแดงหันเส้น ',
#   'น้ำตาล ',
#   'น้ำมัน ',
#   'น้ำเปล่า '],
#  'ไก่สไปซี่สามรส (แคลอรี่เบาๆ 80 kCal)': ['*ปีกบนไก่ 1/2 kg (กก.)',
#   'หอมใหญ่/หอมซุป 2 ถ้วย',
#   'มะเขือเทศ 2 ถ้วย',
#   'ผงหมักไก่สไปซี่ 3 ช้อนโต๊ะ',
#   'ซอสปรุงรส 1-2 ช้อนชา',
#   'เกลือ 1 หยิบมือ'],
#  'กล้วยน้ำว้าอบ': ['กล้วยน้ำว้า 1 หวี ',
#   'งาขาว-งาดำ ตามชอบ',
#   'เตาอบหรือหม้ออบลมร้อน '],
#  'ขนมผกากรอง': ['ถั่วเขียวเลาะเปลือก 250 g',
#   'กะทิเรียลไทย 250 g',
#   'น้ำตาลทราย 100 g',
#   'เกลือ ',
#   'แป้งเค้ก 250 g',
#   'น้ำตาลทราย 50 g',
#   'กะทิ 250 g'],
#  'แซนวิชปูอัดมายองเนส และชีส': ['ขนมปังแผ่น 4 แผ่น',
#   'ปูอัด 4 ชิ้น',
#   'มายองเนส 3 ช้อนโต๊ะ',
#   'ชีสแผ่น 2 แผ่น'],
#  'แกงส้มผักบุ้งกุ้งลอยน้ำ': ['กุ้งสดตัวใหญ่ 3 ขีด',
#   'พริกแกงส้ม 1 ช้อนโต๊ะ',
#   'ผักบุ้ง 2 กำ',
#   'น้ำปลา 1 ช้อนชา',
#   'หัวหอม 2 หัว',
#   'กระชาย 1 ต้น',
#   'กะปิ ครึ่งช้อนชา',
#   'น้ำตาลทราย 1 ช้อนชา',
#   'มะขามเปียก 4 ฝัก',
#   'ใบมะกรูด 4 - 5 ใบ'],
#  'กระดูกหมูต้มผักกาดดอง': ['กระดูกหมู ', 'ผักกาดดอง ', 'น้ำปลา '],
#  'แกงจืดผักกาดดองใส่กระดูกซี่โครงหมู': ['ผักกาดดอง 1 หัว',
#   'กระดูกซี่โครงหมู 500 กรัม',
#   'รากผักชี 4-5 ราก',
#   'พริกไทยดำ 20 เม็ด',
#   'กระเทียม 1 หัว',
#   '*ซุปหมูก้อน 1 ก้อน (unknown unit type)',
#   'ซุปหมูก้อน 1 ก้อน',
#   'เกลือ ',
#   'น้ำเปล่า '],
#  '“ผัดถั่วลันเตาหวานหมูสับ"': ['น้ำมัน 2 ช้อนโต๊ะ',
#   'กระเทียมตำ 1 ช้อนโต๊ะ',
#   '*หมูสับ 1 ช้อนโต๊ะ (ลิตร)',
#   'ถั่วลันเตาหวาน 250 กรัม',
#   'น้ำตาลทราย 1 ช้อนชา',
#   'ผงปรุงรส 1 ช้อนชา',
#   'น้ำมันหอย 1 ช้อนโต๊ะ',
#   'ซอสปรุงรส 1 ช้อนโต๊ะ'],
#  'ข้าวไข่ข้นเนื้อปู': ['เนื้อปู 1ถ้วยเล็กๆ',
#   '*ไข่ไก่ 2ฟอง (ฟอง)',
#   '*นมสดกล่องชนิดจืด 5ช้อนโต๊ะ (ลิตร)',
#   'เกลือ ครึ่งช้อนชา',
#   'ต้นหอมซอย 1ต้น',
#   'ข้าวหอมมะลิ 1ถ้วย'],
#  'แกงปูใบชะพลู 🦀': ['เนื้อปู ตามชอบ',
#   'ใบชะพลู ตามชอบ',
#   'น้ำตาลปึก ',
#   'กะทิ 1 ขวด',
#   'พริกแกงคั่วกลิ้งใต้ ',
#   'น้ำปลา ',
#   'น้ำต้มสุก '],
#  'ข้าวคลุกกะปิหมูหวาน': ['ข้าวสวย 8 ถ้วย',
#   'กะปิ 3-4 ช้อนโต๊ะ',
#   'เครื่องหมูหวาน 👇🏻',
#   '*หมูสันคอ 500 กรัม (กก.)',
#   'ซีอิ๊วดำ 1 ช้อนโต๊ะ',
#   'น้ำมันหอย 3 ช้อนโต๊ะ',
#   'น้ำตาลปี๊ป 2 ช้อนโต๊ะ',
#   'เครื่องเคียง 👇🏻',
#   'ไข่เจียวหั่นฝอย -',
#   'กุนเชียงทอดสไลด์ -',
#   'กุ้งแห้งทอด -',
#   'มะม่วงเปรี้ยวสับ -',
#   'แตงกวาสไลด์ -',
#   'กะหล่ำปลีลวก -',
#   'หอมแดงซอย -',
#   'พริกแดงจินดาซอย -',
#   'น้ำมะนาว -',
#   'น้ำมันพืช 3 ช้อนโต๊ะ'],
#  'ข้าวไข่ข้นต้มยำกุ้ง': ['*ไข่ไก่ 1 ฟอง (ฟอง)',
#   'ข้าวสวย 1 ถ้วย',
#   'เนื้อกุ้งในต้มยำกุ้งหั่น 3 ตัว',
#   'นมข้นจืด 1 ช้อนโต๊ะ',
#   'น้ำปลา 1 ช้อนชา',
#   'น้ำมันพืช 1 ช้อนโต๊ะ'],
#  'ต้มกระดูกหมูผักกาดดอง': ['กระดูกหมู ',
#   'ผักกาดดอง ',
#   'เกลือ ',
#   'กระเทียม4-5 ',
#   'คนอร์ชุปก้อนหมู ',
#   'ซอสปรุงรส '],
#  'หมูผัดเปรี้ยวหวาน': ['ซอสมะเขือเทศ 1 ถ้วยตวง',
#   'ซอสพริก 1/2 ถ้วยตวง',
#   'น้ำตาลทราย 2 ชต',
#   'น้ำปลา 2 ชต',
#   'กระเทียมสับละเอียด 1 ชต',
#   'น้ำมันพืช 2 ชต',
#   'น้ำ 1/2 ถ้วยตวง',
#   'น้ำมันหอยหมักหมู 1 ชต',
#   '*หมูสันนอก 300 กรัม (กก.)',
#   'แตงกวา 100 กรัม',
#   'หอมใหญ่ 100 กรัม',
#   'พริกหวาน3สี 100 กรัม',
#   'มะเขือเทศ 1 ลูก',
#   'สับปะรดเปรี้ยว 100 กรัม'],
#  'ต้มจืดผักกาดดองกระดูกหมู': ['กระดูกหมู 1\u200b กิโล',
#   'ผักกาดดองเค็ม 2\u200b กระป๋อง',
#   'กระเทียม 5\u200b กลีบ',
#   'เกลือ 1\u200b ช้อนชา',
#   'น้ำ 1\u200b ขวดน้ำใหญ่'],
#  'ผัดกะหล่ำปลีกับถั่วลันเตาหวาน': ['กะหล่ำปลีหั่นเป็นชิ้นพอคำ 1/3 หัว',
#   'ถั่วลันเตาหวาน 1 กำ',
#   'กระเทียมสับ 1 ช้อนโต๊ะ',
#   'น้ำซุป 2 ช้อนโต๊ะ',
#   'น้ำมันหอย 1 ช้อนโต๊ะ',
#   'ซีอิ๊วขาว 1 ช้อนโต๊ะ',
#   'น้ำตาล นิดหน่อย',
#   'น้ำมันพืชสำหรับผัด '],
#  'ต้มกระดูกซี่โครงผักกาดดอง': ['กระดูกซี่โครงหมู 1/2 ก.ก.',
#   'ผักกาดดอง 1 กระป๋อง',
#   'น้ำตาลทราย 1 ช้อนชา',
#   'เกลือ 1/2 ช้อนชา',
#   'ซีอิ๊วขาว 1 ช้อนโต๊ะ',
#   'ต้นหอมผักชี 2 ต้น',
#   'กระเทียม 5-6 กลีบ'],
#  'หอมหัวใหญ่ผัดหมูสับพริกหวาน': ['*หมูสับ 80 กรัม (กก.)',
#   'หอมหัวใหญ่ซอย 150 กรัม',
#   'พริกหวานหั่นเต๋า 50 กรัม',
#   'ซีอิ๊วขาว 1/2 ช้อนโต๊ะ',
#   'ซอสน้ำมันหอย 1 + 1/2ช้อนโต๊ะ',
#   'กระเทียมสับ 1/2ช้อนโต๊ะ',
#   'น้ำมันพืช เล็กน้อย',
#   'น้ำเปล่า เล็กน้อย'],
#  'ชาเนสทีนมสดเย็น': ['ผงชาเนสที 3 ช้อนชา',
#   'น้ำตาลทราย 1 ช้อนชา',
#   'ครีมเทียม 2 ช้อนชา',
#   'นมข้นหวาน 3 ช้อนชา',
#   'นมข้นจืด 30 ml',
#   '*นมสด 30 ml (ลิตร)',
#   'น้ำร้อน  75 ml'],
#  'ชามาเลย์โกโก้': ['ชาชักมาเลย์ 1 ชต',
#   'น้ำร้อน 150 มล.',
#   'นมสด ตามชอบ',
#   'นมข้นหวาน 1 + 1/2 ชต',
#   'คอฟฟี่เมท 1/2 ชช',
#   'น้ำร้อน2 1 ชช',
#   'โกโก้ 1 ชช',
#   'น้ำแข็ง '],
#  ...}
